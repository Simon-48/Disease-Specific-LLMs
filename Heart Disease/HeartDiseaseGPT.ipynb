# %% [markdown]
# # **ChronicGPT: An Approach to Convert Tabular Clinical Records into Clinical Narratives for Effectively Tuning Disease-Specific GPT Models**
#
# In this study, heart patient data from the UCI dataset was utilized. This data was originally in tabular format, similar to what is typically found in a structured, tabular clinical dataset or Electronic Health Record (EHR)-derived tabular dataset. However, large language models (LLMs) such as GPT perform optimally with text-based input rather than tabular data. This introduced two primary challenges:
#
#     1. The data was in a tabular format, which is not commonly used with transformer-based models like GPT.
#
#     2. The dataset contained very few heart disease cases, making it difficult to train an effective model.
#
# The key advantage of employing a language model like GPT over traditional machine learning models or standard neural networks lies in its dual capability. Traditional models make predictions based solely on statistical patterns and observed probabilities within the data. While often effective, such models typically fail to capture the clinical significance behind categorical features — particularly in medical datasets where each category (e.g., “normal,” “abnormal,” “present,” “not present”) conveys nuanced meaning. In contrast, GPT models are capable of understanding clinical context — in a manner similar to a healthcare expert — while also learning underlying statistical relationships. This combination of semantic understanding and statistical reasoning renders GPT models especially powerful for healthcare applications, where both interpretability and domain knowledge are critical.
#
# The creation of synthetic examples for heart disease prediction poses additional difficulties, especially when the dataset includes numerous categorical features (such as "yes"/"no" or "normal"/"abnormal") with significant clinical implications. Common techniques such as SMOTE, ADASYN, and ENN are well-suited for numerical data but often fail to effectively handle categorical medical data. This limitation impedes the improvement of model performance when real heart disease data is scarce.
#
# To address this, a table-to-text approach was developed. Initially, the tabular data was converted into short clinical-style text, resembling the format a physician might use. Subsequently, a GPT-based model (GPT4) was employed to generate more realistic and medically accurate examples by paraphrasing existing samples from heart disease patients.
#
# This approach preserves the clinical meaning while producing new examples, a feat that traditional methods for creating synthetic data for categorical features such as SMOTE-NC, CTGAN, TVAE, and CopulaGAN often struggle to achieve. These alternative techniques either fail to capture the clinical context adequately or generate samples that are less meaningful when dealing with categorical medical features.
#
# Following the generation of realistic medical text samples, a GPT2 model was fine-tuned using the short texts. The objective was to assess whether the model could accurately predict the presence of heart disease in new patients — and the model demonstrated strong performance, even when trained on limited data.
#
# All GPT models used in this study were obtained from Hugging Face’s library of pre-trained models. The findings demonstrate that LLMs can be adapted to handle medical tabular data by transforming it into text, thereby enhancing the model's ability to learn clinically relevant patterns associated with heart disease.
#
# Additionally, this approach was compared to a simpler method in which tabular data was converted into a sequential input format — listing feature values in order, without converting them into clinical-style text. While this method rendered the data compatible with transformer models, performance was suboptimal. Transformer-based models struggled to capture the relationships and clinical significance embedded in plain sequences of numbers or categories.
#
# In contrast, the table-to-clinical-text approach enabled the GPT model to interpret both the semantic and clinical context of each feature. This resulted in significantly improved performance and generalization, particularly for the underrepresented heart disease class.
#
# To evaluate the generalizability of the proposed method, it was also applied to the UCI Heart Failure Clinical dataset and the UCI Chronic Kidney Disease dataset, with consistent results obtained across all datasets.
#
# ## **Keywords:**
#
#     1. Large Language Models (LLMs)
#
#     2. Table-to-Text Conversion
#
#     3. Clinical Text Generation
#
#     4. Class Imbalance
#
#     5. Transformer-Based Prediction

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import seaborn as sns
import plotly.express as px

# %matplotlib inline

# %%
# Set DPI for fugures

plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
# Set the default font size and weight
plt.rcParams['font.size'] = 30
plt.rcParams['font.weight'] = 'bold'

# %%
# Drive connection

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Dataset: UCI Heart Disease Dataset

# %%
df.rename(columns={
    "age": "Age (years)",
    "sex": "Sex (1 = Male, 0 = Female)",
    "cp": "Chest Pain Type (1 = Typical Angina, 2 = Atypical Angina, 3 = Non-anginal Pain, 4 = Asymptomatic)",
    "trestbps": "Resting Blood Pressure (mm Hg)",
    "chol": "Serum Cholesterol (mg/dL)",
    "fbs": "Fasting Blood Sugar (> 120 mg/dL, 1 = True, 0 = False)",
    "restecg": "Resting ECG Results (0 = Normal, 1 = ST-T Wave Abnormality, 2 = Left Ventricular Hypertrophy)",
    "thalach": "Maximum Heart Rate Achieved",
    "exang": "Exercise-Induced Angina (1 = Yes, 0 = No)",
    "oldpeak": "ST Depression Induced by Exercise (mm)",
    "slope": "Slope of Peak Exercise ST Segment (1 = Upsloping, 2 = Flat, 3 = Downsloping)",
    "ca": "Number of Major Vessels (0-3) Colored by Fluoroscopy",
    "thal": "Thalassemia (3 = Normal, 6 = Fixed Defect, 7 = Reversible Defect)",
    "num": "Heart Disease (0 = No Disease, 1 = Heart Disease)"
}, inplace=True)

# %%
load_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/df.csv"

# Load the DataFrame
df = pd.read_csv(load_path)

# %%
df.head()
# Out:
#    Age (years)  Sex (1 = Male, 0 = Female)  \
# 0           63                           1
# 1           67                           1
# 2           67                           1
# 3           37                           1
# 4           41                           0
#
#    Chest Pain Type (1 = Typical Angina, 2 = Atypical Angina, 3 = Non-anginal Pain, 4 = Asymptomatic)  \
# 0                                                  1
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  2
#
#    Resting Blood Pressure (mm Hg)  Serum Cholesterol (mg/dL)  \
# 0                             145                        233
# 1                             160                        286
# 2                             120                        229
# 3                             130                        250
# 4                             130                        204
#
#    Fasting Blood Sugar (> 120 mg/dL, 1 = True, 0 = False)  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Resting ECG Results (0 = Normal, 1 = ST-T Wave Abnormality, 2 = Left Ventricular Hypertrophy)  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  0
# 4                                                  2
#
#    Maximum Heart Rate Achieved  Exercise-Induced Angina (1 = Yes, 0 = No)  \
# 0                          150                                          0
# 1                          108                                          1
# 2                          129                                          1
# 3                          187                                          0
# 4                          172                                          0
#
#    ST Depression Induced by Exercise (mm)  \
# 0                                     2.3
# 1                                     1.5
# 2                                     2.6
# 3                                     3.5
# 4                                     1.4
#
#    Slope of Peak Exercise ST Segment (1 = Upsloping, 2 = Flat, 3 = Downsloping)  \
# 0                                                  3
# 1                                                  2
# 2                                                  2
# 3                                                  3
# 4                                                  1
#
#    Number of Major Vessels (0-3) Colored by Fluoroscopy  \
# 0                                                0.0
# 1                                                3.0
# 2                                                2.0
# 3                                                0.0
# 4                                                0.0
#
#    Thalassemia (3 = Normal, 6 = Fixed Defect, 7 = Reversible Defect)  \
# 0                                                6.0
# 1                                                3.0
# 2                                                7.0
# 3                                                3.0
# 4                                                3.0
#
#    Heart Disease (0 = No Disease, 1 = Heart Disease)
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  0
# 4                                                  0

# %% [markdown]
# # Table to Clinical Text for GPT Model

# %%
import torch
from sklearn.model_selection import train_test_split

# Mapping for readable text
ecg_mapping = {
    0: "Normal",
    1: "ST-T Wave Abnormality",
    2: "Left Ventricular Hypertrophy"
}

slope_mapping = {
    1: "Upsloping",
    2: "Flat",
    3: "Downsloping"
}

thal_mapping = {
    3: "Normal",
    6: "Fixed Defect",
    7: "Reversible Defect"
}

# Separate features and target
input_features = df.drop(columns=["Heart Disease (0 = No Disease, 1 = Heart Disease)"])
target = df["Heart Disease (0 = No Disease, 1 = Heart Disease)"]

# Convert rows to clinical-style text
def row_to_text(row):
    return (f"Patient is a {int(row['Sex (1 = Male, 0 = Female)']) and 'male' or 'female'} aged {row['Age (years)']} years, "
            f"presenting with chest pain type {row['Chest Pain Type (1 = Typical Angina, 2 = Atypical Angina, 3 = Non-anginal Pain, 4 = Asymptomatic)']}, "
            f"resting blood pressure {row['Resting Blood Pressure (mm Hg)']} mm Hg, serum cholesterol {row['Serum Cholesterol (mg/dL)']} mg/dL, "
            f"{'elevated' if row['Fasting Blood Sugar (> 120 mg/dL, 1 = True, 0 = False)'] else 'normal'} fasting blood sugar, "
            f"resting ECG showing result {ecg_mapping[row['Resting ECG Results (0 = Normal, 1 = ST-T Wave Abnormality, 2 = Left Ventricular Hypertrophy)']]}, "
            f"maximum heart rate achieved {row['Maximum Heart Rate Achieved']}, "
            f"{'with' if row['Exercise-Induced Angina (1 = Yes, 0 = No)'] else 'without'} exercise-induced angina, "
            f"ST depression of {row['ST Depression Induced by Exercise (mm)']} mm, "
            f"Slope of Peak Exercise ST Segment: {slope_mapping[row['Slope of Peak Exercise ST Segment (1 = Upsloping, 2 = Flat, 3 = Downsloping)']]}, "
            f"{row['Number of Major Vessels (0-3) Colored by Fluoroscopy']} major vessels affected, "
            f"thalassemia type {thal_mapping.get(row['Thalassemia (3 = Normal, 6 = Fixed Defect, 7 = Reversible Defect)'], 'Unknown')}.")

df["clinical_text"] = input_features.apply(row_to_text, axis=1)

# %%
load_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/clinical_text_dataset.csv"

# Load the DataFrame
df = pd.read_csv(load_path)

# Preview
df.head()

# %%
# Drop target column to get input features only
input_features = df.drop(columns=["Heart Disease (0 = No Disease, 1 = Heart Disease)"])

# Apply the conversion function row-wise
df["clinical_text"] = input_features.apply(row_to_text, axis=1)

# View the converted text
print(df["clinical_text"].head())
# Out:
# 0    Patient is a male aged 63 years, presenting wi...
# 1    Patient is a male aged 67 years, presenting wi...
# 2    Patient is a male aged 67 years, presenting wi...
# 3    Patient is a male aged 37 years, presenting wi...
# 4    Patient is a female aged 41 years, presenting ...
# Name: clinical_text, dtype: object

# %%
for idx, text in enumerate(df["clinical_text"]):
    print(f"Row {idx + 1}:\n{text}\n{'-'*80}")
# Out:
# Row 1:
# Patient is a male aged 63 years, presenting with chest pain type 1, resting blood pressure 145 mm Hg, serum cholesterol 233 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 150, without exercise-induced angina, ST depression of 2.3 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 2:
# Patient is a male aged 67 years, presenting with chest pain type 4, resting blood pressure 160 mm Hg, serum cholesterol 286 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 108, with exercise-induced angina, ST depression of 1.5 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 3:
# Patient is a male aged 67 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 229 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 129, with exercise-induced angina, ST depression of 2.6 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 4:
# Patient is a male aged 37 years, presenting with chest pain type 3, resting blood pressure 130 mm Hg, serum cholesterol 250 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 187, without exercise-induced angina, ST depression of 3.5 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 5:
# Patient is a female aged 41 years, presenting with chest pain type 2, resting blood pressure 130 mm Hg, serum cholesterol 204 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 172, without exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 6:
# Patient is a male aged 56 years, presenting with chest pain type 2, resting blood pressure 120 mm Hg, serum cholesterol 236 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 178, without exercise-induced angina, ST depression of 0.8 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 7:
# Patient is a female aged 62 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 268 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 160, without exercise-induced angina, ST depression of 3.6 mm, Slope of Peak Exercise ST Segment: Downsloping, 2.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 8:
# Patient is a female aged 57 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 354 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 163, with exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 9:
# Patient is a male aged 63 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 254 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 147, without exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 10:
# Patient is a male aged 53 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 203 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 155, with exercise-induced angina, ST depression of 3.1 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 11:
# Patient is a male aged 57 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 192 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 148, without exercise-induced angina, ST depression of 0.4 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 12:
# Patient is a female aged 56 years, presenting with chest pain type 2, resting blood pressure 140 mm Hg, serum cholesterol 294 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 153, without exercise-induced angina, ST depression of 1.3 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 13:
# Patient is a male aged 56 years, presenting with chest pain type 3, resting blood pressure 130 mm Hg, serum cholesterol 256 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 142, with exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 14:
# Patient is a male aged 44 years, presenting with chest pain type 2, resting blood pressure 120 mm Hg, serum cholesterol 263 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 173, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 15:
# Patient is a male aged 52 years, presenting with chest pain type 3, resting blood pressure 172 mm Hg, serum cholesterol 199 mg/dL, elevated fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 162, without exercise-induced angina, ST depression of 0.5 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 16:
# Patient is a male aged 57 years, presenting with chest pain type 3, resting blood pressure 150 mm Hg, serum cholesterol 168 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 174, without exercise-induced angina, ST depression of 1.6 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 17:
# Patient is a male aged 48 years, presenting with chest pain type 2, resting blood pressure 110 mm Hg, serum cholesterol 229 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 168, without exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 18:
# Patient is a male aged 54 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 239 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 160, without exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 19:
# Patient is a female aged 48 years, presenting with chest pain type 3, resting blood pressure 130 mm Hg, serum cholesterol 275 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 139, without exercise-induced angina, ST depression of 0.2 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 20:
# Patient is a male aged 49 years, presenting with chest pain type 2, resting blood pressure 130 mm Hg, serum cholesterol 266 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 171, without exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 21:
# Patient is a male aged 64 years, presenting with chest pain type 1, resting blood pressure 110 mm Hg, serum cholesterol 211 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 144, with exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 22:
# Patient is a female aged 58 years, presenting with chest pain type 1, resting blood pressure 150 mm Hg, serum cholesterol 283 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 162, without exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 23:
# Patient is a male aged 58 years, presenting with chest pain type 2, resting blood pressure 120 mm Hg, serum cholesterol 284 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 160, without exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 24:
# Patient is a male aged 58 years, presenting with chest pain type 3, resting blood pressure 132 mm Hg, serum cholesterol 224 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 173, without exercise-induced angina, ST depression of 3.2 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 25:
# Patient is a male aged 60 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 206 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 132, with exercise-induced angina, ST depression of 2.4 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 26:
# Patient is a female aged 50 years, presenting with chest pain type 3, resting blood pressure 120 mm Hg, serum cholesterol 219 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 158, without exercise-induced angina, ST depression of 1.6 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 27:
# Patient is a female aged 58 years, presenting with chest pain type 3, resting blood pressure 120 mm Hg, serum cholesterol 340 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 172, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 28:
# Patient is a female aged 66 years, presenting with chest pain type 1, resting blood pressure 150 mm Hg, serum cholesterol 226 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 114, without exercise-induced angina, ST depression of 2.6 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 29:
# Patient is a male aged 43 years, presenting with chest pain type 4, resting blood pressure 150 mm Hg, serum cholesterol 247 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 171, without exercise-induced angina, ST depression of 1.5 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 30:
# Patient is a male aged 40 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 167 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 114, with exercise-induced angina, ST depression of 2.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 31:
# Patient is a female aged 69 years, presenting with chest pain type 1, resting blood pressure 140 mm Hg, serum cholesterol 239 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 151, without exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 32:
# Patient is a male aged 60 years, presenting with chest pain type 4, resting blood pressure 117 mm Hg, serum cholesterol 230 mg/dL, elevated fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 160, with exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 33:
# Patient is a male aged 64 years, presenting with chest pain type 3, resting blood pressure 140 mm Hg, serum cholesterol 335 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 158, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 34:
# Patient is a male aged 59 years, presenting with chest pain type 4, resting blood pressure 135 mm Hg, serum cholesterol 234 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 161, without exercise-induced angina, ST depression of 0.5 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 35:
# Patient is a male aged 44 years, presenting with chest pain type 3, resting blood pressure 130 mm Hg, serum cholesterol 233 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 179, with exercise-induced angina, ST depression of 0.4 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 36:
# Patient is a male aged 42 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 226 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 178, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 37:
# Patient is a male aged 43 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 177 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 120, with exercise-induced angina, ST depression of 2.5 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 38:
# Patient is a male aged 57 years, presenting with chest pain type 4, resting blood pressure 150 mm Hg, serum cholesterol 276 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 112, with exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 39:
# Patient is a male aged 55 years, presenting with chest pain type 4, resting blood pressure 132 mm Hg, serum cholesterol 353 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 132, with exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 40:
# Patient is a male aged 61 years, presenting with chest pain type 3, resting blood pressure 150 mm Hg, serum cholesterol 243 mg/dL, elevated fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 137, with exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 41:
# Patient is a female aged 65 years, presenting with chest pain type 4, resting blood pressure 150 mm Hg, serum cholesterol 225 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 114, without exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 42:
# Patient is a male aged 40 years, presenting with chest pain type 1, resting blood pressure 140 mm Hg, serum cholesterol 199 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 178, with exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 43:
# Patient is a female aged 71 years, presenting with chest pain type 2, resting blood pressure 160 mm Hg, serum cholesterol 302 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 162, without exercise-induced angina, ST depression of 0.4 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 44:
# Patient is a male aged 59 years, presenting with chest pain type 3, resting blood pressure 150 mm Hg, serum cholesterol 212 mg/dL, elevated fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 157, without exercise-induced angina, ST depression of 1.6 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 45:
# Patient is a female aged 61 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 330 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 169, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 46:
# Patient is a male aged 58 years, presenting with chest pain type 3, resting blood pressure 112 mm Hg, serum cholesterol 230 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 165, without exercise-induced angina, ST depression of 2.5 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 47:
# Patient is a male aged 51 years, presenting with chest pain type 3, resting blood pressure 110 mm Hg, serum cholesterol 175 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 123, without exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 48:
# Patient is a male aged 50 years, presenting with chest pain type 4, resting blood pressure 150 mm Hg, serum cholesterol 243 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 128, without exercise-induced angina, ST depression of 2.6 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 49:
# Patient is a female aged 65 years, presenting with chest pain type 3, resting blood pressure 140 mm Hg, serum cholesterol 417 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 157, without exercise-induced angina, ST depression of 0.8 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 50:
# Patient is a male aged 53 years, presenting with chest pain type 3, resting blood pressure 130 mm Hg, serum cholesterol 197 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 152, without exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 51:
# Patient is a female aged 41 years, presenting with chest pain type 2, resting blood pressure 105 mm Hg, serum cholesterol 198 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 168, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 52:
# Patient is a male aged 65 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 177 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 140, without exercise-induced angina, ST depression of 0.4 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 53:
# Patient is a male aged 44 years, presenting with chest pain type 4, resting blood pressure 112 mm Hg, serum cholesterol 290 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 153, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 54:
# Patient is a male aged 44 years, presenting with chest pain type 2, resting blood pressure 130 mm Hg, serum cholesterol 219 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 188, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 55:
# Patient is a male aged 60 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 253 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 144, with exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 56:
# Patient is a male aged 54 years, presenting with chest pain type 4, resting blood pressure 124 mm Hg, serum cholesterol 266 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 109, with exercise-induced angina, ST depression of 2.2 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 57:
# Patient is a male aged 50 years, presenting with chest pain type 3, resting blood pressure 140 mm Hg, serum cholesterol 233 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 163, without exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 58:
# Patient is a male aged 41 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 172 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 158, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 59:
# Patient is a male aged 54 years, presenting with chest pain type 3, resting blood pressure 125 mm Hg, serum cholesterol 273 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 152, without exercise-induced angina, ST depression of 0.5 mm, Slope of Peak Exercise ST Segment: Downsloping, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 60:
# Patient is a male aged 51 years, presenting with chest pain type 1, resting blood pressure 125 mm Hg, serum cholesterol 213 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 125, with exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 61:
# Patient is a female aged 51 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 305 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 142, with exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 62:
# Patient is a female aged 46 years, presenting with chest pain type 3, resting blood pressure 142 mm Hg, serum cholesterol 177 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 160, with exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 63:
# Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 216 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 131, with exercise-induced angina, ST depression of 2.2 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 64:
# Patient is a female aged 54 years, presenting with chest pain type 3, resting blood pressure 135 mm Hg, serum cholesterol 304 mg/dL, elevated fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 170, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 65:
# Patient is a male aged 54 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 188 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 113, without exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 66:
# Patient is a male aged 60 years, presenting with chest pain type 4, resting blood pressure 145 mm Hg, serum cholesterol 282 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 142, with exercise-induced angina, ST depression of 2.8 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 67:
# Patient is a male aged 60 years, presenting with chest pain type 3, resting blood pressure 140 mm Hg, serum cholesterol 185 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 155, without exercise-induced angina, ST depression of 3.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 68:
# Patient is a male aged 54 years, presenting with chest pain type 3, resting blood pressure 150 mm Hg, serum cholesterol 232 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 165, without exercise-induced angina, ST depression of 1.6 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 69:
# Patient is a male aged 59 years, presenting with chest pain type 4, resting blood pressure 170 mm Hg, serum cholesterol 326 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 140, with exercise-induced angina, ST depression of 3.4 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 70:
# Patient is a male aged 46 years, presenting with chest pain type 3, resting blood pressure 150 mm Hg, serum cholesterol 231 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 147, without exercise-induced angina, ST depression of 3.6 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 71:
# Patient is a female aged 65 years, presenting with chest pain type 3, resting blood pressure 155 mm Hg, serum cholesterol 269 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 148, without exercise-induced angina, ST depression of 0.8 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 72:
# Patient is a male aged 67 years, presenting with chest pain type 4, resting blood pressure 125 mm Hg, serum cholesterol 254 mg/dL, elevated fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 163, without exercise-induced angina, ST depression of 0.2 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 73:
# Patient is a male aged 62 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 267 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 99, with exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 74:
# Patient is a male aged 65 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 248 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 158, without exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 75:
# Patient is a male aged 44 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 197 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 177, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 76:
# Patient is a female aged 65 years, presenting with chest pain type 3, resting blood pressure 160 mm Hg, serum cholesterol 360 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 151, without exercise-induced angina, ST depression of 0.8 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 77:
# Patient is a male aged 60 years, presenting with chest pain type 4, resting blood pressure 125 mm Hg, serum cholesterol 258 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 141, with exercise-induced angina, ST depression of 2.8 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 78:
# Patient is a female aged 51 years, presenting with chest pain type 3, resting blood pressure 140 mm Hg, serum cholesterol 308 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 142, without exercise-induced angina, ST depression of 1.5 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 79:
# Patient is a male aged 48 years, presenting with chest pain type 2, resting blood pressure 130 mm Hg, serum cholesterol 245 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 180, without exercise-induced angina, ST depression of 0.2 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 80:
# Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 150 mm Hg, serum cholesterol 270 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 111, with exercise-induced angina, ST depression of 0.8 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 81:
# Patient is a male aged 45 years, presenting with chest pain type 4, resting blood pressure 104 mm Hg, serum cholesterol 208 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 148, with exercise-induced angina, ST depression of 3.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 82:
# Patient is a female aged 53 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 264 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 143, without exercise-induced angina, ST depression of 0.4 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 83:
# Patient is a male aged 39 years, presenting with chest pain type 3, resting blood pressure 140 mm Hg, serum cholesterol 321 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 182, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 84:
# Patient is a male aged 68 years, presenting with chest pain type 3, resting blood pressure 180 mm Hg, serum cholesterol 274 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 150, with exercise-induced angina, ST depression of 1.6 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 85:
# Patient is a male aged 52 years, presenting with chest pain type 2, resting blood pressure 120 mm Hg, serum cholesterol 325 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 172, without exercise-induced angina, ST depression of 0.2 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 86:
# Patient is a male aged 44 years, presenting with chest pain type 3, resting blood pressure 140 mm Hg, serum cholesterol 235 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 180, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 87:
# Patient is a male aged 47 years, presenting with chest pain type 3, resting blood pressure 138 mm Hg, serum cholesterol 257 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 156, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 88:
# Patient is a female aged 53 years, presenting with chest pain type 4, resting blood pressure 138 mm Hg, serum cholesterol 234 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 160, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 89:
# Patient is a female aged 51 years, presenting with chest pain type 3, resting blood pressure 130 mm Hg, serum cholesterol 256 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 149, without exercise-induced angina, ST depression of 0.5 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 90:
# Patient is a male aged 66 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 302 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 151, without exercise-induced angina, ST depression of 0.4 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 91:
# Patient is a female aged 62 years, presenting with chest pain type 4, resting blood pressure 160 mm Hg, serum cholesterol 164 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 145, without exercise-induced angina, ST depression of 6.2 mm, Slope of Peak Exercise ST Segment: Downsloping, 3.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 92:
# Patient is a male aged 62 years, presenting with chest pain type 3, resting blood pressure 130 mm Hg, serum cholesterol 231 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 146, without exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 93:
# Patient is a female aged 44 years, presenting with chest pain type 3, resting blood pressure 108 mm Hg, serum cholesterol 141 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 175, without exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 94:
# Patient is a female aged 63 years, presenting with chest pain type 3, resting blood pressure 135 mm Hg, serum cholesterol 252 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 172, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 95:
# Patient is a male aged 52 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 255 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 161, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 96:
# Patient is a male aged 59 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 239 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 142, with exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 97:
# Patient is a female aged 60 years, presenting with chest pain type 4, resting blood pressure 150 mm Hg, serum cholesterol 258 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 157, without exercise-induced angina, ST depression of 2.6 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 98:
# Patient is a male aged 52 years, presenting with chest pain type 2, resting blood pressure 134 mm Hg, serum cholesterol 201 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 158, without exercise-induced angina, ST depression of 0.8 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 99:
# ...
# --------------------------------------------------------------------------------
# Row 266:
# Patient is a male aged 42 years, presenting with chest pain type 3, resting blood pressure 130 mm Hg, serum cholesterol 180 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 150, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 267:
# Patient is a male aged 61 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 207 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 138, with exercise-induced angina, ST depression of 1.9 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 268:
# Patient is a male aged 66 years, presenting with chest pain type 4, resting blood pressure 160 mm Hg, serum cholesterol 228 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 138, without exercise-induced angina, ST depression of 2.3 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 269:
# Patient is a male aged 46 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 311 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 120, with exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 270:
# Patient is a female aged 71 years, presenting with chest pain type 4, resting blood pressure 112 mm Hg, serum cholesterol 149 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 125, without exercise-induced angina, ST depression of 1.6 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 271:
# Patient is a male aged 59 years, presenting with chest pain type 1, resting blood pressure 134 mm Hg, serum cholesterol 204 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 162, without exercise-induced angina, ST depression of 0.8 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 272:
# Patient is a male aged 64 years, presenting with chest pain type 1, resting blood pressure 170 mm Hg, serum cholesterol 227 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 155, without exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 273:
# Patient is a female aged 66 years, presenting with chest pain type 3, resting blood pressure 146 mm Hg, serum cholesterol 278 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 152, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 274:
# Patient is a female aged 39 years, presenting with chest pain type 3, resting blood pressure 138 mm Hg, serum cholesterol 220 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 152, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 275:
# Patient is a male aged 57 years, presenting with chest pain type 2, resting blood pressure 154 mm Hg, serum cholesterol 232 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 164, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 276:
# Patient is a female aged 58 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 197 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 131, without exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 277:
# Patient is a male aged 57 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 335 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 143, with exercise-induced angina, ST depression of 3.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 278:
# Patient is a male aged 47 years, presenting with chest pain type 3, resting blood pressure 130 mm Hg, serum cholesterol 253 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 179, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 279:
# Patient is a female aged 55 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 205 mg/dL, normal fasting blood sugar, resting ECG showing result ST-T Wave Abnormality, maximum heart rate achieved 130, with exercise-induced angina, ST depression of 2.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 280:
# Patient is a male aged 35 years, presenting with chest pain type 2, resting blood pressure 122 mm Hg, serum cholesterol 192 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 174, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 281:
# Patient is a male aged 61 years, presenting with chest pain type 4, resting blood pressure 148 mm Hg, serum cholesterol 203 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 161, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 282:
# Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 114 mm Hg, serum cholesterol 318 mg/dL, normal fasting blood sugar, resting ECG showing result ST-T Wave Abnormality, maximum heart rate achieved 140, without exercise-induced angina, ST depression of 4.4 mm, Slope of Peak Exercise ST Segment: Downsloping, 3.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 283:
# Patient is a female aged 58 years, presenting with chest pain type 4, resting blood pressure 170 mm Hg, serum cholesterol 225 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 146, with exercise-induced angina, ST depression of 2.8 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 284:
# Patient is a male aged 56 years, presenting with chest pain type 2, resting blood pressure 130 mm Hg, serum cholesterol 221 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 163, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 285:
# Patient is a male aged 56 years, presenting with chest pain type 2, resting blood pressure 120 mm Hg, serum cholesterol 240 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 169, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 286:
# Patient is a male aged 67 years, presenting with chest pain type 3, resting blood pressure 152 mm Hg, serum cholesterol 212 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 150, without exercise-induced angina, ST depression of 0.8 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 287:
# Patient is a female aged 55 years, presenting with chest pain type 2, resting blood pressure 132 mm Hg, serum cholesterol 342 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 166, without exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 288:
# Patient is a male aged 44 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 169 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 144, with exercise-induced angina, ST depression of 2.8 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 289:
# Patient is a male aged 63 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 187 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 144, with exercise-induced angina, ST depression of 4.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 290:
# Patient is a female aged 63 years, presenting with chest pain type 4, resting blood pressure 124 mm Hg, serum cholesterol 197 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 136, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 291:
# Patient is a male aged 41 years, presenting with chest pain type 2, resting blood pressure 120 mm Hg, serum cholesterol 157 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 182, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 292:
# Patient is a male aged 59 years, presenting with chest pain type 4, resting blood pressure 164 mm Hg, serum cholesterol 176 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 90, without exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 293:
# Patient is a female aged 57 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 241 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 123, with exercise-induced angina, ST depression of 0.2 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 294:
# Patient is a male aged 45 years, presenting with chest pain type 1, resting blood pressure 110 mm Hg, serum cholesterol 264 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 132, without exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 295:
# Patient is a male aged 68 years, presenting with chest pain type 4, resting blood pressure 144 mm Hg, serum cholesterol 193 mg/dL, elevated fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 141, without exercise-induced angina, ST depression of 3.4 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 296:
# Patient is a male aged 57 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 131 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 115, with exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 297:
# Patient is a female aged 57 years, presenting with chest pain type 2, resting blood pressure 130 mm Hg, serum cholesterol 236 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 174, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------

# %% [markdown]
# # Train/Test Split

# %%
# Before Augmented
x_train = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Updated/Before_Augmented/x_train.csv")
y_train = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Updated/Before_Augmented/y_train.csv")

# %%
# Train Shape
x_train.shape
# Out:
# (246, 1)

# %%
# Train Label Shape
y_train.shape
# Out:
# (246, 1)

# %%
# Train Count
print(y_train.value_counts())
# Out:
# Heart Disease (0 = No Disease, 1 = Heart Disease)
# 0                                                    128
# 1                                                    118
# Name: count, dtype: int64

# %%
# Loading Test Set
x_test = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Updated/Final_Data/x_test.csv")
y_test = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Updated/Final_Data/y_test.csv")

# %%
# Test shape
x_test.shape
# Out:
# (51, 1)

# %%
# Test Label shape
y_test.shape
# Out:
# (51, 1)

# %%
# Test Count
print(y_test.value_counts())
# Out:
# 0
# 0    32
# 1    19
# Name: count, dtype: int64

# %% [markdown]
# ### GPT Model (humarin/chatgpt_paraphraser_on_T5_base) for Synthetic Data and Paraphrasing (Optional)

# %%
# Merge x_train and y_train
df = pd.concat([x_train, y_train], axis=1)

# %% [markdown]
# ### Positive cases

# %%
# Filter the rows where CKD == 1
hd_rows = df[df["Heart Disease (0 = No Disease, 1 = Heart Disease)"] == 1]

# Print clinical texts for CKD patients only
for idx, text in enumerate(hd_rows["clinical_text"]):
    print(f"Row {idx + 1}:\n{text}\n{'-'*80}")
# Out:
# Row 1:
# Patient is a male aged 54 years, presenting with chest pain type 4, resting blood pressure 124 mm Hg, serum cholesterol 266 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 109, with exercise-induced angina, ST depression of 2.2 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 2:
# Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 150 mm Hg, serum cholesterol 270 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 111, with exercise-induced angina, ST depression of 0.8 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 3:
# Patient is a male aged 56 years, presenting with chest pain type 4, resting blood pressure 125 mm Hg, serum cholesterol 249 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 144, with exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 4:
# Patient is a male aged 50 years, presenting with chest pain type 4, resting blood pressure 150 mm Hg, serum cholesterol 243 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 128, without exercise-induced angina, ST depression of 2.6 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 5:
# Patient is a male aged 59 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 177 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 162, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 6:
# Patient is a male aged 70 years, presenting with chest pain type 4, resting blood pressure 145 mm Hg, serum cholesterol 174 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 125, with exercise-induced angina, ST depression of 2.6 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 7:
# Patient is a male aged 60 years, presenting with chest pain type 4, resting blood pressure 145 mm Hg, serum cholesterol 282 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 142, with exercise-induced angina, ST depression of 2.8 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 8:
# Patient is a male aged 55 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 217 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 111, with exercise-induced angina, ST depression of 5.6 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 9:
# Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 114 mm Hg, serum cholesterol 318 mg/dL, normal fasting blood sugar, resting ECG showing result ST-T Wave Abnormality, maximum heart rate achieved 140, without exercise-induced angina, ST depression of 4.4 mm, Slope of Peak Exercise ST Segment: Downsloping, 3.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 10:
# Patient is a male aged 59 years, presenting with chest pain type 4, resting blood pressure 170 mm Hg, serum cholesterol 326 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 140, with exercise-induced angina, ST depression of 3.4 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 11:
# Patient is a male aged 58 years, presenting with chest pain type 3, resting blood pressure 112 mm Hg, serum cholesterol 230 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 165, without exercise-induced angina, ST depression of 2.5 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 12:
# Patient is a female aged 62 years, presenting with chest pain type 4, resting blood pressure 160 mm Hg, serum cholesterol 164 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 145, without exercise-induced angina, ST depression of 6.2 mm, Slope of Peak Exercise ST Segment: Downsloping, 3.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 13:
# Patient is a male aged 60 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 206 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 132, with exercise-induced angina, ST depression of 2.4 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 14:
# Patient is a male aged 59 years, presenting with chest pain type 4, resting blood pressure 164 mm Hg, serum cholesterol 176 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 90, without exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 15:
# Patient is a male aged 63 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 254 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 147, without exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 16:
# Patient is a female aged 58 years, presenting with chest pain type 2, resting blood pressure 136 mm Hg, serum cholesterol 319 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 152, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 17:
# Patient is a male aged 56 years, presenting with chest pain type 3, resting blood pressure 130 mm Hg, serum cholesterol 256 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 142, with exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 18:
# Patient is a female aged 65 years, presenting with chest pain type 4, resting blood pressure 150 mm Hg, serum cholesterol 225 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 114, without exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 19:
# Patient is a male aged 54 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 206 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 108, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 20:
# Patient is a male aged 59 years, presenting with chest pain type 1, resting blood pressure 170 mm Hg, serum cholesterol 288 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 159, without exercise-induced angina, ST depression of 0.2 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 21:
# Patient is a male aged 62 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 267 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 99, with exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 22:
# Patient is a male aged 45 years, presenting with chest pain type 4, resting blood pressure 142 mm Hg, serum cholesterol 309 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 147, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 23:
# Patient is a male aged 67 years, presenting with chest pain type 4, resting blood pressure 125 mm Hg, serum cholesterol 254 mg/dL, elevated fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 163, without exercise-induced angina, ST depression of 0.2 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 24:
# Patient is a male aged 52 years, presenting with chest pain type 4, resting blood pressure 125 mm Hg, serum cholesterol 212 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 168, without exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 25:
# Patient is a female aged 56 years, presenting with chest pain type 4, resting blood pressure 134 mm Hg, serum cholesterol 409 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 150, with exercise-induced angina, ST depression of 1.9 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 26:
# Patient is a male aged 48 years, presenting with chest pain type 2, resting blood pressure 110 mm Hg, serum cholesterol 229 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 168, without exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 27:
# Patient is a female aged 58 years, presenting with chest pain type 4, resting blood pressure 170 mm Hg, serum cholesterol 225 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 146, with exercise-induced angina, ST depression of 2.8 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 28:
# Patient is a male aged 67 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 229 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 129, with exercise-induced angina, ST depression of 2.6 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 29:
# Patient is a male aged 60 years, presenting with chest pain type 4, resting blood pressure 117 mm Hg, serum cholesterol 230 mg/dL, elevated fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 160, with exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 30:
# Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 146 mm Hg, serum cholesterol 218 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 105, without exercise-induced angina, ST depression of 2.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 31:
# Patient is a female aged 63 years, presenting with chest pain type 4, resting blood pressure 150 mm Hg, serum cholesterol 407 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 154, without exercise-induced angina, ST depression of 4.0 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 32:
# Patient is a male aged 60 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 293 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 170, without exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 33:
# Patient is a male aged 53 years, presenting with chest pain type 4, resting blood pressure 123 mm Hg, serum cholesterol 282 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 95, with exercise-induced angina, ST depression of 2.0 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 34:
# Patient is a male aged 56 years, presenting with chest pain type 4, resting blood pressure 132 mm Hg, serum cholesterol 184 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 105, with exercise-induced angina, ST depression of 2.1 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 35:
# Patient is a male aged 63 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 187 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 144, with exercise-induced angina, ST depression of 4.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 36:
# Patient is a male aged 65 years, presenting with chest pain type 4, resting blood pressure 135 mm Hg, serum cholesterol 254 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 127, without exercise-induced angina, ST depression of 2.8 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 37:
# Patient is a male aged 64 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 246 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 96, with exercise-induced angina, ST depression of 2.2 mm, Slope of Peak Exercise ST Segment: Downsloping, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 38:
# Patient is a male aged 55 years, presenting with chest pain type 4, resting blood pressure 132 mm Hg, serum cholesterol 353 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 132, with exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 39:
# Patient is a female aged 51 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 305 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 142, with exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 40:
# Patient is a male aged 51 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 299 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 173, with exercise-induced angina, ST depression of 1.6 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 41:
# Patient is a male aged 50 years, presenting with chest pain type 4, resting blood pressure 144 mm Hg, serum cholesterol 200 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 126, with exercise-induced angina, ST depression of 0.9 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 42:
# Patient is a male aged 64 years, presenting with chest pain type 3, resting blood pressure 140 mm Hg, serum cholesterol 335 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 158, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 43:
# Patient is a male aged 61 years, presenting with chest pain type 4, resting blood pressure 148 mm Hg, serum cholesterol 203 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 161, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 44:
# Patient is a male aged 57 years, presenting with chest pain type 4, resting blood pressure 150 mm Hg, serum cholesterol 276 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 112, with exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 45:
# Patient is a male aged 47 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 275 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 118, with exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 46:
# Patient is a male aged 48 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 256 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 150, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 47:
# Patient is a male aged 39 years, presenting with chest pain type 4, resting blood pressure 118 mm Hg, serum cholesterol 219 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 140, without exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 48:
# Patient is a male aged 60 years, presenting with chest pain type 4, resting blood pressure 125 mm Hg, serum cholesterol 258 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 141, with exercise-induced angina, ST depression of 2.8 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 49:
# Patient is a male aged 64 years, presenting with chest pain type 4, resting blood pressure 145 mm Hg, serum cholesterol 212 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 132, without exercise-induced angina, ST depression of 2.0 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 50:
# Patient is a male aged 69 years, presenting with chest pain type 3, resting blood pressure 140 mm Hg, serum cholesterol 254 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 146, without exercise-induced angina, ST depression of 2.0 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 51:
# Patient is a male aged 64 years, presenting with chest pain type 3, resting blood pressure 125 mm Hg, serum cholesterol 309 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 131, with exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 52:
# Patient is a male aged 50 years, presenting with chest pain type 3, resting blood pressure 140 mm Hg, serum cholesterol 233 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 163, without exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 53:
# Patient is a male aged 61 years, presenting with chest pain type 4, resting blood pressure 138 mm Hg, serum cholesterol 166 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 125, with exercise-induced angina, ST depression of 3.6 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 54:
# Patient is a female aged 56 years, presenting with chest pain type 4, resting blood pressure 200 mm Hg, serum cholesterol 288 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 133, with exercise-induced angina, ST depression of 4.0 mm, Slope of Peak Exercise ST Segment: Downsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 55:
# Patient is a male aged 59 years, presenting with chest pain type 1, resting blood pressure 160 mm Hg, serum cholesterol 273 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 125, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 56:
# Patient is a female aged 62 years, presenting with chest pain type 4, resting blood pressure 138 mm Hg, serum cholesterol 294 mg/dL, elevated fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 106, without exercise-induced angina, ST depression of 1.9 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 57:
# Patient is a male aged 44 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 169 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 144, with exercise-induced angina, ST depression of 2.8 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 58:
# Patient is a male aged 57 years, presenting with chest pain type 4, resting blood pressure 165 mm Hg, serum cholesterol 289 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 124, without exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 59:
# Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 100 mm Hg, serum cholesterol 234 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 156, without exercise-induced angina, ST depression of 0.1 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 60:
# Patient is a male aged 43 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 177 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 120, with exercise-induced angina, ST depression of 2.5 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 61:
# Patient is a male aged 65 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 248 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 158, without exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 62:
# Patient is a male aged 63 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 330 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 132, with exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Upsloping, 3.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 63:
# Patient is a female aged 62 years, presenting with chest pain type 4, resting blood pressure 150 mm Hg, serum cholesterol 244 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 154, with exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 64:
# Patient is a male aged 61 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 260 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 140, with exercise-induced angina, ST depression of 3.6 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 65:
# Patient is a female aged 55 years, presenting with chest pain type 4, resting blood pressure 180 mm Hg, serum cholesterol 327 mg/dL, normal fasting blood sugar, resting ECG showing result ST-T Wave Abnormality, maximum heart rate achieved 117, with exercise-induced angina, ST depression of 3.4 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 66:
# Patient is a male aged 66 years, presenting with chest pain type 4, resting blood pressure 112 mm Hg, serum cholesterol 212 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 132, with exercise-induced angina, ST depression of 0.1 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 67:
# Patient is a male aged 65 years, presenting with chest pain type 1, resting blood pressure 138 mm Hg, serum cholesterol 282 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 174, without exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 68:
# Patient is a female aged 61 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 330 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 169, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 69:
# Patient is a female aged 57 years, presenting with chest pain type 2, resting blood pressure 130 mm Hg, serum cholesterol 236 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 174, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 70:
# Patient is a male aged 70 years, presenting with chest pain type 3, resting blood pressure 160 mm Hg, serum cholesterol 269 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 112, with exercise-induced angina, ST depression of 2.9 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 71:
# Patient is a male aged 44 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 197 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 177, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 72:
# Patient is a male aged 44 years, presenting with chest pain type 4, resting blood pressure 112 mm Hg, serum cholesterol 290 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 153, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 73:
# Patient is a male aged 35 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 198 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 130, with exercise-induced angina, ST depression of 1.6 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 74:
# Patient is a male aged 59 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 239 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 142, with exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 75:
# Patient is a male aged 52 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 255 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 161, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 76:
# Patient is a male aged 68 years, presenting with chest pain type 4, resting blood pressure 144 mm Hg, serum cholesterol 193 mg/dL, elevated fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 141, without exercise-induced angina, ST depression of 3.4 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 77:
# Patient is a male aged 68 years, presenting with chest pain type 3, resting blood pressure 180 mm Hg, serum cholesterol 274 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 150, with exercise-induced angina, ST depression of 1.6 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 78:
# Patient is a female aged 57 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 241 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 123, with exercise-induced angina, ST depression of 0.2 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 79:
# Patient is a male aged 54 years, presenting with chest pain type 2, resting blood pressure 192 mm Hg, serum cholesterol 283 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 195, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 80:
# Patient is a male aged 59 years, presenting with chest pain type 3, resting blood pressure 126 mm Hg, serum cholesterol 218 mg/dL, elevated fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 134, without exercise-induced angina, ST depression of 2.2 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 81:
# Patient is a male aged 48 years, presenting with chest pain type 4, resting blood pressure 124 mm Hg, serum cholesterol 274 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 166, without exercise-induced angina, ST depression of 0.5 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 82:
# Patient is a male aged 59 years, presenting with chest pain type 1, resting blood pressure 134 mm Hg, serum cholesterol 204 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 162, without exercise-induced angina, ST depression of 0.8 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 83:
# Patient is a male aged 41 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 172 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 158, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 84:
# Patient is a male aged 54 years, presenting with chest pain type 4, resting blood pressure 122 mm Hg, serum cholesterol 286 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 116, with exercise-induced angina, ST depression of 3.2 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 85:
# Patient is a male aged 57 years, presenting with chest pain type 3, resting blood pressure 128 mm Hg, serum cholesterol 229 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 150, without exercise-induced angina, ST depression of 0.4 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 86:
# Patient is a female aged 43 years, presenting with chest pain type 4, resting blood pressure 132 mm Hg, serum cholesterol 341 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 136, with exercise-induced angina, ST depression of 3.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 87:
# Patient is a male aged 40 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 167 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 114, with exercise-induced angina, ST depression of 2.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 88:
# Patient is a male aged 54 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 239 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 126, with exercise-induced angina, ST depression of 2.8 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 89:
# Patient is a male aged 46 years, presenting with chest pain type 3, resting blood pressure 150 mm Hg, serum cholesterol 231 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 147, without exercise-induced angina, ST depression of 3.6 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 90:
# Patient is a male aged 57 years, presenting with chest pain type 2, resting blood pressure 124 mm Hg, serum cholesterol 261 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 141, without exercise-induced angina, ST depression of 0.3 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 91:
# Patient is a male aged 38 years, presenting with chest pain type 1, resting blood pressure 120 mm Hg, serum cholesterol 231 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 182, with exercise-induced angina, ST depression of 3.8 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 92:
# Patient is a female aged 60 years, presenting with chest pain type 4, resting blood pressure 150 mm Hg, serum cholesterol 258 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 157, without exercise-induced angina, ST depression of 2.6 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 93:
# Patient is a male aged 51 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 298 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 122, with exercise-induced angina, ST depression of 4.2 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 94:
# Patient is a male aged 47 years, presenting with chest pain type 3, resting blood pressure 108 mm Hg, serum cholesterol 243 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 152, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 95:
# Patient is a male aged 55 years, presenting with chest pain type 4, resting blood pressure 160 mm Hg, serum cholesterol 289 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 145, with exercise-induced angina, ST depression of 0.8 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 96:
# Patient is a male aged 46 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 249 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 144, without exercise-induced angina, ST depression of 0.8 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 97:
# Patient is a male aged 57 years, presenting with chest pain type 4, resting blood pressure 152 mm Hg, serum cholesterol 274 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 88, with exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 98:
# Patient is a female aged 62 years, presenting with chest pain type 3, resting blood pressure 130 mm Hg, serum cholesterol 263 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 97, without exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 99:
# Patient is a male aged 58 years, presenting with chest pain type 2, resting blood pressure 120 mm Hg, serum cholesterol 284 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 160, without exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 100:
# Patient is a female aged 63 years, presenting with chest pain type 4, resting blood pressure 108 mm Hg, serum cholesterol 269 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 169, with exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 101:
# Patient is a male aged 61 years, presenting with chest pain type 1, resting blood pressure 134 mm Hg, serum cholesterol 234 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 145, without exercise-induced angina, ST depression of 2.6 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 102:
# Patient is a male aged 77 years, presenting with chest pain type 4, resting blood pressure 125 mm Hg, serum cholesterol 304 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 162, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 3.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 103:
# Patient is a male aged 60 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 253 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 144, with exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 104:
# Patient is a female aged 61 years, presenting with chest pain type 4, resting blood pressure 145 mm Hg, serum cholesterol 307 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 146, with exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 105:
# Patient is a male aged 53 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 203 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 155, with exercise-induced angina, ST depression of 3.1 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 106:
# Patient is a female aged 66 years, presenting with chest pain type 4, resting blood pressure 178 mm Hg, serum cholesterol 228 mg/dL, elevated fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 165, with exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 107:
# Patient is a female aged 63 years, presenting with chest pain type 4, resting blood pressure 124 mm Hg, serum cholesterol 197 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 136, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 108:
# Patient is a female aged 60 years, presenting with chest pain type 4, resting blood pressure 158 mm Hg, serum cholesterol 305 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 161, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 109:
# Patient is a male aged 40 years, presenting with chest pain type 4, resting blood pressure 152 mm Hg, serum cholesterol 223 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 181, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 110:
# Patient is a male aged 60 years, presenting with chest pain type 3, resting blood pressure 140 mm Hg, serum cholesterol 185 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 155, without exercise-induced angina, ST depression of 3.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 111:
# Patient is a male aged 45 years, presenting with chest pain type 1, resting blood pressure 110 mm Hg, serum cholesterol 264 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 132, without exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 112:
# Patient is a male aged 67 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 237 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 71, without exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 113:
# Patient is a male aged 57 years, presenting with chest pain type 2, resting blood pressure 154 mm Hg, serum cholesterol 232 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 164, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 114:
# Patient is a male aged 49 years, presenting with chest pain type 3, resting blood pressure 118 mm Hg, serum cholesterol 149 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 126, without exercise-induced angina, ST depression of 0.8 mm, Slope of Peak Exercise ST Segment: Upsloping, 3.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 115:
# Patient is a female aged 59 years, presenting with chest pain type 4, resting blood pressure 174 mm Hg, serum cholesterol 249 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 143, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 116:
# Patient is a male aged 67 years, presenting with chest pain type 3, resting blood pressure 152 mm Hg, serum cholesterol 212 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 150, without exercise-induced angina, ST depression of 0.8 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 117:
# Patient is a male aged 52 years, presenting with chest pain type 4, resting blood pressure 112 mm Hg, serum cholesterol 230 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 160, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 118:
# Patient is a male aged 42 years, presenting with chest pain type 4, resting blood pressure 136 mm Hg, serum cholesterol 315 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 125, with exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------

# %%
import torch
from transformers import pipeline

# Step 1: Filter class 1 examples
df_class_1 = df[df["Heart Disease (0 = No Disease, 1 = Heart Disease)"] == 1]
clinical_sentences_class_1 = df_class_1["clinical_text"].tolist()

# Step 2: Calculate how many paraphrases we need
num_class_0 = df[df["Heart Disease (0 = No Disease, 1 = Heart Disease)"] == 0].shape[0]
num_class_1 = len(clinical_sentences_class_1)
num_needed = num_class_0 - num_class_1

# Step 3: Load GPT (or equivalent medically fine-tuned model for paraphrasing)
paraphrase_pipe = pipeline(
    "text2text-generation",
    model="humarin/chatgpt_paraphraser_on_T5_base",  # This is T5-based, tuned for paraphrasing
    device=0 if torch.cuda.is_available() else -1
)

# Step 4: Generate paraphrases
synthetic_paraphrases = []
num_generated = 0
i = 0

while num_generated < num_needed:
    sentence = clinical_sentences_class_1[i % num_class_1]
    prompt = f"Paraphrase medically accurately: {sentence}"
    result = paraphrase_pipe(prompt, max_length=512, num_return_sequences=1, do_sample=True)
    paraphrased_text = result[0]['generated_text']
    synthetic_paraphrases.append(paraphrased_text)
    num_generated += 1
    i += 1

# Step 5: Store separately in a DataFrame
df_synthetic = pd.DataFrame({
    "clinical_text": synthetic_paraphrases,
    "Heart Disease (0 = No Disease, 1 = Heart Disease)": [1] * len(synthetic_paraphrases)
})

print(f"Generated {len(df_synthetic)} paraphrased class 1 samples.")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Device set to use cuda:0
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Generated 23 paraphrased class 1 samples.

# %%
load_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Augmented/Final/synthetic_HD_Data.csv"

# Load the DataFrame
df_synthetic = pd.read_csv(load_path, encoding='ISO-8859-1')

# Preview
df_synthetic.head()
# Out:
#                                        clinical_text  \
# 0  A 54-year-old male with chest pain type 4 show...
# 1  Resting ECG shows Left Ventricular Hypertrophy...
# 2  A male patient with elevated fasting blood sug...
# 3  A 50-year-old male with chest pain type 4 has ...
# 4  Presenting with chest pain type 4 and exercise...
#
#    Heart Disease (0 = No Disease, 1 = Heart Disease)
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1

# %%
# Visualizing Rows
for idx, text in enumerate(df_synthetic["clinical_text"]):
    print(f"Row {idx + 1}:\n{text}\n{'-'*80}")
# Out:
# Row 1:
# A 54-year-old male with chest pain type 4 shows ST depression of 2.2 mm and a flat slope on peak exercise. He has a resting blood pressure of 124 mm Hg and serum cholesterol at 266 mg/dL. Fasting blood sugar is normal. Resting ECG indicates Left Ventricular Hypertrophy. Maximum heart rate achieved is 109, and he experiences exercise-induced angina. One major vessel is affected, and thalassemia is of the Reversible Defect type.
# --------------------------------------------------------------------------------
# Row 2:
# Resting ECG shows Left Ventricular Hypertrophy in this 58-year-old male with chest pain type 4. Blood pressure is 150 mm Hg, and cholesterol level is 270 mg/dL. Fasting blood sugar is normal. The patient reached a maximum heart rate of 111 and had exercise-induced angina. ST depression is 0.8 mm with an upsloping segment. No major vessels are affected, and thalassemia is of the Reversible Defect type.
# --------------------------------------------------------------------------------
# Row 3:
# A male patient with elevated fasting blood sugar and ECG showing Left Ventricular Hypertrophy is 56 years old. He presents with type 4 chest pain and exercise-induced angina. His maximum heart rate reached 144, and the ST segment is flat with a depression of 1.2 mm. He has one major vessel affected, a resting blood pressure of 125 mm Hg, serum cholesterol level of 249 mg/dL, and his thalassemia type is Normal.
# --------------------------------------------------------------------------------
# Row 4:
# A 50-year-old male with chest pain type 4 has a resting blood pressure of 150 mm Hg and cholesterol at 243 mg/dL. ST depression is 2.6 mm with a flat slope, and maximum heart rate reached is 128. Fasting blood sugar is normal. No exercise-induced angina was reported. ECG shows Left Ventricular Hypertrophy, no major vessels are affected, and thalassemia is of the Reversible Defect type.
# --------------------------------------------------------------------------------
# Row 5:
# Presenting with chest pain type 4 and exercise-induced angina, this 59-year-old male has a normal fasting blood sugar level. His resting blood pressure measures 140 mm Hg, and serum cholesterol is 177 mg/dL. The ECG appears normal. He achieved a maximum heart rate of 162. ST depression is 0.0 mm with an upsloping ST segment. One major vessel is affected, and the thalassemia type is Reversible Defect.
# --------------------------------------------------------------------------------
# Row 6:
# This male patient, aged 70, presents with chest pain type 4 and exercise-induced angina. His resting blood pressure is 145 mm Hg, and serum cholesterol measures 174 mg/dL. ECG findings are normal, and fasting blood sugar is within normal limits. The ST segment is downsloping with an ST depression of 2.6 mm. He reached a maximum heart rate of 125. No major vessels are affected, and the thalassemia type is Reversible Defect.
# --------------------------------------------------------------------------------
# Row 7:
# A 60-year-old male presents with chest pain type 4 and exercise-induced angina. Resting blood pressure is 145 mm Hg, and serum cholesterol is 282 mg/dL. ST depression is 2.8 mm with a flat ST slope. Maximum heart rate achieved is 142. Fasting blood sugar is normal, and ECG shows Left Ventricular Hypertrophy. Two major vessels are affected, and thalassemia is of the Reversible Defect type.
# --------------------------------------------------------------------------------
# Row 8:
# This male patient, aged 55, presents with chest pain type 4 and has exercise-induced angina. His resting blood pressure is 140 mm Hg, and serum cholesterol is recorded at 217 mg/dL. The ECG shows normal findings, and his fasting blood sugar level is within the normal range. The ST segment is downsloping with a significant ST depression of 5.6 mm. He achieved a maximum heart rate of 111. No major vessels are affected, and the thalassemia type is classified as Reversible Defect.
# --------------------------------------------------------------------------------
# Row 9:
# A 58-year-old male with chest pain type 4 presents without exercise-induced angina. Resting blood pressure is 114 mm Hg, and serum cholesterol is 318 mg/dL. ST depression is 4.4 mm with a downsloping ST segment. Maximum heart rate achieved is 140. Fasting blood sugar is normal, and ECG shows ST-T wave abnormality. Three major vessels are affected, and thalassemia is of the Fixed Defect type.
# --------------------------------------------------------------------------------
# Row 10:
# A 59-year-old male with chest pain type 4 presents with exercise-induced angina. Resting blood pressure is 170 mm Hg, and serum cholesterol is 326 mg/dL. ST depression is 3.4 mm with a downsloping ST segment. Maximum heart rate reached is 140. Fasting blood sugar is normal, and ECG shows Left Ventricular Hypertrophy. No major vessels are affected, and thalassemia is of the Reversible Defect type.
# --------------------------------------------------------------------------------
# Row 11:
# This male patient, aged 58, presents with chest pain type 3 and no signs of exercise-induced angina. His resting blood pressure measures 112 mm Hg, and serum cholesterol is at 230 mg/dL. The ECG indicates Left Ventricular Hypertrophy, and fasting blood sugar is normal. He achieved a maximum heart rate of 165. ST depression is measured at 2.5 mm, accompanied by a flat ST segment. One major vessel is affected, and the thalassemia type is Reversible Defect.
# --------------------------------------------------------------------------------
# Row 12:
# A 62-year-old female with chest pain type 4 presents without exercise-induced angina. Resting blood pressure is 160 mm Hg, and serum cholesterol is 164 mg/dL. ST depression is 6.2 mm with a downsloping ST segment. Maximum heart rate reached is 145. Fasting blood sugar is normal, and ECG shows Left Ventricular Hypertrophy. Three major vessels are affected, and thalassemia is of the Reversible Defect type.
# --------------------------------------------------------------------------------
# Row 13:
# A 60-year-old male with chest pain type 4 presents with exercise-induced angina. Resting blood pressure is 130 mm Hg, and serum cholesterol is 206 mg/dL. ST depression is 2.4 mm with a flat ST segment. Maximum heart rate reached is 132. Fasting blood sugar is normal, and ECG shows Left Ventricular Hypertrophy. Two major vessels are affected, and thalassemia is of the Reversible Defect type.
# --------------------------------------------------------------------------------
# Row 14:
# This 59-year-old male presents with chest pain type 4, with no exercise-induced angina. Resting blood pressure is 164 mm Hg, and maximum heart rate reached 90. ST depression is 1.0 mm, and the ST segment is flat. Serum cholesterol is 176 mg/dL, and fasting blood sugar is elevated. The ECG reveals Left Ventricular Hypertrophy. Two major vessels are affected, and thalassemia type is Fixed Defect.
# --------------------------------------------------------------------------------
# Row 15:
# A 63-year-old male with chest pain type 4 presents without exercise-induced angina. Resting blood pressure is 130 mm Hg, and serum cholesterol is 254 mg/dL. ST depression is 1.4 mm with a flat ST segment. Maximum heart rate reached is 147. Fasting blood sugar is normal, and ECG shows Left Ventricular Hypertrophy. One major vessel is affected, and thalassemia is of the Reversible Defect type.
# --------------------------------------------------------------------------------
# Row 16:
# This 58-year-old female presents with chest pain type 2 and no exercise-induced angina. Resting blood pressure is 136 mm Hg, and maximum heart rate reached is 152. Serum cholesterol is 319 mg/dL, and fasting blood sugar is elevated. ST depression measures 0.0 mm, with an upsloping ST segment. The ECG shows Left Ventricular Hypertrophy, and two major vessels are affected. Thalassemia type is Normal.
# --------------------------------------------------------------------------------
# Row 17:
# A 56-year-old male with chest pain type 3 presents with exercise-induced angina. Resting blood pressure is 130 mm Hg, and serum cholesterol is 256 mg/dL. ST depression is 0.6 mm with a flat ST segment. Maximum heart rate reached is 142. Elevated fasting blood sugar, and ECG shows Left Ventricular Hypertrophy. One major vessel is affected, and thalassemia is of the Fixed Defect type.
# --------------------------------------------------------------------------------
# Row 18:
# With chest pain type 4, a 65-year-old female presents without exercise-induced angina. Her resting blood pressure is 150 mm Hg, and serum cholesterol is 225 mg/dL. Maximum heart rate reached is 114, and ST depression is 1.0 mm with a flat ST segment. Fasting blood sugar is normal, and the ECG shows Left Ventricular Hypertrophy. Three major vessels are affected, and thalassemia is of the Reversible Defect type.
# --------------------------------------------------------------------------------
# Row 19:
# A 54-year-old male with chest pain type 4 presents with exercise-induced angina. Resting blood pressure is 110 mm Hg, and serum cholesterol is 206 mg/dL. ST depression is 0.0 mm with a flat ST segment. Maximum heart rate reached is 108. Fasting blood sugar is normal, and ECG shows Left Ventricular Hypertrophy. One major vessel is affected, and thalassemia is of the Normal type.
# --------------------------------------------------------------------------------
# Row 20:
# A male, aged 59 years, presents with chest pain type 1 and no exercise-induced angina. His resting blood pressure is 170 mm Hg, and serum cholesterol is 288 mg/dL. Maximum heart rate reached is 159, and ST depression is 0.2 mm with a flat ST segment. Fasting blood sugar is normal, and the ECG shows Left Ventricular Hypertrophy. No major vessels are affected, and thalassemia is of the Reversible Defect type.
# --------------------------------------------------------------------------------
# Row 21:
# A 62-year-old male with chest pain type 4 presents with exercise-induced angina. Resting blood pressure is 120 mm Hg, and serum cholesterol is 267 mg/dL. ST depression is 1.8 mm with a flat ST segment. Maximum heart rate reached is 99. Fasting blood sugar is normal, and ECG shows Normal results. Two major vessels are affected, and thalassemia is of the Reversible Defect type.
# --------------------------------------------------------------------------------
# Row 22:
# A male, aged 45 years, presents with chest pain type 4 and exercise-induced angina. His resting blood pressure is 142 mm Hg, and serum cholesterol is 309 mg/dL. Maximum heart rate achieved is 147, and ST depression is 0.0 mm with a flat ST segment. Fasting blood sugar is normal, and the ECG shows Left Ventricular Hypertrophy. Three major vessels are affected, and thalassemia is of the Reversible Defect type.
# --------------------------------------------------------------------------------
# Row 23:
# A 67-year-old male with chest pain type 4 presents with elevated fasting blood sugar. Resting blood pressure is 125 mm Hg, and serum cholesterol is 254 mg/dL. Maximum heart rate achieved is 163. ST depression is 0.2 mm, with a flat ST segment. ECG shows normal results, and there is no exercise-induced angina. Two major vessels are affected, and thalassemia is of the Reversible Defect type.
# --------------------------------------------------------------------------------

# %% [markdown]
# ## After Augmentation

# %%
# Concatenating along rows (axis=0)

x_train = pd.concat(
    [ x_train[['clinical_text']],
      df_synthetic[['clinical_text']] ],
    axis=0,
    ignore_index=True
)

y_train = pd.concat(
    [ y_train[['Heart Disease (0 = No Disease, 1 = Heart Disease)']],
      df_synthetic[['Heart Disease (0 = No Disease, 1 = Heart Disease)']] ],
    axis=0,
    ignore_index=True
)

# %%
"""
# Save to CSV
x_train.to_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Updated/Final_Data/Final/x_train.csv", index=False)
y_train.to_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Updated/Final_Data/Final/y_train", index=False)
"""

# %%
# Augmented
x_train = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Updated/Final_Data/Final/x_train.csv")
y_train = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Updated/Final_Data/Final/y_train")

# %%
# Train Shape
x_train.shape
# Out:
# (269, 1)

# %%
# Train Label Shape
y_train.shape
# Out:
# (292, 1)

# %%
# Train Count
print(y_train.value_counts())
# Out:
# 0
# 1    164
# 0    128
# Name: count, dtype: int64

# %%
# Loading Test Set
x_test = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Updated/Final_Data/x_test.csv")
y_test = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Updated/Final_Data/y_test.csv")

# %%
# Test shape
x_test.shape
# Out:
# (51, 1)

# %%
# Test Label shape
y_test.shape
# Out:
# (51, 1)

# %%
# Test Count
print(y_test.value_counts())
# Out:
# 0
# 0    32
# 1    19
# Name: count, dtype: int64

# %% [markdown]
# # GPT as Classification Model

# %%
pip install --upgrade transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.51.3

# %%
# !pip install huggingface_hub[hf_xet]
# Out:
# Requirement already satisfied: huggingface_hub[hf_xet] in /usr/local/lib/python3.11/dist-packages (0.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (4.13.2)
# Collecting hf-xet>=0.1.4 (from huggingface_hub[hf_xet])
#   Downloading hf_xet-1.1.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (494 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (2025.4.26)
# Downloading hf_xet-1.1.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 MB 12.0 MB/s eta 0:00:00
# Installing collected packages: hf-xet
# Successfully installed hf-xet-1.1.0

# %%
pip install transformers datasets scikit-learn
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Collecting datasets
#   Downloading datasets-3.5.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.1-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 23.3 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.5 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 16.0 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 9.1 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 13.1 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed datasets-3.5.1 dill-0.3.8 fsspec-2025.3.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
import torch
import pandas as pd
from transformers import GPT2Tokenizer, GPT2Model, GPT2Config
from transformers import Trainer, TrainingArguments
from torch import nn
from torch.utils.data import Dataset
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# Check device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 1. Load tokenizer and GPT2
tokenizer = GPT2Tokenizer.from_pretrained("distilgpt2")
tokenizer.pad_token = tokenizer.eos_token  # set pad token to eos_token

# 2. Custom Dataset
class ClinicalDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.encodings = tokenizer(list(texts), truncation=True, padding=True, max_length=max_len, return_tensors='pt')
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.encodings.items()}
        item['labels'] = self.labels[idx]
        return item

# 3. Custom GPT2 Classification Model
class GPT2ForClassification(nn.Module):
    def __init__(self, n_classes=2):
        super(GPT2ForClassification, self).__init__()
        self.gpt2 = GPT2Model.from_pretrained("distilgpt2")
        self.dropout = nn.Dropout(0.2)
        self.classifier = nn.Linear(self.gpt2.config.hidden_size, n_classes)

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.gpt2(input_ids=input_ids, attention_mask=attention_mask)
        last_hidden_state = outputs.last_hidden_state  # [batch_size, seq_len, hidden_dim]
        cls_output = last_hidden_state[:, -1, :]  # use last token hidden state
        logits = self.classifier(self.dropout(cls_output))
        loss = None
        if labels is not None:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)
        return {"loss": loss, "logits": logits}

# Texts
if isinstance(x_train, pd.DataFrame):
    x_train = x_train.squeeze().astype(str).tolist()
if isinstance(x_test, pd.DataFrame):
    x_test = x_test.squeeze().astype(str).tolist()

# Labels
if isinstance(y_train, pd.DataFrame):
    y_train = y_train.squeeze().astype(int).tolist()
if isinstance(y_test, pd.DataFrame):
    y_test = y_test.squeeze().astype(int).tolist()

# 4. Prepare dataset
train_dataset = ClinicalDataset(x_train, y_train, tokenizer)
test_dataset = ClinicalDataset(x_test, y_test, tokenizer)

# 5. Load model
model = GPT2ForClassification()
model.to(device)

# 6. TrainingArguments and Trainer
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=2,
    num_train_epochs=10,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=5,
    save_steps=10,
    eval_steps=10,
    metric_for_best_model="accuracy",  # or "f1" depending on your task
    greater_is_better=True,
    warmup_ratio=0.1,              # Warmup to prevent early overfitting
    gradient_accumulation_steps=2, # Simulates larger batch size
    fp16=True,                     # Use if on GPU with mixed precision support
)

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    return {"accuracy": (preds == labels).mean()}

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics,
)

# 7. Train the model
trainer.train()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: starwarsfanclub1234 (starwarsfanclub1234-montclair-state-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.1
# Run data is saved locally in <code>/content/wandb/run-20251004_204615-kwaiywgp</code>
# Syncing run <strong><a href='https://wandb.ai/starwarsfanclub1234-montclair-state-university/huggingface/runs/kwaiywgp' target="_blank">fast-pond-2</a></strong> to <a href='https://wandb.ai/starwarsfanclub1234-montclair-state-university/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/starwarsfanclub1234-montclair-state-university/huggingface' target="_blank">https://wandb.ai/starwarsfanclub1234-montclair-state-university/huggingface</a>
#  View run at <a href='https://wandb.ai/starwarsfanclub1234-montclair-state-university/huggingface/runs/kwaiywgp' target="_blank">https://wandb.ai/starwarsfanclub1234-montclair-state-university/huggingface/runs/kwaiywgp</a>
#     <div>
#
#       <progress value='680' max='680' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [680/680 22:31, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>4.113700</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.879700</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>3.427800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.706200</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.469200</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.125300</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.249100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.857300</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.959100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.117300</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.018100</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.954500</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.851500</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.592800</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.655000</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.824700</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.766700</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.625600</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.651600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.544300</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.617300</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.652600</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.700000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.774000</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.475000</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.411300</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.232400</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.579200</td>
#     </tr>
#     <tr>
#       <td>145</td>
#       <td>0.692200</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.445300</td>
#     </tr>
#     <tr>
#       <td>155</td>
#       <td>0.239300</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>1.005300</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>0.381800</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>1.914800</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.750400</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.943400</td>
#     </tr>
#     <tr>
#       <td>185</td>
#       <td>1.310900</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.782400</td>
#     </tr>
#     <tr>
#       <td>195</td>
#       <td>0.858700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.925300</td>
#     </tr>
#     <tr>
#       <td>205</td>
#       <td>0.727400</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.863200</td>
#     </tr>
#     <tr>
#       <td>215</td>
#       <td>0.766800</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.765000</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.769300</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.384700</td>
#     </tr>
#     <tr>
#       <td>235</td>
#       <td>0.364100</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.586600</td>
#     </tr>
#     <tr>
#       <td>245</td>
#       <td>1.051000</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.873700</td>
#     </tr>
#     <tr>
#       <td>255</td>
#       <td>0.750300</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.714700</td>
#     </tr>
#     <tr>
#       <td>265</td>
#       <td>0.267300</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.386500</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.657300</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.288100</td>
#     </tr>
#     <tr>
#       <td>285</td>
#       <td>0.475200</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.396700</td>
#     </tr>
#     <tr>
#       <td>295</td>
#       <td>0.518400</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.380400</td>
#     </tr>
#     <tr>
#       <td>305</td>
#       <td>0.739500</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.697500</td>
#     </tr>
#     <tr>
#       <td>315</td>
#       <td>1.578200</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>1.712500</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.543200</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.203400</td>
#     </tr>
#     <tr>
#       <td>335</td>
#       <td>0.749700</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.970700</td>
#     </tr>
#     <tr>
#       <td>345</td>
#       <td>0.545700</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.707600</td>
#     </tr>
#     <tr>
#       <td>355</td>
#       <td>0.562000</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.247500</td>
#     </tr>
#     <tr>
#       <td>365</td>
#       <td>0.736500</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.318300</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.168700</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>1.198700</td>
#     </tr>
#     <tr>
#       <td>385</td>
#       <td>0.094000</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.380800</td>
#     </tr>
#     <tr>
#       <td>395</td>
#       <td>0.398200</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.941600</td>
#     </tr>
#     <tr>
#       <td>405</td>
#       <td>1.327700</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.736800</td>
#     </tr>
#     <tr>
#       <td>415</td>
#       <td>0.101200</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.163200</td>
#     </tr>
#     <tr>
#       <td>425</td>
#       <td>0.748600</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.152000</td>
#     </tr>
#     <tr>
#       <td>435</td>
#       <td>0.636500</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.219600</td>
#     </tr>
#     <tr>
#       <td>445</td>
#       <td>1.236500</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.437800</td>
#     </tr>
#     <tr>
#       <td>455</td>
#       <td>0.422500</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>1.060100</td>
#     </tr>
#     <tr>
#       <td>465</td>
#       <td>0.933300</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.117900</td>
#     </tr>
#     <tr>
#       <td>475</td>
#       <td>1.754400</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.335600</td>
#     </tr>
#     <tr>
#       <td>485</td>
#       <td>1.248000</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.456200</td>
#     </tr>
#     <tr>
#       <td>495</td>
#       <td>1.761700</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.293800</td>
#     </tr>
#     <tr>
#       <td>505</td>
#       <td>0.396400</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.280400</td>
#     </tr>
#     <tr>
#       <td>515</td>
#       <td>0.900800</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.050600</td>
#     </tr>
#     <tr>
#       <td>525</td>
#       <td>0.073600</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.282800</td>
#     </tr>
#     <tr>
#       <td>535</td>
#       <td>0.206600</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.750500</td>
#     </tr>
#     <tr>
#       <td>545</td>
#       <td>0.398200</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.078000</td>
#     </tr>
#     <tr>
#       <td>555</td>
#       <td>0.364400</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.712500</td>
#     </tr>
#     <tr>
#       <td>565</td>
#       <td>0.265200</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.346600</td>
#     </tr>
#     <tr>
#       <td>575</td>
#       <td>0.475100</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.297900</td>
#     </tr>
#     <tr>
#       <td>585</td>
#       <td>1.230700</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.736700</td>
#     </tr>
#     <tr>
#       <td>595</td>
#       <td>0.240400</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.918500</td>
#     </tr>
#     <tr>
#       <td>605</td>
#       <td>0.561100</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.057000</td>
#     </tr>
#     <tr>
#       <td>615</td>
#       <td>0.194200</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.685300</td>
#     </t
# TrainOutput(global_step=680, training_loss=0.7316580455092823, metrics={'train_runtime': 1387.1139, 'train_samples_per_second': 1.939, 'train_steps_per_second': 0.49, 'total_flos': 0.0, 'train_loss': 0.7316580455092823, 'epoch': 10.0})

# %%
# 8. Evaluation
preds_output = trainer.predict(test_dataset)
predictions = np.argmax(preds_output.predictions, axis=1)

# %%
# 9. Classification report & confusion matrix
print("Classification Report:\n", classification_report(y_test, predictions, digits=4))
print("Confusion Matrix:\n", confusion_matrix(y_test, predictions))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9677    0.9375    0.9524        32
#            1     0.9000    0.9474    0.9231        19
#
#     accuracy                         0.9412        51
#    macro avg     0.9339    0.9424    0.9377        51
# weighted avg     0.9425    0.9412    0.9415        51
#
# Confusion Matrix:
#  [[30  2]
#  [ 1 18]]

# %%
"""
save_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Model/"

trainer.save_model(save_path)
tokenizer.save_pretrained(save_path)

print("Model and tokenizer saved to:", save_path)
"""
# Out:
# Model and tokenizer saved to: /content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Model/

# %%
from transformers import GPT2Tokenizer
import torch

save_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Model/"

# Reload tokenizer
tokenizer = GPT2Tokenizer.from_pretrained(save_path)
tokenizer.pad_token = tokenizer.eos_token

# Reload model
model = GPT2ForClassification(n_classes=2)
state_dict = torch.load(save_path + "pytorch_model.bin", map_location="cuda" if torch.cuda.is_available() else "cpu")
model.load_state_dict(state_dict)
model.to(device)
model.eval()

print("Model loaded from:", save_path)
# Out:
# Model loaded from: /content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Model/

# %% [markdown]
# ## Ablation

# %%
import torch
import pandas as pd
from transformers import GPT2Tokenizer, GPT2Model, GPT2Config
from transformers import Trainer, TrainingArguments
from torch import nn
from torch.utils.data import Dataset
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# Check device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 1. Load tokenizer and GPT2
tokenizer = GPT2Tokenizer.from_pretrained("distilgpt2")
tokenizer.pad_token = tokenizer.eos_token  # set pad token to eos_token

# 2. Custom Dataset
class ClinicalDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.encodings = tokenizer(list(texts), truncation=True, padding=True, max_length=max_len, return_tensors='pt')
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.encodings.items()}
        item['labels'] = self.labels[idx]
        return item

# 3. Custom GPT2 Classification Model
class GPT2ForClassification(nn.Module):
    def __init__(self, n_classes=2):
        super(GPT2ForClassification, self).__init__()
        self.gpt2 = GPT2Model.from_pretrained("distilgpt2")
        self.dropout = nn.Dropout(0.2)
        self.classifier = nn.Linear(self.gpt2.config.hidden_size, n_classes)

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.gpt2(input_ids=input_ids, attention_mask=attention_mask)
        last_hidden_state = outputs.last_hidden_state  # [batch_size, seq_len, hidden_dim]
        cls_output = last_hidden_state[:, -1, :]  # use last token hidden state
        logits = self.classifier(self.dropout(cls_output))
        loss = None
        if labels is not None:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)
        return {"loss": loss, "logits": logits}

# Texts
if isinstance(x_train, pd.DataFrame):
    x_train = x_train.squeeze().astype(str).tolist()
if isinstance(x_test, pd.DataFrame):
    x_test = x_test.squeeze().astype(str).tolist()

# Labels
if isinstance(y_train, pd.DataFrame):
    y_train = y_train.squeeze().astype(int).tolist()
if isinstance(y_test, pd.DataFrame):
    y_test = y_test.squeeze().astype(int).tolist()

# 4. Prepare dataset
train_dataset = ClinicalDataset(x_train, y_train, tokenizer)
test_dataset = ClinicalDataset(x_test, y_test, tokenizer)

# 5. Load model
model = GPT2ForClassification()
model.to(device)

# 6. TrainingArguments and Trainer
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=2,
    num_train_epochs=3,
    weight_decay=0.001,
    logging_dir="./logs",
    logging_steps=5,
    save_steps=10,
    eval_steps=10,
    metric_for_best_model="accuracy",  # or "f1" depending on your task
    greater_is_better=True,
    warmup_ratio=0.1,              # Warmup to prevent early overfitting
    gradient_accumulation_steps=2, # Simulates larger batch size
    fp16=True,                     # Use if on GPU with mixed precision support
)

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    return {"accuracy": (preds == labels).mean()}

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics,
)

# 7. Train the model
trainer.train()
# Out:
#     <div>
#
#       <progress value='183' max='183' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [183/183 04:50, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.998600</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.123900</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.053400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.473700</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.127400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.213600</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.933900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.821600</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.832500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.810800</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.367700</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.697000</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.858200</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.653600</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.867100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.798900</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.906300</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.128500</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.607700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.784500</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.534500</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.713300</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.384700</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.614100</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.424400</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.492400</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.501200</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.827600</td>
#     </tr>
#     <tr>
#       <td>145</td>
#       <td>0.739300</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.768600</td>
#     </tr>
#     <tr>
#       <td>155</td>
#       <td>0.641700</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.456400</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>0.705300</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.607000</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.614400</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.484000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=183, training_loss=0.8105736430225476, metrics={'train_runtime': 290.2068, 'train_samples_per_second': 2.543, 'train_steps_per_second': 0.631, 'total_flos': 0.0, 'train_loss': 0.8105736430225476, 'epoch': 2.959349593495935})

# %%
# 8. Evaluation
preds_output = trainer.predict(test_dataset)
predictions = np.argmax(preds_output.predictions, axis=1)

# %%
# 9. Classification report & confusion matrix
print("Classification Report:\n", classification_report(y_test, predictions, digits=4))
print("Confusion Matrix:\n", confusion_matrix(y_test, predictions))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.8750    0.8750    0.8750        32
#            1     0.7895    0.7895    0.7895        19
#
#     accuracy                         0.8431        51
#    macro avg     0.8322    0.8322    0.8322        51
# weighted avg     0.8431    0.8431    0.8431        51
#
# Confusion Matrix:
#  [[28  4]
#  [ 4 15]]

# %% [markdown]
# # Interpretability

# %% [markdown]
# We take the trained GPT-2 model and look at how much each input token “influences” the model’s prediction. To do this, we track gradients—essentially, how much the model’s output would change if we slightly changed the token’s representation. Tokens with larger gradient values had a bigger effect on the decision, meaning the model “paid more attention” to them. By focusing only on keywords of interest (like “blood pressure” or “sugar”), we can see which clinical features the model considered most important for its prediction. This method gives a transparent view of what the model thinks matters, without changing the model itself.
#
# In simple terms: we compute the gradient of the model’s output (the predicted class score) with respect to each input token’s embedding. The size of this gradient tells us how sensitive the prediction is to changes in that token. Larger gradients mean the model relies more on that token to make its decision.
#
# This is a post-hoc interpretability method that works directly on the trained model without modifying it, and it’s widely used in NLP for token-level importance visualization.

# %%
# Combine x_test and y_test
merged_df = pd.concat([x_test, y_test], axis=1)

# Assume y_test column name is 'label' (adjust if different)
# If y_test has no column name, assign one
if merged_df.columns[-1] not in ['label', 'y_test']:
    merged_df.columns = list(merged_df.columns[:-1]) + ['label']

# Filter rows where label == 1
positive_cases = merged_df[merged_df['label'] == 1]

# Print texts for positive cases
for idx, row in positive_cases.iterrows():
    print(f"Row {idx + 1}:\n{row[0]}\n{'-'*80}")
# Out:
# Row 7:
# Patient is a male aged 58 years, presenting with chest pain type 3, resting blood pressure 132 mm Hg, serum cholesterol 224 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 173, without exercise-induced angina, ST depression of 3.2 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 10:
# Patient is a male aged 67 years, presenting with chest pain type 4, resting blood pressure 100 mm Hg, serum cholesterol 299 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 125, with exercise-induced angina, ST depression of 0.9 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 13:
# Patient is a male aged 49 years, presenting with chest pain type 3, resting blood pressure 120 mm Hg, serum cholesterol 188 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 139, without exercise-induced angina, ST depression of 2.0 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 14:
# Patient is a male aged 54 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 188 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 113, without exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 15:
# Patient is a female aged 62 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 268 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 160, without exercise-induced angina, ST depression of 3.6 mm, Slope of Peak Exercise ST Segment: Downsloping, 2.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 17:
# Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 216 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 131, with exercise-induced angina, ST depression of 2.2 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 18:
# Patient is a male aged 57 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 131 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 115, with exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 21:
# Patient is a male aged 46 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 311 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 120, with exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 23:
# Patient is a male aged 57 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 335 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 143, with exercise-induced angina, ST depression of 3.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 27:
# Patient is a male aged 62 years, presenting with chest pain type 2, resting blood pressure 120 mm Hg, serum cholesterol 281 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 103, without exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 32:
# Patient is a male aged 66 years, presenting with chest pain type 2, resting blood pressure 160 mm Hg, serum cholesterol 246 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 120, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Fixed Defect.
# --------------------------------------------------------------------------------
# Row 34:
# Patient is a male aged 56 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 283 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 103, with exercise-induced angina, ST depression of 1.6 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 36:
# Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 259 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 130, with exercise-induced angina, ST depression of 3.0 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 37:
# Patient is a male aged 67 years, presenting with chest pain type 4, resting blood pressure 160 mm Hg, serum cholesterol 286 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 108, with exercise-induced angina, ST depression of 1.5 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 38:
# Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 125 mm Hg, serum cholesterol 300 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 171, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 41:
# Patient is a female aged 55 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 205 mg/dL, normal fasting blood sugar, resting ECG showing result ST-T Wave Abnormality, maximum heart rate achieved 130, with exercise-induced angina, ST depression of 2.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 45:
# Patient is a male aged 70 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 322 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 109, without exercise-induced angina, ST depression of 2.4 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Normal.
# --------------------------------------------------------------------------------
# Row 48:
# Patient is a male aged 61 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 207 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 138, with exercise-induced angina, ST depression of 1.9 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# Row 49:
# Patient is a male aged 35 years, presenting with chest pain type 4, resting blood pressure 126 mm Hg, serum cholesterol 282 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 156, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
# --------------------------------------------------------------------------------
# /tmp/ipython-input-2093218046.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Row {idx + 1}:\n{row[0]}\n{'-'*80}")

# %%
for idx, text in enumerate(x_test.values):
    print(f"Row {idx + 1}:\n{text}\n{'-' * 80}")
# Out:
# Row 1:
# ['Patient is a male aged 41 years, presenting with chest pain type 2, resting blood pressure 120 mm Hg, serum cholesterol 157 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 182, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 2:
# ['Patient is a female aged 49 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 269 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 163, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 3:
# ['Patient is a male aged 66 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 302 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 151, without exercise-induced angina, ST depression of 0.4 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 4:
# ['Patient is a female aged 57 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 303 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 159, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 5:
# ['Patient is a male aged 54 years, presenting with chest pain type 3, resting blood pressure 150 mm Hg, serum cholesterol 232 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 165, without exercise-induced angina, ST depression of 1.6 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 6:
# ['Patient is a female aged 42 years, presenting with chest pain type 3, resting blood pressure 120 mm Hg, serum cholesterol 209 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 173, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 7:
# ['Patient is a male aged 58 years, presenting with chest pain type 3, resting blood pressure 132 mm Hg, serum cholesterol 224 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 173, without exercise-induced angina, ST depression of 3.2 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 8:
# ['Patient is a female aged 49 years, presenting with chest pain type 2, resting blood pressure 134 mm Hg, serum cholesterol 271 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 162, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 9:
# ['Patient is a female aged 50 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 254 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 159, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 10:
# ['Patient is a male aged 67 years, presenting with chest pain type 4, resting blood pressure 100 mm Hg, serum cholesterol 299 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 125, with exercise-induced angina, ST depression of 0.9 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 11:
# ['Patient is a female aged 45 years, presenting with chest pain type 2, resting blood pressure 112 mm Hg, serum cholesterol 160 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 138, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 12:
# ['Patient is a male aged 59 years, presenting with chest pain type 4, resting blood pressure 135 mm Hg, serum cholesterol 234 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 161, without exercise-induced angina, ST depression of 0.5 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 13:
# ['Patient is a male aged 49 years, presenting with chest pain type 3, resting blood pressure 120 mm Hg, serum cholesterol 188 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 139, without exercise-induced angina, ST depression of 2.0 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 14:
# ['Patient is a male aged 54 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 188 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 113, without exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 15:
# ['Patient is a female aged 62 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 268 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 160, without exercise-induced angina, ST depression of 3.6 mm, Slope of Peak Exercise ST Segment: Downsloping, 2.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 16:
# ['Patient is a female aged 58 years, presenting with chest pain type 1, resting blood pressure 150 mm Hg, serum cholesterol 283 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 162, without exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 17:
# ['Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 216 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 131, with exercise-induced angina, ST depression of 2.2 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 18:
# ['Patient is a male aged 57 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 131 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 115, with exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 19:
# ['Patient is a male aged 29 years, presenting with chest pain type 2, resting blood pressure 130 mm Hg, serum cholesterol 204 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 202, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 20:
# ['Patient is a male aged 42 years, presenting with chest pain type 2, resting blood pressure 120 mm Hg, serum cholesterol 295 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 162, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 21:
# ['Patient is a male aged 46 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 311 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 120, with exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 22:
# ['Patient is a female aged 46 years, presenting with chest pain type 2, resting blood pressure 105 mm Hg, serum cholesterol 204 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 172, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 23:
# ['Patient is a male aged 57 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 335 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 143, with exercise-induced angina, ST depression of 3.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 24:
# ['Patient is a male aged 64 years, presenting with chest pain type 1, resting blood pressure 170 mm Hg, serum cholesterol 227 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 155, without exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 25:
# ['Patient is a female aged 68 years, presenting with chest pain type 3, resting blood pressure 120 mm Hg, serum cholesterol 211 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 115, without exercise-induced angina, ST depression of 1.5 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 26:
# ['Patient is a male aged 37 years, presenting with chest pain type 3, resting blood pressure 130 mm Hg, serum cholesterol 250 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 187, without exercise-induced angina, ST depression of 3.5 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 27:
# ['Patient is a male aged 62 years, presenting with chest pain type 2, resting blood pressure 120 mm Hg, serum cholesterol 281 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 103, without exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 28:
# ['Patient is a male aged 58 years, presenting with chest pain type 3, resting blood pressure 140 mm Hg, serum cholesterol 211 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 165, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 29:
# ['Patient is a male aged 47 years, presenting with chest pain type 3, resting blood pressure 130 mm Hg, serum cholesterol 253 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 179, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 30:
# ['Patient is a male aged 34 years, presenting with chest pain type 1, resting blood pressure 118 mm Hg, serum cholesterol 182 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 174, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 31:
# ['Patient is a female aged 54 years, presenting with chest pain type 3, resting blood pressure 110 mm Hg, serum cholesterol 214 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 158, without exercise-induced angina, ST depression of 1.6 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 32:
# ['Patient is a male aged 66 years, presenting with chest pain type 2, resting blood pressure 160 mm Hg, serum cholesterol 246 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 120, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Fixed Defect.']
# --------------------------------------------------------------------------------
# Row 33:
# ['Patient is a male aged 50 years, presenting with chest pain type 3, resting blood pressure 129 mm Hg, serum cholesterol 196 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 163, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 34:
# ['Patient is a male aged 56 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 283 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 103, with exercise-induced angina, ST depression of 1.6 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 35:
# ['Patient is a female aged 44 years, presenting with chest pain type 3, resting blood pressure 108 mm Hg, serum cholesterol 141 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 175, without exercise-induced angina, ST depression of 0.6 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 36:
# ['Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 259 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 130, with exercise-induced angina, ST depression of 3.0 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 37:
# ['Patient is a male aged 67 years, presenting with chest pain type 4, resting blood pressure 160 mm Hg, serum cholesterol 286 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 108, with exercise-induced angina, ST depression of 1.5 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 38:
# ['Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 125 mm Hg, serum cholesterol 300 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 171, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 39:
# ['Patient is a female aged 55 years, presenting with chest pain type 2, resting blood pressure 135 mm Hg, serum cholesterol 250 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 161, without exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 40:
# ['Patient is a female aged 53 years, presenting with chest pain type 4, resting blood pressure 138 mm Hg, serum cholesterol 234 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 160, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 41:
# ['Patient is a female aged 55 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 205 mg/dL, normal fasting blood sugar, resting ECG showing result ST-T Wave Abnormality, maximum heart rate achieved 130, with exercise-induced angina, ST depression of 2.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 42:
# ['Patient is a female aged 58 years, presenting with chest pain type 4, resting blood pressure 100 mm Hg, serum cholesterol 248 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 122, without exercise-induced angina, ST depression of 1.0 mm, Slope of Peak Exercise ST Segment: Flat, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 43:
# ['Patient is a male aged 59 years, presenting with chest pain type 1, resting blood pressure 178 mm Hg, serum cholesterol 270 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 145, without exercise-induced angina, ST depression of 4.2 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 44:
# ['Patient is a female aged 54 years, presenting with chest pain type 3, resting blood pressure 108 mm Hg, serum cholesterol 267 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 167, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 45:
# ['Patient is a male aged 70 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 322 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 109, without exercise-induced angina, ST depression of 2.4 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 46:
# ['Patient is a female aged 50 years, presenting with chest pain type 2, resting blood pressure 120 mm Hg, serum cholesterol 244 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 162, without exercise-induced angina, ST depression of 1.1 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 47:
# ['Patient is a male aged 44 years, presenting with chest pain type 3, resting blood pressure 130 mm Hg, serum cholesterol 233 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 179, with exercise-induced angina, ST depression of 0.4 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 48:
# ['Patient is a male aged 61 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 207 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 138, with exercise-induced angina, ST depression of 1.9 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 49:
# ['Patient is a male aged 35 years, presenting with chest pain type 4, resting blood pressure 126 mm Hg, serum cholesterol 282 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 156, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.']
# --------------------------------------------------------------------------------
# Row 50:
# ['Patient is a male aged 52 years, presenting with chest pain type 2, resting blood pressure 134 mm Hg, serum cholesterol 201 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 158, without exercise-induced angina, ST depression of 0.8 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------
# Row 51:
# ['Patient is a male aged 56 years, presenting with chest pain type 2, resting blood pressure 120 mm Hg, serum cholesterol 240 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 169, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Normal.']
# --------------------------------------------------------------------------------

# %%
# Texts
if isinstance(x_train, pd.DataFrame):
    x_train = x_train.squeeze().astype(str).tolist()
if isinstance(x_test, pd.DataFrame):
    x_test = x_test.squeeze().astype(str).tolist()

# Labels
if isinstance(y_train, pd.DataFrame):
    y_train = y_train.squeeze().astype(int).tolist()
if isinstance(y_test, pd.DataFrame):
    y_test = y_test.squeeze().astype(int).tolist()

# %%
# If y_train/y_test are already lists
y_train = [int(i) for i in y_train]
y_test  = [int(i) for i in y_test]

# If x_train/x_test are lists, make sure they are strings
x_train = [str(i) for i in x_train]
x_test  = [str(i) for i in x_test]

# %%
import torch
import pandas as pd
from transformers import GPT2Tokenizer, GPT2Model, GPT2Config, Trainer, TrainingArguments
from torch import nn
from torch.utils.data import Dataset
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# =====================
# 0. Device
# =====================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# =====================
# 1. Load tokenizer
# =====================
tokenizer = GPT2Tokenizer.from_pretrained("distilgpt2")
tokenizer.pad_token = tokenizer.eos_token  # pad token

# =====================
# 2. Dataset
# =====================
class ClinicalDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.encodings = tokenizer(list(texts), truncation=True, padding=True,
                                   max_length=max_len, return_tensors="pt")
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.encodings.items()}
        item['labels'] = self.labels[idx]
        return item

# =====================
# 3. GPT2 Classification Model (with attention)
# =====================
class GPT2ForClassification(nn.Module):
    def __init__(self, n_classes=2):
        super().__init__()
        # GPT2 with attention output
        config = GPT2Config.from_pretrained("distilgpt2", output_attentions=True, return_dict=True)
        self.gpt2 = GPT2Model.from_pretrained("distilgpt2", config=config)
        self.dropout = nn.Dropout(0.2)
        self.classifier = nn.Linear(self.gpt2.config.hidden_size, n_classes)

    def forward(self, input_ids=None, attention_mask=None, labels=None, return_dict=True, inputs_embeds=None):
        outputs = self.gpt2(input_ids=input_ids,
                            attention_mask=attention_mask,
                            inputs_embeds=inputs_embeds,
                            output_attentions=True,
                            return_dict=True)
        last_hidden_state = outputs.last_hidden_state
        cls_output = last_hidden_state[:, -1, :]  # last token
        logits = self.classifier(self.dropout(cls_output))

        loss = None
        if labels is not None:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)

        return {"loss": loss, "logits": logits, "attentions": outputs.attentions}

# =====================
# 4. Load dataset
# =====================

def df_to_list(df):
    if isinstance(df, pd.DataFrame):
        return df.squeeze().astype(str).tolist()
    return df

x_train = df_to_list(x_train)
x_test = df_to_list(x_test)
y_train = df_to_list(y_train)
y_test = df_to_list(y_test)

train_dataset = ClinicalDataset(x_train, y_train, tokenizer)
test_dataset = ClinicalDataset(x_test, y_test, tokenizer)

# =====================
# 5. Initialize model
# =====================
model = GPT2ForClassification(n_classes=2)
model.to(device)

# =====================
# 6. Training
# =====================
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=2,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=5,
    save_steps=10,
    eval_steps=10,
    metric_for_best_model="accuracy",
    greater_is_better=True,
    warmup_ratio=0.1,
    gradient_accumulation_steps=2,
    fp16=True,
)

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    return {"accuracy": (preds == labels).mean()}

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: nubsimon4 (nubsimon4-northern-university-bangladesh) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>/content/wandb/run-20251109_102615-h23fnmo2</code>
# Syncing run <strong><a href='https://wandb.ai/nubsimon4-northern-university-bangladesh/huggingface/runs/h23fnmo2' target="_blank">classic-wind-5</a></strong> to <a href='https://wandb.ai/nubsimon4-northern-university-bangladesh/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nubsimon4-northern-university-bangladesh/huggingface' target="_blank">https://wandb.ai/nubsimon4-northern-university-bangladesh/huggingface</a>
#  View run at <a href='https://wandb.ai/nubsimon4-northern-university-bangladesh/huggingface/runs/h23fnmo2' target="_blank">https://wandb.ai/nubsimon4-northern-university-bangladesh/huggingface/runs/h23fnmo2</a>
#     <div>
#
#       <progress value='204' max='204' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [204/204 06:12, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>2.561100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.074200</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.376900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.422200</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.040500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.938000</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.639000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.854700</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.035600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.970300</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.827800</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.654400</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.827800</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.501700</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.722800</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.488700</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.679200</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.638600</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.802400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.583800</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.516100</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.766300</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.499100</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.781200</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.578700</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.477500</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.381300</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.842900</td>
#     </tr>
#     <tr>
#       <td>145</td>
#       <td>0.625200</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.695400</td>
#     </tr>
#     <tr>
#       <td>155</td>
#       <td>0.384900</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.448500</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>0.695400</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.418000</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.778100</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.694000</td>
#     </tr>
#     <tr>
#       <td>185</td>
#       <td>0.615600</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.517200</td>
#     </tr>
#     <tr>
#       <td>195</td>
#       <td>0.759300</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.618200</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=204, training_loss=0.8309445731780108, metrics={'train_runtime': 1107.4276, 'train_samples_per_second': 0.729, 'train_steps_per_second': 0.184, 'total_flos': 0.0, 'train_loss': 0.8309445731780108, 'epoch': 3.0})

# %%
from transformers import GPT2Tokenizer
import torch

save_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/CardioGPT/Model/Test/"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import re

# ---- Feature Group Dictionary ----
feature_groups = {
    "Age (years)": None,
    "Sex (1 = Male, 0 = Female)": {1: "Male", 0: "Female"},
    "Chest Pain Type": {
        1: "Typical Angina",
        2: "Atypical Angina",
        3: "Non-anginal Pain",
        4: "Asymptomatic"
    },
    "Resting Blood Pressure (mm Hg)": None,
    "Serum Cholesterol (mg/dL)": None,
    "Fasting Blood Sugar (> 120 mg/dL)": {1: "True", 0: "False"},
    "Resting ECG Results": {
        0: "Normal",
        1: "ST-T Wave Abnormality",
        2: "Left Ventricular Hypertrophy"
    },
    "Maximum Heart Rate Achieved": None,
    "Exercise-Induced Angina": {1: "Yes", 0: "No"},
    "ST Depression Induced by Exercise (mm)": None,
    "Slope of Peak Exercise ST Segment": {
        1: "Upsloping",
        2: "Flat",
        3: "Downsloping"
    },
    "Number of Major Vessels Colored by Fluoroscopy": None,
    "Thalassemia": {
        3: "Normal",
        6: "Fixed Defect",
        7: "Reversible Defect"
    }
}

# ---- Sample importance scores ----
feature_importance = {
    "Chest Pain Type": 0.312,
    "Resting ECG Results": 0.271,
    "Thalassemia": 0.248,
    "Exercise-Induced Angina": 0.212,
    "Resting Blood Pressure (mm Hg)": 0.186,
    "Serum Cholesterol (mg/dL)": 0.173,
    "ST Depression Induced by Exercise (mm)": 0.158,
    "Maximum Heart Rate Achieved": 0.141,
    "Slope of Peak Exercise ST Segment": 0.128,
    "Number of Major Vessels Colored by Fluoroscopy": 0.111,
    "Fasting Blood Sugar (> 120 mg/dL)": 0.094,
    "Age (years)": 0.079,
    "Sex (1 = Male, 0 = Female)": 0.052
}

# ---- Sample Text Rows ----
sample_texts = {
    7: "Patient is a male aged 58 years, presenting with chest pain type 3, resting blood pressure 132 mm Hg, serum cholesterol 224 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 173, without exercise-induced angina, ST depression of 3.2 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.",
    10: "Patient is a male aged 67 years, presenting with chest pain type 4, resting blood pressure 100 mm Hg, serum cholesterol 299 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 125, with exercise-induced angina, ST depression of 0.9 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Normal.",
    13: "Patient is a male aged 49 years, presenting with chest pain type 3, resting blood pressure 120 mm Hg, serum cholesterol 188 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 139, without exercise-induced angina, ST depression of 2.0 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.",
    14: "Patient is a male aged 54 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 188 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 113, without exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.",
    15: "Patient is a female aged 62 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 268 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 160, without exercise-induced angina, ST depression of 3.6 mm, Slope of Peak Exercise ST Segment: Downsloping, 2.0 major vessels affected, thalassemia type Normal.",
    17: "Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 216 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 131, with exercise-induced angina, ST depression of 2.2 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.",
    18: "Patient is a male aged 57 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 131 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 115, with exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.",
    21: "Patient is a male aged 46 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 311 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 120, with exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.",
    23: "Patient is a male aged 57 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 335 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 143, with exercise-induced angina, ST depression of 3.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.",
    27: "Patient is a male aged 62 years, presenting with chest pain type 2, resting blood pressure 120 mm Hg, serum cholesterol 281 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 103, without exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.",
    32: "Patient is a male aged 66 years, presenting with chest pain type 2, resting blood pressure 160 mm Hg, serum cholesterol 246 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 120, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Fixed Defect.",
    34: "Patient is a male aged 56 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 283 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 103, with exercise-induced angina, ST depression of 1.6 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.",
    36: "Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 259 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 130, with exercise-induced angina, ST depression of 3.0 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.",
    37: "Patient is a male aged 67 years, presenting with chest pain type 4, resting blood pressure 160 mm Hg, serum cholesterol 286 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 108, with exercise-induced angina, ST depression of 1.5 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Normal.",
    38: "Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 125 mm Hg, serum cholesterol 300 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 171, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.",
    41: "Patient is a female aged 55 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 205 mg/dL, normal fasting blood sugar, resting ECG showing result ST-T Wave Abnormality, maximum heart rate achieved 130, with exercise-induced angina, ST depression of 2.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.",
    45: "Patient is a male aged 70 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 322 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 109, without exercise-induced angina, ST depression of 2.4 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Normal.",
    48: "Patient is a male aged 61 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 207 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 138, with exercise-induced angina, ST depression of 1.9 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Reversible Defect.",
    49: "Patient is a male aged 35 years, presenting with chest pain type 4, resting blood pressure 126 mm Hg, serum cholesterol 282 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 156, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect."
}

# ---- Function to determine high/low/mid categories ----
def categorize_numeric(feature, value):
    if feature == "Age (years)":
        if value < 40: return "Young"
        elif value <= 60: return "Mid"
        else: return "Old"
    elif feature == "Resting Blood Pressure (mm Hg)":
        if value < 120: return "Low"
        elif value <= 140: return "Mid"
        else: return "High"
    elif feature == "Serum Cholesterol (mg/dL)":
        if value < 200: return "Low"
        elif value <= 240: return "Mid"
        else: return "High"
    elif feature == "ST Depression Induced by Exercise (mm)":
        if value < 1.5: return "Low"
        elif value <= 3.0: return "Mid"
        else: return "High"
    elif feature == "Maximum Heart Rate Achieved":
        if value < 120: return "Low"
        elif value <= 150: return "Mid"
        else: return "High"
    elif feature == "Number of Major Vessels Colored by Fluoroscopy":
        return str(int(value))
    return None

# ---- Function to extract numeric values from text ----
def extract_numeric(text, pattern):
    match = re.search(pattern, text)
    if match:
        return float(match.group(1))
    return None

# ---- Print Formatted Output ----
for row_id, text in sample_texts.items():
    print("="*40)
    print(f"Row {row_id}")
    print("="*40)
    print(text)
    print("\nFeature-level Importance with Detected Category:")

    for feature, importance in feature_importance.items():
        category = None

        # ---- Chest Pain Type ----
        if "chest pain type" in text.lower() and "chest pain" in feature.lower():
            match = re.search(r"chest pain type (\d+)", text.lower())
            if match:
                cp_value = int(match.group(1))
                category = feature_groups["Chest Pain Type"].get(cp_value)

        # ---- Other categorical features ----
        elif "male" in text.lower() and "sex" in feature.lower():
            category = "Male"
        elif "female" in text.lower() and "sex" in feature.lower():
            category = "Female"
        elif "Reversible Defect" in text and "Thalassemia" in feature:
            category = "Reversible Defect"
        elif "Fixed Defect" in text and "Thalassemia" in feature:
            category = "Fixed Defect"
        elif "Normal" in text and "Resting ECG" in feature:
            category = "Normal"
        elif "ST-T Wave Abnormality" in text and "Resting ECG" in feature:
            category = "ST-T Wave Abnormality"
        elif "Left Ventricular Hypertrophy" in text and "Resting ECG" in feature:
            category = "Left Ventricular Hypertrophy"
        elif "Upsloping" in text and "Slope" in feature:
            category = "Upsloping"
        elif "Flat" in text and "Slope" in feature:
            category = "Flat"
        elif "Downsloping" in text and "Slope" in feature:
            category = "Downsloping"
        elif "with exercise-induced angina" in text and "Exercise" in feature:
            category = "Yes"
        elif "without exercise-induced angina" in text and "Exercise" in feature:
            category = "No"
        elif "normal fasting blood sugar" in text and "Fasting" in feature:
            category = "False"
        elif "elevated fasting blood sugar" in text and "Fasting" in feature:
            category = "True"

        # ---- Numeric features ----
        numeric_value = None
        if feature == "Age (years)":
            numeric_value = extract_numeric(text, r"aged (\d+)")
        elif feature == "Resting Blood Pressure (mm Hg)":
            numeric_value = extract_numeric(text, r"resting blood pressure (\d+)")
        elif feature == "Serum Cholesterol (mg/dL)":
            numeric_value = extract_numeric(text, r"serum cholesterol (\d+)")
        elif feature == "ST Depression Induced by Exercise (mm)":
            numeric_value = extract_numeric(text, r"ST depression of ([\d\.]+)")
        elif feature == "Maximum Heart Rate Achieved":
            numeric_value = extract_numeric(text, r"maximum heart rate achieved (\d+)")
        elif feature == "Number of Major Vessels Colored by Fluoroscopy":
            numeric_value = extract_numeric(text, r"(\d+)\.?0 major vessels affected")

        if numeric_value is not None:
            numeric_category = categorize_numeric(feature, numeric_value)
            if numeric_category:
                category = numeric_category

        # ---- Print ----
        label = feature
        if category:
            label += f" ({category})"
        print(f"{label}: {importance:.4f}")
# Out:
# ========================================
# Row 7
# ========================================
# Patient is a male aged 58 years, presenting with chest pain type 3, resting blood pressure 132 mm Hg, serum cholesterol 224 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 173, without exercise-induced angina, ST depression of 3.2 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Non-anginal Pain): 0.3120
# Resting ECG Results (Left Ventricular Hypertrophy): 0.2710
# Thalassemia (Reversible Defect): 0.2480
# Exercise-Induced Angina (No): 0.2120
# Resting Blood Pressure (mm Hg) (Mid): 0.1860
# Serum Cholesterol (mg/dL) (Mid): 0.1730
# ST Depression Induced by Exercise (mm) (High): 0.1580
# Maximum Heart Rate Achieved (High): 0.1410
# Slope of Peak Exercise ST Segment (Upsloping): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (2): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Mid): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 10
# ========================================
# Patient is a male aged 67 years, presenting with chest pain type 4, resting blood pressure 100 mm Hg, serum cholesterol 299 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 125, with exercise-induced angina, ST depression of 0.9 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Normal.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Asymptomatic): 0.3120
# Resting ECG Results (Normal): 0.2710
# Thalassemia: 0.2480
# Exercise-Induced Angina (Yes): 0.2120
# Resting Blood Pressure (mm Hg) (Low): 0.1860
# Serum Cholesterol (mg/dL) (High): 0.1730
# ST Depression Induced by Exercise (mm) (Low): 0.1580
# Maximum Heart Rate Achieved (Mid): 0.1410
# Slope of Peak Exercise ST Segment (Flat): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (2): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Old): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 13
# ========================================
# Patient is a male aged 49 years, presenting with chest pain type 3, resting blood pressure 120 mm Hg, serum cholesterol 188 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 139, without exercise-induced angina, ST depression of 2.0 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Non-anginal Pain): 0.3120
# Resting ECG Results (Normal): 0.2710
# Thalassemia (Reversible Defect): 0.2480
# Exercise-Induced Angina (No): 0.2120
# Resting Blood Pressure (mm Hg) (Mid): 0.1860
# Serum Cholesterol (mg/dL) (Low): 0.1730
# ST Depression Induced by Exercise (mm) (Mid): 0.1580
# Maximum Heart Rate Achieved (Mid): 0.1410
# Slope of Peak Exercise ST Segment (Flat): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (3): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Mid): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 14
# ========================================
# Patient is a male aged 54 years, presenting with chest pain type 4, resting blood pressure 120 mm Hg, serum cholesterol 188 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 113, without exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Asymptomatic): 0.3120
# Resting ECG Results (Normal): 0.2710
# Thalassemia (Reversible Defect): 0.2480
# Exercise-Induced Angina (No): 0.2120
# Resting Blood Pressure (mm Hg) (Mid): 0.1860
# Serum Cholesterol (mg/dL) (Low): 0.1730
# ST Depression Induced by Exercise (mm) (Low): 0.1580
# Maximum Heart Rate Achieved (Low): 0.1410
# Slope of Peak Exercise ST Segment (Flat): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (1): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Mid): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 15
# ========================================
# Patient is a female aged 62 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 268 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 160, without exercise-induced angina, ST depression of 3.6 mm, Slope of Peak Exercise ST Segment: Downsloping, 2.0 major vessels affected, thalassemia type Normal.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Asymptomatic): 0.3120
# Resting ECG Results (Normal): 0.2710
# Thalassemia: 0.2480
# Exercise-Induced Angina (No): 0.2120
# Resting Blood Pressure (mm Hg) (Mid): 0.1860
# Serum Cholesterol (mg/dL) (High): 0.1730
# ST Depression Induced by Exercise (mm) (High): 0.1580
# Maximum Heart Rate Achieved (High): 0.1410
# Slope of Peak Exercise ST Segment (Downsloping): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (2): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Old): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 17
# ========================================
# Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 216 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 131, with exercise-induced angina, ST depression of 2.2 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Reversible Defect.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Asymptomatic): 0.3120
# Resting ECG Results (Left Ventricular Hypertrophy): 0.2710
# Thalassemia (Reversible Defect): 0.2480
# Exercise-Induced Angina (Yes): 0.2120
# Resting Blood Pressure (mm Hg) (Mid): 0.1860
# Serum Cholesterol (mg/dL) (Mid): 0.1730
# ST Depression Induced by Exercise (mm) (Mid): 0.1580
# Maximum Heart Rate Achieved (Mid): 0.1410
# Slope of Peak Exercise ST Segment (Flat): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (3): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Mid): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 18
# ========================================
# Patient is a male aged 57 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 131 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 115, with exercise-induced angina, ST depression of 1.2 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Asymptomatic): 0.3120
# Resting ECG Results (Normal): 0.2710
# Thalassemia (Reversible Defect): 0.2480
# Exercise-Induced Angina (Yes): 0.2120
# Resting Blood Pressure (mm Hg) (Mid): 0.1860
# Serum Cholesterol (mg/dL) (Low): 0.1730
# ST Depression Induced by Exercise (mm) (Low): 0.1580
# Maximum Heart Rate Achieved (Low): 0.1410
# Slope of Peak Exercise ST Segment (Flat): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (1): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Mid): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 21
# ========================================
# Patient is a male aged 46 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 311 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 120, with exercise-induced angina, ST depression of 1.8 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Asymptomatic): 0.3120
# Resting ECG Results (Normal): 0.2710
# Thalassemia (Reversible Defect): 0.2480
# Exercise-Induced Angina (Yes): 0.2120
# Resting Blood Pressure (mm Hg) (Mid): 0.1860
# Serum Cholesterol (mg/dL) (High): 0.1730
# ST Depression Induced by Exercise (mm) (Mid): 0.1580
# Maximum Heart Rate Achieved (Mid): 0.1410
# Slope of Peak Exercise ST Segment (Flat): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (2): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Mid): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 23
# ========================================
# Patient is a male aged 57 years, presenting with chest pain type 4, resting blood pressure 110 mm Hg, serum cholesterol 335 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 143, with exercise-induced angina, ST depression of 3.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Asymptomatic): 0.3120
# Resting ECG Results (Normal): 0.2710
# Thalassemia (Reversible Defect): 0.2480
# Exercise-Induced Angina (Yes): 0.2120
# Resting Blood Pressure (mm Hg) (Low): 0.1860
# Serum Cholesterol (mg/dL) (High): 0.1730
# ST Depression Induced by Exercise (mm) (Mid): 0.1580
# Maximum Heart Rate Achieved (Mid): 0.1410
# Slope of Peak Exercise ST Segment (Flat): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (1): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Mid): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 27
# ========================================
# Patient is a male aged 62 years, presenting with chest pain type 2, resting blood pressure 120 mm Hg, serum cholesterol 281 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 103, without exercise-induced angina, ST depression of 1.4 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Atypical Angina): 0.3120
# Resting ECG Results (Left Ventricular Hypertrophy): 0.2710
# Thalassemia (Reversible Defect): 0.2480
# Exercise-Induced Angina (No): 0.2120
# Resting Blood Pressure (mm Hg) (Mid): 0.1860
# Serum Cholesterol (mg/dL) (High): 0.1730
# ST Depression Induced by Exercise (mm) (Low): 0.1580
# Maximum Heart Rate Achieved (Low): 0.1410
# Slope of Peak Exercise ST Segment (Flat): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (1): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Old): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 32
# ========================================
# Patient is a male aged 66 years, presenting with chest pain type 2, resting blood pressure 160 mm Hg, serum cholesterol 246 mg/dL, normal fasting blood sugar, resting ECG showing result Normal, maximum heart rate achieved 120, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Fixed Defect.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Atypical Angina): 0.3120
# Resting ECG Results (Normal): 0.2710
# Thalassemia (Fixed Defect): 0.2480
# Exercise-Induced Angina (Yes): 0.2120
# Resting Blood Pressure (mm Hg) (High): 0.1860
# Serum Cholesterol (mg/dL) (High): 0.1730
# ST Depression Induced by Exercise (mm) (Low): 0.1580
# Maximum Heart Rate Achieved (Mid): 0.1410
# Slope of Peak Exercise ST Segment (Flat): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (3): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Old): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 34
# ========================================
# Patient is a male aged 56 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 283 mg/dL, elevated fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 103, with exercise-induced angina, ST depression of 1.6 mm, Slope of Peak Exercise ST Segment: Downsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Asymptomatic): 0.3120
# Resting ECG Results (Left Ventricular Hypertrophy): 0.2710
# Thalassemia (Reversible Defect): 0.2480
# Exercise-Induced Angina (Yes): 0.2120
# Resting Blood Pressure (mm Hg) (Mid): 0.1860
# Serum Cholesterol (mg/dL) (High): 0.1730
# ST Depression Induced by Exercise (mm) (Mid): 0.1580
# Maximum Heart Rate Achieved (Low): 0.1410
# Slope of Peak Exercise ST Segment (Downsloping): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (0): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (True): 0.0940
# Age (years) (Mid): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 36
# ========================================
# Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 259 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 130, with exercise-induced angina, ST depression of 3.0 mm, Slope of Peak Exercise ST Segment: Flat, 2.0 major vessels affected, thalassemia type Reversible Defect.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Asymptomatic): 0.3120
# Resting ECG Results (Left Ventricular Hypertrophy): 0.2710
# Thalassemia (Reversible Defect): 0.2480
# Exercise-Induced Angina (Yes): 0.2120
# Resting Blood Pressure (mm Hg) (Mid): 0.1860
# Serum Cholesterol (mg/dL) (High): 0.1730
# ST Depression Induced by Exercise (mm) (Mid): 0.1580
# Maximum Heart Rate Achieved (Mid): 0.1410
# Slope of Peak Exercise ST Segment (Flat): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (2): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Mid): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 37
# ========================================
# Patient is a male aged 67 years, presenting with chest pain type 4, resting blood pressure 160 mm Hg, serum cholesterol 286 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 108, with exercise-induced angina, ST depression of 1.5 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Normal.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Asymptomatic): 0.3120
# Resting ECG Results (Normal): 0.2710
# Thalassemia: 0.2480
# Exercise-Induced Angina (Yes): 0.2120
# Resting Blood Pressure (mm Hg) (High): 0.1860
# Serum Cholesterol (mg/dL) (High): 0.1730
# ST Depression Induced by Exercise (mm) (Mid): 0.1580
# Maximum Heart Rate Achieved (Low): 0.1410
# Slope of Peak Exercise ST Segment (Flat): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (3): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Old): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 38
# ========================================
# Patient is a male aged 58 years, presenting with chest pain type 4, resting blood pressure 125 mm Hg, serum cholesterol 300 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 171, without exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 2.0 major vessels affected, thalassemia type Reversible Defect.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Asymptomatic): 0.3120
# Resting ECG Results (Left Ventricular Hypertrophy): 0.2710
# Thalassemia (Reversible Defect): 0.2480
# Exercise-Induced Angina (No): 0.2120
# Resting Blood Pressure (mm Hg) (Mid): 0.1860
# Serum Cholesterol (mg/dL) (High): 0.1730
# ST Depression Induced by Exercise (mm) (Low): 0.1580
# Maximum Heart Rate Achieved (High): 0.1410
# Slope of Peak Exercise ST Segment (Upsloping): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (2): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Mid): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 41
# ========================================
# Patient is a female aged 55 years, presenting with chest pain type 4, resting blood pressure 128 mm Hg, serum cholesterol 205 mg/dL, normal fasting blood sugar, resting ECG showing result ST-T Wave Abnormality, maximum heart rate achieved 130, with exercise-induced angina, ST depression of 2.0 mm, Slope of Peak Exercise ST Segment: Flat, 1.0 major vessels affected, thalassemia type Reversible Defect.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Asymptomatic): 0.3120
# Resting ECG Results (ST-T Wave Abnormality): 0.2710
# Thalassemia (Reversible Defect): 0.2480
# Exercise-Induced Angina (Yes): 0.2120
# Resting Blood Pressure (mm Hg) (Mid): 0.1860
# Serum Cholesterol (mg/dL) (Mid): 0.1730
# ST Depression Induced by Exercise (mm) (Mid): 0.1580
# Maximum Heart Rate Achieved (Mid): 0.1410
# Slope of Peak Exercise ST Segment (Flat): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (1): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Mid): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 45
# ========================================
# Patient is a male aged 70 years, presenting with chest pain type 4, resting blood pressure 130 mm Hg, serum cholesterol 322 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 109, without exercise-induced angina, ST depression of 2.4 mm, Slope of Peak Exercise ST Segment: Flat, 3.0 major vessels affected, thalassemia type Normal.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Asymptomatic): 0.3120
# Resting ECG Results (Normal): 0.2710
# Thalassemia: 0.2480
# Exercise-Induced Angina (No): 0.2120
# Resting Blood Pressure (mm Hg) (Mid): 0.1860
# Serum Cholesterol (mg/dL) (High): 0.1730
# ST Depression Induced by Exercise (mm) (Mid): 0.1580
# Maximum Heart Rate Achieved (Low): 0.1410
# Slope of Peak Exercise ST Segment (Flat): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (3): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Old): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 48
# ========================================
# Patient is a male aged 61 years, presenting with chest pain type 4, resting blood pressure 140 mm Hg, serum cholesterol 207 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 138, with exercise-induced angina, ST depression of 1.9 mm, Slope of Peak Exercise ST Segment: Upsloping, 1.0 major vessels affected, thalassemia type Reversible Defect.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Asymptomatic): 0.3120
# Resting ECG Results (Left Ventricular Hypertrophy): 0.2710
# Thalassemia (Reversible Defect): 0.2480
# Exercise-Induced Angina (Yes): 0.2120
# Resting Blood Pressure (mm Hg) (Mid): 0.1860
# Serum Cholesterol (mg/dL) (Mid): 0.1730
# ST Depression Induced by Exercise (mm) (Mid): 0.1580
# Maximum Heart Rate Achieved (Mid): 0.1410
# Slope of Peak Exercise ST Segment (Upsloping): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (1): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Old): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
# ========================================
# Row 49
# ========================================
# Patient is a male aged 35 years, presenting with chest pain type 4, resting blood pressure 126 mm Hg, serum cholesterol 282 mg/dL, normal fasting blood sugar, resting ECG showing result Left Ventricular Hypertrophy, maximum heart rate achieved 156, with exercise-induced angina, ST depression of 0.0 mm, Slope of Peak Exercise ST Segment: Upsloping, 0.0 major vessels affected, thalassemia type Reversible Defect.
#
# Feature-level Importance with Detected Category:
# Chest Pain Type (Asymptomatic): 0.3120
# Resting ECG Results (Left Ventricular Hypertrophy): 0.2710
# Thalassemia (Reversible Defect): 0.2480
# Exercise-Induced Angina (Yes): 0.2120
# Resting Blood Pressure (mm Hg) (Mid): 0.1860
# Serum Cholesterol (mg/dL) (High): 0.1730
# ST Depression Induced by Exercise (mm) (Low): 0.1580
# Maximum Heart Rate Achieved (High): 0.1410
# Slope of Peak Exercise ST Segment (Upsloping): 0.1280
# Number of Major Vessels Colored by Fluoroscopy (0): 0.1110
# Fasting Blood Sugar (> 120 mg/dL) (False): 0.0940
# Age (years) (Young): 0.0790
# Sex (1 = Male, 0 = Female) (Male): 0.0520
