# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import seaborn as sns
import plotly.express as px

# %matplotlib inline

# %%
# Set DPI for fugures

plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
# Set the default font size and weight
plt.rcParams['font.size'] = 30
plt.rcParams['font.weight'] = 'bold'

# %%
# Drive connection

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Dataset: UCI Thyroid Cancer Recurrence

# %%
# Dataset
# !pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2025.10.5)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
differentiated_thyroid_cancer_recurrence = fetch_ucirepo(id=915)

# data (as pandas dataframes)
X = differentiated_thyroid_cancer_recurrence.data.features
y = differentiated_thyroid_cancer_recurrence.data.targets

# metadata
print(differentiated_thyroid_cancer_recurrence.metadata)

# variable information
print(differentiated_thyroid_cancer_recurrence.variables)
# Out:
# {'uci_id': 915, 'name': 'Differentiated Thyroid Cancer Recurrence', 'repository_url': 'https://archive.ics.uci.edu/dataset/915/differentiated+thyroid+cancer+recurrence', 'data_url': 'https://archive.ics.uci.edu/static/public/915/data.csv', 'abstract': 'This data set contains 13 clinicopathologic features aiming to predict recurrence of well differentiated thyroid cancer. The data set was collected in duration of 15 years and each patient was followed for at least 10 years.', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Tabular'], 'num_instances': 383, 'num_features': 16, 'feature_types': ['Real', 'Categorical', 'Integer'], 'demographics': ['Age', 'Gender'], 'target_col': ['Recurred'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2023, 'last_updated': 'Wed Mar 20 2024', 'dataset_doi': '10.24432/C5632J', 'creators': ['Shiva Borzooei', 'Aidin Tarokhian'], 'intro_paper': {'ID': 333, 'type': 'NATIVE', 'title': 'Machine learning for risk stratification of thyroid cancer patients: a 15-year cohort study', 'authors': 'Shiva Borzooei, Giovanni Briganti, Mitra Golparian, Jerome R. Lechien, Aidin Tarokhian', 'venue': 'Head and Neck', 'year': 2023, 'journal': None, 'DOI': None, 'URL': 'https://link.springer.com/article/10.1007/s00405-023-08299-w', 'sha': None, 'corpus': None, 'arxiv': None, 'mag': None, 'acl': None, 'pmid': None, 'pmcid': None}, 'additional_info': {'summary': None, 'purpose': 'It was a part of research in the field of AI and Medicine', 'funded_by': 'No funding was provided.', 'instances_represent': 'Individual patients', 'recommended_data_splits': 'No', 'sensitive_data': 'No', 'preprocessing_description': None, 'variable_info': None, 'citation': 'Please cite the original article if you use the data set for secondary research and public demonstrations:\nhttps://doi.org/10.1007/s00405-023-08299-w'}}
#                     name     role         type demographic description units  \
# 0                    Age  Feature      Integer         Age        None  None
# 1                 Gender  Feature  Categorical      Gender        None  None
# 2                Smoking  Feature  Categorical        None        None  None
# 3             Hx Smoking  Feature  Categorical        None        None  None
# 4        Hx Radiothreapy  Feature  Categorical        None        None  None
# 5       Thyroid Function  Feature  Categorical        None        None  None
# 6   Physical Examination  Feature  Categorical        None        None  None
# 7             Adenopathy  Feature  Categorical        None        None  None
# 8              Pathology  Feature  Categorical        None        None  None
# 9               Focality  Feature  Categorical        None        None  None
# 10                  Risk  Feature  Categorical        None        None  None
# 11                     T  Feature  Categorical        None        None  None
# 12                     N  Feature  Categorical        None        None  None
# 13                     M  Feature  Categorical        None        None  None
# 14                 Stage  Feature  Categorical        None        None  None
# 15              Response  Feature  Categorical        None        None  None
# 16              Recurred   Target  Categorical        None        None  None
#
#    missing_values
# 0              no
# 1              no
# 2              no
# 3              no
# 4              no
# 5              no
# 6              no
# 7              no
# 8              no
# 9              no
# 10             no
# 11             no
# 12             no
# 13             no
# 14             no
# 15             no
# 16             no

# %%
# Merge the features and targets into a single DataFrame
df = pd.concat([X, y], axis=1)

# Display the merged DataFrame
print(df.head())
# Out:
#    Age Gender Smoking Hx Smoking Hx Radiothreapy Thyroid Function  \
# 0   27      F      No         No              No        Euthyroid
# 1   34      F      No        Yes              No        Euthyroid
# 2   30      F      No         No              No        Euthyroid
# 3   62      F      No         No              No        Euthyroid
# 4   62      F      No         No              No        Euthyroid
#
#           Physical Examination Adenopathy       Pathology     Focality Risk  \
# 0   Single nodular goiter-left         No  Micropapillary    Uni-Focal  Low
# 1          Multinodular goiter         No  Micropapillary    Uni-Focal  Low
# 2  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 3  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 4          Multinodular goiter         No  Micropapillary  Multi-Focal  Low
#
#      T   N   M Stage       Response Recurred
# 0  T1a  N0  M0     I  Indeterminate       No
# 1  T1a  N0  M0     I      Excellent       No
# 2  T1a  N0  M0     I      Excellent       No
# 3  T1a  N0  M0     I      Excellent       No
# 4  T1a  N0  M0     I      Excellent       No

# %%
# Size
df.shape
# Out:
# (383, 17)

# %%
# Null Values
df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Smoking                 0
# Hx Smoking              0
# Hx Radiothreapy         0
# Thyroid Function        0
# Physical Examination    0
# Adenopathy              0
# Pathology               0
# Focality                0
# Risk                    0
# T                       0
# N                       0
# M                       0
# Stage                   0
# Response                0
# Recurred                0
# dtype: int64

# %%
# Size
df.shape
# Out:
# (383, 17)

# %%
# Count occurrences for each category in each feature
for column in df.columns:
    print(f"Counts for {column}:")
    print(df[column].value_counts())
    print()  # Add a newline for better readability
# Out:
# Counts for Age:
# Age
# 31    22
# 27    13
# 30    12
# 33    12
# 40    12
#       ..
# 79     1
# 15     1
# 82     1
# 64     1
# 78     1
# Name: count, Length: 65, dtype: int64
#
# Counts for Gender:
# Gender
# F    312
# M     71
# Name: count, dtype: int64
#
# Counts for Smoking:
# Smoking
# No     334
# Yes     49
# Name: count, dtype: int64
#
# Counts for Hx Smoking:
# Hx Smoking
# No     355
# Yes     28
# Name: count, dtype: int64
#
# Counts for Hx Radiothreapy:
# Hx Radiothreapy
# No     376
# Yes      7
# Name: count, dtype: int64
#
# Counts for Thyroid Function:
# Thyroid Function
# Euthyroid                      332
# Clinical Hyperthyroidism        20
# Subclinical Hypothyroidism      14
# Clinical Hypothyroidism         12
# Subclinical Hyperthyroidism      5
# Name: count, dtype: int64
#
# Counts for Physical Examination:
# Physical Examination
# Multinodular goiter            140
# Single nodular goiter-right    140
# Single nodular goiter-left      89
# Normal                           7
# Diffuse goiter                   7
# Name: count, dtype: int64
#
# Counts for Adenopathy:
# Adenopathy
# No           277
# Right         48
# Bilateral     32
# Left          17
# Extensive      7
# Posterior      2
# Name: count, dtype: int64
#
# Counts for Pathology:
# Pathology
# Papillary         287
# Micropapillary     48
# Follicular         28
# Hurthel cell       20
# Name: count, dtype: int64
#
# Counts for Focality:
# Focality
# Uni-Focal      247
# Multi-Focal    136
# Name: count, dtype: int64
#
# Counts for Risk:
# Risk
# Low             249
# Intermediate    102
# High             32
# Name: count, dtype: int64
#
# Counts for T:
# T
# T2     151
# T3a     96
# T1a     49
# T1b     43
# T4a     20
# T3b     16
# T4b      8
# Name: count, dtype: int64
#
# Counts for N:
# N
# N0     268
# N1b     93
# N1a     22
# Name: count, dtype: int64
#
# Counts for M:
# M
# M0    365
# M1     18
# Name: count, dtype: int64
#
# Counts for Stage:
# Stage
# I      333
# II      32
# IVB     11
# III      4
# IVA      3
# Name: count, dtype: int64
#
# Counts for Response:
# Response
# Excellent                 208
# Structural Incomplete      91
# Indeterminate              61
# Biochemical Incomplete     23
# Name: count, dtype: int64
#
# Counts for Recurred:
# Recurred
# No     275
# Yes    108
# Name: count, dtype: int64

# %%
# Data
df.head()
# Out:
#    Age Gender Smoking Hx Smoking Hx Radiothreapy Thyroid Function  \
# 0   27      F      No         No              No        Euthyroid
# 1   34      F      No        Yes              No        Euthyroid
# 2   30      F      No         No              No        Euthyroid
# 3   62      F      No         No              No        Euthyroid
# 4   62      F      No         No              No        Euthyroid
#
#           Physical Examination Adenopathy       Pathology     Focality Risk  \
# 0   Single nodular goiter-left         No  Micropapillary    Uni-Focal  Low
# 1          Multinodular goiter         No  Micropapillary    Uni-Focal  Low
# 2  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 3  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 4          Multinodular goiter         No  Micropapillary  Multi-Focal  Low
#
#      T   N   M Stage       Response Recurred
# 0  T1a  N0  M0     I  Indeterminate       No
# 1  T1a  N0  M0     I      Excellent       No
# 2  T1a  N0  M0     I      Excellent       No
# 3  T1a  N0  M0     I      Excellent       No
# 4  T1a  N0  M0     I      Excellent       No

# %%
"""
save_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/df.csv"

# Save to CSV
df.to_csv(save_path, index=False)

print(f"File saved to: {save_path}")
"""
# Out:
# File saved to: /content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/df.csv

# %%
load_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/df.csv"

# Load the DataFrame
df = pd.read_csv(load_path)

# Preview
df.head()
# Out:
#    Age Gender Smoking Hx Smoking Hx Radiothreapy Thyroid Function  \
# 0   27      F      No         No              No        Euthyroid
# 1   34      F      No        Yes              No        Euthyroid
# 2   30      F      No         No              No        Euthyroid
# 3   62      F      No         No              No        Euthyroid
# 4   62      F      No         No              No        Euthyroid
#
#           Physical Examination Adenopathy       Pathology     Focality Risk  \
# 0   Single nodular goiter-left         No  Micropapillary    Uni-Focal  Low
# 1          Multinodular goiter         No  Micropapillary    Uni-Focal  Low
# 2  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 3  Single nodular goiter-right         No  Micropapillary    Uni-Focal  Low
# 4          Multinodular goiter         No  Micropapillary  Multi-Focal  Low
#
#      T   N   M Stage       Response Recurred
# 0  T1a  N0  M0     I  Indeterminate       No
# 1  T1a  N0  M0     I      Excellent       No
# 2  T1a  N0  M0     I      Excellent       No
# 3  T1a  N0  M0     I      Excellent       No
# 4  T1a  N0  M0     I      Excellent       No

# %%
# Column Names
print(df.columns.tolist())
# Out:
# ['Age', 'Gender', 'Smoking', 'Hx Smoking', 'Hx Radiothreapy', 'Thyroid Function', 'Physical Examination', 'Adenopathy', 'Pathology', 'Focality', 'Risk', 'T', 'N', 'M', 'Stage', 'Response', 'Recurred']

# %%
# Binary mappings
binary_maps = {
    "Gender": {"F": 0, "M": 1},
    "Smoking": {"No": 0, "Yes": 1},
    "Hx Smoking": {"No": 0, "Yes": 1},
    "Hx Radiothreapy": {"No": 0, "Yes": 1},
    "Focality": {"Uni-Focal": 0, "Multi-Focal": 1},
    "M": {"M0": 0, "M1": 1},
    "Recurred": {"No": 0, "Yes": 1}
}

# Multi-category mappings
thyroid_map = {
    "Euthyroid": 0,
    "Subclinical Hyperthyroidism": 1,
    "Clinical Hyperthyroidism": 2,
    "Subclinical Hypothyroidism": 3,
    "Clinical Hypothyroidism": 4
}

exam_map = {
    "Normal": 0,
    "Single nodular goiter-right": 1,
    "Single nodular goiter-left": 2,
    "Multinodular goiter": 3,
    "Diffuse goiter": 4
}

adenopathy_map = {
    "No": 0,
    "Left": 1,
    "Right": 2,
    "Bilateral": 3,
    "Extensive": 4,
    "Posterior": 5
}

pathology_map = {
    "Papillary": 0,
    "Micropapillary": 1,
    "Follicular": 2,
    "Hurthel cell": 3
}

risk_map = {"Low": 0, "Intermediate": 1, "High": 2}

t_map = {"T1a": 0, "T1b": 1, "T2": 2, "T3a": 3, "T3b": 4, "T4a": 5, "T4b": 6}

n_map = {"N0": 0, "N1a": 1, "N1b": 2}

stage_map = {"I": 0, "II": 1, "III": 2, "IVA": 3, "IVB": 4}

response_map = {
    "Excellent": 0,
    "Indeterminate": 1,
    "Biochemical Incomplete": 2,
    "Structural Incomplete": 3
}

# Apply all mappings
for col, mapping in binary_maps.items():
    df[col] = df[col].map(mapping)

df["Thyroid Function"] = df["Thyroid Function"].map(thyroid_map)
df["Physical Examination"] = df["Physical Examination"].map(exam_map)
df["Adenopathy"] = df["Adenopathy"].map(adenopathy_map)
df["Pathology"] = df["Pathology"].map(pathology_map)
df["Risk"] = df["Risk"].map(risk_map)
df["T"] = df["T"].map(t_map)
df["N"] = df["N"].map(n_map)
df["Stage"] = df["Stage"].map(stage_map)
df["Response"] = df["Response"].map(response_map)

# %%
df.rename(columns={

    "Age": "Age (years)",

    "Gender": "Gender (0 = Female, 1 = Male)",

    "Smoking": "Smoking Status (0 = No, 1 = Yes)",

    "Hx Smoking": "History of Smoking (0 = No, 1 = Yes)",

    "Hx Radiothreapy": "History of Radiotherapy (0 = No, 1 = Yes)",

    "Thyroid Function": "Thyroid Function (0 = Euthyroid, 1 = Subclinical Hyperthyroidism, 2 = Clinical Hyperthyroidism, 3 = Subclinical Hypothyroidism, 4 = Clinical Hypothyroidism)",

    "Physical Examination": "Physical Examination (0 = Normal, 1 = Single nodular goiter-right, 2 = Single nodular goiter-left, 3 = Multinodular goiter, 4 = Diffuse goiter)",

    "Adenopathy": "Adenopathy (0 = No, 1 = Left, 2 = Right, 3 = Bilateral, 4 = Extensive, 5 = Posterior)",

    "Pathology": "Pathology Type (0 = Papillary, 1 = Micropapillary, 2 = Follicular, 3 = Hurthel cell)",

    "Focality": "Tumor Focality (0 = Uni-Focal, 1 = Multi-Focal)",

    "Risk": "ATA Risk Stratification (0 = Low, 1 = Intermediate, 2 = High)",

    "T": "Tumor Size / Extent (T Stage: 0 = T1a, 1 = T1b, 2 = T2, 3 = T3a, 4 = T3b, 5 = T4a, 6 = T4b)",

    "N": "Lymph Node Involvement (N Stage: 0 = N0, 1 = N1a, 2 = N1b)",

    "M": "Metastasis Status (0 = M0, 1 = M1)",

    "Stage": "AJCC TNM Stage (0 = I, 1 = II, 2 = III, 3 = IVA, 4 = IVB)",

    "Response": "Response to Initial Therapy (0 = Excellent, 1 = Indeterminate, 2 = Biochemical Incomplete, 3 = Structural Incomplete)",

    "Recurred": "Disease Recurrence (0 = No, 1 = Yes)"

}, inplace=True)

# %%
"""
save_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/Updated_Dataset/df.csv"

# Save to CSV
df.to_csv(save_path, index=False)

print(f"File saved to: {save_path}")
"""
# Out:
# File saved to: /content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/Updated_Dataset/df.csv

# %%
load_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/Updated_Dataset/df.csv"

# Load the DataFrame
df = pd.read_csv(load_path)

# Preview
df.head()
# Out:
#    Age (years)  Gender (0 = Female, 1 = Male)  \
# 0           27                              0
# 1           34                              0
# 2           30                              0
# 3           62                              0
# 4           62                              0
#
#    Smoking Status (0 = No, 1 = Yes)  History of Smoking (0 = No, 1 = Yes)  \
# 0                                 0                                     0
# 1                                 0                                     1
# 2                                 0                                     0
# 3                                 0                                     0
# 4                                 0                                     0
#
#    History of Radiotherapy (0 = No, 1 = Yes)  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
#
#    Thyroid Function (0 = Euthyroid, 1 = Subclinical Hyperthyroidism, 2 = Clinical Hyperthyroidism, 3 = Subclinical Hypothyroidism, 4 = Clinical Hypothyroidism)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Physical Examination (0 = Normal, 1 = Single nodular goiter-right, 2 = Single nodular goiter-left, 3 = Multinodular goiter, 4 = Diffuse goiter)  \
# 0                                                  2
# 1                                                  3
# 2                                                  1
# 3                                                  1
# 4                                                  3
#
#    Adenopathy (0 = No, 1 = Left, 2 = Right, 3 = Bilateral, 4 = Extensive, 5 = Posterior)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Pathology Type (0 = Papillary, 1 = Micropapillary, 2 = Follicular, 3 = Hurthel cell)  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    Tumor Focality (0 = Uni-Focal, 1 = Multi-Focal)  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                1
#
#    ATA Risk Stratification (0 = Low, 1 = Intermediate, 2 = High)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Tumor Size / Extent (T Stage: 0 = T1a, 1 = T1b, 2 = T2, 3 = T3a, 4 = T3b, 5 = T4a, 6 = T4b)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Lymph Node Involvement (N Stage: 0 = N0, 1 = N1a, 2 = N1b)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Metastasis Status (0 = M0, 1 = M1)  \
# 0                                   0
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   0
#
#    AJCC TNM Stage (0 = I, 1 = II, 2 = III, 3 = IVA, 4 = IVB)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Response to Initial Therapy (0 = Excellent, 1 = Indeterminate, 2 = Biochemical Incomplete, 3 = Structural Incomplete)  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Disease Recurrence (0 = No, 1 = Yes)
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0

# %%
# New Column Names
print(df.columns.tolist())
# Out:
# ['Age (years)', 'Gender (0 = Female, 1 = Male)', 'Smoking Status (0 = No, 1 = Yes)', 'History of Smoking (0 = No, 1 = Yes)', 'History of Radiotherapy (0 = No, 1 = Yes)', 'Thyroid Function (0 = Euthyroid, 1 = Subclinical Hyperthyroidism, 2 = Clinical Hyperthyroidism, 3 = Subclinical Hypothyroidism, 4 = Clinical Hypothyroidism)', 'Physical Examination (0 = Normal, 1 = Single nodular goiter-right, 2 = Single nodular goiter-left, 3 = Multinodular goiter, 4 = Diffuse goiter)', 'Adenopathy (0 = No, 1 = Left, 2 = Right, 3 = Bilateral, 4 = Extensive, 5 = Posterior)', 'Pathology Type (0 = Papillary, 1 = Micropapillary, 2 = Follicular, 3 = Hurthel cell)', 'Tumor Focality (0 = Uni-Focal, 1 = Multi-Focal)', 'ATA Risk Stratification (0 = Low, 1 = Intermediate, 2 = High)', 'Tumor Size / Extent (T Stage: 0 = T1a, 1 = T1b, 2 = T2, 3 = T3a, 4 = T3b, 5 = T4a, 6 = T4b)', 'Lymph Node Involvement (N Stage: 0 = N0, 1 = N1a, 2 = N1b)', 'Metastasis Status (0 = M0, 1 = M1)', 'AJCC TNM Stage (0 = I, 1 = II, 2 = III, 3 = IVA, 4 = IVB)', 'Response to Initial Therapy (0 = Excellent, 1 = Indeterminate, 2 = Biochemical Incomplete, 3 = Structural Incomplete)', 'Disease Recurrence (0 = No, 1 = Yes)']

# %%
# Size
df.shape
# Out:
# (383, 17)

# %% [markdown]
# # Table to Clinical Text for GPT Model

# %%
# Separate features and target
input_features = df.drop(columns=["Disease Recurrence (0 = No, 1 = Yes)"])
target = df["Disease Recurrence (0 = No, 1 = Yes)"]

# Function to convert each row into a clinical-style sentence
def row_to_text(row):
    return (
        f"Patient is a {int(row['Age (years)'])}-year-old "
        f"{'male' if row['Gender (0 = Female, 1 = Male)'] == 1 else 'female'} with "
        f"{'a history of smoking' if row['History of Smoking (0 = No, 1 = Yes)'] == 1 else 'no history of smoking'}, "
        f"{'a history of radiotherapy' if row['History of Radiotherapy (0 = No, 1 = Yes)'] == 1 else 'no history of radiotherapy'}. "
        f"The patient is {'a smoker' if row['Smoking Status (0 = No, 1 = Yes)'] == 1 else 'a non-smoker'}. "
        f"Thyroid function is classified as "
        f"{['Euthyroid', 'Subclinical Hyperthyroidism', 'Clinical Hyperthyroidism', 'Subclinical Hypothyroidism', 'Clinical Hypothyroidism'][int(row['Thyroid Function (0 = Euthyroid, 1 = Subclinical Hyperthyroidism, 2 = Clinical Hyperthyroidism, 3 = Subclinical Hypothyroidism, 4 = Clinical Hypothyroidism)'])]}. "
        f"Physical examination revealed "
        f"{['Normal', 'Single nodular goiter-right', 'Single nodular goiter-left', 'Multinodular goiter', 'Diffuse goiter'][int(row['Physical Examination (0 = Normal, 1 = Single nodular goiter-right, 2 = Single nodular goiter-left, 3 = Multinodular goiter, 4 = Diffuse goiter)'])]}. "
        f"Adenopathy is "
        f"{['absent', 'present on the left', 'present on the right', 'bilateral', 'extensive', 'posterior'][int(row['Adenopathy (0 = No, 1 = Left, 2 = Right, 3 = Bilateral, 4 = Extensive, 5 = Posterior)'])]}. "
        f"Pathology shows a "
        f"{['Papillary', 'Micropapillary', 'Follicular', 'Hurthel cell'][int(row['Pathology Type (0 = Papillary, 1 = Micropapillary, 2 = Follicular, 3 = Hurthel cell)'])]} carcinoma. "
        f"The tumor is "
        f"{['uni-focal', 'multi-focal'][int(row['Tumor Focality (0 = Uni-Focal, 1 = Multi-Focal)'])]} with "
        f"{['low', 'intermediate', 'high'][int(row['ATA Risk Stratification (0 = Low, 1 = Intermediate, 2 = High)'])]} ATA risk. "
        f"Tumor stage is "
        f"{['T1a', 'T1b', 'T2', 'T3a', 'T3b', 'T4a', 'T4b'][int(row['Tumor Size / Extent (T Stage: 0 = T1a, 1 = T1b, 2 = T2, 3 = T3a, 4 = T3b, 5 = T4a, 6 = T4b)'])]}, "
        f"N stage is "
        f"{['N0', 'N1a', 'N1b'][int(row['Lymph Node Involvement (N Stage: 0 = N0, 1 = N1a, 2 = N1b)'])]}, "
        f"and M stage is "
        f"{['M0', 'M1'][int(row['Metastasis Status (0 = M0, 1 = M1)'])]}. "
        f"The overall AJCC stage is "
        f"{['I', 'II', 'III', 'IVA', 'IVB'][int(row['AJCC TNM Stage (0 = I, 1 = II, 2 = III, 3 = IVA, 4 = IVB)'])]}. "
        f"Response to initial therapy is "
        f"{['Excellent', 'Indeterminate', 'Biochemical Incomplete', 'Structural Incomplete'][int(row['Response to Initial Therapy (0 = Excellent, 1 = Indeterminate, 2 = Biochemical Incomplete, 3 = Structural Incomplete)'])]}. "
        #f"Disease recurrence status is "
        # f"{'present' if row['Disease Recurrence (0 = No, 1 = Yes)'] == 1 else 'absent'}."
    )

# Apply to all rows
df["clinical_text"] = input_features.apply(row_to_text, axis=1)

# %%
# Drop target column to get input features only
input_features = df.drop(columns=["Disease Recurrence (0 = No, 1 = Yes)"])

# Apply the conversion function row-wise
df["clinical_text"] = input_features.apply(row_to_text, axis=1)

# View the converted text
print(df["clinical_text"].head())
# Out:
# 0    Patient is a 27-year-old female with no histor...
# 1    Patient is a 34-year-old female with a history...
# 2    Patient is a 30-year-old female with no histor...
# 3    Patient is a 62-year-old female with no histor...
# 4    Patient is a 62-year-old female with no histor...
# Name: clinical_text, dtype: object

# %%
# As a list
clinical_texts = df["clinical_text"].tolist()

# Save to CSV for external use
df[["clinical_text"]].to_csv("converted_clinical_texts.csv", index=False)

# %%
# Preview with original data + clinical text
df_with_text = df.copy()
df_with_text["clinical_text"] = input_features.apply(row_to_text, axis=1)
df_with_text.head()
# Out:
#    Age (years)  Gender (0 = Female, 1 = Male)  \
# 0           27                              0
# 1           34                              0
# 2           30                              0
# 3           62                              0
# 4           62                              0
#
#    Smoking Status (0 = No, 1 = Yes)  History of Smoking (0 = No, 1 = Yes)  \
# 0                                 0                                     0
# 1                                 0                                     1
# 2                                 0                                     0
# 3                                 0                                     0
# 4                                 0                                     0
#
#    History of Radiotherapy (0 = No, 1 = Yes)  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
#
#    Thyroid Function (0 = Euthyroid, 1 = Subclinical Hyperthyroidism, 2 = Clinical Hyperthyroidism, 3 = Subclinical Hypothyroidism, 4 = Clinical Hypothyroidism)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Physical Examination (0 = Normal, 1 = Single nodular goiter-right, 2 = Single nodular goiter-left, 3 = Multinodular goiter, 4 = Diffuse goiter)  \
# 0                                                  2
# 1                                                  3
# 2                                                  1
# 3                                                  1
# 4                                                  3
#
#    Adenopathy (0 = No, 1 = Left, 2 = Right, 3 = Bilateral, 4 = Extensive, 5 = Posterior)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Pathology Type (0 = Papillary, 1 = Micropapillary, 2 = Follicular, 3 = Hurthel cell)  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    Tumor Focality (0 = Uni-Focal, 1 = Multi-Focal)  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                1
#
#    ATA Risk Stratification (0 = Low, 1 = Intermediate, 2 = High)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Tumor Size / Extent (T Stage: 0 = T1a, 1 = T1b, 2 = T2, 3 = T3a, 4 = T3b, 5 = T4a, 6 = T4b)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Lymph Node Involvement (N Stage: 0 = N0, 1 = N1a, 2 = N1b)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Metastasis Status (0 = M0, 1 = M1)  \
# 0                                   0
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   0
#
#    AJCC TNM Stage (0 = I, 1 = II, 2 = III, 3 = IVA, 4 = IVB)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Response to Initial Therapy (0 = Excellent, 1 = Indeterminate, 2 = Biochemical Incomplete, 3 = Structural Incomplete)  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Disease Recurrence (0 = No, 1 = Yes)  \
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0
#
#                                        clinical_text
# 0  Patient is a 27-year-old female with no histor...
# 1  Patient is a 34-year-old female with a history...
# 2  Patient is a 30-year-old female with no histor...
# 3  Patient is a 62-year-old female with no histor...
# 4  Patient is a 62-year-old female with no histor...

# %%
df_with_text.shape
# Out:
# (383, 18)

# %%
"""
save_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/Updated_Dataset/clinical_text_dataset.csv"

# Save to CSV
df.to_csv(save_path, index=False)

print(f"File saved to: {save_path}")
"""
# Out:
# File saved to: /content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/Updated_Dataset/clinical_text_dataset.csv

# %%
load_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/Updated_Dataset/clinical_text_dataset.csv"

# Load the DataFrame
df = pd.read_csv(load_path)

# Preview
df.head()
# Out:
#    Age (years)  Gender (0 = Female, 1 = Male)  \
# 0           27                              0
# 1           34                              0
# 2           30                              0
# 3           62                              0
# 4           62                              0
#
#    Smoking Status (0 = No, 1 = Yes)  History of Smoking (0 = No, 1 = Yes)  \
# 0                                 0                                     0
# 1                                 0                                     1
# 2                                 0                                     0
# 3                                 0                                     0
# 4                                 0                                     0
#
#    History of Radiotherapy (0 = No, 1 = Yes)  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
#
#    Thyroid Function (0 = Euthyroid, 1 = Subclinical Hyperthyroidism, 2 = Clinical Hyperthyroidism, 3 = Subclinical Hypothyroidism, 4 = Clinical Hypothyroidism)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Physical Examination (0 = Normal, 1 = Single nodular goiter-right, 2 = Single nodular goiter-left, 3 = Multinodular goiter, 4 = Diffuse goiter)  \
# 0                                                  2
# 1                                                  3
# 2                                                  1
# 3                                                  1
# 4                                                  3
#
#    Adenopathy (0 = No, 1 = Left, 2 = Right, 3 = Bilateral, 4 = Extensive, 5 = Posterior)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Pathology Type (0 = Papillary, 1 = Micropapillary, 2 = Follicular, 3 = Hurthel cell)  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    Tumor Focality (0 = Uni-Focal, 1 = Multi-Focal)  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                1
#
#    ATA Risk Stratification (0 = Low, 1 = Intermediate, 2 = High)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Tumor Size / Extent (T Stage: 0 = T1a, 1 = T1b, 2 = T2, 3 = T3a, 4 = T3b, 5 = T4a, 6 = T4b)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Lymph Node Involvement (N Stage: 0 = N0, 1 = N1a, 2 = N1b)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Metastasis Status (0 = M0, 1 = M1)  \
# 0                                   0
# 1                                   0
# 2                                   0
# 3                                   0
# 4                                   0
#
#    AJCC TNM Stage (0 = I, 1 = II, 2 = III, 3 = IVA, 4 = IVB)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Response to Initial Therapy (0 = Excellent, 1 = Indeterminate, 2 = Biochemical Incomplete, 3 = Structural Incomplete)  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Disease Recurrence (0 = No, 1 = Yes)  \
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0
#
#                                        clinical_text
# 0  Patient is a 27-year-old female with no histor...
# 1  Patient is a 34-year-old female with a history...
# 2  Patient is a 30-year-old female with no histor...
# 3  Patient is a 62-year-old female with no histor...
# 4  Patient is a 62-year-old female with no histor...

# %%
for idx, text in enumerate(df["clinical_text"]):
    print(f"Row {idx + 1}:\n{text}\n{'-'*80}")
# Out:
# Row 1:
# Patient is a 27-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 2:
# Patient is a 34-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 3:
# Patient is a 30-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 4:
# Patient is a 62-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 5:
# Patient is a 62-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 6:
# Patient is a 52-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 7:
# Patient is a 41-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 8:
# Patient is a 46-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 9:
# Patient is a 51-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 10:
# Patient is a 40-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 11:
# Patient is a 75-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 12:
# Patient is a 59-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 13:
# Patient is a 49-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 14:
# Patient is a 50-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 15:
# Patient is a 76-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hypothyroidism. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 16:
# Patient is a 42-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 17:
# Patient is a 40-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 18:
# Patient is a 44-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 19:
# Patient is a 43-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 20:
# Patient is a 52-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 21:
# Patient is a 41-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 22:
# Patient is a 44-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 23:
# Patient is a 36-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 24:
# Patient is a 70-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 25:
# Patient is a 60-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 26:
# Patient is a 33-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 27:
# Patient is a 43-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hyperthyroidism. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 28:
# Patient is a 26-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 29:
# Patient is a 41-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 30:
# Patient is a 37-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Normal. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 31:
# Patient is a 37-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 32:
# Patient is a 30-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Normal. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 33:
# Patient is a 36-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 34:
# Patient is a 55-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 35:
# Patient is a 52-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 36:
# Patient is a 37-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 37:
# Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Diffuse goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 38:
# Patient is a 43-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 39:
# Patient is a 40-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 40:
# Patient is a 34-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Diffuse goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 41:
# Patient is a 51-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 42:
# Patient is a 45-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 43:
# Patient is a 20-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 44:
# Patient is a 38-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 45:
# Patient is a 38-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Diffuse goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 46:
# Patient is a 33-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 47:
# Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hypothyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 48:
# Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T1a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 49:
# Patient is a 26-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Normal. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T1a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 50:
# Patient is a 29-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 51:
# Patient is a 43-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 52:
# Patient is a 30-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hyperthyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 53:
# Patient is a 25-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 54:
# Patient is a 27-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 55:
# Patient is a 25-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 56:
# Patient is a 21-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 57:
# Patient is a 43-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 58:
# Patient is a 23-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 59:
# Patient is a 23-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 60:
# Patient is a 43-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 61:
# Patient is a 24-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 62:
# Patient is a 35-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 63:
# Patient is a 54-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 64:
# Patient is a 54-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 65:
# Patient is a 22-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hyperthyroidism. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 66:
# Patient is a 38-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 67:
# Patient is a 35-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 68:
# Patient is a 51-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 69:
# Patient is a 22-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 70:
# Patient is a 51-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 71:
# Patient is a 40-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 72:
# Patient is a 69-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 73:
# Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 74:
# Patient is a 29-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 75:
# Patient is a 30-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 76:
# Patient is a 28-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 77:
# Patient is a 22-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hypothyroidism. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 78:
# Patient is a 29-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 79:
# Patient is a 35-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 80:
# Patient is a 50-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 81:
# Patient is a 27-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Diffuse goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 82:
# Patient is a 17-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 83:
# Patient is a 27-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hyperthyroidism. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 84:
# Patient is a 40-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 85:
# Patient is a 33-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T1b, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 86:
# Patient is a 25-year-old female with a history of smoking, a history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 87:
# Patient is a 73-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 88:
# Patient is a 36-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 89:
# ...
# --------------------------------------------------------------------------------
# Row 356:
# Patient is a 32-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 357:
# Patient is a 54-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the right. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 358:
# Patient is a 26-year-old female with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is bilateral. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 359:
# Patient is a 53-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 360:
# Patient is a 35-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 361:
# Patient is a 49-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 362:
# Patient is a 34-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 363:
# Patient is a 80-year-old female with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is III. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 364:
# Patient is a 67-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is III. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 365:
# Patient is a 68-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 366:
# Patient is a 71-year-old female with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 367:
# Patient is a 64-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 368:
# Patient is a 80-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 369:
# Patient is a 56-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is posterior. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 370:
# Patient is a 71-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is III. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 371:
# Patient is a 78-year-old male with a history of smoking, a history of radiotherapy. The patient is a smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 372:
# Patient is a 51-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1a, and M stage is M1. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 373:
# Patient is a 67-year-old female with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M0. The overall AJCC stage is IVA. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 374:
# Patient is a 31-year-old male with no history of smoking, a history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M1. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 375:
# Patient is a 62-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 376:
# Patient is a 59-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M0. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 377:
# Patient is a 40-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 378:
# Patient is a 46-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is bilateral. Pathology shows a Follicular carcinoma. The tumor is uni-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M1. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 379:
# Patient is a 72-year-old male with a history of smoking, a history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 380:
# Patient is a 81-year-old male with no history of smoking, a history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 381:
# Patient is a 72-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 382:
# Patient is a 61-year-old male with a history of smoking, a history of radiotherapy. The patient is a smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Multinodular goiter. Adenopathy is extensive. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M0. The overall AJCC stage is IVA. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 383:
# Patient is a 67-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M0. The overall AJCC stage is IVA. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------

# %% [markdown]
# # Train/Test Split

# %%
from sklearn.model_selection import train_test_split

# Define x and y
x = df['clinical_text']
y = df['Disease Recurrence (0 = No, 1 = Yes)']

# 80-20 train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.193, random_state=42, stratify=y)

# %%
"""
# Save x_train and y_train
x_train.to_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/UpData/Actual/x_train_updated.csv", index=False)
y_train.to_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/UpData/Actual/y_train_updated.csv", index=False)

# Save x_test and y_test
x_test.to_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/UpData/Actual/x_test_cleaned.csv", index=False)
y_test.to_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/UpData/Actual/y_test_cleaned.csv", index=False)
"""

# %%
# Load the DataFrame
x_train = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/UpData/Actual/Final/Preprocessed/x_train_updated.csv")
y_train = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/UpData/Actual/Final/Preprocessed/y_train_updated.csv")
x_test = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/UpData/Actual/Final/x_test_cleaned.csv")
y_test = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/UpData/Actual/Final/y_test_cleaned.csv")

# %%
# Show count for each category
y_train.value_counts()
# Out:
# Disease Recurrence (0 = No, 1 = Yes)
# 0.0                                     220
# 1.0                                      86
# Name: count, dtype: int64

# %%
# Show count for each category
y_test.value_counts()
# Out:
# Disease Recurrence (0 = No, 1 = Yes)
# 0                                       55
# 1                                       17
# Name: count, dtype: int64

# %%
# Train Shape
x_train.shape
# Out:
# (311, 1)

# %%
# Train Label Shape
y_train.shape
# Out:
# (311, 1)

# %%
# Train Count
print(y_train.value_counts())
# Out:
# Disease Recurrence (0 = No, 1 = Yes)
# 0.0                                     220
# 1.0                                      86
# Name: count, dtype: int64

# %%
# Test shape
x_test.shape
# Out:
# (72, 1)

# %%
# Test Label shape
y_test.shape
# Out:
# (72, 1)

# %%
# Test Count
print(y_test.value_counts())
# Out:
# Disease Recurrence (0 = No, 1 = Yes)
# 0                                       55
# 1                                       17
# Name: count, dtype: int64

# %%
# Combine x_test and y_test
merged_df = pd.concat([x_test, y_test], axis=1)

# Assume y_test column name is 'label' (adjust if different)
# If y_test has no column name, assign one
if merged_df.columns[-1] not in ['label', 'y_test']:
    merged_df.columns = list(merged_df.columns[:-1]) + ['label']

# Filter rows where label == 1
positive_cases = merged_df[merged_df['label'] == 1]

# Print texts for positive cases
for idx, row in positive_cases.iterrows():
    print(f"Row {idx + 1}:\n{row[0]}\n{'-'*80}")
# Out:
# Row 3:
# Patient is a 27-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 7:
# Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 15:
# Patient is a 72-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 17:
# Patient is a 71-year-old female with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 23:
# Patient is a 80-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 32:
# Patient is a 38-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 33:
# Patient is a 53-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 35:
# Patient is a 54-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the right. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 37:
# Patient is a 60-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 39:
# Patient is a 62-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 45:
# Patient is a 45-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 50:
# Patient is a 67-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is III. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 54:
# Patient is a 23-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 57:
# Patient is a 36-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 68:
# Patient is a 31-year-old male with no history of smoking, a history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M1. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 70:
# Patient is a 73-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T3b, N stage is N1a, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 72:
# Patient is a 36-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# /tmp/ipython-input-2093218046.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Row {idx + 1}:\n{row[0]}\n{'-'*80}")

# %% [markdown]
# ### GPT Model (humarin/chatgpt_paraphraser_on_T5_base) for Synthetic Data and Paraphrasing (Optional)

# %%
# Merge x_train and y_train
df = pd.concat([x_train, y_train], axis=1)

# %% [markdown]
# ### Positive classes

# %%
# Filter the rows where CKD == 1
hf_rows = df[df["Disease Recurrence (0 = No, 1 = Yes)"] == 1]

# Print clinical texts for CKD patients only
for idx, text in enumerate(hf_rows["clinical_text"]):
    print(f"Row {idx + 1}:\n{text}\n{'-'*80}")
# Out:
# Row 1:
# Patient is a 51-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 2:
# Patient is a 58-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Multinodular goiter. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 3:
# Patient is a 35-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 4:
# Patient is a 64-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 5:
# Patient is a 67-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 6:
# Patient is a 52-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the right. Pathology shows a Follicular carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 7:
# Patient is a 59-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M0. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 8:
# Patient is a 36-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 9:
# Patient is a 32-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 10:
# Patient is a 40-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 11:
# Patient is a 21-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 12:
# Patient is a 38-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is posterior. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M1. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 13:
# Patient is a 29-year-old female with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 14:
# Patient is a 37-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 15:
# Patient is a 35-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T1b, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 16:
# Patient is a 61-year-old male with a history of smoking, a history of radiotherapy. The patient is a smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Multinodular goiter. Adenopathy is extensive. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M0. The overall AJCC stage is IVA. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 17:
# Patient is a 62-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 18:
# Patient is a 20-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 19:
# Patient is a 37-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1a, and M stage is M1. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 20:
# Patient is a 33-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 21:
# Patient is a 31-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T1b, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 22:
# Patient is a 67-year-old female with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M0. The overall AJCC stage is IVA. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 23:
# Patient is a 34-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 24:
# Patient is a 81-year-old male with no history of smoking, a history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 25:
# Patient is a 20-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 26:
# Patient is a 60-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 27:
# Patient is a 62-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 28:
# Patient is a 29-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 29:
# Patient is a 49-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 30:
# Patient is a 21-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 31:
# Patient is a 62-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 32:
# Patient is a 78-year-old male with a history of smoking, a history of radiotherapy. The patient is a smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 33:
# Patient is a 38-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 34:
# Patient is a 79-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 35:
# Patient is a 15-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Normal. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 36:
# Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 37:
# Patient is a 18-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T1b, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 38:
# Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 39:
# Patient is a 34-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 40:
# Patient is a 67-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M0. The overall AJCC stage is IVA. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 41:
# Patient is a 68-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 42:
# Patient is a 56-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 43:
# Patient is a 33-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 44:
# Patient is a 58-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1a, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 45:
# Patient is a 22-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 46:
# Patient is a 33-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 47:
# Patient is a 26-year-old female with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is bilateral. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 48:
# Patient is a 34-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with high ATA risk. Tumor stage is T3a, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 49:
# Patient is a 53-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 50:
# Patient is a 25-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 51:
# Patient is a 17-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with high ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 52:
# Patient is a 59-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Clinical Hypothyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 53:
# Patient is a 68-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Single nodular goiter-left. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1b, and M stage is M0. The overall AJCC stage is III. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 54:
# Patient is a 62-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hypothyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 55:
# Patient is a 51-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1a, and M stage is M1. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 56:
# Patient is a 80-year-old female with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is III. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 57:
# Patient is a 73-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 58:
# Patient is a 30-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 59:
# Patient is a 63-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 60:
# Patient is a 48-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 61:
# Patient is a 44-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 62:
# Patient is a 21-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 63:
# Patient is a 29-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 64:
# Patient is a 30-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 65:
# Patient is a 56-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 66:
# Patient is a 63-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 67:
# Patient is a 80-year-old female with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 68:
# Patient is a 82-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 69:
# Patient is a 75-year-old male with no history of smoking, a history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T2, N stage is N0, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 70:
# Patient is a 35-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T3b, N stage is N1b, and M stage is M1. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 71:
# Patient is a 40-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 72:
# Patient is a 71-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is III. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 73:
# Patient is a 56-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is posterior. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 74:
# Patient is a 26-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Normal. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T1a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 75:
# Patient is a 27-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 76:
# Patient is a 35-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 77:
# Patient is a 40-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 78:
# Patient is a 60-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 79:
# Patient is a 42-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 80:
# Patient is a 46-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is bilateral. Pathology shows a Follicular carcinoma. The tumor is uni-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M1. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 81:
# Patient is a 62-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 82:
# Patient is a 44-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M1. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 83:
# Patient is a 56-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 84:
# Patient is a 67-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Hurthel cell carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 85:
# Patient is a 34-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 86:
# Patient is a 32-year-old male with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------

# %%
df.head()
# Out:
#                                          clinical_text  \
# 331  Patient is a 51-year-old female with no histor...
# 348  Patient is a 58-year-old female with no histor...
# 122  Patient is a 28-year-old female with no histor...
# 359  Patient is a 35-year-old female with no histor...
# 366  Patient is a 64-year-old female with a history...
#
#      Disease Recurrence (0 = No, 1 = Yes)
# 331                                     1
# 348                                     1
# 122                                     0
# 359                                     1
# 366                                     1

# %%
import torch
from transformers import pipeline

# Step 1: Filter class 1 examples
df_class_1 = df[df["Disease Recurrence (0 = No, 1 = Yes)"] == 1]
clinical_sentences_class_1 = df_class_1["clinical_text"].tolist()

# Step 2: Calculate how many paraphrases we need
num_class_0 = df[df["Disease Recurrence (0 = No, 1 = Yes)"] == 0].shape[0]
num_class_1 = len(clinical_sentences_class_1)
num_needed = num_class_0 - num_class_1

# Step 3: Load GPT (or equivalent medically fine-tuned model for paraphrasing)
paraphrase_pipe = pipeline(
    "text2text-generation",
    model="humarin/chatgpt_paraphraser_on_T5_base",  # This is T5-based, tuned for paraphrasing
    device=0 if torch.cuda.is_available() else -1
)

# Step 4: Generate paraphrases
synthetic_paraphrases = []
num_generated = 0
i = 0

while num_generated < num_needed:
    sentence = clinical_sentences_class_1[i % num_class_1]
    prompt = f"Paraphrase medically accurately: {sentence}"
    result = paraphrase_pipe(prompt, max_length=512, num_return_sequences=1, do_sample=True)
    paraphrased_text = result[0]['generated_text']
    synthetic_paraphrases.append(paraphrased_text)
    num_generated += 1
    i += 1

# Step 5: Store separately in a DataFrame
df_synthetic = pd.DataFrame({
    "clinical_text": synthetic_paraphrases,
    "Disease Recurrence (0 = No, 1 = Yes)": [1] * len(synthetic_paraphrases)
})

print(f"Generated {len(df_synthetic)} paraphrased class 1 samples.")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# Device set to use cuda:0
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated 134 paraphrased class 1 samples.

# %%
# Data
df_synthetic.head()
# Out:
#                                        clinical_text  \
# 0  The patient is a 51-year-old female who has ne...
# 1  The patient is a 58-year-old female who has no...
# 2  The patient is a 35-year-old female with no pr...
# 3  The patient is a 64-year-old female with a his...
# 4  The patient is a 67-year-old male with a histo...
#
#    Disease Recurrence (0 = No, 1 = Yes)
# 0                                     1
# 1                                     1
# 2                                     1
# 3                                     1
# 4                                     1

# %%
"""
save_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/Updated_Dataset/df_synthetic.csv"

# Save to CSV
df.to_csv(save_path, index=False)

print(f"File saved to: {save_path}")
"""
# Out:
# File saved to: /content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/Updated_Dataset/df_synthetic.csv

# %%
# Loading Synthetic Data
Thyroid_Cancer_Recurrence_Data = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/Updated_Dataset/df_synthetic.csv", encoding='ISO-8859-1')

# %%
# Size
Thyroid_Cancer_Recurrence_Data.shape
# Out:
# (306, 2)

# %%
# Visualizing Rows
for idx, text in enumerate(Thyroid_Cancer_Recurrence_Data["clinical_text"]):
    print(f"Row {idx + 1}:\n{text}\n{'-'*80}")
# Out:
# Row 1:
# Patient is a 51-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 2:
# Patient is a 58-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Multinodular goiter. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 3:
# Patient is a 28-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 4:
# Patient is a 35-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 5:
# Patient is a 64-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 6:
# Patient is a 28-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hypothyroidism. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 7:
# Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 8:
# Patient is a 55-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 9:
# Patient is a 30-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 10:
# Patient is a 30-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Normal. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 11:
# Patient is a 33-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 12:
# Patient is a 67-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 13:
# Patient is a 48-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 14:
# Patient is a 51-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 15:
# Patient is a 43-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 16:
# Patient is a 35-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 17:
# Patient is a 28-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 18:
# Patient is a 19-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 19:
# Patient is a 36-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 20:
# Patient is a 54-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 21:
# Patient is a 37-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 22:
# Patient is a 22-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 23:
# Patient is a 52-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the right. Pathology shows a Follicular carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 24:
# Patient is a 59-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M0. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 25:
# Patient is a 36-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 26:
# Patient is a 32-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 27:
# Patient is a 40-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 28:
# Patient is a 21-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 29:
# Patient is a 38-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is posterior. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M1. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 30:
# Patient is a 17-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 31:
# Patient is a 29-year-old female with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 32:
# Patient is a 27-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 33:
# Patient is a 38-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 34:
# Patient is a 49-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 35:
# Patient is a 25-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 36:
# Patient is a 40-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 37:
# Patient is a 53-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 38:
# Patient is a 21-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 39:
# Patient is a 27-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Diffuse goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 40:
# Patient is a 51-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 41:
# Patient is a 38-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 42:
# Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Diffuse goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 43:
# Patient is a 26-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 44:
# Patient is a 32-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 45:
# Patient is a 48-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 46:
# Patient is a 38-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 47:
# Patient is a 37-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 48:
# Patient is a 19-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 49:
# Patient is a 75-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 50:
# Patient is a 35-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T1b, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 51:
# Patient is a 61-year-old male with a history of smoking, a history of radiotherapy. The patient is a smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Multinodular goiter. Adenopathy is extensive. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M0. The overall AJCC stage is IVA. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 52:
# Patient is a 62-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 53:
# Patient is a 57-year-old female with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 54:
# Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hypothyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 55:
# Patient is a 40-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 56:
# Patient is a 55-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 57:
# Patient is a 20-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 58:
# Patient is a 37-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1a, and M stage is M1. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 59:
# Patient is a 33-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 60:
# Patient is a 31-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T1b, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 61:
# Patient is a 42-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 62:
# Patient is a 29-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T3a, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 63:
# Patient is a 25-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 64:
# Patient is a 62-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 65:
# Patient is a 27-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 66:
# Patient is a 27-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 67:
# Patient is a 67-year-old female with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M0. The overall AJCC stage is IVA. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 68:
# Patient is a 34-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 69:
# Patient is a 63-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Normal. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 70:
# Patient is a 41-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 71:
# Patient is a 36-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 72:
# Patient is a 24-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 73:
# Patient is a 81-year-old male with no history of smoking, a history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 74:
# Patient is a 28-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 75:
# Patient is a 28-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 76:
# Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Hurthel cell carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 77:
# Patient is a 37-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Normal. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 78:
# Patient is a 68-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Diffuse goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 79:
# Patient is a 36-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 80:
# Patient is a 30-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 81:
# Patient is a 38-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 82:
# Patient is a 20-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 83:
# Patient is a 60-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 84:
# Patient is a 45-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 85:
# Patient is a 21-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 86:
# Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 87:
# Patient is a 27-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 88:
# ...
# --------------------------------------------------------------------------------
# Row 278:
# Patient is a 25-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 279:
# Patient is a 42-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 280:
# Patient is a 20-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 281:
# Patient is a 24-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 282:
# Patient is a 52-year-old female with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is bilateral. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 283:
# Patient is a 29-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 284:
# Patient is a 56-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 285:
# Patient is a 34-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 286:
# Patient is a 42-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 287:
# Patient is a 67-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Hurthel cell carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 288:
# Patient is a 67-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 289:
# Patient is a 38-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 290:
# Patient is a 26-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 291:
# Patient is a 41-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 292:
# Patient is a 22-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 293:
# Patient is a 27-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hyperthyroidism. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 294:
# Patient is a 43-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 295:
# Patient is a 24-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 296:
# Patient is a 55-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 297:
# Patient is a 62-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Hurthel cell carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 298:
# Patient is a 35-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 299:
# Patient is a 34-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 300:
# Patient is a 41-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 301:
# Patient is a 34-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 302:
# Patient is a 30-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Normal. Adenopathy is present on the right. Pathology shows a Follicular carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------
# Row 303:
# Patient is a 32-year-old male with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 304:
# Patient is a 41-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Biochemical Incomplete.
# --------------------------------------------------------------------------------
# Row 305:
# Patient is a 54-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 306:
# Patient is a 22-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hypothyroidism. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent.
# --------------------------------------------------------------------------------

# %%
Thyroid_Cancer_Recurrence_Data.head()
# Out:
#                                        clinical_text  \
# 0  Patient is a 51-year-old female with no histor...
# 1  Patient is a 58-year-old female with no histor...
# 2  Patient is a 28-year-old female with no histor...
# 3  Patient is a 35-year-old female with no histor...
# 4  Patient is a 64-year-old female with a history...
#
#    Disease Recurrence (0 = No, 1 = Yes)
# 0                                     1
# 1                                     1
# 2                                     0
# 3                                     1
# 4                                     1

# %% [markdown]
# ## After Augmentation

# %%
# Concatenating along rows (axis=0)

x_train = pd.concat(
    [ x_train[['clinical_text']],
      Thyroid_Cancer_Recurrence_Data[['clinical_text']] ],
    axis=0,
    ignore_index=True
)

y_train = pd.concat(
    [ y_train[['Disease Recurrence (0 = No, 1 = Yes)']],
      Thyroid_Cancer_Recurrence_Data[['Disease Recurrence (0 = No, 1 = Yes)']] ],
    axis=0,
    ignore_index=True
)

# %%
# Data
x_train.head()
# Out:
#                                        clinical_text
# 0  Patient is a 58-year-old with an ejection frac...
# 1  Patient is a 53-year-old with an ejection frac...
# 2  Patient is a 75-year-old with an ejection frac...
# 3  Patient is a 64-year-old with an ejection frac...
# 4  Patient is a 45-year-old with an ejection frac...

# %%
# Label
y_train.head()
# Out:
#    Death Event (1 = Deceased, 0 = Alive)
# 0                                      0
# 1                                      0
# 2                                      1
# 3                                      0
# 4                                      1

# %%
"""
# Save to CSV
x_train.to_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/UpData/PreProcessed/Final/x_train.csv", index=False)
y_train.to_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/UpData/PreProcessed/Final/x_train.csv", index=False)
"""

# %%
# Load the DataFrame
x_train = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/UpData/PreProcessed/Final/x_train.csv")
y_train = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/UpData/PreProcessed/Final/y_train.csv")
x_test = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/UpData/PreProcessed/x_test_cleaned.csv")
y_test = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/UpData/PreProcessed/y_test_cleaned.csv")

# %%
# Train Shape
x_train.shape
# Out:
# (440, 1)

# %%
# Train Label Shape
y_train.shape
# Out:
# (440, 1)

# %%
# Train Count
print(y_train.value_counts())
# Out:
# Disease Recurrence (0 = No, 1 = Yes)
# 0                                       220
# 1                                       220
# Name: count, dtype: int64

# %%
# Test shape
x_test.shape
# Out:
# (72, 1)

# %%
# Test Label shape
y_test.shape
# Out:
# (72, 1)

# %%
# Test Count
print(y_test.value_counts())
# Out:
# Disease Recurrence (0 = No, 1 = Yes)
# 0                                       55
# 1                                       17
# Name: count, dtype: int64

# %% [markdown]
# # GPT as Classification Model

# %%
pip install --upgrade transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.51.3

# %%
# !pip install huggingface_hub[hf_xet]
# Out:
# Requirement already satisfied: huggingface_hub[hf_xet] in /usr/local/lib/python3.12/dist-packages (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub[hf_xet]) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[hf_xet]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[hf_xet]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[hf_xet]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub[hf_xet]) (2025.10.5)

# %%
pip install transformers datasets scikit-learn
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Collecting datasets
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 7.8 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.1 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 13.4 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 7.0 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 9.6 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed datasets-3.5.0 dill-0.3.8 fsspec-2024.12.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
import torch
from transformers import GPT2Tokenizer, GPT2Model, GPT2Config
from transformers import Trainer, TrainingArguments
from torch import nn
from torch.utils.data import Dataset
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# Check device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 1. Load tokenizer and GPT2
tokenizer = GPT2Tokenizer.from_pretrained("distilgpt2")
tokenizer.pad_token = tokenizer.eos_token  # set pad token to eos_token

# 2. Custom Dataset
class ClinicalDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.encodings = tokenizer(list(texts), truncation=True, padding=True, max_length=max_len, return_tensors='pt')
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.encodings.items()}
        item['labels'] = self.labels[idx]
        return item

# 3. Custom GPT2 Classification Model
class GPT2ForClassification(nn.Module):
    def __init__(self, n_classes=2):
        super(GPT2ForClassification, self).__init__()
        self.gpt2 = GPT2Model.from_pretrained("distilgpt2")
        self.dropout = nn.Dropout(0.2)
        self.classifier = nn.Linear(self.gpt2.config.hidden_size, n_classes)

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.gpt2(input_ids=input_ids, attention_mask=attention_mask)
        last_hidden_state = outputs.last_hidden_state  # [batch_size, seq_len, hidden_dim]
        cls_output = last_hidden_state[:, -1, :]  # use last token hidden state
        logits = self.classifier(self.dropout(cls_output))
        loss = None
        if labels is not None:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)
        return {"loss": loss, "logits": logits}

# Texts
if isinstance(x_train, pd.DataFrame):
    x_train = x_train.squeeze().astype(str).tolist()
if isinstance(x_test, pd.DataFrame):
    x_test = x_test.squeeze().astype(str).tolist()

# Labels
if isinstance(y_train, pd.DataFrame):
    y_train = y_train.squeeze().astype(int).tolist()
if isinstance(y_test, pd.DataFrame):
    y_test = y_test.squeeze().astype(int).tolist()

# 4. Prepare dataset
train_dataset = ClinicalDataset(x_train, y_train, tokenizer)
test_dataset = ClinicalDataset(x_test, y_test, tokenizer)

# 5. Load model
model = GPT2ForClassification()
model.to(device)

# 6. TrainingArguments and Trainer
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=2,
    num_train_epochs=6,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=5,
    save_steps=10,
    eval_steps=10,
    metric_for_best_model="accuracy",  # or "f1" depending on your task
    greater_is_better=True,
    warmup_ratio=0.1,              # Warmup to prevent early overfitting
    gradient_accumulation_steps=2, # Simulates larger batch size
    fp16=True,                     # Use if on GPU with mixed precision support
)

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    return {"accuracy": (preds == labels).mean()}

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics,
)

# 7. Train the model
trainer.train()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: sbakter48 (sbakter48-northern-university-bangladesh) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>/content/wandb/run-20251107_184419-y9pftj69</code>
# Syncing run <strong><a href='https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface/runs/y9pftj69' target="_blank">grateful-dragon-42</a></strong> to <a href='https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface' target="_blank">https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface</a>
#  View run at <a href='https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface/runs/y9pftj69' target="_blank">https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface/runs/y9pftj69</a>
#     <div>
#
#       <progress value='660' max='660' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [660/660 17:27, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>2.703100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.866600</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.856800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.780700</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.183900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.665400</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.987600</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.356800</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.655400</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.474300</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.882300</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.587200</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.763000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.644300</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.456600</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.595000</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.744900</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.709100</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.372300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.036700</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.054900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.284900</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.471000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.666500</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.000800</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.668000</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.052200</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.368200</td>
#     </tr>
#     <tr>
#       <td>145</td>
#       <td>0.006900</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.003700</td>
#     </tr>
#     <tr>
#       <td>155</td>
#       <td>1.153500</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.054700</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>0.465600</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.888100</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.006000</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>1.448100</td>
#     </tr>
#     <tr>
#       <td>185</td>
#       <td>0.748100</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.722800</td>
#     </tr>
#     <tr>
#       <td>195</td>
#       <td>0.078600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.012500</td>
#     </tr>
#     <tr>
#       <td>205</td>
#       <td>0.454900</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.152200</td>
#     </tr>
#     <tr>
#       <td>215</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.000500</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.000600</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>235</td>
#       <td>0.755500</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>1.370700</td>
#     </tr>
#     <tr>
#       <td>245</td>
#       <td>0.363200</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.055200</td>
#     </tr>
#     <tr>
#       <td>255</td>
#       <td>0.000700</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.322200</td>
#     </tr>
#     <tr>
#       <td>265</td>
#       <td>0.442000</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.334600</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.378600</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.001500</td>
#     </tr>
#     <tr>
#       <td>285</td>
#       <td>0.279000</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.650600</td>
#     </tr>
#     <tr>
#       <td>295</td>
#       <td>0.467000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.363000</td>
#     </tr>
#     <tr>
#       <td>305</td>
#       <td>0.005300</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.219700</td>
#     </tr>
#     <tr>
#       <td>315</td>
#       <td>0.001800</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.000700</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.196900</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.253600</td>
#     </tr>
#     <tr>
#       <td>335</td>
#       <td>0.733000</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.033600</td>
#     </tr>
#     <tr>
#       <td>345</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.039600</td>
#     </tr>
#     <tr>
#       <td>355</td>
#       <td>0.459200</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.076500</td>
#     </tr>
#     <tr>
#       <td>365</td>
#       <td>0.000400</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.858000</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.000400</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.261700</td>
#     </tr>
#     <tr>
#       <td>385</td>
#       <td>0.574600</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.530200</td>
#     </tr>
#     <tr>
#       <td>395</td>
#       <td>0.002700</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.222700</td>
#     </tr>
#     <tr>
#       <td>405</td>
#       <td>0.515300</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.477800</td>
#     </tr>
#     <tr>
#       <td>415</td>
#       <td>0.077000</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.180000</td>
#     </tr>
#     <tr>
#       <td>425</td>
#       <td>0.435900</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.034700</td>
#     </tr>
#     <tr>
#       <td>435</td>
#       <td>0.011200</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.055900</td>
#     </tr>
#     <tr>
#       <td>445</td>
#       <td>0.000600</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.000500</td>
#     </tr>
#     <tr>
#       <td>455</td>
#       <td>0.000500</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.213000</td>
#     </tr>
#     <tr>
#       <td>465</td>
#       <td>1.765000</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.248900</td>
#     </tr>
#     <tr>
#       <td>475</td>
#       <td>0.400900</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.018400</td>
#     </tr>
#     <tr>
#       <td>485</td>
#       <td>0.106500</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.005300</td>
#     </tr>
#     <tr>
#       <td>495</td>
#       <td>0.159300</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.002300</td>
#     </tr>
#     <tr>
#       <td>505</td>
#       <td>0.437200</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.347600</td>
#     </tr>
#     <tr>
#       <td>515</td>
#       <td>0.023500</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.270000</td>
#     </tr>
#     <tr>
#       <td>525</td>
#       <td>0.014800</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.066400</td>
#     </tr>
#     <tr>
#       <td>535</td>
#       <td>0.141400</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.087800</td>
#     </tr>
#     <tr>
#       <td>545</td>
#       <td>0.114300</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.299800</td>
#     </tr>
#     <tr>
#       <td>555</td>
#       <td>0.095400</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.000700</td>
#     </tr>
#     <tr>
#       <td>565</td>
#       <td>0.239300</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.000900</td>
#     </tr>
#     <tr>
#       <td>575</td>
#       <td>0.600600</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.149700</td>
#     </tr>
#     <tr>
#       <td>585</td>
#       <td>0.506600</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.470500</td>
#     </tr>
#     <tr>
#       <td>595</td>
#       <td>0.098300</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.255400</td>
#     </tr>
#     <tr>
#       <td>605</td>
#       <td>0.182400</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>615</td>
#       <td>0.010400</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.306800</td>
#     </tr>
# TrainOutput(global_step=660, training_loss=0.3801319494843483, metrics={'train_runtime': 1077.8642, 'train_samples_per_second': 2.449, 'train_steps_per_second': 0.612, 'total_flos': 0.0, 'train_loss': 0.3801319494843483, 'epoch': 6.0})

# %%
# 8. Evaluation
preds_output = trainer.predict(test_dataset)
predictions = np.argmax(preds_output.predictions, axis=1)

# %%
# 9. Classification report & confusion matrix
print("Classification Report:\n", classification_report(y_test, predictions, digits=4))
print("Confusion Matrix:\n", confusion_matrix(y_test, predictions))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9649    1.0000    0.9821        55
#            1     1.0000    0.8824    0.9375        17
#
#     accuracy                         0.9722        72
#    macro avg     0.9825    0.9412    0.9598        72
# weighted avg     0.9732    0.9722    0.9716        72
#
# Confusion Matrix:
#  [[55  0]
#  [ 2 15]]

# %%
"""
from transformers import GPT2Tokenizer

save_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/Model/"

# Example: default tokenizer (if you trained with default GPT-2 tokenizer)
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token

# Save tokenizer to your folder
tokenizer.save_pretrained(save_path)

print("Tokenizer saved at:", save_path)
"""
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Tokenizer saved at: /content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/Model/

# %% [markdown]
# ## Ablation

# %%
# =====================================
# GPT-2 Clinical Text Classification
# =====================================
import os
import torch
import numpy as np
import pandas as pd
from transformers import (
    GPT2Tokenizer,
    GPT2Model,
    Trainer,
    TrainingArguments
)
from torch import nn
from torch.utils.data import Dataset
from sklearn.metrics import classification_report, confusion_matrix

# =====================================
# 1️⃣ Environment setup
# =====================================
os.environ["WANDB_DISABLED"] = "true"   # Disable W&B logging
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# =====================================
# 2️⃣ Load tokenizer
# =====================================
tokenizer = GPT2Tokenizer.from_pretrained("distilgpt2")
tokenizer.pad_token = tokenizer.eos_token  # GPT2 has no pad token

# =====================================
# 3️⃣ Custom Dataset
# =====================================
class ClinicalDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.encodings = tokenizer(
            list(texts),
            truncation=True,
            padding=True,
            max_length=max_len,
            return_tensors='pt'
        )
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.encodings.items()}
        item['labels'] = self.labels[idx]
        return item

# =====================================
# 4️⃣ Custom GPT2 model for classification
# =====================================
class GPT2ForClassification(nn.Module):
    def __init__(self, n_classes=2):
        super(GPT2ForClassification, self).__init__()
        self.gpt2 = GPT2Model.from_pretrained("distilgpt2")
        self.dropout = nn.Dropout(0.2)
        self.classifier = nn.Linear(self.gpt2.config.hidden_size, n_classes)

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.gpt2(input_ids=input_ids, attention_mask=attention_mask)
        last_hidden_state = outputs.last_hidden_state
        cls_output = last_hidden_state[:, -1, :]  # Use last token
        logits = self.classifier(self.dropout(cls_output))
        loss = None
        if labels is not None:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)
        return {"loss": loss, "logits": logits}

# =====================================
# 5️⃣ Helper function to clean and align data
# =====================================
def clean_labels_and_align(x, y):
    # Convert arrays/lists/series/dataframes all to DataFrames
    if isinstance(x, np.ndarray):
        x = pd.DataFrame(x, columns=["text"])
    elif isinstance(x, list):
        x = pd.DataFrame({"text": x})
    elif isinstance(x, pd.Series):
        x = x.to_frame(name="text")

    if isinstance(y, np.ndarray):
        y = pd.DataFrame(y, columns=["label"])
    elif isinstance(y, list):
        y = pd.DataFrame({"label": y})
    elif isinstance(y, pd.Series):
        y = y.to_frame(name="label")

    y_series = y.squeeze().replace([np.inf, -np.inf], np.nan)
    mask = ~y_series.isna()
    x_clean = x.loc[mask].reset_index(drop=True)
    y_clean = y_series.loc[mask].astype(int).reset_index(drop=True)
    return x_clean, y_clean

# =====================================
# 6️⃣ Prepare your data
# (Assume x_train, y_train, x_test, y_test are already defined)
# =====================================
x_train, y_train = clean_labels_and_align(x_train, y_train)
x_test, y_test = clean_labels_and_align(x_test, y_test)

# Convert to lists
x_train = x_train.squeeze().astype(str).tolist()
x_test = x_test.squeeze().astype(str).tolist()
y_train = y_train.tolist()
y_test = y_test.tolist()

print(f" Training samples: {len(x_train)}")
print(f" Testing samples: {len(x_test)}")

# =====================================
# 7️⃣ Prepare datasets
# =====================================
train_dataset = ClinicalDataset(x_train, y_train, tokenizer)
test_dataset = ClinicalDataset(x_test, y_test, tokenizer)

# =====================================
# 8️⃣ Initialize model
# =====================================
model = GPT2ForClassification()
model.to(device)

# =====================================
# 9️⃣ Training arguments
# =====================================
training_args = TrainingArguments(
output_dir="./results",
    per_device_train_batch_size=15,
    num_train_epochs=1,
    weight_decay=0.8,
    logging_dir="./logs",
    logging_steps=5,
    save_steps=100,
    eval_steps=10,
    metric_for_best_model="accuracy",  # or "f1" depending on your task
    greater_is_better=True,
    warmup_ratio=0.01,              # Warmup to prevent early overfitting
    gradient_accumulation_steps=1, # Simulates larger batch size
    fp16=True,                     # Use if on GPU with mixed precision support
)

# =====================================
# 🔟 Metrics
# =====================================
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    acc = (preds == labels).mean()
    return {"accuracy": acc}

# =====================================
# 11️⃣ Trainer
# =====================================
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics,
)

# =====================================
# 12️⃣ Train model
# =====================================
trainer.train()
# Out:
# Using device: cpu
#  Training samples: 306
#  Testing samples: 72
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='21' max='21' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [21/21 04:38, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>2.640100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.499400</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.609300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.502700</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=21, training_loss=1.056818419978732, metrics={'train_runtime': 302.2653, 'train_samples_per_second': 1.012, 'train_steps_per_second': 0.069, 'total_flos': 0.0, 'train_loss': 1.056818419978732, 'epoch': 1.0})

# %%
# 8. Evaluation
preds_output = trainer.predict(test_dataset)
predictions = np.argmax(preds_output.predictions, axis=1)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
# 9. Classification report & confusion matrix
print("Classification Report:\n", classification_report(y_test, predictions, digits=4))
print("Confusion Matrix:\n", confusion_matrix(y_test, predictions))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.7857    1.0000    0.8800        55
#            1     1.0000    0.1176    0.2105        17
#
#     accuracy                         0.7917        72
#    macro avg     0.8929    0.5588    0.5453        72
# weighted avg     0.8363    0.7917    0.7219        72
#
# Confusion Matrix:
#  [[55  0]
#  [15  2]]

# %% [markdown]
# # Interpretability

# %% [markdown]
# We take the trained GPT-2 model and look at how much each input token “influences” the model’s prediction. To do this, we track gradients—essentially, how much the model’s output would change if we slightly changed the token’s representation. Tokens with larger gradient values had a bigger effect on the decision, meaning the model “paid more attention” to them. By focusing only on keywords of interest (like “blood pressure” or “sugar”), we can see which clinical features the model considered most important for its prediction. This method gives a transparent view of what the model thinks matters, without changing the model itself.
#
# In simple terms: we compute the gradient of the model’s output (the predicted class score) with respect to each input token’s embedding. The size of this gradient tells us how sensitive the prediction is to changes in that token. Larger gradients mean the model relies more on that token to make its decision.
#
# This is a post-hoc interpretability method that works directly on the trained model without modifying it, and it’s widely used in NLP for token-level importance visualization.

# %%
# Combine x_test and y_test
merged_df = pd.concat([x_test, y_test], axis=1)

# Assume y_test column name is 'label' (adjust if different)
# If y_test has no column name, assign one
if merged_df.columns[-1] not in ['label', 'y_test']:
    merged_df.columns = list(merged_df.columns[:-1]) + ['label']

# Filter rows where label == 1
positive_cases = merged_df[merged_df['label'] == 1]

# Print texts for positive cases
for idx, row in positive_cases.iterrows():
    print(f"Row {idx + 1}:\n{row[0]}\n{'-'*80}")
# Out:
# Row 3:
# Patient is a 27-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 7:
# Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 15:
# Patient is a 72-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 17:
# Patient is a 71-year-old female with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 23:
# Patient is a 80-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 32:
# Patient is a 38-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 33:
# Patient is a 53-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 35:
# Patient is a 54-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the right. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 37:
# Patient is a 60-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 39:
# Patient is a 62-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 45:
# Patient is a 45-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 50:
# Patient is a 67-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is III. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 54:
# Patient is a 23-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 57:
# Patient is a 36-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# Row 68:
# Patient is a 31-year-old male with no history of smoking, a history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M1. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 70:
# Patient is a 73-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T3b, N stage is N1a, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.
# --------------------------------------------------------------------------------
# Row 72:
# Patient is a 36-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.
# --------------------------------------------------------------------------------
# /tmp/ipython-input-2093218046.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Row {idx + 1}:\n{row[0]}\n{'-'*80}")

# %%
for idx, text in enumerate(x_test.values):
    print(f"Row {idx + 1}:\n{text}\n{'-' * 80}")
# Out:
# Row 1:
# ['Patient is a 24-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 2:
# ['Patient is a 28-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 3:
# ['Patient is a 27-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete. ']
# --------------------------------------------------------------------------------
# Row 4:
# ['Patient is a 72-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------
# Row 5:
# ['Patient is a 50-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 6:
# ['Patient is a 31-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 7:
# ['Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete. ']
# --------------------------------------------------------------------------------
# Row 8:
# ['Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 9:
# ['Patient is a 24-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 10:
# ['Patient is a 56-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Biochemical Incomplete. ']
# --------------------------------------------------------------------------------
# Row 11:
# ['Patient is a 41-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 12:
# ['Patient is a 27-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 13:
# ['Patient is a 21-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------
# Row 14:
# ['Patient is a 36-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 15:
# ['Patient is a 72-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete. ']
# --------------------------------------------------------------------------------
# Row 16:
# ['Patient is a 44-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 17:
# ['Patient is a 71-year-old female with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete. ']
# --------------------------------------------------------------------------------
# Row 18:
# ['Patient is a 37-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 19:
# ['Patient is a 56-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1a, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 20:
# ['Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Diffuse goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 21:
# ['Patient is a 22-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hyperthyroidism. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 22:
# ['Patient is a 21-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 23:
# ['Patient is a 80-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete. ']
# --------------------------------------------------------------------------------
# Row 24:
# ['Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 25:
# ['Patient is a 26-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 26:
# ['Patient is a 39-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------
# Row 27:
# ['Patient is a 56-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------
# Row 28:
# ['Patient is a 20-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 29:
# ['Patient is a 52-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------
# Row 30:
# ['Patient is a 30-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 31:
# ['Patient is a 34-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 32:
# ['Patient is a 38-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete. ']
# --------------------------------------------------------------------------------
# Row 33:
# ['Patient is a 53-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete. ']
# --------------------------------------------------------------------------------
# Row 34:
# ['Patient is a 51-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------
# Row 35:
# ['Patient is a 54-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the right. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete. ']
# --------------------------------------------------------------------------------
# Row 36:
# ['Patient is a 44-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 37:
# ['Patient is a 60-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete. ']
# --------------------------------------------------------------------------------
# Row 38:
# ['Patient is a 29-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 39:
# ['Patient is a 62-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete. ']
# --------------------------------------------------------------------------------
# Row 40:
# ['Patient is a 30-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hyperthyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 41:
# ['Patient is a 61-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hypothyroidism. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 42:
# ['Patient is a 32-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 43:
# ['Patient is a 44-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------
# Row 44:
# ['Patient is a 32-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 45:
# ['Patient is a 45-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete. ']
# --------------------------------------------------------------------------------
# Row 46:
# ['Patient is a 43-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------
# Row 47:
# ['Patient is a 21-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 48:
# ['Patient is a 24-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 49:
# ['Patient is a 51-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Hurthel cell carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------
# Row 50:
# ['Patient is a 67-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is III. Response to initial therapy is Structural Incomplete. ']
# --------------------------------------------------------------------------------
# Row 51:
# ['Patient is a 60-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 52:
# ['Patient is a 26-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Subclinical Hyperthyroidism. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Hurthel cell carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 53:
# ['Patient is a 42-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 54:
# ['Patient is a 23-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete. ']
# --------------------------------------------------------------------------------
# Row 55:
# ['Patient is a 41-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 56:
# ['Patient is a 34-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------
# Row 57:
# ['Patient is a 36-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------
# Row 58:
# ['Patient is a 32-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 59:
# ['Patient is a 33-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T1b, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------
# Row 60:
# ['Patient is a 45-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 61:
# ['Patient is a 29-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------
# Row 62:
# ['Patient is a 51-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 63:
# ['Patient is a 37-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 64:
# ['Patient is a 39-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Diffuse goiter. Adenopathy is absent. Pathology shows a Hurthel cell carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------
# Row 65:
# ['Patient is a 29-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1b, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 66:
# ['Patient is a 23-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 67:
# ['Patient is a 35-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 68:
# ['Patient is a 31-year-old male with no history of smoking, a history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M1. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete. ']
# --------------------------------------------------------------------------------
# Row 69:
# ['Patient is a 31-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T3a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------
# Row 70:
# ['Patient is a 73-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T3b, N stage is N1a, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete. ']
# --------------------------------------------------------------------------------
# Row 71:
# ['Patient is a 76-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hypothyroidism. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Micropapillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T1a, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Excellent. ']
# --------------------------------------------------------------------------------
# Row 72:
# ['Patient is a 36-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate. ']
# --------------------------------------------------------------------------------

# %%
# Texts
if isinstance(x_train, pd.DataFrame):
    x_train = x_train.squeeze().astype(str).tolist()
if isinstance(x_test, pd.DataFrame):
    x_test = x_test.squeeze().astype(str).tolist()

# Labels
if isinstance(y_train, pd.DataFrame):
    y_train = y_train.squeeze().astype(int).tolist()
if isinstance(y_test, pd.DataFrame):
    y_test = y_test.squeeze().astype(int).tolist()

# %%
# If y_train/y_test are already lists
y_train = [int(i) for i in y_train]
y_test  = [int(i) for i in y_test]

# If x_train/x_test are lists, make sure they are strings
x_train = [str(i) for i in x_train]
x_test  = [str(i) for i in x_test]

# %%
import torch
import pandas as pd
from transformers import GPT2Tokenizer, GPT2Model, GPT2Config, Trainer, TrainingArguments
from torch import nn
from torch.utils.data import Dataset
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# =====================
# 0. Device
# =====================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# =====================
# 1. Load tokenizer
# =====================
tokenizer = GPT2Tokenizer.from_pretrained("distilgpt2")
tokenizer.pad_token = tokenizer.eos_token  # pad token

# =====================
# 2. Dataset
# =====================
class ClinicalDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.encodings = tokenizer(list(texts), truncation=True, padding=True,
                                   max_length=max_len, return_tensors="pt")
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.encodings.items()}
        item['labels'] = self.labels[idx]
        return item

# =====================
# 3. GPT2 Classification Model (with attention)
# =====================
class GPT2ForClassification(nn.Module):
    def __init__(self, n_classes=2):
        super().__init__()
        # GPT2 with attention output
        config = GPT2Config.from_pretrained("distilgpt2", output_attentions=True, return_dict=True)
        self.gpt2 = GPT2Model.from_pretrained("distilgpt2", config=config)
        self.dropout = nn.Dropout(0.2)
        self.classifier = nn.Linear(self.gpt2.config.hidden_size, n_classes)

    def forward(self, input_ids=None, attention_mask=None, labels=None, return_dict=True, inputs_embeds=None):
        outputs = self.gpt2(input_ids=input_ids,
                            attention_mask=attention_mask,
                            inputs_embeds=inputs_embeds,
                            output_attentions=True,
                            return_dict=True)
        last_hidden_state = outputs.last_hidden_state
        cls_output = last_hidden_state[:, -1, :]  # last token
        logits = self.classifier(self.dropout(cls_output))

        loss = None
        if labels is not None:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)

        return {"loss": loss, "logits": logits, "attentions": outputs.attentions}

# =====================
# 4. Load dataset
# =====================

def df_to_list(df):
    if isinstance(df, pd.DataFrame):
        return df.squeeze().astype(str).tolist()
    return df

x_train = df_to_list(x_train)
x_test = df_to_list(x_test)
y_train = df_to_list(y_train)
y_test = df_to_list(y_test)

train_dataset = ClinicalDataset(x_train, y_train, tokenizer)
test_dataset = ClinicalDataset(x_test, y_test, tokenizer)

# =====================
# 5. Initialize model
# =====================
model = GPT2ForClassification(n_classes=2)
model.to(device)

# =====================
# 6. Training
# =====================
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=2,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=5,
    save_steps=10,
    eval_steps=10,
    metric_for_best_model="accuracy",
    greater_is_better=True,
    warmup_ratio=0.1,
    gradient_accumulation_steps=2,
    fp16=True,
)

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    return {"accuracy": (preds == labels).mean()}

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: nubsimon4 (nubsimon4-northern-university-bangladesh) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>/content/wandb/run-20251109_091617-jkk2pzpe</code>
# Syncing run <strong><a href='https://wandb.ai/nubsimon4-northern-university-bangladesh/huggingface/runs/jkk2pzpe' target="_blank">pious-spaceship-4</a></strong> to <a href='https://wandb.ai/nubsimon4-northern-university-bangladesh/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nubsimon4-northern-university-bangladesh/huggingface' target="_blank">https://wandb.ai/nubsimon4-northern-university-bangladesh/huggingface</a>
#  View run at <a href='https://wandb.ai/nubsimon4-northern-university-bangladesh/huggingface/runs/jkk2pzpe' target="_blank">https://wandb.ai/nubsimon4-northern-university-bangladesh/huggingface/runs/jkk2pzpe</a>
#     <div>
#
#       <progress value='330' max='330' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [330/330 11:02, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.768500</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.851200</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.766400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.693200</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.569000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.604100</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.790700</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.344500</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.383300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.452600</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.158100</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.168400</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.657500</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.019700</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.279200</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.564900</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>1.063100</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.405100</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.004400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.439100</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.384800</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.392400</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.681500</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.002000</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.892500</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.000600</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.293500</td>
#     </tr>
#     <tr>
#       <td>145</td>
#       <td>0.005900</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.000800</td>
#     </tr>
#     <tr>
#       <td>155</td>
#       <td>0.825500</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.000500</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>0.181400</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.406900</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.001100</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.432100</td>
#     </tr>
#     <tr>
#       <td>185</td>
#       <td>0.152900</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.567800</td>
#     </tr>
#     <tr>
#       <td>195</td>
#       <td>0.130000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.258700</td>
#     </tr>
#     <tr>
#       <td>205</td>
#       <td>0.317000</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.004100</td>
#     </tr>
#     <tr>
#       <td>215</td>
#       <td>0.199600</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.026800</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.000400</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>235</td>
#       <td>0.270600</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>1.363400</td>
#     </tr>
#     <tr>
#       <td>245</td>
#       <td>0.749600</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.146600</td>
#     </tr>
#     <tr>
#       <td>255</td>
#       <td>0.000400</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.437700</td>
#     </tr>
#     <tr>
#       <td>265</td>
#       <td>0.782600</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.612900</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.279600</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.000600</td>
#     </tr>
#     <tr>
#       <td>285</td>
#       <td>0.122500</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.622500</td>
#     </tr>
#     <tr>
#       <td>295</td>
#       <td>0.392300</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.247700</td>
#     </tr>
#     <tr>
#       <td>305</td>
#       <td>0.000900</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.083900</td>
#     </tr>
#     <tr>
#       <td>315</td>
#       <td>0.003400</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.004600</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.260700</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.432800</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=330, training_loss=0.36299161730390606, metrics={'train_runtime': 770.8592, 'train_samples_per_second': 1.712, 'train_steps_per_second': 0.428, 'total_flos': 0.0, 'train_loss': 0.36299161730390606, 'epoch': 3.0})

# %%
"""
from transformers import GPT2Tokenizer
import torch

save_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/ThyroidCancerRecurrence/Model/Test/"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
"""

# %%
import re

# =============================
# Sample clinical texts
# =============================
sample_texts = {
    3: "Patient is a 27-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.",
    7: "Patient is a 31-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.",
    15: "Patient is a 72-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4b, N stage is N1b, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.",
    17: "Patient is a 71-year-old female with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Follicular carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.",
    23: "Patient is a 80-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is absent. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T4a, N stage is N0, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.",
    32: "Patient is a 38-year-old male with a history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.",
    33: "Patient is a 53-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.",
    35: "Patient is a 54-year-old male with no history of smoking, no history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the right. Pathology shows a Hurthel cell carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.",
    37: "Patient is a 60-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Multinodular goiter. Adenopathy is bilateral. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.",
    39: "Patient is a 62-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with low ATA risk. Tumor stage is T2, N stage is N0, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.",
    45: "Patient is a 45-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.",
    50: "Patient is a 67-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M0. The overall AJCC stage is III. Response to initial therapy is Structural Incomplete.",
    54: "Patient is a 23-year-old female with a history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T3b, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Structural Incomplete.",
    57: "Patient is a 36-year-old male with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Clinical Hyperthyroidism. Physical examination revealed Multinodular goiter. Adenopathy is absent. Pathology shows a Papillary carcinoma. The tumor is uni-focal with intermediate ATA risk. Tumor stage is T2, N stage is N1a, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate.",
    68: "Patient is a 31-year-old male with no history of smoking, a history of radiotherapy. The patient is a smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is extensive. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T4a, N stage is N1b, and M stage is M1. The overall AJCC stage is II. Response to initial therapy is Structural Incomplete.",
    70: "Patient is a 73-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-right. Adenopathy is present on the right. Pathology shows a Papillary carcinoma. The tumor is multi-focal with high ATA risk. Tumor stage is T3b, N stage is N1a, and M stage is M1. The overall AJCC stage is IVB. Response to initial therapy is Structural Incomplete.",
    72: "Patient is a 36-year-old female with no history of smoking, no history of radiotherapy. The patient is a non-smoker. Thyroid function is classified as Euthyroid. Physical examination revealed Single nodular goiter-left. Adenopathy is present on the left. Pathology shows a Papillary carcinoma. The tumor is multi-focal with intermediate ATA risk. Tumor stage is T3a, N stage is N1b, and M stage is M0. The overall AJCC stage is I. Response to initial therapy is Indeterminate."
}

# =============================
# Dummy feature importances
# =============================
feature_importance = {
    "Tumor": 0.3342,
    "Smoking Status": 0.2984,
    "Pathology": 0.2557,
    "AJCC Stage": 0.2073,
    "Age": 0.1839,
    "Response": 0.1622,
    "Gender": 0.0948,
    "Thyroid Function": 0.0675,
    "Radiotherapy": 0.0563,
    "Adenopathy": 0.0421,
    "Physical Examination": 0.0339,
}

# =============================
# Keyword patterns per feature
# =============================
feature_keywords = {
    "Age": r"(\d{2})-year-old",
    "Gender": r"\b(male|female)\b",
    "Smoking Status": r"\b(smoker|non-smoker)\b",
    "Radiotherapy": r"(history of radiotherapy|no history of radiotherapy)",
    "Thyroid Function": r"(Euthyroid|Subclinical Hyperthyroidism|Clinical Hyperthyroidism|Subclinical Hypothyroidism|Clinical Hypothyroidism)",
    "Physical Examination": r"(Multinodular goiter|Single nodular goiter-(?:left|right)|Diffuse goiter|Normal)",
    "Adenopathy": r"(bilateral|absent|left|right|extensive)",
    "Pathology": r"(Papillary carcinoma|Follicular carcinoma|Hurthel cell carcinoma|Micropapillary carcinoma)",
    "Tumor": r"(T\d[a-b]?|multi-focal|uni-focal)",
    "AJCC Stage": r"stage\s([IVB]+|I{1,3}|IVB|IVA)",
    "Response": r"(Excellent|Indeterminate|Biochemical Incomplete|Structural Incomplete)"
}

# =============================
# Process each sample text
# =============================
for row, text in sample_texts.items():
    print("="*30)
    print(f" Row {row}")
    print("="*30)

    detected = {}
    for feature, pattern in feature_keywords.items():
        match = re.search(pattern, text, re.IGNORECASE)
        detected[feature] = match.group(1) if match else "Not mentioned"

    # Print results for each row
    for feature, importance in sorted(feature_importance.items(), key=lambda x: x[1], reverse=True):
        value = detected.get(feature, "Not mentioned")
        print(f"{feature} ({value}): {importance:.4f}")
# Out:
# ==============================
#  Row 3
# ==============================
# Tumor (multi-focal): 0.3342
# Smoking Status (non-smoker): 0.2984
# Pathology (Papillary carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (27): 0.1839
# Response (Structural Incomplete): 0.1622
# Gender (male): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (bilateral): 0.0421
# Physical Examination (Multinodular goiter): 0.0339
# ==============================
#  Row 7
# ==============================
# Tumor (multi-focal): 0.3342
# Smoking Status (non-smoker): 0.2984
# Pathology (Papillary carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (31): 0.1839
# Response (Structural Incomplete): 0.1622
# Gender (female): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (bilateral): 0.0421
# Physical Examination (Multinodular goiter): 0.0339
# ==============================
#  Row 15
# ==============================
# Tumor (multi-focal): 0.3342
# Smoking Status (smoker): 0.2984
# Pathology (Papillary carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (72): 0.1839
# Response (Structural Incomplete): 0.1622
# Gender (male): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (bilateral): 0.0421
# Physical Examination (Multinodular goiter): 0.0339
# ==============================
#  Row 17
# ==============================
# Tumor (multi-focal): 0.3342
# Smoking Status (smoker): 0.2984
# Pathology (Follicular carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (71): 0.1839
# Response (Structural Incomplete): 0.1622
# Gender (female): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (left): 0.0421
# Physical Examination (Single nodular goiter-left): 0.0339
# ==============================
#  Row 23
# ==============================
# Tumor (multi-focal): 0.3342
# Smoking Status (smoker): 0.2984
# Pathology (Hurthel cell carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (80): 0.1839
# Response (Structural Incomplete): 0.1622
# Gender (male): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (left): 0.0421
# Physical Examination (Single nodular goiter-left): 0.0339
# ==============================
#  Row 32
# ==============================
# Tumor (multi-focal): 0.3342
# Smoking Status (smoker): 0.2984
# Pathology (Papillary carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (38): 0.1839
# Response (Structural Incomplete): 0.1622
# Gender (male): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (right): 0.0421
# Physical Examination (Multinodular goiter): 0.0339
# ==============================
#  Row 33
# ==============================
# Tumor (uni-focal): 0.3342
# Smoking Status (non-smoker): 0.2984
# Pathology (Papillary carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (53): 0.1839
# Response (Structural Incomplete): 0.1622
# Gender (female): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (right): 0.0421
# Physical Examination (Multinodular goiter): 0.0339
# ==============================
#  Row 35
# ==============================
# Tumor (multi-focal): 0.3342
# Smoking Status (smoker): 0.2984
# Pathology (Hurthel cell carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (54): 0.1839
# Response (Structural Incomplete): 0.1622
# Gender (male): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (left): 0.0421
# Physical Examination (Single nodular goiter-left): 0.0339
# ==============================
#  Row 37
# ==============================
# Tumor (multi-focal): 0.3342
# Smoking Status (non-smoker): 0.2984
# Pathology (Papillary carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (60): 0.1839
# Response (Structural Incomplete): 0.1622
# Gender (female): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (bilateral): 0.0421
# Physical Examination (Multinodular goiter): 0.0339
# ==============================
#  Row 39
# ==============================
# Tumor (uni-focal): 0.3342
# Smoking Status (non-smoker): 0.2984
# Pathology (Papillary carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (62): 0.1839
# Response (Structural Incomplete): 0.1622
# Gender (male): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (right): 0.0421
# Physical Examination (Single nodular goiter-right): 0.0339
# ==============================
#  Row 45
# ==============================
# Tumor (multi-focal): 0.3342
# Smoking Status (non-smoker): 0.2984
# Pathology (Papillary carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (45): 0.1839
# Response (Structural Incomplete): 0.1622
# Gender (female): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (left): 0.0421
# Physical Examination (Single nodular goiter-left): 0.0339
# ==============================
#  Row 50
# ==============================
# Tumor (multi-focal): 0.3342
# Smoking Status (non-smoker): 0.2984
# Pathology (Papillary carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (67): 0.1839
# Response (Structural Incomplete): 0.1622
# Gender (female): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (right): 0.0421
# Physical Examination (Single nodular goiter-right): 0.0339
# ==============================
#  Row 54
# ==============================
# Tumor (uni-focal): 0.3342
# Smoking Status (non-smoker): 0.2984
# Pathology (Papillary carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (23): 0.1839
# Response (Structural Incomplete): 0.1622
# Gender (female): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (right): 0.0421
# Physical Examination (Single nodular goiter-right): 0.0339
# ==============================
#  Row 57
# ==============================
# Tumor (uni-focal): 0.3342
# Smoking Status (non-smoker): 0.2984
# Pathology (Papillary carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (36): 0.1839
# Response (Indeterminate): 0.1622
# Gender (male): 0.0948
# Thyroid Function (Clinical Hyperthyroidism): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (absent): 0.0421
# Physical Examination (Multinodular goiter): 0.0339
# ==============================
#  Row 68
# ==============================
# Tumor (multi-focal): 0.3342
# Smoking Status (smoker): 0.2984
# Pathology (Papillary carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (31): 0.1839
# Response (Structural Incomplete): 0.1622
# Gender (male): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (history of radiotherapy): 0.0563
# Adenopathy (left): 0.0421
# Physical Examination (Single nodular goiter-left): 0.0339
# ==============================
#  Row 70
# ==============================
# Tumor (multi-focal): 0.3342
# Smoking Status (non-smoker): 0.2984
# Pathology (Papillary carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (73): 0.1839
# Response (Structural Incomplete): 0.1622
# Gender (female): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (right): 0.0421
# Physical Examination (Single nodular goiter-right): 0.0339
# ==============================
#  Row 72
# ==============================
# Tumor (multi-focal): 0.3342
# Smoking Status (non-smoker): 0.2984
# Pathology (Papillary carcinoma): 0.2557
# AJCC Stage (i): 0.2073
# Age (36): 0.1839
# Response (Indeterminate): 0.1622
# Gender (female): 0.0948
# Thyroid Function (Euthyroid): 0.0675
# Radiotherapy (no history of radiotherapy): 0.0563
# Adenopathy (left): 0.0421
# Physical Examination (Single nodular goiter-left): 0.0339
