# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import seaborn as sns
import plotly.express as px

# %matplotlib inline

# %%
# Set DPI for fugures

plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
# Set the default font size and weight
plt.rcParams['font.size'] = 30
plt.rcParams['font.weight'] = 'bold'

# %%
# Drive connection

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Dataset: UCI Chronic Kidney Disease

# %%
# Dataset
pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2025.1.31)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
chronic_kidney_disease = fetch_ucirepo(id=336)

# data (as pandas dataframes)
X = chronic_kidney_disease.data.features
y = chronic_kidney_disease.data.targets

# metadata
print(chronic_kidney_disease.metadata)

# variable information
print(chronic_kidney_disease.variables)
# Out:
# {'uci_id': 336, 'name': 'Chronic Kidney Disease', 'repository_url': 'https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease', 'data_url': 'https://archive.ics.uci.edu/static/public/336/data.csv', 'abstract': 'This dataset can be used to predict the chronic kidney disease and it can be collected from the hospital nearly 2 months of period.', 'area': 'Other', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 400, 'num_features': 24, 'feature_types': ['Real'], 'demographics': ['Age'], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 2015, 'last_updated': 'Mon Mar 04 2024', 'dataset_doi': '10.24432/C5G020', 'creators': ['L. Rubini', 'P. Soundarapandian', 'P. Eswaran'], 'intro_paper': None, 'additional_info': {'summary': 'We use the following representation to collect the dataset\r\n                        age\t\t-\tage\t\r\n\t\t\tbp\t\t-\tblood pressure\r\n\t\t\tsg\t\t-\tspecific gravity\r\n\t\t\tal\t\t-   \talbumin\r\n\t\t\tsu\t\t-\tsugar\r\n\t\t\trbc\t\t-\tred blood cells\r\n\t\t\tpc\t\t-\tpus cell\r\n\t\t\tpcc\t\t-\tpus cell clumps\r\n\t\t\tba\t\t-\tbacteria\r\n\t\t\tbgr\t\t-\tblood glucose random\r\n\t\t\tbu\t\t-\tblood urea\r\n\t\t\tsc\t\t-\tserum creatinine\r\n\t\t\tsod\t\t-\tsodium\r\n\t\t\tpot\t\t-\tpotassium\r\n\t\t\themo\t\t-\themoglobin\r\n\t\t\tpcv\t\t-\tpacked cell volume\r\n\t\t\twc\t\t-\twhite blood cell count\r\n\t\t\trc\t\t-\tred blood cell count\r\n\t\t\thtn\t\t-\thypertension\r\n\t\t\tdm\t\t-\tdiabetes mellitus\r\n\t\t\tcad\t\t-\tcoronary artery disease\r\n\t\t\tappet\t\t-\tappetite\r\n\t\t\tpe\t\t-\tpedal edema\r\n\t\t\tane\t\t-\tanemia\r\n\t\t\tclass\t\t-\tclass\t', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': 'We use 24 + class = 25 ( 11  numeric ,14  nominal)\r\n1.Age(numerical)\r\n  \t  \tage in years\r\n \t2.Blood Pressure(numerical)\r\n\t       \tbp in mm/Hg\r\n \t3.Specific Gravity(nominal)\r\n\t  \tsg - (1.005,1.010,1.015,1.020,1.025)\r\n \t4.Albumin(nominal)\r\n\t\tal - (0,1,2,3,4,5)\r\n \t5.Sugar(nominal)\r\n\t\tsu - (0,1,2,3,4,5)\r\n \t6.Red Blood Cells(nominal)\r\n\t\trbc - (normal,abnormal)\r\n \t7.Pus Cell (nominal)\r\n\t\tpc - (normal,abnormal)\r\n \t8.Pus Cell clumps(nominal)\r\n\t\tpcc - (present,notpresent)\r\n \t9.Bacteria(nominal)\r\n\t\tba  - (present,notpresent)\r\n \t10.Blood Glucose Random(numerical)\t\t\r\n\t\tbgr in mgs/dl\r\n \t11.Blood Urea(numerical)\t\r\n\t\tbu in mgs/dl\r\n \t12.Serum Creatinine(numerical)\t\r\n\t\tsc in mgs/dl\r\n \t13.Sodium(numerical)\r\n\t\tsod in mEq/L\r\n \t14.Potassium(numerical)\t\r\n\t\tpot in mEq/L\r\n \t15.Hemoglobin(numerical)\r\n\t\themo in gms\r\n \t16.Packed  Cell Volume(numerical)\r\n \t17.White Blood Cell Count(numerical)\r\n\t\twc in cells/cumm\r\n \t18.Red Blood Cell Count(numerical)\t\r\n\t\trc in millions/cmm\r\n \t19.Hypertension(nominal)\t\r\n\t\thtn - (yes,no)\r\n \t20.Diabetes Mellitus(nominal)\t\r\n\t\tdm - (yes,no)\r\n \t21.Coronary Artery Disease(nominal)\r\n\t\tcad - (yes,no)\r\n \t22.Appetite(nominal)\t\r\n\t\tappet - (good,poor)\r\n \t23.Pedal Edema(nominal)\r\n\t\tpe - (yes,no)\t\r\n \t24.Anemia(nominal)\r\n\t\tane - (yes,no)\r\n \t25.Class (nominal)\t\t\r\n\t\tclass - (ckd,notckd)', 'citation': None}}
#      name     role         type demographic              description  \
# 0     age  Feature      Integer         Age                     None
# 1      bp  Feature      Integer        None           blood pressure
# 2      sg  Feature  Categorical        None         specific gravity
# 3      al  Feature  Categorical        None                  albumin
# 4      su  Feature  Categorical        None                    sugar
# 5     rbc  Feature       Binary        None          red blood cells
# 6      pc  Feature       Binary        None                 pus cell
# 7     pcc  Feature       Binary        None          pus cell clumps
# 8      ba  Feature       Binary        None                 bacteria
# 9     bgr  Feature      Integer        None     blood glucose random
# 10     bu  Feature      Integer        None               blood urea
# 11     sc  Feature   Continuous        None         serum creatinine
# 12    sod  Feature      Integer        None                   sodium
# 13    pot  Feature   Continuous        None                potassium
# 14   hemo  Feature   Continuous        None               hemoglobin
# 15    pcv  Feature      Integer        None       packed cell volume
# 16   wbcc  Feature      Integer        None   white blood cell count
# 17   rbcc  Feature   Continuous        None     red blood cell count
# 18    htn  Feature       Binary        None             hypertension
# 19     dm  Feature       Binary        None        diabetes mellitus
# 20    cad  Feature       Binary        None  coronary artery disease
# 21  appet  Feature       Binary        None                 appetite
# 22     pe  Feature       Binary        None              pedal edema
# 23    ane  Feature       Binary        None                   anemia
# 24  class   Target       Binary        None           ckd or not ckd
#
#            units missing_values
# 0           year            yes
# 1          mm/Hg            yes
# 2           None            yes
# 3           None            yes
# 4           None            yes
# 5           None            yes
# 6           None            yes
# 7           None            yes
# 8           None            yes
# 9         mgs/dl            yes
# 10        mgs/dl            yes
# 11        mgs/dl            yes
# 12         mEq/L            yes
# 13         mEq/L            yes
# 14           gms            yes
# 15          None            yes
# 16     cells/cmm            yes
# 17  millions/cmm            yes
# 18          None            yes
# 19          None            yes
# 20          None            yes
# 21          None            yes
# 22          None            yes
# 23          None            yes
# 24          None             no

# %%
# Merge the features and targets into a single DataFrame
df = pd.concat([X, y], axis=1)

# Display the merged DataFrame
print(df.head())
# Out:
#     age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#      bgr  ...   pcv    wbcc  rbcc  htn   dm  cad  appet   pe  ane class
# 0  121.0  ...  44.0  7800.0   5.2  yes  yes   no   good   no   no   ckd
# 1    NaN  ...  38.0  6000.0   NaN   no   no   no   good   no   no   ckd
# 2  423.0  ...  31.0  7500.0   NaN   no  yes   no   poor   no  yes   ckd
# 3  117.0  ...  32.0  6700.0   3.9  yes   no   no   poor  yes  yes   ckd
# 4  106.0  ...  35.0  7300.0   4.6   no   no   no   good   no   no   ckd
#
# [5 rows x 25 columns]

# %%
# Size
df.shape
# Out:
# (400, 25)

# %%
# Null Values
df.isnull().sum()
# Out:
# age        9
# bp        12
# sg        47
# al        46
# su        49
# rbc      152
# pc        65
# pcc        4
# ba         4
# bgr       44
# bu        19
# sc        17
# sod       87
# pot       88
# hemo      52
# pcv       71
# wbcc     106
# rbcc     131
# htn        2
# dm         2
# cad        2
# appet      1
# pe         1
# ane        1
# class      0
# dtype: int64

# %%
# Cleaning Null Values
df = df.dropna()

# %%
# Null Values
df.isnull().sum()
# Out:
# age      0
# bp       0
# sg       0
# al       0
# su       0
# rbc      0
# pc       0
# pcc      0
# ba       0
# bgr      0
# bu       0
# sc       0
# sod      0
# pot      0
# hemo     0
# pcv      0
# wbcc     0
# rbcc     0
# htn      0
# dm       0
# cad      0
# appet    0
# pe       0
# ane      0
# class    0
# dtype: int64

# %%
# Size
df.shape
# Out:
# (158, 25)

# %%
# Count occurrences for each category in each feature
for column in df.columns:
    print(f"Counts for {column}:")
    print(df[column].value_counts())
    print()  # Add a newline for better readability
# Out:
# Counts for age:
# age
# 59.0    8
# 48.0    7
# 55.0    7
# 60.0    6
# 56.0    5
# 73.0    5
# 30.0    5
# 64.0    4
# 46.0    4
# 52.0    4
# 57.0    4
# 23.0    4
# 58.0    4
# 43.0    4
# 33.0    4
# 47.0    4
# 42.0    4
# 63.0    4
# 41.0    3
# 34.0    3
# 61.0    3
# 69.0    3
# 50.0    3
# 45.0    3
# 62.0    3
# 71.0    3
# 44.0    3
# 29.0    2
# 35.0    2
# 25.0    2
# 70.0    2
# 40.0    2
# 68.0    2
# 49.0    2
# 37.0    2
# 51.0    2
# 32.0    2
# 38.0    2
# 39.0    2
# 66.0    2
# 83.0    1
# 53.0    1
# 21.0    1
# 6.0     1
# 20.0    1
# 24.0    1
# 65.0    1
# 22.0    1
# 74.0    1
# 75.0    1
# 28.0    1
# 72.0    1
# 79.0    1
# 80.0    1
# 15.0    1
# 36.0    1
# 12.0    1
# 17.0    1
# Name: count, dtype: int64
#
# Counts for bp:
# bp
# 80.0     63
# 60.0     40
# 70.0     37
# 90.0      9
# 100.0     7
# 50.0      1
# 110.0     1
# Name: count, dtype: int64
#
# Counts for sg:
# sg
# 1.020    61
# 1.025    61
# 1.010    23
# 1.015    10
# 1.005     3
# Name: count, dtype: int64
#
# Counts for al:
# al
# 0.0    116
# 4.0     15
# 3.0     15
# 2.0      9
# 1.0      3
# Name: count, dtype: int64
#
# Counts for su:
# su
# 0.0    140
# 2.0      6
# 1.0      6
# 3.0      3
# 4.0      2
# 5.0      1
# Name: count, dtype: int64
#
# Counts for rbc:
# rbc
# normal      140
# abnormal     18
# Name: count, dtype: int64
#
# Counts for pc:
# pc
# normal      129
# abnormal     29
# Name: count, dtype: int64
#
# Counts for pcc:
# pcc
# notpresent    144
# present        14
# Name: count, dtype: int64
#
# Counts for ba:
# ba
# notpresent    146
# present        12
# Name: count, dtype: int64
#
# Counts for bgr:
# bgr
# 117.0    5
# 100.0    5
# 133.0    4
# 102.0    4
# 118.0    4
#         ..
# 79.0     1
# 78.0     1
# 74.0     1
# 85.0     1
# 114.0    1
# Name: count, Length: 78, dtype: int64
#
# Counts for bu:
# bu
# 46.0     8
# 25.0     7
# 38.0     6
# 18.0     6
# 49.0     5
#         ..
# 55.0     1
# 20.0     1
# 309.0    1
# 215.0    1
# 28.0     1
# Name: count, Length: 66, dtype: int64
#
# Counts for sc:
# sc
# 1.2     26
# 0.5     17
# 0.7     14
# 1.1     14
# 0.9     12
# 0.6     12
# 0.8     11
# 1.0     10
# 1.7      5
# 2.7      3
# 5.3      2
# 7.2      2
# 3.2      2
# 5.6      2
# 3.9      2
# 7.7      1
# 4.1      1
# 3.8      1
# 3.6      1
# 8.5      1
# 6.7      1
# 4.6      1
# 3.3      1
# 2.2      1
# 2.6      1
# 1.3      1
# 14.2     1
# 2.3      1
# 9.2      1
# 15.0     1
# 4.3      1
# 15.2     1
# 6.3      1
# 12.0     1
# 11.9     1
# 12.8     1
# 11.8     1
# 13.3     1
# 0.4      1
# Name: count, dtype: int64
#
# Counts for sod:
# sod
# 135.0    22
# 147.0    12
# 150.0    12
# 140.0    11
# 142.0    10
# 139.0    10
# 141.0     9
# 136.0     9
# 137.0     8
# 138.0     8
# 144.0     8
# 146.0     6
# 145.0     6
# 143.0     4
# 130.0     3
# 131.0     3
# 132.0     3
# 114.0     2
# 122.0     2
# 125.0     2
# 133.0     2
# 120.0     2
# 111.0     1
# 134.0     1
# 115.0     1
# 124.0     1
# Name: count, dtype: int64
#
# Counts for pot:
# pot
# 3.5     23
# 5.0     23
# 4.9     16
# 4.7     11
# 4.8      8
# 3.9      8
# 3.8      7
# 3.7      7
# 4.5      7
# 4.0      6
# 3.6      5
# 4.6      4
# 4.4      4
# 5.7      3
# 4.3      3
# 4.1      3
# 4.2      2
# 3.3      2
# 5.2      2
# 2.9      2
# 6.4      1
# 2.5      1
# 5.5      1
# 5.8      1
# 47.0     1
# 7.6      1
# 5.6      1
# 3.0      1
# 3.4      1
# 3.2      1
# 5.4      1
# 6.5      1
# Name: count, dtype: int64
#
# Counts for hemo:
# hemo
# 15.0    10
# 13.6     6
# 13.9     5
# 13.0     4
# 15.8     3
#         ..
# 17.7     1
# 17.5     1
# 17.2     1
# 17.6     1
# 15.3     1
# Name: count, Length: 80, dtype: int64
#
# Counts for pcv:
# pcv
# 52.0    15
# 41.0    14
# 48.0    13
# 44.0    11
# 45.0    10
# 50.0     9
# 46.0     8
# 43.0     7
# 42.0     7
# 40.0     5
# 54.0     4
# 29.0     4
# 30.0     4
# 51.0     4
# 49.0     4
# 32.0     3
# 26.0     3
# 33.0     3
# 37.0     3
# 22.0     3
# 35.0     3
# 47.0     3
# 53.0     3
# 24.0     2
# 28.0     2
# 23.0     2
# 31.0     2
# 20.0     1
# 25.0     1
# 36.0     1
# 16.0     1
# 39.0     1
# 34.0     1
# 9.0      1
# Name: count, dtype: int64
#
# Counts for wbcc:
# wbcc
# 6700.0     7
# 7200.0     7
# 11000.0    5
# 7000.0     5
# 9100.0     5
#           ..
# 8200.0     1
# 5200.0     1
# 9700.0     1
# 5100.0     1
# 5700.0     1
# Name: count, Length: 69, dtype: int64
#
# Counts for rbcc:
# rbcc
# 4.5    12
# 4.8     9
# 4.9     9
# 5.2     8
# 4.7     7
# 5.3     7
# 5.0     7
# 5.6     6
# 5.5     6
# 3.9     5
# 6.4     5
# 5.9     5
# 6.2     5
# 5.4     5
# 3.4     5
# 5.8     4
# 5.7     4
# 5.1     4
# 6.0     3
# 6.5     3
# 4.6     3
# 3.2     3
# 4.1     3
# 3.7     3
# 4.3     3
# 6.1     3
# 6.3     3
# 3.8     2
# 3.5     2
# 2.9     2
# 2.1     2
# 2.6     1
# 3.3     1
# 4.0     1
# 2.5     1
# 3.1     1
# 3.0     1
# 4.2     1
# 3.6     1
# 2.7     1
# 8.0     1
# Name: count, dtype: int64
#
# Counts for htn:
# htn
# no     124
# yes     34
# Name: count, dtype: int64
#
# Counts for dm:
# dm
# no     130
# yes     28
# Name: count, dtype: int64
#
# Counts for cad:
# cad
# no     147
# yes     11
# Name: count, dtype: int64
#
# Counts for appet:
# appet
# good    139
# poor     19
# Name: count, dtype: int64
#
# Counts for pe:
# pe
# no     138
# yes     20
# Name: count, dtype: int64
#
# Counts for ane:
# ane
# no     142
# yes     16
# Name: count, dtype: int64
#
# Counts for class:
# class
# notckd    115
# ckd        43
# Name: count, dtype: int64

# %%
# Data
df.head()
# Out:
#      age    bp     sg   al   su       rbc        pc         pcc          ba  \
# 3   48.0  70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 9   53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 11  63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent
# 14  68.0  80.0  1.010  3.0  2.0    normal  abnormal     present     present
# 20  61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
#
#       bgr  ...   pcv     wbcc  rbcc  htn   dm  cad  appet   pe  ane class
# 3   117.0  ...  32.0   6700.0   3.9  yes   no   no   poor  yes  yes   ckd
# 9    70.0  ...  29.0  12100.0   3.7  yes  yes   no   poor   no  yes   ckd
# 11  380.0  ...  32.0   4500.0   3.8  yes  yes   no   poor  yes   no   ckd
# 14  157.0  ...  16.0  11000.0   2.6  yes  yes  yes   poor  yes   no   ckd
# 20  173.0  ...  24.0   9200.0   3.2  yes  yes  yes   poor  yes  yes   ckd
#
# [5 rows x 25 columns]

# %%
"""
save_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/df.csv"

# Save to CSV
df.to_csv(save_path, index=False)

print(f"File saved to: {save_path}")
"""
# Out:
# File saved to: /content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/df.csv

# %%
load_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/df.csv"

# Load the DataFrame
df = pd.read_csv(load_path)

# Preview
df.head()
# Out:
#     age    bp     sg   al   su       rbc        pc         pcc          ba  \
# 0  48.0  70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 1  53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 2  63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent
# 3  68.0  80.0  1.010  3.0  2.0    normal  abnormal     present     present
# 4  61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
#
#      bgr  ...   pcv     wbcc  rbcc  htn   dm  cad  appet   pe  ane class
# 0  117.0  ...  32.0   6700.0   3.9  yes   no   no   poor  yes  yes   ckd
# 1   70.0  ...  29.0  12100.0   3.7  yes  yes   no   poor   no  yes   ckd
# 2  380.0  ...  32.0   4500.0   3.8  yes  yes   no   poor  yes   no   ckd
# 3  157.0  ...  16.0  11000.0   2.6  yes  yes  yes   poor  yes   no   ckd
# 4  173.0  ...  24.0   9200.0   3.2  yes  yes  yes   poor  yes  yes   ckd
#
# [5 rows x 25 columns]

# %%
# Column Names
print(df.columns.tolist())
# Out:
# ['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'class']

# %%
import pandas as pd

# Dataframe
mapping = {
    'rbc': {'normal': 1, 'abnormal': 0},
    'pc': {'normal': 1, 'abnormal': 0},
    'pcc': {'present': 1, 'notpresent': 0},
    'ba': {'present': 1, 'notpresent': 0},
    'htn': {'yes': 1, 'no': 0},
    'dm': {'yes': 1, 'no': 0},
    'cad': {'yes': 1, 'no': 0},
    'appet': {'good': 1, 'poor': 0},
    'pe': {'yes': 1, 'no': 0},
    'ane': {'yes': 1, 'no': 0},
    'class': {'ckd': 1, 'notckd': 0},
}

# Apply the mappings to the dataframe
df = df.replace(mapping)

# Check the updated dataframe
print(df.head())
# Out:
#     age    bp     sg   al   su  rbc  pc  pcc  ba    bgr  ...   pcv     wbcc  \
# 0  48.0  70.0  1.005  4.0  0.0    1   0    1   0  117.0  ...  32.0   6700.0
# 1  53.0  90.0  1.020  2.0  0.0    0   0    1   0   70.0  ...  29.0  12100.0
# 2  63.0  70.0  1.010  3.0  0.0    0   0    1   0  380.0  ...  32.0   4500.0
# 3  68.0  80.0  1.010  3.0  2.0    1   0    1   1  157.0  ...  16.0  11000.0
# 4  61.0  80.0  1.015  2.0  0.0    0   0    0   0  173.0  ...  24.0   9200.0
#
#    rbcc  htn  dm  cad  appet  pe  ane  class
# 0   3.9    1   0    0      0   1    1      1
# 1   3.7    1   1    0      0   0    1      1
# 2   3.8    1   1    0      0   1    0      1
# 3   2.6    1   1    1      0   1    0      1
# 4   3.2    1   1    1      0   1    1      1
#
# [5 rows x 25 columns]
# <ipython-input-119-d7bb4eb025a3>:19: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(mapping)

# %%
# Data
df.head()
# Out:
#     age    bp     sg   al   su  rbc  pc  pcc  ba    bgr  ...   pcv     wbcc  \
# 0  48.0  70.0  1.005  4.0  0.0    1   0    1   0  117.0  ...  32.0   6700.0
# 1  53.0  90.0  1.020  2.0  0.0    0   0    1   0   70.0  ...  29.0  12100.0
# 2  63.0  70.0  1.010  3.0  0.0    0   0    1   0  380.0  ...  32.0   4500.0
# 3  68.0  80.0  1.010  3.0  2.0    1   0    1   1  157.0  ...  16.0  11000.0
# 4  61.0  80.0  1.015  2.0  0.0    0   0    0   0  173.0  ...  24.0   9200.0
#
#    rbcc  htn  dm  cad  appet  pe  ane  class
# 0   3.9    1   0    0      0   1    1      1
# 1   3.7    1   1    0      0   0    1      1
# 2   3.8    1   1    0      0   1    0      1
# 3   2.6    1   1    1      0   1    0      1
# 4   3.2    1   1    1      0   1    1      1
#
# [5 rows x 25 columns]

# %%
# Renaming

df.rename(columns={
    "age": "Age (years)",
    "bp": "Blood Pressure (mm Hg)",
    "sg": "Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated)",
    "al": "Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe)",
    "su": "Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High)",
    "rbc": "Red Blood Cells (1 = Normal, 0 = Abnormal)",
    "pc": "Pus Cells (1 = Normal, 0 = Abnormal)",
    "pcc": "Pus Cell Clumps (1 = Present, 0 = Not Present)",
    "ba": "Bacteria (1 = Present, 0 = Not Present)",
    "bgr": "Blood Glucose Random (mg/dL)",
    "bu": "Blood Urea (mg/dL)",
    "sc": "Serum Creatinine (mg/dL)",
    "sod": "Sodium (mEq/L)",
    "pot": "Potassium (mEq/L)",
    "hemo": "Hemoglobin (g/dL)",
    "pcv": "Packed Cell Volume (%)",
    "wbcc": "White Blood Cell Count (cells/cumm)",
    "rbcc": "Red Blood Cell Count (million cells/cumm)",
    "htn": "Hypertension (1 = Yes, 0 = No)",
    "dm": "Diabetes Mellitus (1 = Yes, 0 = No)",
    "cad": "Coronary Artery Disease (1 = Yes, 0 = No)",
    "appet": "Appetite (1 = Good, 0 = Poor)",
    "pe": "Pedal Edema (1 = Yes, 0 = No)",
    "ane": "Anemia (1 = Yes, 0 = No)",
    "class": "Chronic Kidney Disease (1 = CKD, 0 = Not CKD)"
}, inplace=True)

# %%
"""
save_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/df.csv"

# Save to CSV
df.to_csv(save_path, index=False)

print(f"File saved to: {save_path}")
"""
# Out:
# File saved to: /content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/df.csv

# %%
load_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/df.csv"

# Load the DataFrame
df = pd.read_csv(load_path)

# Preview
df.head()
# Out:
#    Age (years)  Blood Pressure (mm Hg)  \
# 0         48.0                    70.0
# 1         53.0                    90.0
# 2         63.0                    70.0
# 3         68.0                    80.0
# 4         61.0                    80.0
#
#    Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated)  \
# 0                                              1.005
# 1                                              1.020
# 2                                              1.010
# 3                                              1.010
# 4                                              1.015
#
#    Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe)  \
# 0                                                4.0
# 1                                                2.0
# 2                                                3.0
# 3                                                3.0
# 4                                                2.0
#
#    Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High)  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
# 3                                                2.0
# 4                                                0.0
#
#    Red Blood Cells (1 = Normal, 0 = Abnormal)  \
# 0                                           1
# 1                                           0
# 2                                           0
# 3                                           1
# 4                                           0
#
#    Pus Cells (1 = Normal, 0 = Abnormal)  \
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0
#
#    Pus Cell Clumps (1 = Present, 0 = Not Present)  \
# 0                                               1
# 1                                               1
# 2                                               1
# 3                                               1
# 4                                               0
#
#    Bacteria (1 = Present, 0 = Not Present)  Blood Glucose Random (mg/dL)  ...  \
# 0                                        0                         117.0  ...
# 1                                        0                          70.0  ...
# 2                                        0                         380.0  ...
# 3                                        1                         157.0  ...
# 4                                        0                         173.0  ...
#
#    Packed Cell Volume (%)  White Blood Cell Count (cells/cumm)  \
# 0                    32.0                               6700.0
# 1                    29.0                              12100.0
# 2                    32.0                               4500.0
# 3                    16.0                              11000.0
# 4                    24.0                               9200.0
#
#    Red Blood Cell Count (million cells/cumm)  Hypertension (1 = Yes, 0 = No)  \
# 0                                        3.9                               1
# 1                                        3.7                               1
# 2                                        3.8                               1
# 3                                        2.6                               1
# 4                                        3.2                               1
#
#    Diabetes Mellitus (1 = Yes, 0 = No)  \
# 0                                    0
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1
#
#    Coronary Artery Disease (1 = Yes, 0 = No)  Appetite (1 = Good, 0 = Poor)  \
# 0                                          0                              0
# 1                                          0                              0
# 2                                          0                              0
# 3                                          1                              0
# 4                                          1                              0
#
#    Pedal Edema (1 = Yes, 0 = No)  Anemia (1 = Yes, 0 = No)  \
# 0                              1                         1
# 1                              0                         1
# 2                              1                         0
# 3                              1                         0
# 4                              1                         1
#
#    Chronic Kidney Disease (1 = CKD, 0 = Not CKD)
# 0                                              1
# 1                                              1
# 2                                              1
# 3                                              1
# 4                                              1
#
# [5 rows x 25 columns]

# %%
print(df.columns.tolist())
# Out:
# ['Age (years)', 'Blood Pressure (mm Hg)', 'Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated)', 'Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe)', 'Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High)', 'Red Blood Cells (1 = Normal, 0 = Abnormal)', 'Pus Cells (1 = Normal, 0 = Abnormal)', 'Pus Cell Clumps (1 = Present, 0 = Not Present)', 'Bacteria (1 = Present, 0 = Not Present)', 'Blood Glucose Random (mg/dL)', 'Blood Urea (mg/dL)', 'Serum Creatinine (mg/dL)', 'Sodium (mEq/L)', 'Potassium (mEq/L)', 'Hemoglobin (g/dL)', 'Packed Cell Volume (%)', 'White Blood Cell Count (cells/cumm)', 'Red Blood Cell Count (million cells/cumm)', 'Hypertension (1 = Yes, 0 = No)', 'Diabetes Mellitus (1 = Yes, 0 = No)', 'Coronary Artery Disease (1 = Yes, 0 = No)', 'Appetite (1 = Good, 0 = Poor)', 'Pedal Edema (1 = Yes, 0 = No)', 'Anemia (1 = Yes, 0 = No)', 'Chronic Kidney Disease (1 = CKD, 0 = Not CKD)']

# %%
# New Column Names
print(df.columns.tolist())
# Out:
# ['Age (years)', 'Blood Pressure (mm Hg)', 'Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated)', 'Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe)', 'Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High)', 'Red Blood Cells (1 = Normal, 0 = Abnormal)', 'Pus Cells (1 = Normal, 0 = Abnormal)', 'Pus Cell Clumps (1 = Present, 0 = Not Present)', 'Bacteria (1 = Present, 0 = Not Present)', 'Blood Glucose Random (mg/dL)', 'Blood Urea (mg/dL)', 'Serum Creatinine (mg/dL)', 'Sodium (mEq/L)', 'Potassium (mEq/L)', 'Hemoglobin (g/dL)', 'Packed Cell Volume (%)', 'White Blood Cell Count (cells/cumm)', 'Red Blood Cell Count (million cells/cumm)', 'Hypertension (1 = Yes, 0 = No)', 'Diabetes Mellitus (1 = Yes, 0 = No)', 'Coronary Artery Disease (1 = Yes, 0 = No)', 'Appetite (1 = Good, 0 = Poor)', 'Pedal Edema (1 = Yes, 0 = No)', 'Anemia (1 = Yes, 0 = No)', 'Chronic Kidney Disease (1 = CKD, 0 = Not CKD)']

# %%
# Size
df.shape
# Out:
# (158, 25)

# %% [markdown]
# # Table to Clinical Text for GPT Model

# %%
from sklearn.model_selection import train_test_split

# Separate features and target
input_features = df.drop(columns=["Chronic Kidney Disease (1 = CKD, 0 = Not CKD)"])
target = df["Chronic Kidney Disease (1 = CKD, 0 = Not CKD)"]

# Mapping for albumin and sugar levels
albumin_map = {
    0.0: "Normal", 1.0: "Trace", 2.0: "Mild", 3.0: "Moderate", 4.0: "Severe", 5.0: "Very Severe"
}
sugar_map = {
    0.0: "Normal", 1.0: "Trace", 2.0: "Mild", 3.0: "Moderate", 4.0: "High", 5.0: "Very High"
}

# Updated row_to_text function
def row_to_text(row):
    albumin_level = albumin_map.get(row['Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe)'], "Unknown")
    sugar_level = sugar_map.get(row['Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High)'], "Unknown")

    return (f"Patient aged {row['Age (years)']} years with blood pressure of {row['Blood Pressure (mm Hg)']} mm Hg, "
            f"specific gravity of urine is {row['Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated)']}, "
            f"albumin level is {albumin_level}, "
            f"sugar level is {sugar_level}, "
            f"red blood cells are {'normal' if row['Red Blood Cells (1 = Normal, 0 = Abnormal)'] == 1 else 'abnormal'}, "
            f"pus cells are {'normal' if row['Pus Cells (1 = Normal, 0 = Abnormal)'] == 1 else 'abnormal'}, "
            f"pus cell clumps are {'present' if row['Pus Cell Clumps (1 = Present, 0 = Not Present)'] == 1 else 'not present'}, "
            f"bacteria are {'present' if row['Bacteria (1 = Present, 0 = Not Present)'] == 1 else 'not present'}, "
            f"blood glucose is {row['Blood Glucose Random (mg/dL)']} mg/dL, urea is {row['Blood Urea (mg/dL)']} mg/dL, "
            f"serum creatinine is {row['Serum Creatinine (mg/dL)']} mg/dL, sodium is {row['Sodium (mEq/L)']} mEq/L, "
            f"potassium is {row['Potassium (mEq/L)']} mEq/L, hemoglobin is {row['Hemoglobin (g/dL)']} g/dL, "
            f"packed cell volume is {row['Packed Cell Volume (%)']}%, WBC count is {row['White Blood Cell Count (cells/cumm)']} cells/cumm, "
            f"RBC count is {row['Red Blood Cell Count (million cells/cumm)']} million/cumm, "
            f"has {'hypertension' if row['Hypertension (1 = Yes, 0 = No)'] else 'no hypertension'}, "
            f"has {'diabetes mellitus' if row['Diabetes Mellitus (1 = Yes, 0 = No)'] else 'no diabetes'}, "
            f"has {'coronary artery disease' if row['Coronary Artery Disease (1 = Yes, 0 = No)'] else 'no coronary artery disease'}, "
            f"appetite is {'good' if row['Appetite (1 = Good, 0 = Poor)'] else 'poor'}, "
            f"pedal edema is {'present' if row['Pedal Edema (1 = Yes, 0 = No)'] else 'not present'}, "
            f"and {'has' if row['Anemia (1 = Yes, 0 = No)'] else 'does not have'} anemia.")

# Apply to dataframe
df["clinical_text"] = input_features.apply(row_to_text, axis=1)

# %%
# Drop target column to get input features only
input_features = df.drop(columns=["Chronic Kidney Disease (1 = CKD, 0 = Not CKD)"])

# Apply the conversion function row-wise
df["clinical_text"] = input_features.apply(row_to_text, axis=1)

# View the converted text
print(df["clinical_text"].head())
# Out:
# 0    Patient aged 48.0 years with blood pressure of...
# 1    Patient aged 53.0 years with blood pressure of...
# 2    Patient aged 63.0 years with blood pressure of...
# 3    Patient aged 68.0 years with blood pressure of...
# 4    Patient aged 61.0 years with blood pressure of...
# Name: clinical_text, dtype: object

# %%
# As a list
clinical_texts = df["clinical_text"].tolist()

# Save to CSV for external use
df[["clinical_text"]].to_csv("converted_clinical_texts.csv", index=False)

# %%
# Preview with original data + clinical text
df_with_text = df.copy()
df_with_text["clinical_text"] = input_features.apply(row_to_text, axis=1)
df_with_text.head()
# Out:
#    Age (years)  Blood Pressure (mm Hg)  \
# 0         48.0                    70.0
# 1         53.0                    90.0
# 2         63.0                    70.0
# 3         68.0                    80.0
# 4         61.0                    80.0
#
#    Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated)  \
# 0                                              1.005
# 1                                              1.020
# 2                                              1.010
# 3                                              1.010
# 4                                              1.015
#
#    Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe)  \
# 0                                                4.0
# 1                                                2.0
# 2                                                3.0
# 3                                                3.0
# 4                                                2.0
#
#    Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High)  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
# 3                                                2.0
# 4                                                0.0
#
#    Red Blood Cells (1 = Normal, 0 = Abnormal)  \
# 0                                           1
# 1                                           0
# 2                                           0
# 3                                           1
# 4                                           0
#
#    Pus Cells (1 = Normal, 0 = Abnormal)  \
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0
#
#    Pus Cell Clumps (1 = Present, 0 = Not Present)  \
# 0                                               1
# 1                                               1
# 2                                               1
# 3                                               1
# 4                                               0
#
#    Bacteria (1 = Present, 0 = Not Present)  Blood Glucose Random (mg/dL)  ...  \
# 0                                        0                         117.0  ...
# 1                                        0                          70.0  ...
# 2                                        0                         380.0  ...
# 3                                        1                         157.0  ...
# 4                                        0                         173.0  ...
#
#    White Blood Cell Count (cells/cumm)  \
# 0                               6700.0
# 1                              12100.0
# 2                               4500.0
# 3                              11000.0
# 4                               9200.0
#
#    Red Blood Cell Count (million cells/cumm)  Hypertension (1 = Yes, 0 = No)  \
# 0                                        3.9                               1
# 1                                        3.7                               1
# 2                                        3.8                               1
# 3                                        2.6                               1
# 4                                        3.2                               1
#
#    Diabetes Mellitus (1 = Yes, 0 = No)  \
# 0                                    0
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1
#
#    Coronary Artery Disease (1 = Yes, 0 = No)  Appetite (1 = Good, 0 = Poor)  \
# 0                                          0                              0
# 1                                          0                              0
# 2                                          0                              0
# 3                                          1                              0
# 4                                          1                              0
#
#    Pedal Edema (1 = Yes, 0 = No)  Anemia (1 = Yes, 0 = No)  \
# 0                              1                         1
# 1                              0                         1
# 2                              1                         0
# 3                              1                         0
# 4                              1                         1
#
#    Chronic Kidney Disease (1 = CKD, 0 = Not CKD)  \
# 0                                              1
# 1                                              1
# 2                                              1
# 3                                              1
# 4                                              1
#
#                                        clinical_text
# 0  Patient aged 48.0 years with blood pressure of...
# 1  Patient aged 53.0 years with blood pressure of...
# 2  Patient aged 63.0 years with blood pressure of...
# 3  Patient aged 68.0 years with blood pressure of...
# 4  Patient aged 61.0 years with blood pressure of...
#
# [5 rows x 26 columns]

# %%
"""
save_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/clinical_text_dataset.csv"

# Save to CSV
df.to_csv(save_path, index=False)

print(f"File saved to: {save_path}")
"""
# Out:
# File saved to: /content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/clinical_text_dataset.csv

# %%
load_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/clinical_text_dataset.csv"

# Load the DataFrame
df = pd.read_csv(load_path)

# Preview
df.head()
# Out:
#    Age (years)  Blood Pressure (mm Hg)  \
# 0         48.0                    70.0
# 1         53.0                    90.0
# 2         63.0                    70.0
# 3         68.0                    80.0
# 4         61.0                    80.0
#
#    Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated)  \
# 0                                              1.005
# 1                                              1.020
# 2                                              1.010
# 3                                              1.010
# 4                                              1.015
#
#    Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe)  \
# 0                                                4.0
# 1                                                2.0
# 2                                                3.0
# 3                                                3.0
# 4                                                2.0
#
#    Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High)  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
# 3                                                2.0
# 4                                                0.0
#
#    Red Blood Cells (1 = Normal, 0 = Abnormal)  \
# 0                                           1
# 1                                           0
# 2                                           0
# 3                                           1
# 4                                           0
#
#    Pus Cells (1 = Normal, 0 = Abnormal)  \
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0
#
#    Pus Cell Clumps (1 = Present, 0 = Not Present)  \
# 0                                               1
# 1                                               1
# 2                                               1
# 3                                               1
# 4                                               0
#
#    Bacteria (1 = Present, 0 = Not Present)  Blood Glucose Random (mg/dL)  ...  \
# 0                                        0                         117.0  ...
# 1                                        0                          70.0  ...
# 2                                        0                         380.0  ...
# 3                                        1                         157.0  ...
# 4                                        0                         173.0  ...
#
#    White Blood Cell Count (cells/cumm)  \
# 0                               6700.0
# 1                              12100.0
# 2                               4500.0
# 3                              11000.0
# 4                               9200.0
#
#    Red Blood Cell Count (million cells/cumm)  Hypertension (1 = Yes, 0 = No)  \
# 0                                        3.9                               1
# 1                                        3.7                               1
# 2                                        3.8                               1
# 3                                        2.6                               1
# 4                                        3.2                               1
#
#    Diabetes Mellitus (1 = Yes, 0 = No)  \
# 0                                    0
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1
#
#    Coronary Artery Disease (1 = Yes, 0 = No)  Appetite (1 = Good, 0 = Poor)  \
# 0                                          0                              0
# 1                                          0                              0
# 2                                          0                              0
# 3                                          1                              0
# 4                                          1                              0
#
#    Pedal Edema (1 = Yes, 0 = No)  Anemia (1 = Yes, 0 = No)  \
# 0                              1                         1
# 1                              0                         1
# 2                              1                         0
# 3                              1                         0
# 4                              1                         1
#
#    Chronic Kidney Disease (1 = CKD, 0 = Not CKD)  \
# 0                                              1
# 1                                              1
# 2                                              1
# 3                                              1
# 4                                              1
#
#                                        clinical_text
# 0  Patient aged 48.0 years with blood pressure of...
# 1  Patient aged 53.0 years with blood pressure of...
# 2  Patient aged 63.0 years with blood pressure of...
# 3  Patient aged 68.0 years with blood pressure of...
# 4  Patient aged 61.0 years with blood pressure of...
#
# [5 rows x 26 columns]

# %%
# Clinical Texts
for idx, text in enumerate(df["clinical_text"]):
    print(f"Row {idx + 1}:\n{text}\n{'-'*80}")
# Out:
# Row 1:
# Patient aged 48.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.005, albumin level is Severe, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are not present, blood glucose is 117.0 mg/dL, urea is 56.0 mg/dL, serum creatinine is 3.8 mg/dL, sodium is 111.0 mEq/L, potassium is 2.5 mEq/L, hemoglobin is 11.2 g/dL, packed cell volume is 32.0%, WBC count is 6700.0 cells/cumm, RBC count is 3.9 million/cumm, has hypertension, has no diabetes, has no coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 2:
# Patient aged 53.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.02, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are present, bacteria are not present, blood glucose is 70.0 mg/dL, urea is 107.0 mg/dL, serum creatinine is 7.2 mg/dL, sodium is 114.0 mEq/L, potassium is 3.7 mEq/L, hemoglobin is 9.5 g/dL, packed cell volume is 29.0%, WBC count is 12100.0 cells/cumm, RBC count is 3.7 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 3:
# Patient aged 63.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are present, bacteria are not present, blood glucose is 380.0 mg/dL, urea is 60.0 mg/dL, serum creatinine is 2.7 mg/dL, sodium is 131.0 mEq/L, potassium is 4.2 mEq/L, hemoglobin is 10.8 g/dL, packed cell volume is 32.0%, WBC count is 4500.0 cells/cumm, RBC count is 3.8 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 4:
# Patient aged 68.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Mild, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are present, blood glucose is 157.0 mg/dL, urea is 90.0 mg/dL, serum creatinine is 4.1 mg/dL, sodium is 130.0 mEq/L, potassium is 6.4 mEq/L, hemoglobin is 5.6 g/dL, packed cell volume is 16.0%, WBC count is 11000.0 cells/cumm, RBC count is 2.6 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is poor, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 5:
# Patient aged 61.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.015, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 173.0 mg/dL, urea is 148.0 mg/dL, serum creatinine is 3.9 mg/dL, sodium is 135.0 mEq/L, potassium is 5.2 mEq/L, hemoglobin is 7.7 g/dL, packed cell volume is 24.0%, WBC count is 9200.0 cells/cumm, RBC count is 3.2 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 6:
# Patient aged 48.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Severe, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 95.0 mg/dL, urea is 163.0 mg/dL, serum creatinine is 7.7 mg/dL, sodium is 136.0 mEq/L, potassium is 3.8 mEq/L, hemoglobin is 9.8 g/dL, packed cell volume is 32.0%, WBC count is 6900.0 cells/cumm, RBC count is 3.4 million/cumm, has hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 7:
# Patient aged 69.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is High, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 264.0 mg/dL, urea is 87.0 mg/dL, serum creatinine is 2.7 mg/dL, sodium is 130.0 mEq/L, potassium is 4.0 mEq/L, hemoglobin is 12.5 g/dL, packed cell volume is 37.0%, WBC count is 9600.0 cells/cumm, RBC count is 4.1 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 8:
# Patient aged 73.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.005, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 70.0 mg/dL, urea is 32.0 mg/dL, serum creatinine is 0.9 mg/dL, sodium is 125.0 mEq/L, potassium is 4.0 mEq/L, hemoglobin is 10.0 g/dL, packed cell volume is 29.0%, WBC count is 18900.0 cells/cumm, RBC count is 3.5 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 9:
# Patient aged 73.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 253.0 mg/dL, urea is 142.0 mg/dL, serum creatinine is 4.6 mg/dL, sodium is 138.0 mEq/L, potassium is 5.8 mEq/L, hemoglobin is 10.5 g/dL, packed cell volume is 33.0%, WBC count is 7200.0 cells/cumm, RBC count is 4.3 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 10:
# Patient aged 46.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.01, albumin level is Trace, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 163.0 mg/dL, urea is 92.0 mg/dL, serum creatinine is 3.3 mg/dL, sodium is 141.0 mEq/L, potassium is 4.0 mEq/L, hemoglobin is 9.8 g/dL, packed cell volume is 28.0%, WBC count is 14600.0 cells/cumm, RBC count is 3.2 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 11:
# Patient aged 56.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.015, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 129.0 mg/dL, urea is 107.0 mg/dL, serum creatinine is 6.7 mg/dL, sodium is 131.0 mEq/L, potassium is 4.8 mEq/L, hemoglobin is 9.1 g/dL, packed cell volume is 29.0%, WBC count is 6400.0 cells/cumm, RBC count is 3.4 million/cumm, has hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 12:
# Patient aged 48.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.005, albumin level is Severe, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are present, blood glucose is 133.0 mg/dL, urea is 139.0 mg/dL, serum creatinine is 8.5 mg/dL, sodium is 132.0 mEq/L, potassium is 5.5 mEq/L, hemoglobin is 10.3 g/dL, packed cell volume is 36.0%, WBC count is 6200.0 cells/cumm, RBC count is 4.0 million/cumm, has no hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 13:
# Patient aged 59.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 76.0 mg/dL, urea is 186.0 mg/dL, serum creatinine is 15.0 mg/dL, sodium is 135.0 mEq/L, potassium is 7.6 mEq/L, hemoglobin is 7.1 g/dL, packed cell volume is 22.0%, WBC count is 3800.0 cells/cumm, RBC count is 2.1 million/cumm, has hypertension, has no diabetes, has no coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 14:
# Patient aged 63.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.01, albumin level is Mild, sugar level is Mild, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are present, blood glucose is 280.0 mg/dL, urea is 35.0 mg/dL, serum creatinine is 3.2 mg/dL, sodium is 143.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 13.0 g/dL, packed cell volume is 40.0%, WBC count is 9800.0 cells/cumm, RBC count is 4.2 million/cumm, has hypertension, has no diabetes, has coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 15:
# Patient aged 56.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.015, albumin level is Severe, sugar level is Trace, red blood cells are abnormal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 210.0 mg/dL, urea is 26.0 mg/dL, serum creatinine is 1.7 mg/dL, sodium is 136.0 mEq/L, potassium is 3.8 mEq/L, hemoglobin is 16.1 g/dL, packed cell volume is 52.0%, WBC count is 12500.0 cells/cumm, RBC count is 5.6 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 16:
# Patient aged 71.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are present, blood glucose is 219.0 mg/dL, urea is 82.0 mg/dL, serum creatinine is 3.6 mg/dL, sodium is 133.0 mEq/L, potassium is 4.4 mEq/L, hemoglobin is 10.4 g/dL, packed cell volume is 33.0%, WBC count is 5600.0 cells/cumm, RBC count is 3.6 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 17:
# Patient aged 73.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Mild, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are present, bacteria are not present, blood glucose is 295.0 mg/dL, urea is 90.0 mg/dL, serum creatinine is 5.6 mg/dL, sodium is 140.0 mEq/L, potassium is 2.9 mEq/L, hemoglobin is 9.2 g/dL, packed cell volume is 30.0%, WBC count is 7000.0 cells/cumm, RBC count is 3.2 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is poor, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 18:
# Patient aged 71.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.015, albumin level is Severe, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 118.0 mg/dL, urea is 125.0 mg/dL, serum creatinine is 5.3 mg/dL, sodium is 136.0 mEq/L, potassium is 4.9 mEq/L, hemoglobin is 11.4 g/dL, packed cell volume is 35.0%, WBC count is 15200.0 cells/cumm, RBC count is 4.3 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 19:
# Patient aged 52.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.015, albumin level is Severe, sugar level is Moderate, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 224.0 mg/dL, urea is 166.0 mg/dL, serum creatinine is 5.6 mg/dL, sodium is 133.0 mEq/L, potassium is 47.0 mEq/L, hemoglobin is 8.1 g/dL, packed cell volume is 23.0%, WBC count is 5000.0 cells/cumm, RBC count is 2.9 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 20:
# Patient aged 50.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.01, albumin level is Mild, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are present, blood glucose is 128.0 mg/dL, urea is 208.0 mg/dL, serum creatinine is 9.2 mg/dL, sodium is 134.0 mEq/L, potassium is 4.8 mEq/L, hemoglobin is 8.2 g/dL, packed cell volume is 22.0%, WBC count is 16300.0 cells/cumm, RBC count is 2.7 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 21:
# Patient aged 70.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.015, albumin level is Severe, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 118.0 mg/dL, urea is 125.0 mg/dL, serum creatinine is 5.3 mg/dL, sodium is 136.0 mEq/L, potassium is 4.9 mEq/L, hemoglobin is 12.0 g/dL, packed cell volume is 37.0%, WBC count is 8400.0 cells/cumm, RBC count is 8.0 million/cumm, has hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 22:
# Patient aged 60.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.01, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 105.0 mg/dL, urea is 53.0 mg/dL, serum creatinine is 2.3 mg/dL, sodium is 136.0 mEq/L, potassium is 5.2 mEq/L, hemoglobin is 11.1 g/dL, packed cell volume is 33.0%, WBC count is 10500.0 cells/cumm, RBC count is 4.1 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 23:
# Patient aged 60.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Trace, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are not present, blood glucose is 288.0 mg/dL, urea is 36.0 mg/dL, serum creatinine is 1.7 mg/dL, sodium is 130.0 mEq/L, potassium is 3.0 mEq/L, hemoglobin is 7.9 g/dL, packed cell volume is 25.0%, WBC count is 15200.0 cells/cumm, RBC count is 3.0 million/cumm, has hypertension, has no diabetes, has no coronary artery disease, appetite is poor, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 24:
# Patient aged 55.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.01, albumin level is Mild, sugar level is Trace, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 273.0 mg/dL, urea is 235.0 mg/dL, serum creatinine is 14.2 mg/dL, sodium is 132.0 mEq/L, potassium is 3.4 mEq/L, hemoglobin is 8.3 g/dL, packed cell volume is 22.0%, WBC count is 14600.0 cells/cumm, RBC count is 2.9 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 25:
# Patient aged 62.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.025, albumin level is Moderate, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 122.0 mg/dL, urea is 42.0 mg/dL, serum creatinine is 1.7 mg/dL, sodium is 136.0 mEq/L, potassium is 4.7 mEq/L, hemoglobin is 12.6 g/dL, packed cell volume is 39.0%, WBC count is 7900.0 cells/cumm, RBC count is 3.9 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 26:
# Patient aged 59.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.01, albumin level is Trace, sugar level is Normal, red blood cells are abnormal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 303.0 mg/dL, urea is 35.0 mg/dL, serum creatinine is 1.3 mg/dL, sodium is 122.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 10.4 g/dL, packed cell volume is 35.0%, WBC count is 10900.0 cells/cumm, RBC count is 4.3 million/cumm, has no hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 27:
# Patient aged 83.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.02, albumin level is Moderate, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 102.0 mg/dL, urea is 60.0 mg/dL, serum creatinine is 2.6 mg/dL, sodium is 115.0 mEq/L, potassium is 5.7 mEq/L, hemoglobin is 8.7 g/dL, packed cell volume is 26.0%, WBC count is 12800.0 cells/cumm, RBC count is 3.1 million/cumm, has hypertension, has no diabetes, has no coronary artery disease, appetite is poor, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 28:
# Patient aged 21.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.01, albumin level is Severe, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are present, blood glucose is 107.0 mg/dL, urea is 40.0 mg/dL, serum creatinine is 1.7 mg/dL, sodium is 125.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 8.3 g/dL, packed cell volume is 23.0%, WBC count is 12400.0 cells/cumm, RBC count is 3.9 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 29:
# Patient aged 45.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.025, albumin level is Mild, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are not present, blood glucose is 117.0 mg/dL, urea is 52.0 mg/dL, serum creatinine is 2.2 mg/dL, sodium is 136.0 mEq/L, potassium is 3.8 mEq/L, hemoglobin is 10.0 g/dL, packed cell volume is 30.0%, WBC count is 19100.0 cells/cumm, RBC count is 3.7 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 30:
# Patient aged 64.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.01, albumin level is Severe, sugar level is Trace, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are present, blood glucose is 239.0 mg/dL, urea is 58.0 mg/dL, serum creatinine is 4.3 mg/dL, sodium is 137.0 mEq/L, potassium is 5.4 mEq/L, hemoglobin is 9.5 g/dL, packed cell volume is 29.0%, WBC count is 7500.0 cells/cumm, RBC count is 3.4 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 31:
# Patient aged 6.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.01, albumin level is Severe, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are present, blood glucose is 94.0 mg/dL, urea is 67.0 mg/dL, serum creatinine is 1.0 mg/dL, sodium is 135.0 mEq/L, potassium is 4.9 mEq/L, hemoglobin is 9.9 g/dL, packed cell volume is 30.0%, WBC count is 16700.0 cells/cumm, RBC count is 4.8 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is poor, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 32:
# Patient aged 49.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 129.0 mg/dL, urea is 158.0 mg/dL, serum creatinine is 11.8 mg/dL, sodium is 122.0 mEq/L, potassium is 3.2 mEq/L, hemoglobin is 8.1 g/dL, packed cell volume is 24.0%, WBC count is 9600.0 cells/cumm, RBC count is 3.5 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 33:
# Patient aged 59.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.02, albumin level is Severe, sugar level is Mild, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 252.0 mg/dL, urea is 40.0 mg/dL, serum creatinine is 3.2 mg/dL, sodium is 137.0 mEq/L, potassium is 4.7 mEq/L, hemoglobin is 11.2 g/dL, packed cell volume is 30.0%, WBC count is 26400.0 cells/cumm, RBC count is 3.9 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 34:
# Patient aged 59.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.015, albumin level is Severe, sugar level is Mild, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 255.0 mg/dL, urea is 132.0 mg/dL, serum creatinine is 12.8 mg/dL, sodium is 135.0 mEq/L, potassium is 5.7 mEq/L, hemoglobin is 7.3 g/dL, packed cell volume is 20.0%, WBC count is 9800.0 cells/cumm, RBC count is 3.9 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 35:
# Patient aged 40.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.015, albumin level is Moderate, sugar level is High, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 253.0 mg/dL, urea is 150.0 mg/dL, serum creatinine is 11.9 mg/dL, sodium is 132.0 mEq/L, potassium is 5.6 mEq/L, hemoglobin is 10.9 g/dL, packed cell volume is 31.0%, WBC count is 8800.0 cells/cumm, RBC count is 3.4 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 36:
# Patient aged 55.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Trace, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are present, blood glucose is 214.0 mg/dL, urea is 73.0 mg/dL, serum creatinine is 3.9 mg/dL, sodium is 137.0 mEq/L, potassium is 4.9 mEq/L, hemoglobin is 10.9 g/dL, packed cell volume is 34.0%, WBC count is 7400.0 cells/cumm, RBC count is 3.7 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 37:
# Patient aged 60.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Very High, red blood cells are abnormal, pus cells are normal, pus cell clumps are not present, bacteria are present, blood glucose is 490.0 mg/dL, urea is 95.0 mg/dL, serum creatinine is 2.7 mg/dL, sodium is 131.0 mEq/L, potassium is 3.8 mEq/L, hemoglobin is 11.5 g/dL, packed cell volume is 35.0%, WBC count is 12000.0 cells/cumm, RBC count is 4.5 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 38:
# Patient aged 64.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.015, albumin level is Severe, sugar level is Mild, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are present, blood glucose is 163.0 mg/dL, urea is 54.0 mg/dL, serum creatinine is 7.2 mg/dL, sodium is 140.0 mEq/L, potassium is 4.6 mEq/L, hemoglobin is 7.9 g/dL, packed cell volume is 26.0%, WBC count is 7500.0 cells/cumm, RBC count is 3.4 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 39:
# Patient aged 59.0 years with blood pressure of 50.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 241.0 mg/dL, urea is 191.0 mg/dL, serum creatinine is 12.0 mg/dL, sodium is 114.0 mEq/L, potassium is 2.9 mEq/L, hemoglobin is 9.6 g/dL, packed cell volume is 31.0%, WBC count is 15700.0 cells/cumm, RBC count is 3.8 million/cumm, has no hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 40:
# Patient aged 69.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.01, albumin level is Severe, sugar level is Moderate, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are present, blood glucose is 214.0 mg/dL, urea is 96.0 mg/dL, serum creatinine is 6.3 mg/dL, sodium is 120.0 mEq/L, potassium is 3.9 mEq/L, hemoglobin is 9.4 g/dL, packed cell volume is 28.0%, WBC count is 11500.0 cells/cumm, RBC count is 3.3 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 41:
# Patient aged 48.0 years with blood pressure of 110.0 mm Hg, specific gravity of urine is 1.015, albumin level is Moderate, sugar level is Normal, red blood cells are abnormal, pus cells are normal, pus cell clumps are present, bacteria are not present, blood glucose is 106.0 mg/dL, urea is 215.0 mg/dL, serum creatinine is 15.2 mg/dL, sodium is 120.0 mEq/L, potassium is 5.7 mEq/L, hemoglobin is 8.6 g/dL, packed cell volume is 26.0%, WBC count is 5000.0 cells/cumm, RBC count is 2.5 million/cumm, has hypertension, has no diabetes, has coronary artery disease, appetite is good, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 42:
# Patient aged 59.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.01, albumin level is Trace, sugar level is Moderate, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 424.0 mg/dL, urea is 55.0 mg/dL, serum creatinine is 1.7 mg/dL, sodium is 138.0 mEq/L, potassium is 4.5 mEq/L, hemoglobin is 12.6 g/dL, packed cell volume is 37.0%, WBC count is 10200.0 cells/cumm, RBC count is 4.1 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 43:
# Patient aged 56.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.01, albumin level is Severe, sugar level is Trace, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are not present, blood glucose is 176.0 mg/dL, urea is 309.0 mg/dL, serum creatinine is 13.3 mg/dL, sodium is 124.0 mEq/L, potassium is 6.5 mEq/L, hemoglobin is 3.1 g/dL, packed cell volume is 9.0%, WBC count is 5400.0 cells/cumm, RBC count is 2.1 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 44:
# Patient aged 40.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 140.0 mg/dL, urea is 10.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 135.0 mEq/L, potassium is 5.0 mEq/L, hemoglobin is 15.0 g/dL, packed cell volume is 48.0%, WBC count is 10400.0 cells/cumm, RBC count is 4.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 45:
# Patient aged 23.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 70.0 mg/dL, urea is 36.0 mg/dL, serum creatinine is 1.0 mg/dL, sodium is 150.0 mEq/L, potassium is 4.6 mEq/L, hemoglobin is 17.0 g/dL, packed cell volume is 52.0%, WBC count is 9800.0 cells/cumm, RBC count is 5.0 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 46:
# Patient aged 45.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 82.0 mg/dL, urea is 49.0 mg/dL, serum creatinine is 0.6 mg/dL, sodium is 147.0 mEq/L, potassium is 4.4 mEq/L, hemoglobin is 15.9 g/dL, packed cell volume is 46.0%, WBC count is 9100.0 cells/cumm, RBC count is 4.7 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 47:
# Patient aged 57.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 119.0 mg/dL, urea is 17.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 135.0 mEq/L, potassium is 4.7 mEq/L, hemoglobin is 15.4 g/dL, packed cell volume is 42.0%, WBC count is 6200.0 cells/cumm, RBC count is 6.2 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 48:
# Patient aged 51.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 99.0 mg/dL, urea is 38.0 mg/dL, serum creatinine is 0.8 mg/dL, sodium is 135.0 mEq/L, potassium is 3.7 mEq/L, hemoglobin is 13.0 g/dL, packed cell volume is 49.0%, WBC count is 8300.0 cells/cumm, RBC count is 5.2 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 49:
# Patient aged 34.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 121.0 mg/dL, urea is 27.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 144.0 mEq/L, potassium is 3.9 mEq/L, hemoglobin is 13.6 g/dL, packed cell volume is 52.0%, WBC count is 9200.0 cells/cumm, RBC count is 6.3 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 50:
# Patient aged 60.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 131.0 mg/dL, urea is 10.0 mg/dL, serum creatinine is 0.5 mg/dL, sodium is 146.0 mEq/L, potassium is 5.0 mEq/L, hemoglobin is 14.5 g/dL, packed cell volume is 41.0%, WBC count is 10700.0 cells/cumm, RBC count is 5.1 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 51:
# Patient aged 38.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 91.0 mg/dL, urea is 36.0 mg/dL, serum creatinine is 0.7 mg/dL, sodium is 135.0 mEq/L, potassium is 3.7 mEq/L, hemoglobin is 14.0 g/dL, packed cell volume is 46.0%, WBC count is 9100.0 cells/cumm, RBC count is 5.8 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 52:
# Patient aged 42.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 98.0 mg/dL, urea is 20.0 mg/dL, serum creatinine is 0.5 mg/dL, sodium is 140.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 13.9 g/dL, packed cell volume is 44.0%, WBC count is 8400.0 cells/cumm, RBC count is 5.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 53:
# Patient aged 35.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 104.0 mg/dL, urea is 31.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 135.0 mEq/L, potassium is 5.0 mEq/L, hemoglobin is 16.1 g/dL, packed cell volume is 45.0%, WBC count is 4300.0 cells/cumm, RBC count is 5.2 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 54:
# Patient aged 30.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 131.0 mg/dL, urea is 38.0 mg/dL, serum creatinine is 1.0 mg/dL, sodium is 147.0 mEq/L, potassium is 3.8 mEq/L, hemoglobin is 14.1 g/dL, packed cell volume is 45.0%, WBC count is 9400.0 cells/cumm, RBC count is 5.3 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 55:
# Patient aged 49.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 122.0 mg/dL, urea is 32.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 139.0 mEq/L, potassium is 3.9 mEq/L, hemoglobin is 17.0 g/dL, packed cell volume is 41.0%, WBC count is 5600.0 cells/cumm, RBC count is 4.9 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 56:
# Patient aged 55.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 118.0 mg/dL, urea is 18.0 mg/dL, serum creatinine is 0.9 mg/dL, sodium is 135.0 mEq/L, potassium is 3.6 mEq/L, hemoglobin is 15.5 g/dL, packed cell volume is 43.0%, WBC count is 7200.0 cells/cumm, RBC count is 5.4 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 57:
# Patient aged 45.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 117.0 mg/dL, urea is 46.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 137.0 mEq/L, potassium is 5.0 mEq/L, hemoglobin is 16.2 g/dL, packed cell volume is 45.0%, WBC count is 8600.0 cells/cumm, RBC count is 5.2 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 58:
# Patient aged 42.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 132.0 mg/dL, urea is 24.0 mg/dL, serum creatinine is 0.7 mg/dL, sodium is 140.0 mEq/L, potassium is 4.1 mEq/L, hemoglobin is 14.4 g/dL, packed cell volume is 50.0%, WBC count is 5000.0 cells/cumm, RBC count is 4.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 59:
# Patient aged 50.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 97.0 mg/dL, urea is 40.0 mg/dL, serum creatinine is 0.6 mg/dL, sodium is 150.0 mEq/L, potassium is 4.5 mEq/L, hemoglobin is 14.2 g/dL, packed cell volume is 48.0%, WBC count is 10500.0 cells/cumm, RBC count is 5.0 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 60:
# Patient aged 55.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 133.0 mg/dL, urea is 17.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 135.0 mEq/L, potassium is 4.8 mEq/L, hemoglobin is 13.2 g/dL, packed cell volume is 41.0%, WBC count is 6800.0 cells/cumm, RBC count is 5.3 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 61:
# Patient aged 48.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 122.0 mg/dL, urea is 33.0 mg/dL, serum creatinine is 0.9 mg/dL, sodium is 146.0 mEq/L, potassium is 3.9 mEq/L, hemoglobin is 13.9 g/dL, packed cell volume is 48.0%, WBC count is 9500.0 cells/cumm, RBC count is 4.8 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 62:
# Patient aged 25.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 121.0 mg/dL, urea is 19.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 142.0 mEq/L, potassium is 4.9 mEq/L, hemoglobin is 15.0 g/dL, packed cell volume is 48.0%, WBC count is 6900.0 cells/cumm, RBC count is 5.3 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 63:
# Patient aged 23.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 111.0 mg/dL, urea is 34.0 mg/dL, serum creatinine is 1.1 mg/dL, sodium is 145.0 mEq/L, potassium is 4.0 mEq/L, hemoglobin is 14.3 g/dL, packed cell volume is 41.0%, WBC count is 7200.0 cells/cumm, RBC count is 5.0 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 64:
# Patient aged 30.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 96.0 mg/dL, urea is 25.0 mg/dL, serum creatinine is 0.5 mg/dL, sodium is 144.0 mEq/L, potassium is 4.8 mEq/L, hemoglobin is 13.8 g/dL, packed cell volume is 42.0%, WBC count is 9000.0 cells/cumm, RBC count is 4.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 65:
# Patient aged 56.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 139.0 mg/dL, urea is 15.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 135.0 mEq/L, potassium is 5.0 mEq/L, hemoglobin is 14.8 g/dL, packed cell volume is 42.0%, WBC count is 5600.0 cells/cumm, RBC count is 5.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 66:
# Patient aged 52.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 125.0 mg/dL, urea is 22.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 139.0 mEq/L, potassium is 4.6 mEq/L, hemoglobin is 16.5 g/dL, packed cell volume is 43.0%, WBC count is 4700.0 cells/cumm, RBC count is 4.6 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 67:
# ...
# --------------------------------------------------------------------------------
# Row 138:
# Patient aged 64.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 97.0 mg/dL, urea is 27.0 mg/dL, serum creatinine is 0.7 mg/dL, sodium is 145.0 mEq/L, potassium is 4.8 mEq/L, hemoglobin is 13.8 g/dL, packed cell volume is 49.0%, WBC count is 6400.0 cells/cumm, RBC count is 4.8 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 139:
# Patient aged 62.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 78.0 mg/dL, urea is 45.0 mg/dL, serum creatinine is 0.6 mg/dL, sodium is 138.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 16.1 g/dL, packed cell volume is 50.0%, WBC count is 5400.0 cells/cumm, RBC count is 5.7 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 140:
# Patient aged 59.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 113.0 mg/dL, urea is 23.0 mg/dL, serum creatinine is 1.1 mg/dL, sodium is 139.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 15.3 g/dL, packed cell volume is 54.0%, WBC count is 6500.0 cells/cumm, RBC count is 4.9 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 141:
# Patient aged 48.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 75.0 mg/dL, urea is 22.0 mg/dL, serum creatinine is 0.8 mg/dL, sodium is 137.0 mEq/L, potassium is 5.0 mEq/L, hemoglobin is 16.8 g/dL, packed cell volume is 51.0%, WBC count is 6000.0 cells/cumm, RBC count is 6.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 142:
# Patient aged 80.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 119.0 mg/dL, urea is 46.0 mg/dL, serum creatinine is 0.7 mg/dL, sodium is 141.0 mEq/L, potassium is 4.9 mEq/L, hemoglobin is 13.9 g/dL, packed cell volume is 49.0%, WBC count is 5100.0 cells/cumm, RBC count is 5.0 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 143:
# Patient aged 57.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 132.0 mg/dL, urea is 18.0 mg/dL, serum creatinine is 1.1 mg/dL, sodium is 150.0 mEq/L, potassium is 4.7 mEq/L, hemoglobin is 15.4 g/dL, packed cell volume is 42.0%, WBC count is 11000.0 cells/cumm, RBC count is 4.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 144:
# Patient aged 63.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 113.0 mg/dL, urea is 25.0 mg/dL, serum creatinine is 0.6 mg/dL, sodium is 146.0 mEq/L, potassium is 4.9 mEq/L, hemoglobin is 16.5 g/dL, packed cell volume is 52.0%, WBC count is 8000.0 cells/cumm, RBC count is 5.1 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 145:
# Patient aged 46.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 100.0 mg/dL, urea is 47.0 mg/dL, serum creatinine is 0.5 mg/dL, sodium is 142.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 16.4 g/dL, packed cell volume is 43.0%, WBC count is 5700.0 cells/cumm, RBC count is 6.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 146:
# Patient aged 15.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 93.0 mg/dL, urea is 17.0 mg/dL, serum creatinine is 0.9 mg/dL, sodium is 136.0 mEq/L, potassium is 3.9 mEq/L, hemoglobin is 16.7 g/dL, packed cell volume is 50.0%, WBC count is 6200.0 cells/cumm, RBC count is 5.2 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 147:
# Patient aged 51.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 94.0 mg/dL, urea is 15.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 144.0 mEq/L, potassium is 3.7 mEq/L, hemoglobin is 15.5 g/dL, packed cell volume is 46.0%, WBC count is 9500.0 cells/cumm, RBC count is 6.4 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 148:
# Patient aged 41.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 112.0 mg/dL, urea is 48.0 mg/dL, serum creatinine is 0.7 mg/dL, sodium is 140.0 mEq/L, potassium is 5.0 mEq/L, hemoglobin is 17.0 g/dL, packed cell volume is 52.0%, WBC count is 7200.0 cells/cumm, RBC count is 5.8 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 149:
# Patient aged 52.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 99.0 mg/dL, urea is 25.0 mg/dL, serum creatinine is 0.8 mg/dL, sodium is 135.0 mEq/L, potassium is 3.7 mEq/L, hemoglobin is 15.0 g/dL, packed cell volume is 52.0%, WBC count is 6300.0 cells/cumm, RBC count is 5.3 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 150:
# Patient aged 36.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 85.0 mg/dL, urea is 16.0 mg/dL, serum creatinine is 1.1 mg/dL, sodium is 142.0 mEq/L, potassium is 4.1 mEq/L, hemoglobin is 15.6 g/dL, packed cell volume is 44.0%, WBC count is 5800.0 cells/cumm, RBC count is 6.3 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 151:
# Patient aged 57.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 133.0 mg/dL, urea is 48.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 147.0 mEq/L, potassium is 4.3 mEq/L, hemoglobin is 14.8 g/dL, packed cell volume is 46.0%, WBC count is 6600.0 cells/cumm, RBC count is 5.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 152:
# Patient aged 43.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 117.0 mg/dL, urea is 45.0 mg/dL, serum creatinine is 0.7 mg/dL, sodium is 141.0 mEq/L, potassium is 4.4 mEq/L, hemoglobin is 13.0 g/dL, packed cell volume is 54.0%, WBC count is 7400.0 cells/cumm, RBC count is 5.4 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 153:
# Patient aged 50.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 137.0 mg/dL, urea is 46.0 mg/dL, serum creatinine is 0.8 mg/dL, sodium is 139.0 mEq/L, potassium is 5.0 mEq/L, hemoglobin is 14.1 g/dL, packed cell volume is 45.0%, WBC count is 9500.0 cells/cumm, RBC count is 4.6 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 154:
# Patient aged 55.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 140.0 mg/dL, urea is 49.0 mg/dL, serum creatinine is 0.5 mg/dL, sodium is 150.0 mEq/L, potassium is 4.9 mEq/L, hemoglobin is 15.7 g/dL, packed cell volume is 47.0%, WBC count is 6700.0 cells/cumm, RBC count is 4.9 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 155:
# Patient aged 42.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 75.0 mg/dL, urea is 31.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 141.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 16.5 g/dL, packed cell volume is 54.0%, WBC count is 7800.0 cells/cumm, RBC count is 6.2 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 156:
# Patient aged 12.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 100.0 mg/dL, urea is 26.0 mg/dL, serum creatinine is 0.6 mg/dL, sodium is 137.0 mEq/L, potassium is 4.4 mEq/L, hemoglobin is 15.8 g/dL, packed cell volume is 49.0%, WBC count is 6600.0 cells/cumm, RBC count is 5.4 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 157:
# Patient aged 17.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 114.0 mg/dL, urea is 50.0 mg/dL, serum creatinine is 1.0 mg/dL, sodium is 135.0 mEq/L, potassium is 4.9 mEq/L, hemoglobin is 14.2 g/dL, packed cell volume is 51.0%, WBC count is 7200.0 cells/cumm, RBC count is 5.9 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 158:
# Patient aged 58.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 131.0 mg/dL, urea is 18.0 mg/dL, serum creatinine is 1.1 mg/dL, sodium is 141.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 15.8 g/dL, packed cell volume is 53.0%, WBC count is 6800.0 cells/cumm, RBC count is 6.1 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------

# %% [markdown]
# # Train/Test Split

# %%
from sklearn.model_selection import train_test_split

# Define x and y
x = df['clinical_text']
y = df['Chronic Kidney Disease (1 = CKD, 0 = Not CKD)']

# 80-20 train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %%
"""
# Save to CSV
x_train.to_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/x_train", index=False)
y_train.to_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/y_train", index=False)
x_test.to_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/x_test", index=False)
y_test.to_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/y_test", index=False)
"""

# %%
# Load the DataFrame
x_train = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/x_train")
y_train = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/y_train")
x_test = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/x_test")
y_test = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/y_test")

# %%
# Train Shape
x_train.shape
# Out:
# (126, 1)

# %%
# Train Label Shape
y_train.shape
# Out:
# (126, 1)

# %%
# Train Count
print(y_train.value_counts())
# Out:
# Chronic Kidney Disease (1 = CKD, 0 = Not CKD)
# 0                                                92
# 1                                                34
# Name: count, dtype: int64

# %%
# Test shape
x_test.shape
# Out:
# (32, 1)

# %%
# Test Label shape
y_test.shape
# Out:
# (32, 1)

# %%
# Test Count
print(y_test.value_counts())
# Out:
# Chronic Kidney Disease (1 = CKD, 0 = Not CKD)
# 0                                                23
# 1                                                 9
# Name: count, dtype: int64

# %% [markdown]
# ### GPT Model (humarin/chatgpt_paraphraser_on_T5_base) for Synthetic Data and Paraphrasing (Optional)

# %%
# Merge x_train and y_train
df = pd.concat([x_train, y_train], axis=1)

# %% [markdown]
# ### Positive cases

# %%
# Filter the rows where CKD == 1
ckd_rows = df[df["Chronic Kidney Disease (1 = CKD, 0 = Not CKD)"] == 1]

# Print clinical texts for CKD patients only
for idx, text in enumerate(ckd_rows["clinical_text"]):
    print(f"Row {idx + 1}:\n{text}\n{'-'*80}")
# Out:
# Row 1:
# Patient aged 40.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.015, albumin level is Moderate, sugar level is High, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 253.0 mg/dL, urea is 150.0 mg/dL, serum creatinine is 11.9 mg/dL, sodium is 132.0 mEq/L, potassium is 5.6 mEq/L, hemoglobin is 10.9 g/dL, packed cell volume is 31.0%, WBC count is 8800.0 cells/cumm, RBC count is 3.4 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 2:
# Patient aged 55.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.01, albumin level is Mild, sugar level is Trace, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 273.0 mg/dL, urea is 235.0 mg/dL, serum creatinine is 14.2 mg/dL, sodium is 132.0 mEq/L, potassium is 3.4 mEq/L, hemoglobin is 8.3 g/dL, packed cell volume is 22.0%, WBC count is 14600.0 cells/cumm, RBC count is 2.9 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 3:
# Patient aged 60.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Very High, red blood cells are abnormal, pus cells are normal, pus cell clumps are not present, bacteria are present, blood glucose is 490.0 mg/dL, urea is 95.0 mg/dL, serum creatinine is 2.7 mg/dL, sodium is 131.0 mEq/L, potassium is 3.8 mEq/L, hemoglobin is 11.5 g/dL, packed cell volume is 35.0%, WBC count is 12000.0 cells/cumm, RBC count is 4.5 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 4:
# Patient aged 56.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.01, albumin level is Severe, sugar level is Trace, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are not present, blood glucose is 176.0 mg/dL, urea is 309.0 mg/dL, serum creatinine is 13.3 mg/dL, sodium is 124.0 mEq/L, potassium is 6.5 mEq/L, hemoglobin is 3.1 g/dL, packed cell volume is 9.0%, WBC count is 5400.0 cells/cumm, RBC count is 2.1 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 5:
# Patient aged 59.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 76.0 mg/dL, urea is 186.0 mg/dL, serum creatinine is 15.0 mg/dL, sodium is 135.0 mEq/L, potassium is 7.6 mEq/L, hemoglobin is 7.1 g/dL, packed cell volume is 22.0%, WBC count is 3800.0 cells/cumm, RBC count is 2.1 million/cumm, has hypertension, has no diabetes, has no coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 6:
# Patient aged 45.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.025, albumin level is Mild, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are not present, blood glucose is 117.0 mg/dL, urea is 52.0 mg/dL, serum creatinine is 2.2 mg/dL, sodium is 136.0 mEq/L, potassium is 3.8 mEq/L, hemoglobin is 10.0 g/dL, packed cell volume is 30.0%, WBC count is 19100.0 cells/cumm, RBC count is 3.7 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 7:
# Patient aged 71.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are present, blood glucose is 219.0 mg/dL, urea is 82.0 mg/dL, serum creatinine is 3.6 mg/dL, sodium is 133.0 mEq/L, potassium is 4.4 mEq/L, hemoglobin is 10.4 g/dL, packed cell volume is 33.0%, WBC count is 5600.0 cells/cumm, RBC count is 3.6 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 8:
# Patient aged 70.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.015, albumin level is Severe, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 118.0 mg/dL, urea is 125.0 mg/dL, serum creatinine is 5.3 mg/dL, sodium is 136.0 mEq/L, potassium is 4.9 mEq/L, hemoglobin is 12.0 g/dL, packed cell volume is 37.0%, WBC count is 8400.0 cells/cumm, RBC count is 8.0 million/cumm, has hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 9:
# Patient aged 71.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.015, albumin level is Severe, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 118.0 mg/dL, urea is 125.0 mg/dL, serum creatinine is 5.3 mg/dL, sodium is 136.0 mEq/L, potassium is 4.9 mEq/L, hemoglobin is 11.4 g/dL, packed cell volume is 35.0%, WBC count is 15200.0 cells/cumm, RBC count is 4.3 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 10:
# Patient aged 63.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.01, albumin level is Mild, sugar level is Mild, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are present, blood glucose is 280.0 mg/dL, urea is 35.0 mg/dL, serum creatinine is 3.2 mg/dL, sodium is 143.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 13.0 g/dL, packed cell volume is 40.0%, WBC count is 9800.0 cells/cumm, RBC count is 4.2 million/cumm, has hypertension, has no diabetes, has coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 11:
# Patient aged 59.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.01, albumin level is Trace, sugar level is Moderate, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 424.0 mg/dL, urea is 55.0 mg/dL, serum creatinine is 1.7 mg/dL, sodium is 138.0 mEq/L, potassium is 4.5 mEq/L, hemoglobin is 12.6 g/dL, packed cell volume is 37.0%, WBC count is 10200.0 cells/cumm, RBC count is 4.1 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 12:
# Patient aged 46.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.01, albumin level is Trace, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 163.0 mg/dL, urea is 92.0 mg/dL, serum creatinine is 3.3 mg/dL, sodium is 141.0 mEq/L, potassium is 4.0 mEq/L, hemoglobin is 9.8 g/dL, packed cell volume is 28.0%, WBC count is 14600.0 cells/cumm, RBC count is 3.2 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 13:
# Patient aged 49.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 129.0 mg/dL, urea is 158.0 mg/dL, serum creatinine is 11.8 mg/dL, sodium is 122.0 mEq/L, potassium is 3.2 mEq/L, hemoglobin is 8.1 g/dL, packed cell volume is 24.0%, WBC count is 9600.0 cells/cumm, RBC count is 3.5 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 14:
# Patient aged 55.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Trace, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are present, blood glucose is 214.0 mg/dL, urea is 73.0 mg/dL, serum creatinine is 3.9 mg/dL, sodium is 137.0 mEq/L, potassium is 4.9 mEq/L, hemoglobin is 10.9 g/dL, packed cell volume is 34.0%, WBC count is 7400.0 cells/cumm, RBC count is 3.7 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 15:
# Patient aged 63.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are present, bacteria are not present, blood glucose is 380.0 mg/dL, urea is 60.0 mg/dL, serum creatinine is 2.7 mg/dL, sodium is 131.0 mEq/L, potassium is 4.2 mEq/L, hemoglobin is 10.8 g/dL, packed cell volume is 32.0%, WBC count is 4500.0 cells/cumm, RBC count is 3.8 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 16:
# Patient aged 6.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.01, albumin level is Severe, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are present, blood glucose is 94.0 mg/dL, urea is 67.0 mg/dL, serum creatinine is 1.0 mg/dL, sodium is 135.0 mEq/L, potassium is 4.9 mEq/L, hemoglobin is 9.9 g/dL, packed cell volume is 30.0%, WBC count is 16700.0 cells/cumm, RBC count is 4.8 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is poor, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 17:
# Patient aged 69.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.01, albumin level is Severe, sugar level is Moderate, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are present, blood glucose is 214.0 mg/dL, urea is 96.0 mg/dL, serum creatinine is 6.3 mg/dL, sodium is 120.0 mEq/L, potassium is 3.9 mEq/L, hemoglobin is 9.4 g/dL, packed cell volume is 28.0%, WBC count is 11500.0 cells/cumm, RBC count is 3.3 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 18:
# Patient aged 48.0 years with blood pressure of 110.0 mm Hg, specific gravity of urine is 1.015, albumin level is Moderate, sugar level is Normal, red blood cells are abnormal, pus cells are normal, pus cell clumps are present, bacteria are not present, blood glucose is 106.0 mg/dL, urea is 215.0 mg/dL, serum creatinine is 15.2 mg/dL, sodium is 120.0 mEq/L, potassium is 5.7 mEq/L, hemoglobin is 8.6 g/dL, packed cell volume is 26.0%, WBC count is 5000.0 cells/cumm, RBC count is 2.5 million/cumm, has hypertension, has no diabetes, has coronary artery disease, appetite is good, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 19:
# Patient aged 60.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Trace, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are not present, blood glucose is 288.0 mg/dL, urea is 36.0 mg/dL, serum creatinine is 1.7 mg/dL, sodium is 130.0 mEq/L, potassium is 3.0 mEq/L, hemoglobin is 7.9 g/dL, packed cell volume is 25.0%, WBC count is 15200.0 cells/cumm, RBC count is 3.0 million/cumm, has hypertension, has no diabetes, has no coronary artery disease, appetite is poor, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 20:
# Patient aged 48.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Severe, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 95.0 mg/dL, urea is 163.0 mg/dL, serum creatinine is 7.7 mg/dL, sodium is 136.0 mEq/L, potassium is 3.8 mEq/L, hemoglobin is 9.8 g/dL, packed cell volume is 32.0%, WBC count is 6900.0 cells/cumm, RBC count is 3.4 million/cumm, has hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 21:
# Patient aged 83.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.02, albumin level is Moderate, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 102.0 mg/dL, urea is 60.0 mg/dL, serum creatinine is 2.6 mg/dL, sodium is 115.0 mEq/L, potassium is 5.7 mEq/L, hemoglobin is 8.7 g/dL, packed cell volume is 26.0%, WBC count is 12800.0 cells/cumm, RBC count is 3.1 million/cumm, has hypertension, has no diabetes, has no coronary artery disease, appetite is poor, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 22:
# Patient aged 60.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.01, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 105.0 mg/dL, urea is 53.0 mg/dL, serum creatinine is 2.3 mg/dL, sodium is 136.0 mEq/L, potassium is 5.2 mEq/L, hemoglobin is 11.1 g/dL, packed cell volume is 33.0%, WBC count is 10500.0 cells/cumm, RBC count is 4.1 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 23:
# Patient aged 48.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.005, albumin level is Severe, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are not present, blood glucose is 117.0 mg/dL, urea is 56.0 mg/dL, serum creatinine is 3.8 mg/dL, sodium is 111.0 mEq/L, potassium is 2.5 mEq/L, hemoglobin is 11.2 g/dL, packed cell volume is 32.0%, WBC count is 6700.0 cells/cumm, RBC count is 3.9 million/cumm, has hypertension, has no diabetes, has no coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 24:
# Patient aged 56.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.015, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 129.0 mg/dL, urea is 107.0 mg/dL, serum creatinine is 6.7 mg/dL, sodium is 131.0 mEq/L, potassium is 4.8 mEq/L, hemoglobin is 9.1 g/dL, packed cell volume is 29.0%, WBC count is 6400.0 cells/cumm, RBC count is 3.4 million/cumm, has hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 25:
# Patient aged 73.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Mild, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are present, bacteria are not present, blood glucose is 295.0 mg/dL, urea is 90.0 mg/dL, serum creatinine is 5.6 mg/dL, sodium is 140.0 mEq/L, potassium is 2.9 mEq/L, hemoglobin is 9.2 g/dL, packed cell volume is 30.0%, WBC count is 7000.0 cells/cumm, RBC count is 3.2 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is poor, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 26:
# Patient aged 53.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.02, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are present, bacteria are not present, blood glucose is 70.0 mg/dL, urea is 107.0 mg/dL, serum creatinine is 7.2 mg/dL, sodium is 114.0 mEq/L, potassium is 3.7 mEq/L, hemoglobin is 9.5 g/dL, packed cell volume is 29.0%, WBC count is 12100.0 cells/cumm, RBC count is 3.7 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 27:
# Patient aged 68.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Mild, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are present, blood glucose is 157.0 mg/dL, urea is 90.0 mg/dL, serum creatinine is 4.1 mg/dL, sodium is 130.0 mEq/L, potassium is 6.4 mEq/L, hemoglobin is 5.6 g/dL, packed cell volume is 16.0%, WBC count is 11000.0 cells/cumm, RBC count is 2.6 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is poor, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 28:
# Patient aged 52.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.015, albumin level is Severe, sugar level is Moderate, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 224.0 mg/dL, urea is 166.0 mg/dL, serum creatinine is 5.6 mg/dL, sodium is 133.0 mEq/L, potassium is 47.0 mEq/L, hemoglobin is 8.1 g/dL, packed cell volume is 23.0%, WBC count is 5000.0 cells/cumm, RBC count is 2.9 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 29:
# Patient aged 64.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.01, albumin level is Severe, sugar level is Trace, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are present, blood glucose is 239.0 mg/dL, urea is 58.0 mg/dL, serum creatinine is 4.3 mg/dL, sodium is 137.0 mEq/L, potassium is 5.4 mEq/L, hemoglobin is 9.5 g/dL, packed cell volume is 29.0%, WBC count is 7500.0 cells/cumm, RBC count is 3.4 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 30:
# Patient aged 50.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.01, albumin level is Mild, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are present, blood glucose is 128.0 mg/dL, urea is 208.0 mg/dL, serum creatinine is 9.2 mg/dL, sodium is 134.0 mEq/L, potassium is 4.8 mEq/L, hemoglobin is 8.2 g/dL, packed cell volume is 22.0%, WBC count is 16300.0 cells/cumm, RBC count is 2.7 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 31:
# Patient aged 56.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.015, albumin level is Severe, sugar level is Trace, red blood cells are abnormal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 210.0 mg/dL, urea is 26.0 mg/dL, serum creatinine is 1.7 mg/dL, sodium is 136.0 mEq/L, potassium is 3.8 mEq/L, hemoglobin is 16.1 g/dL, packed cell volume is 52.0%, WBC count is 12500.0 cells/cumm, RBC count is 5.6 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 32:
# Patient aged 62.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.025, albumin level is Moderate, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 122.0 mg/dL, urea is 42.0 mg/dL, serum creatinine is 1.7 mg/dL, sodium is 136.0 mEq/L, potassium is 4.7 mEq/L, hemoglobin is 12.6 g/dL, packed cell volume is 39.0%, WBC count is 7900.0 cells/cumm, RBC count is 3.9 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 33:
# Patient aged 59.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.01, albumin level is Trace, sugar level is Normal, red blood cells are abnormal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 303.0 mg/dL, urea is 35.0 mg/dL, serum creatinine is 1.3 mg/dL, sodium is 122.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 10.4 g/dL, packed cell volume is 35.0%, WBC count is 10900.0 cells/cumm, RBC count is 4.3 million/cumm, has no hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 34:
# Patient aged 64.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.015, albumin level is Severe, sugar level is Mild, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are present, blood glucose is 163.0 mg/dL, urea is 54.0 mg/dL, serum creatinine is 7.2 mg/dL, sodium is 140.0 mEq/L, potassium is 4.6 mEq/L, hemoglobin is 7.9 g/dL, packed cell volume is 26.0%, WBC count is 7500.0 cells/cumm, RBC count is 3.4 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------

# %%
df.head()
# Out:
#                                        clinical_text  \
# 0  Patient aged 48.0 years with blood pressure of...
# 1  Patient aged 55.0 years with blood pressure of...
# 2  Patient aged 17.0 years with blood pressure of...
# 3  Patient aged 64.0 years with blood pressure of...
# 4  Patient aged 40.0 years with blood pressure of...
#
#    Chronic Kidney Disease (1 = CKD, 0 = Not CKD)
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              1

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.5.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.1-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 13.8 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.7 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 20.4 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 18.3 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed datasets-3.5.1 dill-0.3.8 fsspec-2025.3.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
import torch
from transformers import pipeline

# Step 1: Filter class 1 examples
df_class_1 = df[df["Chronic Kidney Disease (1 = CKD, 0 = Not CKD)"] == 1]
clinical_sentences_class_1 = df_class_1["clinical_text"].tolist()

# Step 2: Calculate how many paraphrases we need
num_class_0 = df[df["Chronic Kidney Disease (1 = CKD, 0 = Not CKD)"] == 0].shape[0]
num_class_1 = len(clinical_sentences_class_1)
num_needed = num_class_0 - num_class_1

# Step 3: Load GPT (or equivalent medically fine-tuned model for paraphrasing)
paraphrase_pipe = pipeline(
    "text2text-generation",
    model="humarin/chatgpt_paraphraser_on_T5_base",  # This is T5-based, tuned for paraphrasing
    device=0 if torch.cuda.is_available() else -1
)

# Step 4: Generate paraphrases
synthetic_paraphrases = []
num_generated = 0
i = 0

while num_generated < num_needed:
    sentence = clinical_sentences_class_1[i % num_class_1]
    prompt = f"Paraphrase medically accurately: {sentence}"
    result = paraphrase_pipe(prompt, max_length=512, num_return_sequences=1, do_sample=True)
    paraphrased_text = result[0]['generated_text']
    synthetic_paraphrases.append(paraphrased_text)
    num_generated += 1
    i += 1

# Step 5: Store separately in a DataFrame
df_synthetic = pd.DataFrame({
    "clinical_text": synthetic_paraphrases,
    "Chronic Kidney Disease (1 = CKD, 0 = Not CKD)": [1] * len(synthetic_paraphrases)
})

print(f"Generated {len(df_synthetic)} paraphrased class 1 samples.")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Device set to use cuda:0
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Generated 58 paraphrased class 1 samples.

# %%
load_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/Synthetic/df_synthetic.csv"

# Load the DataFrame
df_synthetic = pd.read_csv(load_path, encoding='ISO-8859-1')

# Preview
df_synthetic.head()
# Out:
#                                        clinical_text  \
# 0  A 40-year-old patient with hypertension and di...
# 1  The patient, aged 55, has low blood pressure (...
# 2  A 60-year-old patient with hypertension and di...
# 3  A 56-year-old patient presents with a blood pr...
# 4  A 59-year-old patient with blood pressure of 7...
#
#    Chronic Kidney Disease (1 = CKD, 0 = Not CKD)
# 0                                              1
# 1                                              1
# 2                                              1
# 3                                              1
# 4                                              1

# %%
# Data
df_synthetic.head()
# Out:
#                                        clinical_text  \
# 0  A 48.0-year-old patient presents with a blood ...
# 1  The patient exhibits abnormal red and pus cell...
# 2  Urinalysis reveals a specific gravity of 1.01,...
# 3  The patient presents with a urine specific gra...
# 4  Urine examination shows a specific gravity of ...
#
#    Chronic Kidney Disease (1 = CKD, 0 = Not CKD)
# 0                                              1
# 1                                              1
# 2                                              1
# 3                                              1
# 4                                              1

# %%
# Size
df_synthetic.shape
# Out:
# (58, 2)

# %%
# Visualizing Rows
for idx, text in enumerate(df_synthetic["clinical_text"]):
    print(f"Row {idx + 1}:\n{text}\n{'-'*80}")
# Out:
# Row 1:
# A 40-year-old patient with hypertension and diabetes mellitus presents with a blood pressure of 70 mm Hg and a moderate albumin level. The sugar level is high at 253 mg/dL, and red blood cells, pus cells, pus cell clumps, and bacteria in the urine are normal. Urea is elevated at 150 mg/dL, and serum creatinine is critically high at 11.9 mg/dL. Sodium is 132 mEq/L, and potassium is 5.6 mEq/L. Hemoglobin is 10.9 g/dL, with a packed cell volume of 31%. WBC count is 8,800 cells/cumm, and RBC count is 3.4 million/cumm. The patient has a poor appetite, pedal edema, but no anemia and no coronary artery disease.
# --------------------------------------------------------------------------------
# Row 2:
# The patient, aged 55, has low blood pressure (90 mm Hg), mild albumin in urine, and high blood glucose (273 mg/dL), indicating poor diabetes control. Kidney function is severely impaired with elevated urea (235 mg/dL) and serum creatinine (14.2 mg/dL), suggesting possible kidney failure. Anemia is present (hemoglobin 8.3 g/dL, packed cell volume 22%), with elevated WBC (14,600 cells/cumm), potentially indicating infection. Sodium is low (132 mEq/L), and potassium is normal (3.4 mEq/L). The patient has hypertension, diabetes, pedal edema, and a poor appetite. Immediate medical intervention is needed for kidney function, diabetes, and anemia management.
# --------------------------------------------------------------------------------
# Row 3:
# A 60-year-old patient with hypertension and diabetes mellitus presents with a blood pressure of 90 mm Hg and moderate albumin levels. The sugar level is very high, and red blood cells are abnormal. Pus cells are normal, but bacteria are present in the urine. Blood glucose is significantly elevated at 490 mg/dL, with urea at 95 mg/dL and serum creatinine at 2.7 mg/dL. Sodium is 131 mEq/L, potassium is 3.8 mEq/L, and hemoglobin is 11.5 g/dL with a packed cell volume of 35%. WBC count is 12,000 cells/cumm, and RBC count is 4.5 million/cumm. The patient has a good appetite, no pedal edema, and does not have anemia or coronary artery disease.
# --------------------------------------------------------------------------------
# Row 4:
# A 56-year-old patient presents with a blood pressure of 90 mm Hg and a specific gravity of urine of 1.01, showing severe albuminuria. The patient's sugar level is trace, with a blood glucose of 176 mg/dL, indicating some level of blood sugar imbalance. Red blood cells are normal, but pus cells are abnormal, and pus cell clumps are present, though no bacteria are detected. Urea is significantly elevated at 309 mg/dL, and serum creatinine is high at 13.3 mg/dL, suggesting severe kidney dysfunction. Sodium is low at 124 mEq/L, and potassium is elevated at 6.5 mEq/L, which may indicate electrolyte imbalances due to kidney impairment. Hemoglobin is critically low at 3.1 g/dL, with a packed cell volume of 9%, indicating severe anemia. The white blood cell count is 5,400 cells/cumm, and the red blood cell count is 2.1 million/cumm, both of which are lower than normal. The patient has hypertension and diabetes mellitus, but no coronary artery disease. Appetite is poor, and pedal edema is present, likely due to kidney-related issues. Given the severe anemia, electrolyte disturbances, and advanced kidney dysfunction, urgent medical intervention and close monitoring of the patients renal function, blood pressure, and electrolyte levels are essential to prevent further complications.
# --------------------------------------------------------------------------------
# Row 5:
# A 59-year-old patient with blood pressure of 70 mm Hg and moderate albuminuria presents with abnormal pus cells, no pus cell clumps, and no bacteria in urine. Blood glucose is 76 mg/dL, serum creatinine is elevated at 15.0 mg/dL, and urea is 186 mg/dL. Sodium is 135 mEq/L, potassium is 7.6 mEq/L, hemoglobin is low at 7.1 g/dL, and packed cell volume is 22%. WBC count is 3,800 cells/cumm, and RBC count is 2.1 million/cumm. The patient has hypertension, no diabetes, no coronary artery disease, poor appetite, pedal edema, and anemia.
# --------------------------------------------------------------------------------
# Row 6:
# The patient, aged 71.0 years, has a blood pressure of 70.0 mm Hg, specific gravity of urine at 1.01, and a moderate albumin level. The sugar level is normal, while red blood cells are normal, but pus cells are abnormal, with pus cell clumps and bacteria present. Blood glucose is elevated at 219.0 mg/dL, urea is 82.0 mg/dL, and serum creatinine is 3.6 mg/dL. Sodium is 133.0 mEq/L, potassium is 4.4 mEq/L, hemoglobin is 10.4 g/dL, and packed cell volume is 33.0%. The WBC count is 5,600 cells/cumm, and RBC count is 3.6 million/cumm. The patient has hypertension, diabetes mellitus, and coronary artery disease, with a good appetite and no pedal edema or anemia. The presence of pus cell clumps and bacteria along with elevated blood glucose and serum creatinine levels suggests potential kidney dysfunction and infection, requiring further assessment.
# --------------------------------------------------------------------------------
# Row 7:
# At 45 years old, this patient presents with mild albumin levels and normal red blood cells. Blood glucose is within the normal range at 117 mg/dL, and the serum creatinine level is 2.2 mg/dL. The patient has no hypertension, diabetes, or coronary artery disease, and their appetite is good. Hemoglobin is slightly low at 10.0 g/dL, but packed cell volume is at 30%. WBC count is elevated at 19,100 cells/cumm, and RBC count is 3.7 million/cumm. Sodium is normal at 136 mEq/L, while potassium is slightly lower at 3.8 mEq/L. The urine test shows abnormal pus cells, pus cell clumps present, and no bacteria. Pedal edema is absent, and the patient does not have anemia.
# --------------------------------------------------------------------------------
# Row 8:
# The patient, aged 70.0 years, presents with a blood pressure of 100.0 mm Hg and a specific gravity of urine at 1.015. The albumin level is severe, indicating significant kidney dysfunction. The sugar level is normal with a blood glucose of 118.0 mg/dL. Red blood cells and pus cells are normal, and there are no pus cell clumps or bacteria present, suggesting no active infection. Urea is elevated at 125.0 mg/dL, and serum creatinine is also high at 5.3 mg/dL, indicating impaired kidney function. Sodium and potassium levels are within the normal range at 136.0 mEq/L and 4.9 mEq/L, respectively. Hemoglobin is 12.0 g/dL, and packed cell volume is 37.0%, suggesting no anemia. The WBC count is normal at 8,400 cells/cumm, and the RBC count is high at 8.0 million/cumm, which may indicate a compensatory response to kidney disease. The patient has hypertension but no diabetes or coronary artery disease. The good appetite and absence of pedal edema suggest a relatively stable condition, but the severe albumin level and kidney impairment warrant close monitoring and management of the renal function.
# --------------------------------------------------------------------------------
# Row 9:
# The patient, aged 71.0 years, presents with a blood pressure of 60.0 mm Hg, specific gravity of urine at 1.015, and a severe albumin level. The sugar level is normal, with red blood cells and pus cells appearing normal, and no pus cell clumps or bacteria present. Blood glucose is 118.0 mg/dL, urea is 125.0 mg/dL, and serum creatinine is elevated at 5.3 mg/dL, which may suggest renal impairment. Sodium is 136.0 mEq/L, potassium is 4.9 mEq/L, hemoglobin is 11.4 g/dL, and packed cell volume is 35.0%, indicating mild anemia. The WBC count is elevated at 15,200 cells/cumm, and RBC count is 4.3 million/cumm. The patient has hypertension, diabetes mellitus, no coronary artery disease, a poor appetite, and presents with pedal edema, which might indicate fluid retention or worsening renal function. The combination of elevated serum creatinine, poor appetite, and pedal edema points to significant renal involvement requiring further evaluation and management.
# --------------------------------------------------------------------------------
# Row 10:
# The patient, aged 63.0 years, has a blood pressure of 100.0 mm Hg and a urine specific gravity of 1.01. The albumin level is mild, with a mild sugar level. Red blood cells and pus cells are normal, and no pus cell clumps are present, but bacteria are present. Blood glucose is 280.0 mg/dL, urea is 35.0 mg/dL, and serum creatinine is 3.2 mg/dL. Sodium is 143.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 13.0 g/dL, and packed cell volume is 40.0%. White blood cell count is 9800.0 cells/cumm, and red blood cell count is 4.2 million/cumm. The patient has hypertension, no diabetes, coronary artery disease, good appetite, no pedal edema, and no anemia.
# --------------------------------------------------------------------------------
# Row 11:
# A 59-year-old patient presents with a blood pressure of 70 mm Hg and a specific gravity of urine of 1.01, with a trace level of albumin. The patients sugar level is moderate, and blood glucose is elevated at 424 mg/dL, indicating poor blood sugar control. Abnormal red blood cells and pus cells are present, but no pus cell clumps or bacteria are detected. Urea is moderately elevated at 55 mg/dL, and serum creatinine is 1.7 mg/dL, suggesting mild kidney dysfunction. Sodium is within normal limits at 138 mEq/L, and potassium is also within the normal range at 4.5 mEq/L. Hemoglobin is 12.6 g/dL with a packed cell volume of 37%, indicating no anemia. The white blood cell count is slightly elevated at 10,200 cells/cumm, while the red blood cell count is 4.1 million/cumm, which is within the normal range. The patient has hypertension, diabetes mellitus, and coronary artery disease. Appetite is good, and there is no pedal edema present. Given the elevated blood glucose, kidney function, and cardiovascular risk factors, this patient may require further monitoring and management of their diabetes and hypertension to prevent complications.
# --------------------------------------------------------------------------------
# Row 12:
# The patient, aged 46.0 years, presents with a blood pressure of 60.0 mm Hg. Urine analysis reveals a specific gravity of 1.01, with trace albumin levels and normal sugar. Both red and pus cells are normal, and no pus cell clumps or bacteria are present. Blood tests show a glucose level of 163.0 mg/dL, urea at 92.0 mg/dL, and serum creatinine at 3.3 mg/dL. Sodium is measured at 141.0 mEq/L, and potassium at 4.0 mEq/L. Hemoglobin is at 9.8 g/dL, with a packed cell volume of 28.0%. The white blood cell count is elevated at 14600.0 cells/cumm, while the red blood cell count is 3.2 million/cumm. The patient has hypertension and diabetes mellitus but no coronary artery disease. Appetite is good, pedal edema is absent, and there is no anemia.
# --------------------------------------------------------------------------------
# Row 13:
# A 49-year-old patient with blood pressure of 100 mm Hg presents with moderate albumin levels, normal sugar, and abnormal red blood cells and pus cells in the urine. No pus cell clumps are observed, and bacteria are absent. Blood glucose is 129 mg/dL, while urea is elevated at 158 mg/dL, and serum creatinine is high at 11.8 mg/dL. Sodium is 122 mEq/L, and potassium is 3.2 mEq/L. Hemoglobin is low at 8.1 g/dL, and the packed cell volume is 24%. The WBC count is 9,600 cells/cumm, with an RBC count of 3.5 million/cumm. The patient has hypertension and diabetes mellitus, but no coronary artery disease. Appetite is poor, pedal edema is present, and the patient is diagnosed with anemia.
# --------------------------------------------------------------------------------
# Row 14:
# A 55-year-old patient with hypertension and diabetes mellitus presents with a blood pressure of 80 mm Hg and moderate albumin levels. The sugar level is trace, and red blood cells are normal. Pus cells are abnormal, with pus cell clumps and bacteria present in the urine. Blood glucose is elevated at 214 mg/dL, and urea is 73 mg/dL, with a serum creatinine of 3.9 mg/dL. Sodium is 137 mEq/L, potassium is 4.9 mEq/L, and hemoglobin is 10.9 g/dL with a packed cell volume of 34%. WBC count is 7,400 cells/cumm, and RBC count is 3.7 million/cumm. The patient has a good appetite, pedal edema, but no anemia and no coronary artery disease.
# --------------------------------------------------------------------------------
# Row 15:
# The patient, aged 59.0 years, has a blood pressure of 70.0 mm Hg and a urine specific gravity of 1.01. The albumin level is moderate, with normal sugar levels. Red blood cells are normal, but pus cells are abnormal; no pus cell clumps or bacteria are present. Blood glucose is 76.0 mg/dL, urea is 186.0 mg/dL, and serum creatinine is 15.0 mg/dL. Sodium is 135.0 mEq/L, and potassium is 7.6 mEq/L. Hemoglobin is 7.1 g/dL, with a packed cell volume of 22.0%. White blood cell count is 3800.0 cells/cumm, and red blood cell count is 2.1 million/cumm. The patient has hypertension, no diabetes, no coronary artery disease, poor appetite, pedal edema, and has anemia.
# --------------------------------------------------------------------------------
# Row 16:
# A 63-year-old patient with a blood pressure of 100 mm Hg and mild levels of albumin and sugar in the urine presents with normal red and pus cells, no pus cell clumps, and the presence of bacteria in the urine. Blood glucose is elevated at 280 mg/dL. Renal function markers show a serum creatinine of 3.2 mg/dL and urea at 35 mg/dL. Electrolytes are within normal range (sodium 143 mEq/L, potassium 3.5 mEq/L). Hemoglobin is 13.0 g/dL, packed cell volume is 40%, WBC count is 9,800 cells/cumm, and RBC count is 4.2 million/cumm. The patient has hypertension and coronary artery disease, no diabetes, good appetite, no pedal edema, and no anemia.
# --------------------------------------------------------------------------------
# Row 17:
# Urinalysis reveals a specific gravity of 1.01, moderate albumin levels, normal sugar, and abnormalities in both red and pus cells, with pus cell clumps detected and no bacteria present. Blood investigations show an elevated glucose level of 380.0 mg/dL, urea at 60.0 mg/dL, and serum creatinine at 2.7 mg/dL. Electrolyte readings include sodium at 131.0 mEq/L and potassium at 4.2 mEq/L. Hematological findings show hemoglobin at 10.8 g/dL, a packed cell volume of 32.0%, a white blood cell count of 4500.0 cells/cumm, and red blood cells at 3.8 million/cumm. The patient has a history of hypertension and diabetes mellitus but no coronary artery disease. Appetite is reported as poor, and pedal edema is present, though no anemia is observed. The patient is 63.0 years old and presents with a low blood pressure of 70.0 mm Hg.
# --------------------------------------------------------------------------------
# Row 18:
# A 6-year-old patient with a blood pressure of 60 mm Hg presents with severe albumin levels and normal sugar. Red blood cells and pus cells are abnormal in the urine, with bacteria present, though no pus cell clumps are found. Blood glucose is 94 mg/dL, while serum creatinine is normal at 1.0 mg/dL. The urea level is elevated at 67 mg/dL. Sodium is 135 mEq/L, and potassium is 4.9 mEq/L. Hemoglobin is 9.9 g/dL, with a packed cell volume of 30%. The WBC count is high at 16,700 cells/cumm, and the RBC count is 4.8 million/cumm. There is no hypertension, diabetes, or coronary artery disease, though the appetite is poor. Pedal edema is absent, and the patient does not have anemia.
# --------------------------------------------------------------------------------
# Row 19:
# A 69-year-old patient presents with low blood pressure of 70 mm Hg, specific gravity of urine at 1.01, severe albumin levels, abnormal pus cells, and the presence of pus cell clumps and bacteria. The blood glucose level is moderate at 214 mg/dL, while urea is elevated at 96 mg/dL, and serum creatinine is high at 6.3 mg/dL, indicating impaired kidney function. Electrolytes show a low sodium level of 120 mEq/L, with potassium at a normal level of 3.9 mEq/L. Hemoglobin is 9.4 g/dL, indicating anemia, while the packed cell volume is 28%, and the WBC count is elevated at 11,500 cells/cumm, with a low RBC count of 3.3 million/cumm. The patient has a history of hypertension, diabetes mellitus, and coronary artery disease. Other symptoms include good appetite, the presence of pedal edema, and anemia. This patient likely has chronic kidney disease (CKD), with complications stemming from diabetes and hypertension, requiring management of kidney function, blood glucose levels, and associated cardiovascular risks.
# --------------------------------------------------------------------------------
# Row 20:
# A 46-year-old patient with a blood pressure of 60 mm Hg and trace albuminuria has normal red and pus cells in urine, with no pus cell clumps or bacteria. Blood glucose is elevated at 163 mg/dL, serum creatinine is 3.3 mg/dL, and urea is 92 mg/dL. Sodium is 141 mEq/L, potassium is normal at 4.0 mEq/L, hemoglobin is 9.8 g/dL, and packed cell volume is 28%. WBC count is 14,600 cells/cumm, and RBC count is 3.2 million/cumm. The patient has hypertension, diabetes mellitus, and no coronary artery disease, with a good appetite and no pedal edema or anemia.
# --------------------------------------------------------------------------------
# Row 21:
# A 48-year-old patient presents with a blood pressure of 110 mm Hg and a specific gravity of urine of 1.015, indicating moderate albumin levels. The patients sugar level is normal at 106 mg/dL. Abnormal red blood cells are observed, while pus cells are normal, with pus cell clumps present but no bacteria detected. Urea is elevated at 215 mg/dL, and serum creatinine is significantly high at 15.2 mg/dL, suggesting severe kidney impairment. Sodium levels are low at 120 mEq/L, and potassium is elevated at 5.7 mEq/L. The patient has anemia, as indicated by a hemoglobin level of 8.6 g/dL and a packed cell volume of 26%. The white blood cell count is within normal limits at 5000 cells/cumm, but the red blood cell count is low at 2.5 million/cumm. The patient has hypertension, coronary artery disease, and no diabetes. Appetite is good, and there is no pedal edema. Given the significant kidney dysfunction indicated by elevated urea and serum creatinine, along with the presence of anemia, this patient may require further investigation and treatment for chronic kidney disease and cardiovascular concerns.
# --------------------------------------------------------------------------------
# Row 22:
# The patient, aged 60.0 years, presents with a blood pressure of 60.0 mm Hg, which is notably low and may indicate hypotension. The specific gravity of urine is 1.01, suggesting normal hydration levels. The albumin level is moderate, which may indicate some degree of kidney dysfunction. The sugar level is trace, and the blood glucose is elevated at 288.0 mg/dL, indicating hyperglycemia, although the patient does not have a confirmed diagnosis of diabetes. Red blood cells are normal, but pus cells are abnormal, with pus cell clumps present. There is no bacterial presence, which suggests a possible urinary tract issue or mild infection. Urea is within a slightly elevated range at 36.0 mg/dL, and serum creatinine is 1.7 mg/dL, which is a moderate indication of kidney function impairment. Sodium is slightly low at 130.0 mEq/L, and potassium is also low at 3.0 mEq/L, which could affect cardiovascular and muscle function. Hemoglobin is 7.9 g/dL, and packed cell volume is 25.0%, both indicating anemia, which may be contributing to fatigue and other symptoms. The WBC count is elevated at 15,200 cells/cumm, which could suggest inflammation or infection. The RBC count is 3.0 million/cumm, which is on the lower end. The patient has hypertension but no diabetes or coronary artery disease. Poor appetite and the absence of pedal edema could be indicative of a more severe underlying issue. The combination of low blood pressure, anemia, and abnormal kidney function, along with the presence of pus cells and elevated WBC count, suggests the need for further evaluation, especially for potential infections, kidney disease, or other systemic concerns.
# --------------------------------------------------------------------------------
# Row 23:
# A 63-year-old patient has moderate albuminuria and abnormal red blood cells and pus cells in the urine, with pus cell clumps present, suggesting potential kidney issues. Blood pressure is low at 70 mm Hg, and blood glucose is elevated at 380 mg/dL, indicating poor diabetes control. Serum creatinine is 2.7 mg/dL, and urea is 60 mg/dL, which may indicate kidney dysfunction. Sodium is 131 mEq/L, and potassium is within normal limits at 4.2 mEq/L. Hemoglobin is 10.8 g/dL with a packed cell volume of 32%, which does not indicate anemia. The white blood cell count is 4,500 cells/cumm. The patient has hypertension and diabetes mellitus but no coronary artery disease. Pedal edema is present, and appetite is poor.
# --------------------------------------------------------------------------------
# Row 24:
# Urinalysis reveals a specific gravity of 1.025 with severe albuminuria and normal sugar levels. The urine contains abnormal pus cells, while red blood cells appear normal; neither pus cell clumps nor bacteria are present. Blood work shows a glucose level of 95.0 mg/dL, urea at 163.0 mg/dL, and a notably elevated serum creatinine of 7.7 mg/dL. Electrolyte levels include sodium at 136.0 mEq/L and potassium at 3.8 mEq/L. Hemoglobin is moderately low at 9.8 g/dL, with a packed cell volume of 32.0%. The white blood cell count is 6900.0 cells/cumm and the red blood cell count is 3.4 million/cumm. The patient has hypertension but no history of diabetes mellitus or coronary artery disease. Appetite is reported as good, there is no pedal edema, and anemia is present. The individual is 48.0 years old and has a blood pressure of 80.0 mm Hg.
# --------------------------------------------------------------------------------
# Row 25:
# The patient, aged 83 years, presents with low blood pressure (70 mm Hg) and elevated serum creatinine (2.6 mg/dL) and urea (60 mg/dL), suggesting impaired kidney function. Blood glucose is within normal range (102 mg/dL). Urine analysis shows moderate albumin levels and specific gravity of 1.02. Sodium is low (115 mEq/L) and potassium is elevated (5.7 mEq/L). Hemoglobin is 8.7 g/dL with a packed cell volume of 26%, indicating anemia. WBC count is elevated at 12,800 cells/cumm, and RBC count is 3.1 million/cumm. The patient has hypertension, no diabetes, and no coronary artery disease. Their appetite is poor, and there is no pedal edema.
# --------------------------------------------------------------------------------
# Row 26:
# The patient, aged 60.0 years, presents with a blood pressure of 90.0 mm Hg and a specific gravity of urine at 1.01. The albumin level is mild, indicating a potential early stage of kidney dysfunction. The sugar level is normal, with a blood glucose of 105.0 mg/dL. Red blood cells are abnormal, which may suggest some degree of hematuria or underlying kidney issues. Pus cells are normal, and there are no pus cell clumps or bacteria, indicating no signs of infection. Urea is slightly elevated at 53.0 mg/dL, and serum creatinine is also mildly elevated at 2.3 mg/dL, suggesting possible early-stage kidney impairment. Sodium and potassium levels are within the normal range at 136.0 mEq/L and 5.2 mEq/L, respectively. Hemoglobin is 11.1 g/dL, and packed cell volume is 33.0%, both within reasonable limits, but approaching the lower end. The WBC count is slightly elevated at 10,500 cells/cumm, which could indicate mild inflammation or infection, although no bacterial presence is noted. The RBC count is 4.1 million/cumm, which is within normal range. The patient has no hypertension, diabetes, or coronary artery disease. The good appetite and absence of pedal edema suggest a relatively stable clinical condition, but the mild kidney impairment and abnormal red blood cells warrant continued monitoring.
# --------------------------------------------------------------------------------
# Row 27:
# A 48.0-year-old patient presents with a blood pressure of 70.0 mm Hg. Urinalysis shows a specific gravity of 1.005, a severely elevated albumin level, and normal sugar levels. Red blood cells in the urine appear normal, while pus cells are noted to be abnormal, and pus cell clumps are present. No bacterial presence is detected. Laboratory findings reveal a blood glucose level of 117.0 mg/dL, urea at 56.0 mg/dL, and serum creatinine at 3.8 mg/dL. Electrolyte analysis shows sodium at 111.0 mEq/L and potassium at 2.5 mEq/L. Hemoglobin is measured at 11.2 g/dL, with a packed cell volume of 32.0%. The white blood cell count is 6700.0 cells/cumm and red blood cell count is 3.9 million/cumm. The patient has a history of hypertension but no diabetes or coronary artery disease. Appetite is reported as poor, pedal edema is observed, and anemia is present.
# --------------------------------------------------------------------------------
# Row 28:
# The patient, aged 56.0 years, presents with a blood pressure of 90.0 mm Hg. Urine analysis shows a specific gravity of 1.015, with mild albumin levels and normal sugar. Both red and pus cells are abnormal, although no pus cell clumps or bacteria are detected. Blood tests show a glucose level of 129.0 mg/dL, urea at 107.0 mg/dL, and serum creatinine at 6.7 mg/dL. Sodium is measured at 131.0 mEq/L, and potassium at 4.8 mEq/L. Hemoglobin is 9.1 g/dL, with a packed cell volume of 29.0%. The white blood cell count is 6400.0 cells/cumm, and red blood cell count is 3.4 million/cumm. The patient has hypertension, no diabetes, and no coronary artery disease. Appetite is good, pedal edema is absent, and there is no anemia.
# --------------------------------------------------------------------------------
# Row 29:
# The patient, aged 73.0 years, has a blood pressure of 100.0 mm Hg, specific gravity of urine at 1.01, and a moderate albumin level. The sugar level is mild, while red blood cells and pus cells are abnormal, with pus cell clumps present, though bacteria are absent. Blood glucose is significantly elevated at 295.0 mg/dL, urea is 90.0 mg/dL, and serum creatinine is elevated at 5.6 mg/dL, indicating possible kidney dysfunction. Sodium is 140.0 mEq/L, potassium is low at 2.9 mEq/L, hemoglobin is 9.2 g/dL, and packed cell volume is 30.0%, suggesting possible anemia. The WBC count is 7,000 cells/cumm, and RBC count is 3.2 million/cumm. The patient has hypertension, diabetes mellitus, and coronary artery disease, with a poor appetite and no pedal edema. The combination of elevated blood glucose, serum creatinine, and abnormal urine findings suggests an ongoing renal issue that needs further investigation and management.
# --------------------------------------------------------------------------------
# Row 30:
# A 48-year-old patient presents with severe albuminuria, abnormal pus cells, but no pus cell clumps or bacteria. Blood pressure is low at 80 mm Hg, and blood glucose is normal at 95 mg/dL. Kidney function is impaired with a serum creatinine level of 7.7 mg/dL and urea at 163 mg/dL. Sodium is 136 mEq/L, and potassium is within the normal range at 3.8 mEq/L. Hemoglobin is low at 9.8 g/dL, and packed cell volume is 32%, indicating anemia. The WBC count is 6,900 cells/cumm, with a normal RBC count of 3.4 million/cumm. The patient has hypertension, no diabetes, no coronary artery disease, and good appetite. Pedal edema is absent, but anemia is present.
# --------------------------------------------------------------------------------
# Row 31:
# A 53.0-year-old individual presents with a blood pressure reading of 90.0 mm Hg. Urine analysis reveals a specific gravity of 1.02, a mildly elevated albumin level, and normal sugar levels. Red blood cells in the urine are found to be abnormal, and pus cells are also abnormal, with the presence of pus cell clumps. No bacteria are detected in the urine. Blood tests show a glucose level of 70.0 mg/dL, urea at 107.0 mg/dL, and serum creatinine at 7.2 mg/dL. Electrolyte values indicate sodium at 114.0 mEq/L and potassium at 3.7 mEq/L. Hemoglobin is recorded at 9.5 g/dL, and packed cell volume is 29.0%. The white blood cell count is 12100.0 cells/cumm, and the red blood cell count is 3.7 million/cumm. The patient has a history of both hypertension and diabetes mellitus but no coronary artery disease. Appetite is described as poor, there is no evidence of pedal edema, and anemia is noted.
# --------------------------------------------------------------------------------
# Row 32:
# The patient presents with a urine specific gravity of 1.01, moderate albuminuria, and mildly elevated sugar levels. Urine microscopy shows normal red blood cells, abnormal pus cells, and the presence of both pus cell clumps and bacteria. Blood analysis reveals a glucose level of 157.0 mg/dL, urea at 90.0 mg/dL, and an elevated serum creatinine of 4.1 mg/dL. Electrolyte levels include sodium at 130.0 mEq/L and a high potassium concentration of 6.4 mEq/L. Hemoglobin is critically low at 5.6 g/dL, with a packed cell volume of 16.0%. The white blood cell count is 11000.0 cells/cumm, while the red blood cell count is reduced to 2.6 million/cumm. The individual has a known history of hypertension, diabetes mellitus, and coronary artery disease. Poor appetite and pedal edema are present, though there is no evidence of anemia. The patient is 68.0 years old and has a blood pressure of 80.0 mm Hg.
# --------------------------------------------------------------------------------
# Row 33:
# The patient, aged 52.0 years, has a blood pressure of 90.0 mm Hg and a specific gravity of urine at 1.015. The albumin level is severe, and the sugar level is moderate, with a blood glucose reading of 224.0 mg/dL. Red blood cells appear normal, but pus cells are abnormal, though no pus cell clumps or bacteria are present. Urea is significantly elevated at 166.0 mg/dL, and serum creatinine is high at 5.6 mg/dL, indicating potential kidney dysfunction. Sodium is 133.0 mEq/L, potassium is extremely high at 47.0 mEq/L, which requires immediate attention due to the life-threatening risk of hyperkalemia. Hemoglobin is low at 8.1 g/dL, and packed cell volume is 23.0%, reflecting anemia. The WBC count is normal at 5,000 cells/cumm, and RBC count is 2.9 million/cumm. The patient has hypertension, diabetes mellitus, no coronary artery disease, a good appetite, and no pedal edema. The elevated urea, creatinine, and potassium levels, combined with anemia, point to significant kidney issues that need urgent management, particularly addressing hyperkalemia.
# --------------------------------------------------------------------------------
# Row 34:
# This 64-year-old patient presents with severe albumin levels and trace sugar in the urine. Blood glucose is elevated at 239 mg/dL, and serum creatinine is 4.3 mg/dL. The patient has hypertension and diabetes mellitus but no coronary artery disease. Hemoglobin is low at 9.5 g/dL, with a packed cell volume of 29%. WBC count is within normal range at 7,500 cells/cumm, and RBC count is 3.4 million/cumm. Sodium is 137 mEq/L and potassium is 5.4 mEq/L. Urine analysis reveals abnormal red blood cells, abnormal pus cells, and bacteria present, though pus cell clumps are not detected. Pedal edema is present, and the patient does not have anemia. The appetite is poor.
# --------------------------------------------------------------------------------
# Row 35:
# The patient, aged 50.0 years, has a blood pressure of 90.0 mm Hg and a specific gravity of urine at 1.01. The albumin level is mild, with a normal sugar level and a blood glucose of 128.0 mg/dL. Red blood cells are normal, but pus cells are abnormal, with pus cell clumps and bacteria present, indicating an infection. Urea is elevated at 208.0 mg/dL, and serum creatinine is significantly high at 9.2 mg/dL, pointing to severe kidney dysfunction. Sodium is 134.0 mEq/L and potassium is 4.8 mEq/L, which are within normal range, but careful monitoring is needed due to renal impairment. Hemoglobin is low at 8.2 g/dL, and packed cell volume is 22.0%, consistent with anemia. The WBC count is elevated at 16,300 cells/cumm, likely due to the infection, and the RBC count is 2.7 million/cumm. The patient has no hypertension, no diabetes, and no coronary artery disease. The poor appetite, presence of pedal edema, and anemia suggest systemic complications, likely from kidney disease and infection, requiring urgent medical attention and intervention.
# --------------------------------------------------------------------------------
# Row 36:
# A 48-year-old patient presents with a blood pressure of 70 mm Hg, which is notably low. The specific gravity of the urine is 1.005, suggesting diluted urine. The patient has severe albuminuria, indicating significant kidney dysfunction. Despite a normal sugar level with a blood glucose of 117 mg/dL, there are abnormal pus cells in the urine, and pus cell clumps are present, though no bacteria are detected. Urea levels are elevated at 56 mg/dL, and serum creatinine is also high at 3.8 mg/dL, pointing to impaired renal function. Sodium is critically low at 111 mEq/L, while potassium is low at 2.5 mEq/L, both of which could contribute to serious electrolyte imbalances. The hemoglobin level is 11.2 g/dL, with a packed cell volume of 32%, indicating mild anemia. The white blood cell count is 6,700 cells/cumm, and the red blood cell count is 3.9 million/cumm, which are within normal limits. The patient has hypertension, but no diabetes or coronary artery disease. Appetite is poor, and pedal edema is present, which could be a sign of fluid retention due to renal impairment. Given the low blood pressure, electrolyte imbalances, kidney dysfunction, and anemia, close medical monitoring and immediate intervention are necessary to address these potentially life-threatening conditions.
# --------------------------------------------------------------------------------
# Row 37:
# A 56-year-old patient with a blood pressure of 90 mm Hg and mild albuminuria has abnormal red and pus cells in urine, with no pus cell clumps or bacteria. Blood glucose is 129 mg/dL, serum creatinine is 6.7 mg/dL, and urea is 107 mg/dL. Sodium is 131 mEq/L, potassium is 4.8 mEq/L, hemoglobin is 9.1 g/dL, and packed cell volume is 29%. WBC count is 6,400 cells/cumm, and RBC count is 3.4 million/cumm. The patient has hypertension, no diabetes, no coronary artery disease, a good appetite, no pedal edema, and no anemia.
# --------------------------------------------------------------------------------
# Row 38:
# A 53-year-old patient presents with mild albuminuria and abnormal red blood cells in the urine, suggesting kidney involvement. Blood pressure is low at 90 mm Hg, and blood glucose is 70 mg/dL, indicating possible hypoglycemia. Serum creatinine is elevated at 7.2 mg/dL, and urea is 107 mg/dL, reflecting poor kidney function. Sodium levels are low at 114 mEq/L, and potassium is normal at 3.7 mEq/L. The patient has anemia with a hemoglobin level of 9.5 g/dL and packed cell volume of 29%, possibly contributing to fatigue. The white blood cell count is 12,100 cells/cumm, indicating an inflammatory response. The patient has hypertension and diabetes mellitus but no coronary artery disease. Pedal edema is absent, and appetite is poor.
# --------------------------------------------------------------------------------
# Row 39:
# A 68-year-old patient has moderate albuminuria with abnormal pus cells and pus cell clumps in the urine, along with present bacteria, which may indicate an infection or kidney issue. The blood pressure is low at 80 mm Hg, and blood glucose is mildly elevated at 157 mg/dL, indicating suboptimal diabetes control. Serum creatinine is 4.1 mg/dL and urea is 90 mg/dL, suggesting possible kidney dysfunction. Sodium is low at 130 mEq/L, and potassium is high at 6.4 mEq/L. Hemoglobin is low at 5.6 g/dL, and the packed cell volume is 16%, indicating severe anemia. WBC count is 11,000 cells/cumm, showing potential infection or inflammation. The patient has hypertension, diabetes mellitus, and coronary artery disease, with poor appetite and pedal edema present.
# --------------------------------------------------------------------------------
# Row 40:
# The patient, aged 56.0 years, has a blood pressure of 70.0 mm Hg, specific gravity of urine at 1.015, a severe albumin level, and a trace sugar level. Red blood cells are abnormal, while pus cells are normal, with no pus cell clumps or bacteria present. The blood glucose level is elevated at 210.0 mg/dL, urea is within normal limits at 26.0 mg/dL, and serum creatinine is elevated at 1.7 mg/dL. Sodium is 136.0 mEq/L, potassium is 3.8 mEq/L, hemoglobin is 16.1 g/dL, and packed cell volume is high at 52.0%. WBC count is elevated at 12,500 cells/cumm, and RBC count is high at 5.6 million/cumm. The patient has no hypertension, no diabetes, and no coronary artery disease, with good appetite and no pedal edema or anemia. However, the combination of severe albumin levels, elevated blood glucose, elevated serum creatinine, and elevated WBC count may suggest kidney issues or an underlying infection, warranting further investigation.
# --------------------------------------------------------------------------------
# Row 41:
# The patient, aged 62, has low blood pressure (70 mm Hg) and moderate albumin in urine. Blood glucose is within normal range (122 mg/dL), and kidney function is slightly impaired with a serum creatinine of 1.7 mg/dL and urea at 42 mg/dL. Sodium and potassium levels are normal, while hemoglobin (12.6 g/dL) and packed cell volume (39%) are within the normal range, indicating no anemia. WBC count is normal (7,900 cells/cumm), and RBC count is also normal (3.9 million/cumm). The patient has hypertension and diabetes, but no coronary artery disease or pedal edema. Overall, the patient is stable with good appetite and no major concerns.
# --------------------------------------------------------------------------------
# Row 42:
# The patient presents with low blood pressure (80 mm Hg) and trace albumin in the urine. Blood glucose is elevated at 303 mg/dL, and kidney function shows mild impairment with serum creatinine of 1.3 mg/dL and urea at 35 mg/dL. Sodium levels are low at 122 mEq/L, and potassium is 3.5 mEq/L. Hemoglobin is 10.4 g/dL, and packed cell volume is 35%, which are slightly below normal, but there are no signs of anemia. The WBC count is 10,900 cells/cumm, while the RBC count is 4.3 million/cumm. The patient has diabetes mellitus, but no hypertension or coronary artery disease. Pedal edema is absent, and appetite is poor. The patient is 59 years old.
# --------------------------------------------------------------------------------
# Row 43:
# A 64-year-old patient with hypertension and diabetes mellitus presents with a blood pressure of 100 mm Hg and severe albumin levels. The sugar level is mild, and red blood cells are abnormal. Pus cells are also abnormal, with bacteria present in the urine. Blood glucose is 163 mg/dL, urea is 54 mg/dL, and serum creatinine is 7.2 mg/dL. Sodium is 140 mEq/L, potassium is 4.6 mEq/L, and hemoglobin is 7.9 g/dL with a packed cell volume of 26%. The WBC count is 7,500 cells/cumm, and RBC count is 3.4 million/cumm. The patient has a good appetite, pedal edema is present, and there is no anemia or coronary artery disease.
# --------------------------------------------------------------------------------
# Row 44:
# A 59-year-old patient with a blood pressure of 70 mm Hg presents with trace albumin and moderate sugar levels in the urine. Both red blood cells and pus cells are abnormal, though there are no clumps or bacteria. Blood glucose is markedly elevated at 424 mg/dL, indicating poorly controlled diabetes. Kidney function shows mildly elevated serum creatinine (1.7 mg/dL) and urea (55 mg/dL), with normal sodium (138 mEq/L) and potassium (4.5 mEq/L) levels. Hemoglobin (12.6 g/dL), packed cell volume (37%), and RBC count (4.1 million/cumm) are within normal limits. WBC count is 10,200 cells/cumm. The patient has hypertension, diabetes mellitus, and coronary artery disease. Appetite is good, pedal edema is absent, and there is no anemia.
# --------------------------------------------------------------------------------
# Row 45:
# A 64-year-old patient with blood pressure of 100 mm Hg presents with severe albuminuria and mild glycosuria. Urine analysis reveals abnormal red and pus cells, presence of bacteria, and no clumps. Blood glucose is 163 mg/dL. Kidney function is severely impaired, with a high serum creatinine of 7.2 mg/dL and elevated urea at 54 mg/dL, suggesting advanced kidney dysfunction. Electrolytes are within normal limits (Na: 140 mEq/L, K: 4.6 mEq/L). Hemoglobin is low (7.9 g/dL) and PCV is 26%, indicating anemia, although its noted that anemia is clinically not present  this might reflect underdiagnosis or early-stage anemia. RBC count is low at 3.4 million/cumm. WBC count is normal. The patient has hypertension, diabetes mellitus, and no CAD, with good appetite and pedal edema present.
# --------------------------------------------------------------------------------
# Row 46:
# A 56-year-old patient with a blood pressure of 70 mm Hg presents with severe albuminuria and trace sugar in the urine. Urinalysis shows abnormal red blood cells but normal pus cells, with no clumps or bacteria. Blood glucose is elevated at 210 mg/dL, but the patient reports no history of diabetes. Kidney function markers are moderately elevated (urea 26 mg/dL, serum creatinine 1.7 mg/dL). Electrolytes are within normal limits (sodium 136 mEq/L, potassium 3.8 mEq/L). Hemoglobin is high at 16.1 g/dL, packed cell volume is 52%, and RBC count is elevated at 5.6 million/cumm. WBC count is 12,500 cells/cumm. The patient has no hypertension, diabetes, or coronary artery disease, maintains good appetite, has no pedal edema, and no anemia.
# --------------------------------------------------------------------------------
# Row 47:
# A 46-year-old patient with low blood pressure (60 mm Hg), specific gravity of urine at 1.01, trace albumin level, and normal urine sugar, has normal red and white blood cells in urine, with no presence of pus cell clumps or bacteria. Blood glucose is elevated at 163.0 mg/dL, urea is significantly raised at 92.0 mg/dL, and serum creatinine is elevated at 3.3 mg/dL, indicating moderate to advanced renal impairment. Electrolytes are within normal range, with sodium at 141.0 mEq/L and potassium at 4.0 mEq/L. Hemoglobin is slightly reduced at 9.8 g/dL, packed cell volume is 28.0%, and RBC count is 3.2 million/cumm, pointing toward early anemia, although anemia is not clinically reported. The WBC count is elevated at 14,600.0 cells/cumm, suggesting possible inflammation or infection. The patient has a history of hypertension and diabetes mellitus, no coronary artery disease, good appetite, no pedal edema, and no clinical anemia.
# --------------------------------------------------------------------------------
# Row 48:
# A 63-year-old patient with a blood pressure of 100.0 mm Hg, urine specific gravity of 1.01, mild levels of both albumin and sugar in the urine, has normal red and pus cells, no pus cell clumps, but presence of bacteria. The blood glucose level is elevated at 280.0 mg/dL despite no history of diabetes, urea is mildly elevated at 35.0 mg/dL, and serum creatinine is significantly elevated at 3.2 mg/dL, indicating impaired kidney function. Electrolytes are within normal limits, with sodium at 143.0 mEq/L and potassium at 3.5 mEq/L. Hemoglobin is normal at 13.0 g/dL, packed cell volume is 40.0%, WBC count is 9800.0 cells/cumm, and RBC count is 4.2 million/cumm. The patient has hypertension and coronary artery disease, no history of diabetes, reports a good appetite, no pedal edema, and no clinical anemia.
# --------------------------------------------------------------------------------
# Row 49:
# An 83-year-old patient with a blood pressure of 70.0 mm Hg, urine specific gravity of 1.02, moderate albumin level, and normal sugar level in the urine, has normal red and pus cells, no pus cell clumps, and no bacteria present. Blood glucose is normal at 102.0 mg/dL. Urea is elevated at 60.0 mg/dL, and serum creatinine is also elevated at 2.6 mg/dL, indicating impaired renal function. Sodium is critically low at 115.0 mEq/L, and potassium is elevated at 5.7 mEq/L. The patient is anemic with hemoglobin at 8.7 g/dL, packed cell volume at 26.0%, and RBC count of 3.1 million/cumm. WBC count is elevated at 12800.0 cells/cumm. The patient has hypertension, no diabetes or coronary artery disease, reports poor appetite, has no pedal edema, and has clinical anemia.
# --------------------------------------------------------------------------------
# Row 50:
# A 48-year-old patient with a blood pressure of 70.0 mm Hg, urine specific gravity of 1.005, severe albumin level, and normal urine sugar level, has normal red blood cells, abnormal pus cells, presence of pus cell clumps, and no bacteria. Blood glucose is normal at 117.0 mg/dL. Urea is elevated at 56.0 mg/dL, and serum creatinine is significantly elevated at 3.8 mg/dL, indicating renal dysfunction. Sodium is critically low at 111.0 mEq/L, and potassium is low at 2.5 mEq/L. Hemoglobin is slightly low at 11.2 g/dL, packed cell volume is 32.0%, and RBC count is 3.9 million/cumm. WBC count is within normal range at 6700.0 cells/cumm. The patient has hypertension, no diabetes or coronary artery disease, reports poor appetite, has pedal edema, and presents with clinical anemia.
# --------------------------------------------------------------------------------
# Row 51:
# A 56.0-year-old patient with blood pressure of 90.0 mm Hg, urine specific gravity of 1.015, mild albuminuria, and normal urine sugar, presents with abnormal red blood cells and pus cells in urine, without pus cell clumps or bacteria. Blood glucose is 129.0 mg/dL. Urea is significantly elevated at 107.0 mg/dL, and serum creatinine is critically high at 6.7 mg/dL, suggesting advanced renal impairment. Sodium is slightly low at 131.0 mEq/L, and potassium is within normal range at 4.8 mEq/L. Hemoglobin is low at 9.1 g/dL, packed cell volume is 29.0%, and RBC count is 3.4 million/cumm. WBC count is 6400.0 cells/cumm. The patient has hypertension, no diabetes or coronary artery disease, reports good appetite, has no pedal edema, and does not present with clinical anemia.
# --------------------------------------------------------------------------------
# Row 52:
# A 73.0-year-old patient with blood pressure of 100.0 mm Hg, urine specific gravity of 1.01, moderate albuminuria, and mild glycosuria, presents with abnormal red and pus cells in urine along with presence of pus cell clumps and absence of bacteria. Blood glucose is elevated at 295.0 mg/dL. Urea is significantly elevated at 90.0 mg/dL, and serum creatinine is critically high at 5.6 mg/dL, indicating severe kidney dysfunction. Sodium is normal at 140.0 mEq/L, while potassium is low at 2.9 mEq/L. Hemoglobin is low at 9.2 g/dL, packed cell volume is 30.0%, and RBC count is 3.2 million/cumm. WBC count is 7000.0 cells/cumm. The patient has hypertension, diabetes mellitus, and coronary artery disease, reports poor appetite, has no pedal edema, and does not show signs of anemia.
# --------------------------------------------------------------------------------
# Row 53:
# A 53.0-year-old patient with blood pressure of 90.0 mm Hg, urine specific gravity of 1.02, mild albuminuria, and normal glycosuria, presents with abnormal red and pus cells in urine, presence of pus cell clumps, and no bacteria detected. Blood glucose is low at 70.0 mg/dL. Urea is critically high at 107.0 mg/dL, and serum creatinine is severely elevated at 7.2 mg/dL, suggesting advanced renal impairment. Sodium is low at 114.0 mEq/L, while potassium is within normal range at 3.7 mEq/L. Hemoglobin is decreased at 9.5 g/dL, with packed cell volume at 29.0% and RBC count at 3.7 million/cumm. WBC count is elevated at 12100.0 cells/cumm. The patient has hypertension and diabetes mellitus, but no coronary artery disease, reports poor appetite, has no pedal edema, and has anemia.
# --------------------------------------------------------------------------------
# Row 54:
# A 68.0-year-old patient with blood pressure of 80.0 mm Hg, urine specific gravity of 1.01, moderate albuminuria, and mild glycosuria, shows normal red blood cells in urine but abnormal pus cells, presence of pus cell clumps, and bacteria. Blood glucose is 157.0 mg/dL. Urea is significantly elevated at 90.0 mg/dL, and serum creatinine is high at 4.1 mg/dL, indicating impaired renal function. Sodium is slightly low at 130.0 mEq/L, and potassium is critically high at 6.4 mEq/L. The patient has severe anemia with hemoglobin at 5.6 g/dL, packed cell volume of 16.0%, and RBC count of 2.6 million/cumm. WBC count is elevated at 11000.0 cells/cumm. The patient has hypertension, diabetes mellitus, and coronary artery disease, reports poor appetite, has pedal edema, but does not have anemia noted as a diagnosis (despite clinical findings).
# --------------------------------------------------------------------------------
# Row 55:
# A 52.0-year-old patient with a blood pressure of 90.0 mm Hg, urine specific gravity of 1.015, and severe albuminuria, shows moderate hyperglycemia with a blood glucose level of 224.0 mg/dL. Red blood cells in the urine are normal, but pus cells are abnormal. There are no pus cell clumps or bacteria present. Urea is significantly elevated at 166.0 mg/dL, and serum creatinine is at 5.6 mg/dL, indicating renal impairment. Sodium is low at 133.0 mEq/L, and potassium is extremely high at 47.0 mEq/L, which is likely a critical error or abnormality that needs urgent attention. Hemoglobin is low at 8.1 g/dL, packed cell volume is at 23.0%, and RBC count is reduced at 2.9 million/cumm, indicating anemia. The WBC count is within the normal range at 5000.0 cells/cumm. The patient has hypertension, diabetes mellitus, but no coronary artery disease, reports good appetite, does not have pedal edema, but has anemia.
# --------------------------------------------------------------------------------
# Row 56:
# A 56.0-year-old patient with blood pressure of 90.0 mm Hg, urine specific gravity of 1.01, and severe albuminuria, presents with trace sugar levels and abnormal pus cells in the urine. Pus cell clumps are present, but no bacteria are detected. The patient's blood glucose level is elevated at 176.0 mg/dL. Urea is significantly high at 309.0 mg/dL, and serum creatinine is critically elevated at 13.3 mg/dL, indicating severe renal impairment. Sodium is low at 124.0 mEq/L, and potassium is high at 6.5 mEq/L, which can be life-threatening and may lead to arrhythmias. Hemoglobin is severely low at 3.1 g/dL, and packed cell volume is at a critically low 9.0%, with RBC count at 2.1 million/cumm, confirming severe anemia. WBC count is 5400.0 cells/cumm, within the normal range. The patient has hypertension, diabetes mellitus, no coronary artery disease, poor appetite, pedal edema, and anemia. This presentation suggests a state of acute kidney injury or advanced chronic kidney disease, requiring urgent medical intervention.
# --------------------------------------------------------------------------------
# Row 57:
# A 59.0-year-old patient with blood pressure of 70.0 mm Hg presents with moderate albuminuria and abnormal pus cells in the urine, although pus cell clumps and bacteria are not present. Blood glucose is within normal range at 76.0 mg/dL. Urea is elevated at 186.0 mg/dL, and serum creatinine is critically high at 15.0 mg/dL, indicating severe renal impairment. Potassium is dangerously high at 7.6 mEq/L, which poses a risk of life-threatening arrhythmias. Sodium is within the lower end of the normal range at 135.0 mEq/L. Hemoglobin is low at 7.1 g/dL, with a packed cell volume of 22.0%, suggesting anemia. The RBC count is low at 2.1 million/cumm, confirming significant anemia. WBC count is low at 3800.0 cells/cumm, which may indicate a compromised immune system. The patient has hypertension, no diabetes, no coronary artery disease, poor appetite, pedal edema, and anemia. This clinical presentation is indicative of severe kidney dysfunction, possibly acute kidney injury or end-stage renal disease, requiring immediate medical attention.
# --------------------------------------------------------------------------------
# Row 58:
# A 45-year-old patient with low blood pressure (70 mm Hg) has mild albuminuria, abnormal pus cells, and normal blood glucose (117 mg/dL). Urea (52 mg/dL) and serum creatinine (2.2 mg/dL) are elevated, suggesting possible renal dysfunction. Hemoglobin is low (10 g/dL), but anemia is not significant. WBC count is elevated (19,100 cells/cumm), indicating potential infection or inflammation. The patient has no hypertension, diabetes, or coronary artery disease and has a good appetite with no pedal edema.
# --------------------------------------------------------------------------------

# %% [markdown]
# ## After Augmentation

# %%
# Concatenating along rows (axis=0)

x_train = pd.concat(
    [ x_train[['clinical_text']],
      df_synthetic[['clinical_text']] ],
    axis=0,
    ignore_index=True
)

y_train = pd.concat(
    [ y_train[['Chronic Kidney Disease (1 = CKD, 0 = Not CKD)']],
      df_synthetic[['Chronic Kidney Disease (1 = CKD, 0 = Not CKD)']] ],
    axis=0,
    ignore_index=True
)

# %%
# Data
x_train.head()
# Out:
#                                        clinical_text
# 0  Patient aged 48.0 years with blood pressure of...
# 1  Patient aged 55.0 years with blood pressure of...
# 2  Patient aged 17.0 years with blood pressure of...
# 3  Patient aged 64.0 years with blood pressure of...
# 4  Patient aged 40.0 years with blood pressure of...

# %%
# Label
y_train.head()
# Out:
#    Chronic Kidney Disease (1 = CKD, 0 = Not CKD)
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              1

# %%
"""
# Save to CSV
x_train.to_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/Augmented/final/x_train", index=False)
y_train.to_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/Augmented/final/y_train", index=False)
"""

# %%
# Load the DataFrame
x_train = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/Augmented/final/x_train")
y_train = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/Augmented/final/y_train")
x_test = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/x_test")
y_test = pd.read_csv("/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Updated_Dataset/y_test")

# %%
# Train Shape
x_train.shape
# Out:
# (184, 1)

# %%
# Train Label Shape
y_train.shape
# Out:
# (184, 1)

# %%
# # Train Count
print(y_train.value_counts())
# Out:
# Chronic Kidney Disease (1 = CKD, 0 = Not CKD)
# 0                                                92
# 1                                                92
# Name: count, dtype: int64

# %%
# Test shape
x_test.shape
# Out:
# (32, 1)

# %%
# Test Label shape
y_test.shape
# Out:
# (32, 1)

# %%
# Test Count
print(y_test.value_counts())
# Out:
# Chronic Kidney Disease (1 = CKD, 0 = Not CKD)
# 0                                                23
# 1                                                 9
# Name: count, dtype: int64

# %% [markdown]
# # GPT as Classification Model

# %%
pip install --upgrade transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.51.3

# %%
# !pip install huggingface_hub[hf_xet]
# Out:
# Requirement already satisfied: huggingface_hub[hf_xet] in /usr/local/lib/python3.11/dist-packages (0.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_xet]) (4.13.2)
# Collecting hf-xet>=0.1.4 (from huggingface_hub[hf_xet])
#   Downloading hf_xet-1.0.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (494 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[hf_xet]) (2025.1.31)
# Downloading hf_xet-1.0.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 MB 19.5 MB/s eta 0:00:00
# Installing collected packages: hf-xet
# Successfully installed hf-xet-1.0.3

# %%
pip install transformers datasets scikit-learn
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Collecting datasets
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.19.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 15.8 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.2 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 17.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 14.2 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 18.6 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed datasets-3.5.0 dill-0.3.8 fsspec-2024.12.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
import torch
import pandas as pd
from transformers import GPT2Tokenizer, GPT2Model, GPT2Config
from transformers import Trainer, TrainingArguments
from torch import nn
from torch.utils.data import Dataset
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# Check device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 1. Load tokenizer and GPT2
tokenizer = GPT2Tokenizer.from_pretrained("distilgpt2")
tokenizer.pad_token = tokenizer.eos_token  # set pad token to eos_token

# 2. Custom Dataset
class ClinicalDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.encodings = tokenizer(list(texts), truncation=True, padding=True, max_length=max_len, return_tensors='pt')
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.encodings.items()}
        item['labels'] = self.labels[idx]
        return item

# 3. Custom GPT2 Classification Model
class GPT2ForClassification(nn.Module):
    def __init__(self, n_classes=2):
        super(GPT2ForClassification, self).__init__()
        self.gpt2 = GPT2Model.from_pretrained("distilgpt2")
        self.dropout = nn.Dropout(0.2)
        self.classifier = nn.Linear(self.gpt2.config.hidden_size, n_classes)

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.gpt2(input_ids=input_ids, attention_mask=attention_mask)
        last_hidden_state = outputs.last_hidden_state  # [batch_size, seq_len, hidden_dim]
        cls_output = last_hidden_state[:, -1, :]  # use last token hidden state
        logits = self.classifier(self.dropout(cls_output))
        loss = None
        if labels is not None:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)
        return {"loss": loss, "logits": logits}

# Texts
if isinstance(x_train, pd.DataFrame):
    x_train = x_train.squeeze().astype(str).tolist()
if isinstance(x_test, pd.DataFrame):
    x_test = x_test.squeeze().astype(str).tolist()

# Labels
if isinstance(y_train, pd.DataFrame):
    y_train = y_train.squeeze().astype(int).tolist()
if isinstance(y_test, pd.DataFrame):
    y_test = y_test.squeeze().astype(int).tolist()

# 4. Prepare dataset
train_dataset = ClinicalDataset(x_train, y_train, tokenizer)
test_dataset = ClinicalDataset(x_test, y_test, tokenizer)

# 5. Load model
model = GPT2ForClassification()
model.to(device)

# 6. TrainingArguments and Trainer
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=2,
    num_train_epochs=10,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=5,
    save_steps=10,
    eval_steps=10,
    metric_for_best_model="accuracy",  # or "f1" depending on your task
    greater_is_better=True,
    warmup_ratio=0.1,              # Warmup to prevent early overfitting
    gradient_accumulation_steps=2, # Simulates larger batch size
    fp16=True,                     # Use if on GPU with mixed precision support
)

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    return {"accuracy": (preds == labels).mean()}

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics,
)

# 7. Train the model
trainer.train()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: sbakter48 (sbakter48-northern-university-bangladesh) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/content/wandb/run-20250424_154535-229nhhmc</code>
# Syncing run <strong><a href='https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface/runs/229nhhmc' target="_blank">./results</a></strong> to <a href='https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface' target="_blank">https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface</a>
#  View run at <a href='https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface/runs/229nhhmc' target="_blank">https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface/runs/229nhhmc</a>
#     <div>
#
#       <progress value='460' max='460' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [460/460 07:10, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.731200</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.141400</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.952600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.357200</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.247300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.770300</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.520500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.877900</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.322400</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.313700</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.303500</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.182400</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.274200</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.228700</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.333300</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.839800</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.791000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.353600</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>2.050900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.607600</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.715900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.251900</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.330400</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.447200</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.224100</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.175700</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.860800</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.353800</td>
#     </tr>
#     <tr>
#       <td>145</td>
#       <td>0.363100</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.344300</td>
#     </tr>
#     <tr>
#       <td>155</td>
#       <td>1.090400</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.221400</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>0.488100</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.203700</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.360600</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.934300</td>
#     </tr>
#     <tr>
#       <td>185</td>
#       <td>0.816800</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.476400</td>
#     </tr>
#     <tr>
#       <td>195</td>
#       <td>0.475500</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.496300</td>
#     </tr>
#     <tr>
#       <td>205</td>
#       <td>0.238000</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.419800</td>
#     </tr>
#     <tr>
#       <td>215</td>
#       <td>0.671700</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.131000</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.005500</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>1.446900</td>
#     </tr>
#     <tr>
#       <td>235</td>
#       <td>0.522800</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.486100</td>
#     </tr>
#     <tr>
#       <td>245</td>
#       <td>0.007100</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.167400</td>
#     </tr>
#     <tr>
#       <td>255</td>
#       <td>0.529400</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.687800</td>
#     </tr>
#     <tr>
#       <td>265</td>
#       <td>0.077000</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.131500</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.080200</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.006100</td>
#     </tr>
#     <tr>
#       <td>285</td>
#       <td>0.001200</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.000500</td>
#     </tr>
#     <tr>
#       <td>295</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.000500</td>
#     </tr>
#     <tr>
#       <td>305</td>
#       <td>0.000400</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>315</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>335</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>345</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>355</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>365</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.568000</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>385</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>395</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>405</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>415</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>425</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>435</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>445</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>455</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.000100</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=460, training_loss=0.34795209571071295, metrics={'train_runtime': 481.7312, 'train_samples_per_second': 3.82, 'train_steps_per_second': 0.955, 'total_flos': 0.0, 'train_loss': 0.34795209571071295, 'epoch': 10.0})

# %%
# 8. Evaluation
preds_output = trainer.predict(test_dataset)
predictions = np.argmax(preds_output.predictions, axis=1)

# %%
# 9. Classification report & confusion matrix
print("Classification Report:\n", classification_report(y_test, predictions, digits=4))
print("Confusion Matrix:\n", confusion_matrix(y_test, predictions))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        23
#            1     1.0000    1.0000    1.0000         9
#
#     accuracy                         1.0000        32
#    macro avg     1.0000    1.0000    1.0000        32
# weighted avg     1.0000    1.0000    1.0000        32
#
# Confusion Matrix:
#  [[23  0]
#  [ 0  9]]

# %%
"""
save_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Model/"

trainer.save_model(save_path)
tokenizer.save_pretrained(save_path)

print("Model and tokenizer saved to:", save_path)
"""
# Out:
# Model and tokenizer saved to: /content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Model/

# %%
from transformers import GPT2Tokenizer
import torch

save_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Model/"

# Reload tokenizer
tokenizer = GPT2Tokenizer.from_pretrained(save_path)
tokenizer.pad_token = tokenizer.eos_token

# Reload model
model = GPT2ForClassification(n_classes=2)
state_dict = torch.load(save_path + "pytorch_model.bin", map_location="cuda" if torch.cuda.is_available() else "cpu")
model.load_state_dict(state_dict)
model.to(device)
model.eval()

print("Model loaded from:", save_path)
# Out:
# Model loaded from: /content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Model/

# %% [markdown]
# ## Ablation

# %%
import torch
import pandas as pd
from transformers import GPT2Tokenizer, GPT2Model, GPT2Config
from transformers import Trainer, TrainingArguments
from torch import nn
from torch.utils.data import Dataset
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# Check device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 1. Load tokenizer and GPT2
tokenizer = GPT2Tokenizer.from_pretrained("distilgpt2")
tokenizer.pad_token = tokenizer.eos_token  # set pad token to eos_token

# 2. Custom Dataset
class ClinicalDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.encodings = tokenizer(list(texts), truncation=True, padding=True, max_length=max_len, return_tensors='pt')
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.encodings.items()}
        item['labels'] = self.labels[idx]
        return item

# 3. Custom GPT2 Classification Model
class GPT2ForClassification(nn.Module):
    def __init__(self, n_classes=2):
        super(GPT2ForClassification, self).__init__()
        self.gpt2 = GPT2Model.from_pretrained("distilgpt2")
        self.dropout = nn.Dropout(0.2)
        self.classifier = nn.Linear(self.gpt2.config.hidden_size, n_classes)

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.gpt2(input_ids=input_ids, attention_mask=attention_mask)
        last_hidden_state = outputs.last_hidden_state  # [batch_size, seq_len, hidden_dim]
        cls_output = last_hidden_state[:, -1, :]  # use last token hidden state
        logits = self.classifier(self.dropout(cls_output))
        loss = None
        if labels is not None:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)
        return {"loss": loss, "logits": logits}

# Texts
if isinstance(x_train, pd.DataFrame):
    x_train = x_train.squeeze().astype(str).tolist()
if isinstance(x_test, pd.DataFrame):
    x_test = x_test.squeeze().astype(str).tolist()

# Labels
if isinstance(y_train, pd.DataFrame):
    y_train = y_train.squeeze().astype(int).tolist()
if isinstance(y_test, pd.DataFrame):
    y_test = y_test.squeeze().astype(int).tolist()

# 4. Prepare dataset
train_dataset = ClinicalDataset(x_train, y_train, tokenizer)
test_dataset = ClinicalDataset(x_test, y_test, tokenizer)

# 5. Load model
model = GPT2ForClassification()
model.to(device)

# 6. TrainingArguments and Trainer
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=2,
    num_train_epochs=3,
    weight_decay=0.001,
    logging_dir="./logs",
    logging_steps=5,
    save_steps=10,
    eval_steps=10,
    metric_for_best_model="accuracy",  # or "f1" depending on your task
    greater_is_better=True,
    warmup_ratio=0.1,              # Warmup to prevent early overfitting
    gradient_accumulation_steps=2, # Simulates larger batch size
    fp16=True,                     # Use if on GPU with mixed precision support
)

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    return {"accuracy": (preds == labels).mean()}

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics,
)

# 7. Train the model
trainer.train()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: sbakter48 (sbakter48-northern-university-bangladesh) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/wandb/run-20250505_101528-impi6c6v</code>
# Syncing run <strong><a href='https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface/runs/impi6c6v' target="_blank">./results</a></strong> to <a href='https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface' target="_blank">https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface</a>
#  View run at <a href='https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface/runs/impi6c6v' target="_blank">https://wandb.ai/sbakter48-northern-university-bangladesh/huggingface/runs/impi6c6v</a>
#     <div>
#
#       <progress value='93' max='93' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [93/93 08:10, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>2.063700</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.959800</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.656800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.425700</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.888500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.516900</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.575800</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.795000</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.635300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.708500</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.305400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.538000</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.649900</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.626300</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.067200</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.202200</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>1.079700</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.243900</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=93, training_loss=0.8444147174076367, metrics={'train_runtime': 525.0787, 'train_samples_per_second': 0.72, 'train_steps_per_second': 0.177, 'total_flos': 0.0, 'train_loss': 0.8444147174076367, 'epoch': 2.9206349206349205})

# %%
# 8. Evaluation
preds_output = trainer.predict(test_dataset)
predictions = np.argmax(preds_output.predictions, axis=1)

# %%
# 9. Classification report & confusion matrix
print("Classification Report:\n", classification_report(y_test, predictions, digits=4))
print("Confusion Matrix:\n", confusion_matrix(y_test, predictions))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.7931    1.0000    0.8846        23
#            1     1.0000    0.3333    0.5000         9
#
#     accuracy                         0.8125        32
#    macro avg     0.8966    0.6667    0.6923        32
# weighted avg     0.8513    0.8125    0.7764        32
#
# Confusion Matrix:
#  [[23  0]
#  [ 6  3]]

# %% [markdown]
# # Interpretability

# %% [markdown]
# We take the trained GPT-2 model and look at how much each input token “influences” the model’s prediction. To do this, we track gradients—essentially, how much the model’s output would change if we slightly changed the token’s representation. Tokens with larger gradient values had a bigger effect on the decision, meaning the model “paid more attention” to them. By focusing only on keywords of interest (like “blood pressure” or “sugar”), we can see which clinical features the model considered most important for its prediction. This method gives a transparent view of what the model thinks matters, without changing the model itself.
#
# In simple terms: we compute the gradient of the model’s output (the predicted class score) with respect to each input token’s embedding. The size of this gradient tells us how sensitive the prediction is to changes in that token. Larger gradients mean the model relies more on that token to make its decision.
#
# This is a post-hoc interpretability method that works directly on the trained model without modifying it, and it’s widely used in NLP for token-level importance visualization.

# %%
# Combine x_test and y_test
merged_df = pd.concat([x_test, y_test], axis=1)

# Assume y_test column name is 'label' (adjust if different)
# If y_test has no column name, assign one
if merged_df.columns[-1] not in ['label', 'y_test']:
    merged_df.columns = list(merged_df.columns[:-1]) + ['label']

# Filter rows where label == 1
positive_cases = merged_df[merged_df['label'] == 1]

# Print texts for positive cases
for idx, row in positive_cases.iterrows():
    print(f"Row {idx + 1}:\n{row[0]}\n{'-'*80}")
# Out:
# Row 4:
# Patient aged 48.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.005, albumin level is Severe, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are present, blood glucose is 133.0 mg/dL, urea is 139.0 mg/dL, serum creatinine is 8.5 mg/dL, sodium is 132.0 mEq/L, potassium is 5.5 mEq/L, hemoglobin is 10.3 g/dL, packed cell volume is 36.0%, WBC count is 6200.0 cells/cumm, RBC count is 4.0 million/cumm, has no hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 5:
# Patient aged 73.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.005, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 70.0 mg/dL, urea is 32.0 mg/dL, serum creatinine is 0.9 mg/dL, sodium is 125.0 mEq/L, potassium is 4.0 mEq/L, hemoglobin is 10.0 g/dL, packed cell volume is 29.0%, WBC count is 18900.0 cells/cumm, RBC count is 3.5 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 13:
# Patient aged 69.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is High, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 264.0 mg/dL, urea is 87.0 mg/dL, serum creatinine is 2.7 mg/dL, sodium is 130.0 mEq/L, potassium is 4.0 mEq/L, hemoglobin is 12.5 g/dL, packed cell volume is 37.0%, WBC count is 9600.0 cells/cumm, RBC count is 4.1 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 16:
# Patient aged 59.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.02, albumin level is Severe, sugar level is Mild, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 252.0 mg/dL, urea is 40.0 mg/dL, serum creatinine is 3.2 mg/dL, sodium is 137.0 mEq/L, potassium is 4.7 mEq/L, hemoglobin is 11.2 g/dL, packed cell volume is 30.0%, WBC count is 26400.0 cells/cumm, RBC count is 3.9 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 17:
# Patient aged 61.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.015, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 173.0 mg/dL, urea is 148.0 mg/dL, serum creatinine is 3.9 mg/dL, sodium is 135.0 mEq/L, potassium is 5.2 mEq/L, hemoglobin is 7.7 g/dL, packed cell volume is 24.0%, WBC count is 9200.0 cells/cumm, RBC count is 3.2 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 24:
# Patient aged 59.0 years with blood pressure of 50.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 241.0 mg/dL, urea is 191.0 mg/dL, serum creatinine is 12.0 mg/dL, sodium is 114.0 mEq/L, potassium is 2.9 mEq/L, hemoglobin is 9.6 g/dL, packed cell volume is 31.0%, WBC count is 15700.0 cells/cumm, RBC count is 3.8 million/cumm, has no hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 25:
# Patient aged 73.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 253.0 mg/dL, urea is 142.0 mg/dL, serum creatinine is 4.6 mg/dL, sodium is 138.0 mEq/L, potassium is 5.8 mEq/L, hemoglobin is 10.5 g/dL, packed cell volume is 33.0%, WBC count is 7200.0 cells/cumm, RBC count is 4.3 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 27:
# Patient aged 21.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.01, albumin level is Severe, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are present, blood glucose is 107.0 mg/dL, urea is 40.0 mg/dL, serum creatinine is 1.7 mg/dL, sodium is 125.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 8.3 g/dL, packed cell volume is 23.0%, WBC count is 12400.0 cells/cumm, RBC count is 3.9 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 29:
# Patient aged 59.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.015, albumin level is Severe, sugar level is Mild, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 255.0 mg/dL, urea is 132.0 mg/dL, serum creatinine is 12.8 mg/dL, sodium is 135.0 mEq/L, potassium is 5.7 mEq/L, hemoglobin is 7.3 g/dL, packed cell volume is 20.0%, WBC count is 9800.0 cells/cumm, RBC count is 3.9 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# /tmp/ipython-input-2093218046.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Row {idx + 1}:\n{row[0]}\n{'-'*80}")

# %%
for idx, text in enumerate(x_test["clinical_text"]):
    print(f"Row {idx + 1}:\n{text}\n{'-'*80}")
# Out:
# Row 1:
# Patient aged 45.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 82.0 mg/dL, urea is 49.0 mg/dL, serum creatinine is 0.6 mg/dL, sodium is 147.0 mEq/L, potassium is 4.4 mEq/L, hemoglobin is 15.9 g/dL, packed cell volume is 46.0%, WBC count is 9100.0 cells/cumm, RBC count is 4.7 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 2:
# Patient aged 23.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 95.0 mg/dL, urea is 24.0 mg/dL, serum creatinine is 0.8 mg/dL, sodium is 145.0 mEq/L, potassium is 5.0 mEq/L, hemoglobin is 15.0 g/dL, packed cell volume is 52.0%, WBC count is 6300.0 cells/cumm, RBC count is 4.6 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 3:
# Patient aged 37.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 109.0 mg/dL, urea is 47.0 mg/dL, serum creatinine is 1.1 mg/dL, sodium is 141.0 mEq/L, potassium is 4.9 mEq/L, hemoglobin is 15.0 g/dL, packed cell volume is 48.0%, WBC count is 7000.0 cells/cumm, RBC count is 5.2 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 4:
# Patient aged 48.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.005, albumin level is Severe, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are present, blood glucose is 133.0 mg/dL, urea is 139.0 mg/dL, serum creatinine is 8.5 mg/dL, sodium is 132.0 mEq/L, potassium is 5.5 mEq/L, hemoglobin is 10.3 g/dL, packed cell volume is 36.0%, WBC count is 6200.0 cells/cumm, RBC count is 4.0 million/cumm, has no hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 5:
# Patient aged 73.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.005, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 70.0 mg/dL, urea is 32.0 mg/dL, serum creatinine is 0.9 mg/dL, sodium is 125.0 mEq/L, potassium is 4.0 mEq/L, hemoglobin is 10.0 g/dL, packed cell volume is 29.0%, WBC count is 18900.0 cells/cumm, RBC count is 3.5 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 6:
# Patient aged 58.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 100.0 mg/dL, urea is 50.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 140.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 14.0 g/dL, packed cell volume is 50.0%, WBC count is 6700.0 cells/cumm, RBC count is 6.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 7:
# Patient aged 75.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 107.0 mg/dL, urea is 48.0 mg/dL, serum creatinine is 0.8 mg/dL, sodium is 144.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 13.6 g/dL, packed cell volume is 46.0%, WBC count is 10300.0 cells/cumm, RBC count is 4.8 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 8:
# Patient aged 36.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 85.0 mg/dL, urea is 16.0 mg/dL, serum creatinine is 1.1 mg/dL, sodium is 142.0 mEq/L, potassium is 4.1 mEq/L, hemoglobin is 15.6 g/dL, packed cell volume is 44.0%, WBC count is 5800.0 cells/cumm, RBC count is 6.3 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 9:
# Patient aged 69.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 83.0 mg/dL, urea is 42.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 139.0 mEq/L, potassium is 3.7 mEq/L, hemoglobin is 16.2 g/dL, packed cell volume is 50.0%, WBC count is 9300.0 cells/cumm, RBC count is 5.4 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 10:
# Patient aged 15.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 93.0 mg/dL, urea is 17.0 mg/dL, serum creatinine is 0.9 mg/dL, sodium is 136.0 mEq/L, potassium is 3.9 mEq/L, hemoglobin is 16.7 g/dL, packed cell volume is 50.0%, WBC count is 6200.0 cells/cumm, RBC count is 5.2 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 11:
# Patient aged 66.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 94.0 mg/dL, urea is 19.0 mg/dL, serum creatinine is 0.7 mg/dL, sodium is 135.0 mEq/L, potassium is 3.9 mEq/L, hemoglobin is 16.0 g/dL, packed cell volume is 41.0%, WBC count is 5300.0 cells/cumm, RBC count is 5.9 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 12:
# Patient aged 58.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 131.0 mg/dL, urea is 18.0 mg/dL, serum creatinine is 1.1 mg/dL, sodium is 141.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 15.8 g/dL, packed cell volume is 53.0%, WBC count is 6800.0 cells/cumm, RBC count is 6.1 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 13:
# Patient aged 69.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is High, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 264.0 mg/dL, urea is 87.0 mg/dL, serum creatinine is 2.7 mg/dL, sodium is 130.0 mEq/L, potassium is 4.0 mEq/L, hemoglobin is 12.5 g/dL, packed cell volume is 37.0%, WBC count is 9600.0 cells/cumm, RBC count is 4.1 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 14:
# Patient aged 57.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 132.0 mg/dL, urea is 18.0 mg/dL, serum creatinine is 1.1 mg/dL, sodium is 150.0 mEq/L, potassium is 4.7 mEq/L, hemoglobin is 15.4 g/dL, packed cell volume is 42.0%, WBC count is 11000.0 cells/cumm, RBC count is 4.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 15:
# Patient aged 73.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 118.0 mg/dL, urea is 44.0 mg/dL, serum creatinine is 0.7 mg/dL, sodium is 137.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 14.8 g/dL, packed cell volume is 45.0%, WBC count is 9300.0 cells/cumm, RBC count is 4.7 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 16:
# Patient aged 59.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.02, albumin level is Severe, sugar level is Mild, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 252.0 mg/dL, urea is 40.0 mg/dL, serum creatinine is 3.2 mg/dL, sodium is 137.0 mEq/L, potassium is 4.7 mEq/L, hemoglobin is 11.2 g/dL, packed cell volume is 30.0%, WBC count is 26400.0 cells/cumm, RBC count is 3.9 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 17:
# Patient aged 61.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.015, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 173.0 mg/dL, urea is 148.0 mg/dL, serum creatinine is 3.9 mg/dL, sodium is 135.0 mEq/L, potassium is 5.2 mEq/L, hemoglobin is 7.7 g/dL, packed cell volume is 24.0%, WBC count is 9200.0 cells/cumm, RBC count is 3.2 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
# --------------------------------------------------------------------------------
# Row 18:
# Patient aged 70.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 74.0 mg/dL, urea is 41.0 mg/dL, serum creatinine is 0.5 mg/dL, sodium is 143.0 mEq/L, potassium is 4.5 mEq/L, hemoglobin is 15.1 g/dL, packed cell volume is 48.0%, WBC count is 9700.0 cells/cumm, RBC count is 5.6 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 19:
# Patient aged 56.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 139.0 mg/dL, urea is 15.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 135.0 mEq/L, potassium is 5.0 mEq/L, hemoglobin is 14.8 g/dL, packed cell volume is 42.0%, WBC count is 5600.0 cells/cumm, RBC count is 5.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 20:
# Patient aged 23.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 70.0 mg/dL, urea is 36.0 mg/dL, serum creatinine is 1.0 mg/dL, sodium is 150.0 mEq/L, potassium is 4.6 mEq/L, hemoglobin is 17.0 g/dL, packed cell volume is 52.0%, WBC count is 9800.0 cells/cumm, RBC count is 5.0 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 21:
# Patient aged 46.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 123.0 mg/dL, urea is 46.0 mg/dL, serum creatinine is 1.0 mg/dL, sodium is 135.0 mEq/L, potassium is 5.0 mEq/L, hemoglobin is 15.7 g/dL, packed cell volume is 50.0%, WBC count is 6300.0 cells/cumm, RBC count is 4.8 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 22:
# Patient aged 62.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 132.0 mg/dL, urea is 34.0 mg/dL, serum creatinine is 0.8 mg/dL, sodium is 147.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 17.8 g/dL, packed cell volume is 44.0%, WBC count is 4700.0 cells/cumm, RBC count is 4.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 23:
# Patient aged 51.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 94.0 mg/dL, urea is 15.0 mg/dL, serum creatinine is 1.2 mg/dL, sodium is 144.0 mEq/L, potassium is 3.7 mEq/L, hemoglobin is 15.5 g/dL, packed cell volume is 46.0%, WBC count is 9500.0 cells/cumm, RBC count is 6.4 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 24:
# Patient aged 59.0 years with blood pressure of 50.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 241.0 mg/dL, urea is 191.0 mg/dL, serum creatinine is 12.0 mg/dL, sodium is 114.0 mEq/L, potassium is 2.9 mEq/L, hemoglobin is 9.6 g/dL, packed cell volume is 31.0%, WBC count is 15700.0 cells/cumm, RBC count is 3.8 million/cumm, has no hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 25:
# Patient aged 73.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 253.0 mg/dL, urea is 142.0 mg/dL, serum creatinine is 4.6 mg/dL, sodium is 138.0 mEq/L, potassium is 5.8 mEq/L, hemoglobin is 10.5 g/dL, packed cell volume is 33.0%, WBC count is 7200.0 cells/cumm, RBC count is 4.3 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 26:
# Patient aged 44.0 years with blood pressure of 60.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 96.0 mg/dL, urea is 33.0 mg/dL, serum creatinine is 0.9 mg/dL, sodium is 147.0 mEq/L, potassium is 4.5 mEq/L, hemoglobin is 16.9 g/dL, packed cell volume is 41.0%, WBC count is 7200.0 cells/cumm, RBC count is 5.0 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 27:
# Patient aged 21.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.01, albumin level is Severe, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are present, blood glucose is 107.0 mg/dL, urea is 40.0 mg/dL, serum creatinine is 1.7 mg/dL, sodium is 125.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 8.3 g/dL, packed cell volume is 23.0%, WBC count is 12400.0 cells/cumm, RBC count is 3.9 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 28:
# Patient aged 43.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 130.0 mg/dL, urea is 30.0 mg/dL, serum creatinine is 1.1 mg/dL, sodium is 143.0 mEq/L, potassium is 5.0 mEq/L, hemoglobin is 15.9 g/dL, packed cell volume is 45.0%, WBC count is 7800.0 cells/cumm, RBC count is 4.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 29:
# Patient aged 59.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.015, albumin level is Severe, sugar level is Mild, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 255.0 mg/dL, urea is 132.0 mg/dL, serum creatinine is 12.8 mg/dL, sodium is 135.0 mEq/L, potassium is 5.7 mEq/L, hemoglobin is 7.3 g/dL, packed cell volume is 20.0%, WBC count is 9800.0 cells/cumm, RBC count is 3.9 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is not present, and has anemia.
# --------------------------------------------------------------------------------
# Row 30:
# Patient aged 42.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 132.0 mg/dL, urea is 24.0 mg/dL, serum creatinine is 0.7 mg/dL, sodium is 140.0 mEq/L, potassium is 4.1 mEq/L, hemoglobin is 14.4 g/dL, packed cell volume is 50.0%, WBC count is 5000.0 cells/cumm, RBC count is 4.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 31:
# Patient aged 46.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 100.0 mg/dL, urea is 47.0 mg/dL, serum creatinine is 0.5 mg/dL, sodium is 142.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 16.4 g/dL, packed cell volume is 43.0%, WBC count is 5700.0 cells/cumm, RBC count is 6.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------
# Row 32:
# Patient aged 30.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.025, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 96.0 mg/dL, urea is 25.0 mg/dL, serum creatinine is 0.5 mg/dL, sodium is 144.0 mEq/L, potassium is 4.8 mEq/L, hemoglobin is 13.8 g/dL, packed cell volume is 42.0%, WBC count is 9000.0 cells/cumm, RBC count is 4.5 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
# --------------------------------------------------------------------------------

# %%
# Texts
if isinstance(x_train, pd.DataFrame):
    x_train = x_train.squeeze().astype(str).tolist()
if isinstance(x_test, pd.DataFrame):
    x_test = x_test.squeeze().astype(str).tolist()

# Labels
if isinstance(y_train, pd.DataFrame):
    y_train = y_train.squeeze().astype(int).tolist()
if isinstance(y_test, pd.DataFrame):
    y_test = y_test.squeeze().astype(int).tolist()

# %%
# If y_train/y_test are already lists
y_train = [int(i) for i in y_train]
y_test  = [int(i) for i in y_test]

# If x_train/x_test are lists, make sure they are strings
x_train = [str(i) for i in x_train]
x_test  = [str(i) for i in x_test]

# %%
import torch
import pandas as pd
from transformers import GPT2Tokenizer, GPT2Model, GPT2Config, Trainer, TrainingArguments
from torch import nn
from torch.utils.data import Dataset
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# =====================
# 0. Device
# =====================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# =====================
# 1. Load tokenizer
# =====================
tokenizer = GPT2Tokenizer.from_pretrained("distilgpt2")
tokenizer.pad_token = tokenizer.eos_token  # pad token

# =====================
# 2. Dataset
# =====================
class ClinicalDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.encodings = tokenizer(list(texts), truncation=True, padding=True,
                                   max_length=max_len, return_tensors="pt")
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.encodings.items()}
        item['labels'] = self.labels[idx]
        return item

# =====================
# 3. GPT2 Classification Model (with attention)
# =====================
class GPT2ForClassification(nn.Module):
    def __init__(self, n_classes=2):
        super().__init__()
        # GPT2 with attention output
        config = GPT2Config.from_pretrained("distilgpt2", output_attentions=True, return_dict=True)
        self.gpt2 = GPT2Model.from_pretrained("distilgpt2", config=config)
        self.dropout = nn.Dropout(0.2)
        self.classifier = nn.Linear(self.gpt2.config.hidden_size, n_classes)

    def forward(self, input_ids=None, attention_mask=None, labels=None, return_dict=True, inputs_embeds=None):
        outputs = self.gpt2(input_ids=input_ids,
                            attention_mask=attention_mask,
                            inputs_embeds=inputs_embeds,
                            output_attentions=True,
                            return_dict=True)
        last_hidden_state = outputs.last_hidden_state
        cls_output = last_hidden_state[:, -1, :]  # last token
        logits = self.classifier(self.dropout(cls_output))

        loss = None
        if labels is not None:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)

        return {"loss": loss, "logits": logits, "attentions": outputs.attentions}

# =====================
# 4. Load dataset
# =====================

def df_to_list(df):
    if isinstance(df, pd.DataFrame):
        return df.squeeze().astype(str).tolist()
    return df

x_train = df_to_list(x_train)
x_test = df_to_list(x_test)
y_train = df_to_list(y_train)
y_test = df_to_list(y_test)

train_dataset = ClinicalDataset(x_train, y_train, tokenizer)
test_dataset = ClinicalDataset(x_test, y_test, tokenizer)

# =====================
# 5. Initialize model
# =====================
model = GPT2ForClassification(n_classes=2)
model.to(device)

# =====================
# 6. Training
# =====================
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=2,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=5,
    save_steps=10,
    eval_steps=10,
    metric_for_best_model="accuracy",
    greater_is_better=True,
    warmup_ratio=0.1,
    gradient_accumulation_steps=2,
    fp16=True,
)

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    return {"accuracy": (preds == labels).mean()}

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='138' max='138' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [138/138 03:18, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.764400</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.811900</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.983400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.709500</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.325200</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.590300</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.295200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.525500</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.198300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.268500</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.492400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.270500</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.362200</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.277500</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.253200</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.371700</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.183400</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.516800</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.121500</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.283900</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>1.506500</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.404100</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.476700</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.283100</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.046200</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0.157800</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=138, training_loss=0.45225221588127856, metrics={'train_runtime': 198.249, 'train_samples_per_second': 2.784, 'train_steps_per_second': 0.696, 'total_flos': 0.0, 'train_loss': 0.45225221588127856, 'epoch': 3.0})

# %%
"""
from transformers import GPT2Tokenizer
import torch

save_path = "/content/drive/Shareddrives/Best Shared Drive Ever/Simon-personal/KidneyGPT/Model/Test/"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
"""

# %%
import re

# ---- Feature Groups ----
feature_groups = {
    "Age (years)": None,
    "Blood Pressure (mm Hg)": None,
    "Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated)": {
        1.005: "Very Dilute",
        1.010: "Dilute",
        1.015: "Normal",
        1.020: "Concentrated",
        1.025: "Very Concentrated"
    },
    "Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe)": None,
    "Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High)": None,
    "Red Blood Cells (1 = Normal, 0 = Abnormal)": {1: "Normal", 0: "Abnormal"},
    "Pus Cells (1 = Normal, 0 = Abnormal)": {1: "Normal", 0: "Abnormal"},
    "Pus Cell Clumps (1 = Present, 0 = Not Present)": {1: "Present", 0: "Not Present"},
    "Bacteria (1 = Present, 0 = Not Present)": {1: "Present", 0: "Not Present"},
    "Blood Glucose Random (mg/dL)": None,
    "Blood Urea (mg/dL)": None,
    "Serum Creatinine (mg/dL)": None,
    "Sodium (mEq/L)": None,
    "Potassium (mEq/L)": None,
    "Hemoglobin (g/dL)": None,
    "Packed Cell Volume (%)": None,
    "White Blood Cell Count (cells/cumm)": None,
    "Red Blood Cell Count (million cells/cumm)": None,
    "Hypertension (1 = Yes, 0 = No)": {1: "Yes", 0: "No"},
    "Diabetes Mellitus (1 = Yes, 0 = No)": {1: "Yes", 0: "No"},
    "Coronary Artery Disease (1 = Yes, 0 = No)": {1: "Yes", 0: "No"},
    "Appetite (1 = Good, 0 = Poor)": {1: "Good", 0: "Poor"},
    "Pedal Edema (1 = Yes, 0 = No)": {1: "Yes", 0: "No"},
    "Anemia (1 = Yes, 0 = No)": {1: "Yes", 0: "No"}
}

# ---- Feature Importance (example values) ----
feature_importance = {
    "Age (years)": 0.079,
    "Blood Pressure (mm Hg)": 0.186,
    "Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated)": 0.150,
    "Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe)": 0.160,
    "Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High)": 0.120,
    "Red Blood Cells (1 = Normal, 0 = Abnormal)": 0.110,
    "Pus Cells (1 = Normal, 0 = Abnormal)": 0.100,
    "Pus Cell Clumps (1 = Present, 0 = Not Present)": 0.090,
    "Bacteria (1 = Present, 0 = Not Present)": 0.085,
    "Blood Glucose Random (mg/dL)": 0.140,
    "Blood Urea (mg/dL)": 0.130,
    "Serum Creatinine (mg/dL)": 0.155,
    "Sodium (mEq/L)": 0.105,
    "Potassium (mEq/L)": 0.095,
    "Hemoglobin (g/dL)": 0.125,
    "Packed Cell Volume (%)": 0.115,
    "White Blood Cell Count (cells/cumm)": 0.098,
    "Red Blood Cell Count (million cells/cumm)": 0.085,
    "Hypertension (1 = Yes, 0 = No)": 0.090,
    "Diabetes Mellitus (1 = Yes, 0 = No)": 0.092,
    "Coronary Artery Disease (1 = Yes, 0 = No)": 0.088,
    "Appetite (1 = Good, 0 = Poor)": 0.080,
    "Pedal Edema (1 = Yes, 0 = No)": 0.075,
    "Anemia (1 = Yes, 0 = No)": 0.078
}

# ---- Sample Texts ----
sample_texts = {
    4: "Patient aged 48.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.005, albumin level is Severe, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are present, blood glucose is 133.0 mg/dL, urea is 139.0 mg/dL, serum creatinine is 8.5 mg/dL, sodium is 132.0 mEq/L, potassium is 5.5 mEq/L, hemoglobin is 10.3 g/dL, packed cell volume is 36.0%, WBC count is 6200.0 cells/cumm, RBC count is 4.0 million/cumm, has no hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.",
    5: "Patient aged 73.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.005, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 70.0 mg/dL, urea is 32.0 mg/dL, serum creatinine is 0.9 mg/dL, sodium is 125.0 mEq/L, potassium is 4.0 mEq/L, hemoglobin is 10.0 g/dL, packed cell volume is 29.0%, WBC count is 18900.0 cells/cumm, RBC count is 3.5 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.",
    13: "Patient aged 69.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is High, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 264.0 mg/dL, urea is 87.0 mg/dL, serum creatinine is 2.7 mg/dL, sodium is 130.0 mEq/L, potassium is 4.0 mEq/L, hemoglobin is 12.5 g/dL, packed cell volume is 37.0%, WBC count is 9600.0 cells/cumm, RBC count is 4.1 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.",
    16: "Patient aged 59.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.02, albumin level is Severe, sugar level is Mild, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 252.0 mg/dL, urea is 40.0 mg/dL, serum creatinine is 3.2 mg/dL, sodium is 137.0 mEq/L, potassium is 4.7 mEq/L, hemoglobin is 11.2 g/dL, packed cell volume is 30.0%, WBC count is 26400.0 cells/cumm, RBC count is 3.9 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and does not have anemia.",
    17: "Patient aged 61.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.015, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 173.0 mg/dL, urea is 148.0 mg/dL, serum creatinine is 3.9 mg/dL, sodium is 135.0 mEq/L, potassium is 5.2 mEq/L, hemoglobin is 7.7 g/dL, packed cell volume is 24.0%, WBC count is 9200.0 cells/cumm, RBC count is 3.2 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is poor, pedal edema is present, and has anemia.",
    24: "Patient aged 59.0 years with blood pressure of 50.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 241.0 mg/dL, urea is 191.0 mg/dL, serum creatinine is 12.0 mg/dL, sodium is 114.0 mEq/L, potassium is 2.9 mEq/L, hemoglobin is 9.6 g/dL, packed cell volume is 31.0%, WBC count is 15700.0 cells/cumm, RBC count is 3.8 million/cumm, has no hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.",
    25: "Patient aged 73.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 253.0 mg/dL, urea is 142.0 mg/dL, serum creatinine is 4.6 mg/dL, sodium is 138.0 mEq/L, potassium is 5.8 mEq/L, hemoglobin is 10.5 g/dL, packed cell volume is 33.0%, WBC count is 7200.0 cells/cumm, RBC count is 4.3 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.",
    27: "Patient aged 21.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.01, albumin level is Severe, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are present, blood glucose is 107.0 mg/dL, urea is 40.0 mg/dL, serum creatinine is 1.7 mg/dL, sodium is 125.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 8.3 g/dL, packed cell volume is 23.0%, WBC count is 12400.0 cells/cumm, RBC count is 3.9 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and has anemia.",
    29: "Patient aged 59.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.015, albumin level is Severe, sugar level is Mild, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 255.0 mg/dL, urea is 132.0 mg/dL, serum creatinine is 12.8 mg/dL, sodium is 135.0 mEq/L, potassium is 5.7 mEq/L, hemoglobin is 7.3 g/dL, packed cell volume is 20.0%, WBC count is 9800.0 cells/cumm, RBC count is 3.9 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is not present, and has anemia."
}

# ---- Numeric category mapping ----
def categorize_numeric(feature, value):
    if feature == "Age (years)":
        if value < 40: return "Young"
        elif value <= 60: return "Mid"
        else: return "Old"
    elif feature == "Blood Pressure (mm Hg)":
        if value < 80: return "Low"
        elif value <= 120: return "Mid"
        else: return "High"
    elif feature == "Blood Glucose Random (mg/dL)":
        if value < 80: return "Low"
        elif value <= 140: return "Mid"
        else: return "High"
    elif feature == "Blood Urea (mg/dL)":
        if value < 30: return "Low"
        elif value <= 100: return "Mid"
        else: return "High"
    elif feature == "Serum Creatinine (mg/dL)":
        if value < 1: return "Low"
        elif value <= 3: return "Mid"
        else: return "High"
    elif feature == "Sodium (mEq/L)":
        if value < 135: return "Low"
        elif value <= 145: return "Normal"
        else: return "High"
    elif feature == "Potassium (mEq/L)":
        if value < 3.5: return "Low"
        elif value <= 5: return "Normal"
        else: return "High"
    elif feature == "Hemoglobin (g/dL)":
        if value < 12: return "Low"
        elif value <= 16: return "Normal"
        else: return "High"
    elif feature == "Packed Cell Volume (%)":
        if value < 30: return "Low"
        elif value <= 40: return "Normal"
        else: return "High"
    elif feature == "White Blood Cell Count (cells/cumm)":
        if value < 4000: return "Low"
        elif value <= 11000: return "Normal"
        else: return "High"
    elif feature == "Red Blood Cell Count (million cells/cumm)":
        if value < 4: return "Low"
        elif value <= 5: return "Normal"
        else: return "High"
    elif feature == "Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated)":
        return feature_groups[feature].get(value)
    return None

# ---- Extract numeric from text ----
def extract_numeric(text, pattern):
    match = re.search(pattern, text)
    if match:
        return float(match.group(1))
    return None

# ---- Print Feature-level Importance with Categories ----
for row_id, text in sample_texts.items():
    print("="*40)
    print(f"Row {row_id}")
    print("="*40)
    print(text)
    print("\nFeature-level Importance with Detected Category:")

    for feature, importance in feature_importance.items():
        category = None
        numeric_value = None

        # ---- Categorical features mapping ----
        if "red blood cells" in text.lower() and "red blood cells" in feature.lower():
            category = "Normal" if "normal" in text.lower() else "Abnormal"
        elif "pus cells" in text.lower() and "pus cells (" in feature.lower():
            category = "Normal" if "normal" in text.lower() else "Abnormal"
        elif "pus cell clumps" in text.lower() and "pus cell clumps" in feature.lower():
            category = "Present" if "present" in text.lower() else "Not Present"
        elif "bacteria" in text.lower() and "bacteria" in feature.lower():
            category = "Present" if "present" in text.lower() else "Not Present"
        elif "hypertension" in text.lower() and "hypertension" in feature.lower():
            category = "Yes" if "has hypertension" in text.lower() else "No"
        elif "diabetes" in text.lower() and "diabetes" in feature.lower():
            category = "Yes" if "has diabetes" in text.lower() else "No"
        elif "coronary artery disease" in text.lower() and "coronary" in feature.lower():
            category = "Yes" if "has coronary artery disease" in text.lower() else "No"
        elif "appetite" in text.lower() and "appetite" in feature.lower():
            category = "Good" if "appetite is good" in text.lower() else "Poor"
        elif "pedal edema" in text.lower() and "pedal edema" in feature.lower():
            category = "Yes" if "pedal edema is present" in text.lower() else "No"
        elif "anemia" in text.lower() and "anemia" in feature.lower():
            category = "Yes" if "has anemia" in text.lower() else "No"
        elif "albumin" in text.lower() and "albumin" in feature.lower():
            match = re.search(r"albumin level is (\w+)", text.lower())
            if match: category = match.group(1).capitalize()
        elif "sugar" in text.lower() and "sugar" in feature.lower():
            match = re.search(r"sugar level is (\w+)", text.lower())
            if match: category = match.group(1).capitalize()

        # ---- Numeric features ----
        numeric_patterns = {
            "Age (years)": r"aged ([\d\.]+)",
            "Blood Pressure (mm Hg)": r"blood pressure of ([\d\.]+)",
            "Blood Glucose Random (mg/dL)": r"blood glucose is ([\d\.]+)",
            "Blood Urea (mg/dL)": r"urea is ([\d\.]+)",
            "Serum Creatinine (mg/dL)": r"serum creatinine is ([\d\.]+)",
            "Sodium (mEq/L)": r"sodium is ([\d\.]+)",
            "Potassium (mEq/L)": r"potassium is ([\d\.]+)",
            "Hemoglobin (g/dL)": r"hemoglobin is ([\d\.]+)",
            "Packed Cell Volume (%)": r"packed cell volume is ([\d\.]+)",
            "White Blood Cell Count (cells/cumm)": r"WBC count is ([\d\.]+)",
            "Red Blood Cell Count (million cells/cumm)": r"RBC count is ([\d\.]+)",
            "Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated)": r"specific gravity of urine is ([\d\.]+)"
        }

        if feature in numeric_patterns:
            numeric_value = extract_numeric(text, numeric_patterns[feature])
            if numeric_value is not None:
                numeric_category = categorize_numeric(feature, numeric_value)
                if numeric_category: category = numeric_category

        # ---- Print ----
        label = feature
        if category:
            label += f" ({category})"
        print(f"{label}: {importance:.4f}")
# Out:
# ========================================
# Row 4
# ========================================
# Patient aged 48.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.005, albumin level is Severe, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are present, blood glucose is 133.0 mg/dL, urea is 139.0 mg/dL, serum creatinine is 8.5 mg/dL, sodium is 132.0 mEq/L, potassium is 5.5 mEq/L, hemoglobin is 10.3 g/dL, packed cell volume is 36.0%, WBC count is 6200.0 cells/cumm, RBC count is 4.0 million/cumm, has no hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
#
# Feature-level Importance with Detected Category:
# Age (years) (Mid): 0.0790
# Blood Pressure (mm Hg) (Mid): 0.1860
# Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated) (Very Dilute): 0.1500
# Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe) (Severe): 0.1600
# Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High) (Normal): 0.1200
# Red Blood Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1100
# Pus Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1000
# Pus Cell Clumps (1 = Present, 0 = Not Present) (Present): 0.0900
# Bacteria (1 = Present, 0 = Not Present) (Present): 0.0850
# Blood Glucose Random (mg/dL) (Mid): 0.1400
# Blood Urea (mg/dL) (High): 0.1300
# Serum Creatinine (mg/dL) (High): 0.1550
# Sodium (mEq/L) (Low): 0.1050
# Potassium (mEq/L) (High): 0.0950
# Hemoglobin (g/dL) (Low): 0.1250
# Packed Cell Volume (%) (Normal): 0.1150
# White Blood Cell Count (cells/cumm) (Normal): 0.0980
# Red Blood Cell Count (million cells/cumm) (Normal): 0.0850
# Hypertension (1 = Yes, 0 = No) (No): 0.0900
# Diabetes Mellitus (1 = Yes, 0 = No) (Yes): 0.0920
# Coronary Artery Disease (1 = Yes, 0 = No) (No): 0.0880
# Appetite (1 = Good, 0 = Poor) (Good): 0.0800
# Pedal Edema (1 = Yes, 0 = No) (Yes): 0.0750
# Anemia (1 = Yes, 0 = No) (No): 0.0780
# ========================================
# Row 5
# ========================================
# Patient aged 73.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.005, albumin level is Normal, sugar level is Normal, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 70.0 mg/dL, urea is 32.0 mg/dL, serum creatinine is 0.9 mg/dL, sodium is 125.0 mEq/L, potassium is 4.0 mEq/L, hemoglobin is 10.0 g/dL, packed cell volume is 29.0%, WBC count is 18900.0 cells/cumm, RBC count is 3.5 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
#
# Feature-level Importance with Detected Category:
# Age (years) (Old): 0.0790
# Blood Pressure (mm Hg) (Low): 0.1860
# Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated) (Very Dilute): 0.1500
# Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe) (Normal): 0.1600
# Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High) (Normal): 0.1200
# Red Blood Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1100
# Pus Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1000
# Pus Cell Clumps (1 = Present, 0 = Not Present) (Present): 0.0900
# Bacteria (1 = Present, 0 = Not Present) (Present): 0.0850
# Blood Glucose Random (mg/dL) (Low): 0.1400
# Blood Urea (mg/dL) (Mid): 0.1300
# Serum Creatinine (mg/dL) (Low): 0.1550
# Sodium (mEq/L) (Low): 0.1050
# Potassium (mEq/L) (Normal): 0.0950
# Hemoglobin (g/dL) (Low): 0.1250
# Packed Cell Volume (%) (Low): 0.1150
# White Blood Cell Count (cells/cumm) (High): 0.0980
# Red Blood Cell Count (million cells/cumm) (Low): 0.0850
# Hypertension (1 = Yes, 0 = No) (Yes): 0.0900
# Diabetes Mellitus (1 = Yes, 0 = No) (Yes): 0.0920
# Coronary Artery Disease (1 = Yes, 0 = No) (No): 0.0880
# Appetite (1 = Good, 0 = Poor) (Good): 0.0800
# Pedal Edema (1 = Yes, 0 = No) (Yes): 0.0750
# Anemia (1 = Yes, 0 = No) (No): 0.0780
# ========================================
# Row 13
# ========================================
# Patient aged 69.0 years with blood pressure of 70.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is High, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 264.0 mg/dL, urea is 87.0 mg/dL, serum creatinine is 2.7 mg/dL, sodium is 130.0 mEq/L, potassium is 4.0 mEq/L, hemoglobin is 12.5 g/dL, packed cell volume is 37.0%, WBC count is 9600.0 cells/cumm, RBC count is 4.1 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
#
# Feature-level Importance with Detected Category:
# Age (years) (Old): 0.0790
# Blood Pressure (mm Hg) (Low): 0.1860
# Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated) (Dilute): 0.1500
# Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe) (Moderate): 0.1600
# Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High) (High): 0.1200
# Red Blood Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1100
# Pus Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1000
# Pus Cell Clumps (1 = Present, 0 = Not Present) (Present): 0.0900
# Bacteria (1 = Present, 0 = Not Present) (Present): 0.0850
# Blood Glucose Random (mg/dL) (High): 0.1400
# Blood Urea (mg/dL) (Mid): 0.1300
# Serum Creatinine (mg/dL) (Mid): 0.1550
# Sodium (mEq/L) (Low): 0.1050
# Potassium (mEq/L) (Normal): 0.0950
# Hemoglobin (g/dL) (Normal): 0.1250
# Packed Cell Volume (%) (Normal): 0.1150
# White Blood Cell Count (cells/cumm) (Normal): 0.0980
# Red Blood Cell Count (million cells/cumm) (Normal): 0.0850
# Hypertension (1 = Yes, 0 = No) (Yes): 0.0900
# Diabetes Mellitus (1 = Yes, 0 = No) (Yes): 0.0920
# Coronary Artery Disease (1 = Yes, 0 = No) (Yes): 0.0880
# Appetite (1 = Good, 0 = Poor) (Good): 0.0800
# Pedal Edema (1 = Yes, 0 = No) (Yes): 0.0750
# Anemia (1 = Yes, 0 = No) (No): 0.0780
# ========================================
# Row 16
# ========================================
# Patient aged 59.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.02, albumin level is Severe, sugar level is Mild, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 252.0 mg/dL, urea is 40.0 mg/dL, serum creatinine is 3.2 mg/dL, sodium is 137.0 mEq/L, potassium is 4.7 mEq/L, hemoglobin is 11.2 g/dL, packed cell volume is 30.0%, WBC count is 26400.0 cells/cumm, RBC count is 3.9 million/cumm, has hypertension, has diabetes mellitus, has no coronary artery disease, appetite is poor, pedal edema is present, and does not have anemia.
#
# Feature-level Importance with Detected Category:
# Age (years) (Mid): 0.0790
# Blood Pressure (mm Hg) (Mid): 0.1860
# Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated) (Concentrated): 0.1500
# Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe) (Severe): 0.1600
# Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High) (Mild): 0.1200
# Red Blood Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1100
# Pus Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1000
# Pus Cell Clumps (1 = Present, 0 = Not Present) (Present): 0.0900
# Bacteria (1 = Present, 0 = Not Present) (Present): 0.0850
# Blood Glucose Random (mg/dL) (High): 0.1400
# Blood Urea (mg/dL) (Mid): 0.1300
# Serum Creatinine (mg/dL) (High): 0.1550
# Sodium (mEq/L) (Normal): 0.1050
# Potassium (mEq/L) (Normal): 0.0950
# Hemoglobin (g/dL) (Low): 0.1250
# Packed Cell Volume (%) (Normal): 0.1150
# White Blood Cell Count (cells/cumm) (High): 0.0980
# Red Blood Cell Count (million cells/cumm) (Low): 0.0850
# Hypertension (1 = Yes, 0 = No) (Yes): 0.0900
# Diabetes Mellitus (1 = Yes, 0 = No) (Yes): 0.0920
# Coronary Artery Disease (1 = Yes, 0 = No) (No): 0.0880
# Appetite (1 = Good, 0 = Poor) (Poor): 0.0800
# Pedal Edema (1 = Yes, 0 = No) (Yes): 0.0750
# Anemia (1 = Yes, 0 = No) (No): 0.0780
# ========================================
# Row 17
# ========================================
# Patient aged 61.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.015, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 173.0 mg/dL, urea is 148.0 mg/dL, serum creatinine is 3.9 mg/dL, sodium is 135.0 mEq/L, potassium is 5.2 mEq/L, hemoglobin is 7.7 g/dL, packed cell volume is 24.0%, WBC count is 9200.0 cells/cumm, RBC count is 3.2 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is poor, pedal edema is present, and has anemia.
#
# Feature-level Importance with Detected Category:
# Age (years) (Old): 0.0790
# Blood Pressure (mm Hg) (Mid): 0.1860
# Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated) (Normal): 0.1500
# Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe) (Mild): 0.1600
# Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High) (Normal): 0.1200
# Red Blood Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1100
# Pus Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1000
# Pus Cell Clumps (1 = Present, 0 = Not Present) (Present): 0.0900
# Bacteria (1 = Present, 0 = Not Present) (Present): 0.0850
# Blood Glucose Random (mg/dL) (High): 0.1400
# Blood Urea (mg/dL) (High): 0.1300
# Serum Creatinine (mg/dL) (High): 0.1550
# Sodium (mEq/L) (Normal): 0.1050
# Potassium (mEq/L) (High): 0.0950
# Hemoglobin (g/dL) (Low): 0.1250
# Packed Cell Volume (%) (Low): 0.1150
# White Blood Cell Count (cells/cumm) (Normal): 0.0980
# Red Blood Cell Count (million cells/cumm) (Low): 0.0850
# Hypertension (1 = Yes, 0 = No) (Yes): 0.0900
# Diabetes Mellitus (1 = Yes, 0 = No) (Yes): 0.0920
# Coronary Artery Disease (1 = Yes, 0 = No) (Yes): 0.0880
# Appetite (1 = Good, 0 = Poor) (Poor): 0.0800
# Pedal Edema (1 = Yes, 0 = No) (Yes): 0.0750
# Anemia (1 = Yes, 0 = No) (Yes): 0.0780
# ========================================
# Row 24
# ========================================
# Patient aged 59.0 years with blood pressure of 50.0 mm Hg, specific gravity of urine is 1.01, albumin level is Moderate, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 241.0 mg/dL, urea is 191.0 mg/dL, serum creatinine is 12.0 mg/dL, sodium is 114.0 mEq/L, potassium is 2.9 mEq/L, hemoglobin is 9.6 g/dL, packed cell volume is 31.0%, WBC count is 15700.0 cells/cumm, RBC count is 3.8 million/cumm, has no hypertension, has diabetes mellitus, has no coronary artery disease, appetite is good, pedal edema is present, and does not have anemia.
#
# Feature-level Importance with Detected Category:
# Age (years) (Mid): 0.0790
# Blood Pressure (mm Hg) (Low): 0.1860
# Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated) (Dilute): 0.1500
# Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe) (Moderate): 0.1600
# Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High) (Normal): 0.1200
# Red Blood Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1100
# Pus Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1000
# Pus Cell Clumps (1 = Present, 0 = Not Present) (Present): 0.0900
# Bacteria (1 = Present, 0 = Not Present) (Present): 0.0850
# Blood Glucose Random (mg/dL) (High): 0.1400
# Blood Urea (mg/dL) (High): 0.1300
# Serum Creatinine (mg/dL) (High): 0.1550
# Sodium (mEq/L) (Low): 0.1050
# Potassium (mEq/L) (Low): 0.0950
# Hemoglobin (g/dL) (Low): 0.1250
# Packed Cell Volume (%) (Normal): 0.1150
# White Blood Cell Count (cells/cumm) (High): 0.0980
# Red Blood Cell Count (million cells/cumm) (Low): 0.0850
# Hypertension (1 = Yes, 0 = No) (No): 0.0900
# Diabetes Mellitus (1 = Yes, 0 = No) (Yes): 0.0920
# Coronary Artery Disease (1 = Yes, 0 = No) (No): 0.0880
# Appetite (1 = Good, 0 = Poor) (Good): 0.0800
# Pedal Edema (1 = Yes, 0 = No) (Yes): 0.0750
# Anemia (1 = Yes, 0 = No) (No): 0.0780
# ========================================
# Row 25
# ========================================
# Patient aged 73.0 years with blood pressure of 80.0 mm Hg, specific gravity of urine is 1.02, albumin level is Mild, sugar level is Normal, red blood cells are abnormal, pus cells are abnormal, pus cell clumps are not present, bacteria are not present, blood glucose is 253.0 mg/dL, urea is 142.0 mg/dL, serum creatinine is 4.6 mg/dL, sodium is 138.0 mEq/L, potassium is 5.8 mEq/L, hemoglobin is 10.5 g/dL, packed cell volume is 33.0%, WBC count is 7200.0 cells/cumm, RBC count is 4.3 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is not present, and does not have anemia.
#
# Feature-level Importance with Detected Category:
# Age (years) (Old): 0.0790
# Blood Pressure (mm Hg) (Mid): 0.1860
# Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated) (Concentrated): 0.1500
# Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe) (Mild): 0.1600
# Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High) (Normal): 0.1200
# Red Blood Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1100
# Pus Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1000
# Pus Cell Clumps (1 = Present, 0 = Not Present) (Present): 0.0900
# Bacteria (1 = Present, 0 = Not Present) (Present): 0.0850
# Blood Glucose Random (mg/dL) (High): 0.1400
# Blood Urea (mg/dL) (High): 0.1300
# Serum Creatinine (mg/dL) (High): 0.1550
# Sodium (mEq/L) (Normal): 0.1050
# Potassium (mEq/L) (High): 0.0950
# Hemoglobin (g/dL) (Low): 0.1250
# Packed Cell Volume (%) (Normal): 0.1150
# White Blood Cell Count (cells/cumm) (Normal): 0.0980
# Red Blood Cell Count (million cells/cumm) (Normal): 0.0850
# Hypertension (1 = Yes, 0 = No) (Yes): 0.0900
# Diabetes Mellitus (1 = Yes, 0 = No) (Yes): 0.0920
# Coronary Artery Disease (1 = Yes, 0 = No) (Yes): 0.0880
# Appetite (1 = Good, 0 = Poor) (Good): 0.0800
# Pedal Edema (1 = Yes, 0 = No) (No): 0.0750
# Anemia (1 = Yes, 0 = No) (No): 0.0780
# ========================================
# Row 27
# ========================================
# Patient aged 21.0 years with blood pressure of 90.0 mm Hg, specific gravity of urine is 1.01, albumin level is Severe, sugar level is Normal, red blood cells are normal, pus cells are abnormal, pus cell clumps are present, bacteria are present, blood glucose is 107.0 mg/dL, urea is 40.0 mg/dL, serum creatinine is 1.7 mg/dL, sodium is 125.0 mEq/L, potassium is 3.5 mEq/L, hemoglobin is 8.3 g/dL, packed cell volume is 23.0%, WBC count is 12400.0 cells/cumm, RBC count is 3.9 million/cumm, has no hypertension, has no diabetes, has no coronary artery disease, appetite is good, pedal edema is not present, and has anemia.
#
# Feature-level Importance with Detected Category:
# Age (years) (Young): 0.0790
# Blood Pressure (mm Hg) (Mid): 0.1860
# Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated) (Dilute): 0.1500
# Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe) (Severe): 0.1600
# Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High) (Normal): 0.1200
# Red Blood Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1100
# Pus Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1000
# Pus Cell Clumps (1 = Present, 0 = Not Present) (Present): 0.0900
# Bacteria (1 = Present, 0 = Not Present) (Present): 0.0850
# Blood Glucose Random (mg/dL) (Mid): 0.1400
# Blood Urea (mg/dL) (Mid): 0.1300
# Serum Creatinine (mg/dL) (Mid): 0.1550
# Sodium (mEq/L) (Low): 0.1050
# Potassium (mEq/L) (Normal): 0.0950
# Hemoglobin (g/dL) (Low): 0.1250
# Packed Cell Volume (%) (Low): 0.1150
# White Blood Cell Count (cells/cumm) (High): 0.0980
# Red Blood Cell Count (million cells/cumm) (Low): 0.0850
# Hypertension (1 = Yes, 0 = No) (No): 0.0900
# Diabetes Mellitus (1 = Yes, 0 = No) (No): 0.0920
# Coronary Artery Disease (1 = Yes, 0 = No) (No): 0.0880
# Appetite (1 = Good, 0 = Poor) (Good): 0.0800
# Pedal Edema (1 = Yes, 0 = No) (No): 0.0750
# Anemia (1 = Yes, 0 = No) (Yes): 0.0780
# ========================================
# Row 29
# ========================================
# Patient aged 59.0 years with blood pressure of 100.0 mm Hg, specific gravity of urine is 1.015, albumin level is Severe, sugar level is Mild, red blood cells are normal, pus cells are normal, pus cell clumps are not present, bacteria are not present, blood glucose is 255.0 mg/dL, urea is 132.0 mg/dL, serum creatinine is 12.8 mg/dL, sodium is 135.0 mEq/L, potassium is 5.7 mEq/L, hemoglobin is 7.3 g/dL, packed cell volume is 20.0%, WBC count is 9800.0 cells/cumm, RBC count is 3.9 million/cumm, has hypertension, has diabetes mellitus, has coronary artery disease, appetite is good, pedal edema is not present, and has anemia.
#
# Feature-level Importance with Detected Category:
# Age (years) (Mid): 0.0790
# Blood Pressure (mm Hg) (Mid): 0.1860
# Specific Gravity of Urine (1.005 = Very Dilute, 1.010 = Dilute, 1.015 = Normal, 1.020 = Concentrated, 1.025 = Very Concentrated) (Normal): 0.1500
# Albumin (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = Severe, 5 = Very Severe) (Severe): 0.1600
# Sugar (0 = None, 1 = Trace, 2 = Mild, 3 = Moderate, 4 = High, 5 = Very High) (Mild): 0.1200
# Red Blood Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1100
# Pus Cells (1 = Normal, 0 = Abnormal) (Normal): 0.1000
# Pus Cell Clumps (1 = Present, 0 = Not Present) (Present): 0.0900
# Bacteria (1 = Present, 0 = Not Present) (Present): 0.0850
# Blood Glucose Random (mg/dL) (High): 0.1400
# Blood Urea (mg/dL) (High): 0.1300
# Serum Creatinine (mg/dL) (High): 0.1550
# Sodium (mEq/L) (Normal): 0.1050
# Potassium (mEq/L) (High): 0.0950
# Hemoglobin (g/dL) (Low): 0.1250
# Packed Cell Volume (%) (Low): 0.1150
# White Blood Cell Count (cells/cumm) (Normal): 0.0980
# Red Blood Cell Count (million cells/cumm) (Low): 0.0850
# Hypertension (1 = Yes, 0 = No) (Yes): 0.0900
# Diabetes Mellitus (1 = Yes, 0 = No) (Yes): 0.0920
# Coronary Artery Disease (1 = Yes, 0 = No) (Yes): 0.0880
# Appetite (1 = Good, 0 = Poor) (Good): 0.0800
# Pedal Edema (1 = Yes, 0 = No) (No): 0.0750
# Anemia (1 = Yes, 0 = No) (Yes): 0.0780
